# %%
import os, sys, time
from time import sleep
import pathlib, fnmatch
from pathlib import Path
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import shutil

# %%
def main(): # {
    # RE-INSTANTIATE GLOBALS
    global in_file, in_directory, out_directory, outbound_directory
    # TRY THE FOLLOWING
    try: # {
        # DIFFERENCE DATAFRAME
        diff_df = pd.read_csv(in_file, dtype=np.str)
        print(diff_df)
        # CREATE LIST TO HOLD FAILURES (dont exist)
        dont_exist = []
        # ITERATE THRU LOOP
        for file in diff_df["FILENAME"]: # {
            # CREATE TEST PATH
            test_path = os.path.join(in_directory, file)
            print("TEST_PATH == " + str(test_path))
            # TEST AND SEE IF IT EXISTS
            if_exists = os.path.exists(test_path)
            print(" >>> EXISTS >>> ", end="\t")
            if bool(if_exists): # {
                print(" TRUE! ")
                # CREATE NEW DESTINATION PATH
                dst_path = os.path.join(outbound_directory, file)
                print("NEW PATH == " + str(dst_path), end="\n\n")
                # COPY TO NEW LOCATION
                shutil.copy2(src=test_path, dst=dst_path)
            # }
            else: # {
                print("FALSE!", end="\n\n")
                # APPEND TO DONT EXIST
                dont_exist.append(file)
            # }
        # }
        # CREATE DATAFRAME FROM DONT EXIST
        fails_df = pd.DataFrame(data=dont_exist, dtype=np.str)
        # EXPORT
        fails_df.to_csv("dont_exist.csv", header=["dont_exist"], index=False)
    # }
    except: # {
        errorMessage = str(sys.exc_info()[0]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage))
        print("\n" + typeE +
                      "\n" + fileE +
                      "\n" + lineE +
                      "\n" + messageE)
    # }
    else: # {
        print("Operation Completed Succesfully...")
    # }
# }

# %%
if __name__ == "__main__": # {
    # INSTANTIATE GLOBAL VARIABLES
    in_file = "set_diff_df.csv"
    in_directory = Path("G:/C of A's/#CofA with background for web")
    out_directory = Path("C:/data/outbound/2020-01-17")
    outbound_directory = Path("G:/C of A's/#CofA with background for web/Replace Web CofAs")
    # MAIN FUNCTION CALL
    main()
# }
# Out:
#                         FILENAME
# 0     CUS-14053@CM-1234@hide.PDF
# 1      ISM-333XC-500@CR-6092.pdf
# 2      ISM-333XC-500@CR-6101.pdf
# 3          ICP-030@CM-3989@2.pdf
# 4   ICP-034@D00042.Se@Update.pdf
# ..                           ...
# 61     PST-3935A1000@CM-2406.PDF
# 62     PST-3940A1000@CM-2496.PDF
# 63     PST-6330K1000@CM-2885.PDF
# 64      PST-770K1000@CM-2412.PDF
# 65         Sma-200-1@Cr-2868.PDF
#
# [66 rows x 1 columns]
# TEST_PATH == G:\C of A's\#CofA with background for web\CUS-14053@CM-1234@hide.PDF
#  >>> EXISTS >>> 	FALSE!
#
# TEST_PATH == G:\C of A's\#CofA with background for web\ISM-333XC-500@CR-6092.pdf
#  >>> EXISTS >>> 	FALSE!
#
# TEST_PATH == G:\C of A's\#CofA with background for web\ISM-333XC-500@CR-6101.pdf
#  >>> EXISTS >>> 	FALSE!
#
# TEST_PATH == G:\C of A's\#CofA with background for web\ICP-030@CM-3989@2.pdf
#  >>> EXISTS >>> 	FALSE!
#
# TEST_PATH == G:\C of A's\#CofA with background for web\ICP-034@D00042.Se@Update.pdf
#  >>> EXISTS >>> 	FALSE!
# ...
