# %%
import os, sys, time
from time import sleep
from pathlib import Path
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import fnmatch, logging

# %%
# SETUP LOGGER
try: #{
    logging.basicConfig(level=logging.INFO,
                       format='%(asctime)s : %(message)s',
                       datefmt='%Y-%m-%d-%H%M%S',
                       filemode='a')
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
    print("\n" + typeE +
          "\n" + fileE +
          "\n" + lineE +
          "\n" + messageE)
#}
else: #{
    print("[Setup-Logger] SUCCESS! VERY NICE!")
#}
# Out:
# [Setup-Logger] SUCCESS! VERY NICE!

# %% [markdown]
# #### 1) loop thru OneDrive folder
# #### 2) check if file exists in F:/APPS/CofA/ (create file_path)
# #### 3) check if file exists in G:/C of A's/Agilent/ (create_file_path)
# #### 4) get time stamp (created time) from ^THAT^ FILE
# #### 5) copy/watermark and OVERWRITE in its place (stay in current directory)

# %%
logging.info(os.getcwd())
# Out:
# 2019-09-09-151051 : C:\Users\derbates\OneDrive - Agilent Technologies\Documents\_staging\Data-Developer-Droolkit\AGILENT

# %%
one_drive_dir = "C:/Users/derbates/OneDrive - Agilent Technologies/"

# %%
in_dir_1 = "F:/APPS/CofA/"

# %%
in_dir_2 = "G:/C of A's/Agilent/"

# %%
odrive_list = os.listdir(one_drive_dir)

# %%
for nameski in odrive_list: #{
    logging.info(nameski)
#}
# Out:
# 2019-09-09-151051 : .849C9593-D756-4E56-8D6E-42412F2A707B
# 2019-09-09-151051 : 05_16_2019.docx
# 2019-09-09-151051 : 2019-09-06
# 2019-09-09-151051 : CofA-2019-08-28.zip
# 2019-09-09-151051 : CofA_Daily_Pull_List_v2_headless.exe
# 2019-09-09-151051 : CofA_F_Scanner.exe
# 2019-09-09-151051 : CofA_F_Scanner_v2.exe
# 2019-09-09-151051 : CofA_G_Scanner.exe
# 2019-09-09-151051 : CofA_Nightly_Node.exe
# 2019-09-09-151051 : CofA_Nightly_Node.xml
# 2019-09-09-151051 : CofA_Nightly_Node_v1.exe
# 2019-09-09-151051 : CofA_scan_v1.exe
# 2019-09-09-151051 : CofA_test_1.exe
# 2019-09-09-151051 : Custom Quotes.accdb
# 2019-09-09-151051 : Custom Quotes.zip
# 2019-09-09-151051 : CUSTOM_CRATES
# 2019-09-09-151051 : data
# 2019-09-09-151051 : DEREK @ Agilent Technologies.url
# 2019-09-09-151051 : Desktop
# 2019-09-09-151051 : desktop.ini
# 2019-09-09-151051 : Documents
# 2019-09-09-151051 : Documents2019-06-25-114415_CUSTOM_SDS_COUNT.csv
# 2019-09-09-151051 : H_w___Dr_v_M_pp___.docx
# ...

# %%
in_directory = os.path.join(one_drive_dir, "2019-09-06")

# %%
logging.info(in_directory)
# Out:
# 2019-09-09-151051 : C:/Users/derbates/OneDrive - Agilent Technologies/2019-09-06

# %%
file_list = os.listdir(in_directory)

# %%
logging.info(str(len(file_list)))
# Out:
# 2019-09-09-151051 : 907

# %% [markdown]
# ---

# %% [markdown]
# ## *DEFINE FUNCTIONS*

# %%
"""
TAKES IN:
(1) file_path to file
RETURNS:
the STRING of that PDF to match the naming convention
in F:/APPS/CofA/ from G:/C of A's/#Email Node/
"""
def generate_naming_convention(the_pdf_path): #{
    # get/set filename to variable
    the_file_name = str(os.path.basename(the_pdf_path))
    # MAKE SURE FILE IS OF TYPE .PDF
    if fnmatch.fnmatch(the_file_name, "*.pdf"): #{
        logging.info("\tFILE NAME >>> " + str(the_file_name))
        # PERFORM STRING OPERATIONS
        #################################
        idx_mrk = the_file_name.find('CofA', 0, len(the_file_name))
        half1 = str(the_file_name[5:idx_mrk-1])
        # RESET/REASSIGN index marker for str operations
        idx_mrk = the_file_name.find('#', 0, len(the_file_name))
        half2 = str(the_file_name[idx_mrk+2:len(the_file_name)])
        logging.debug("\t\t[*************************]")
        logging.debug("\t\t|>>> HALF 1 == " + half1)
        logging.debug("\t\t|>>> HALF 2 == " + half2)
        #  setup OLD FILE NAME (for copy)
        old_name = ""
        old_name += str(half1)
        old_name += "@"
        old_name += str(half2)
        logging.info("\tNEW NAME == " + str(old_name))
        logging.info("\t\t[*************************]")
        #################################
        return str(old_name)
    #}
    else: #{
        logging.debug("NOT A PDF!")
    #}
    
#}

# %% [markdown]
# ---
# `iterate`

# %%
for file in file_list: #{
    logging.debug("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
    logging.info("\n\t\t\tFILE >>>\t" + str(file))
    # CREATE BOTH DIR VARIABLES
    dir_path_1 = os.path.join(in_dir_1, file)
    logging.info("\tDIR_PATH_1 >>>\t" + str(dir_path_1))
    dir_path_2 = os.path.join(in_dir_2, file)
    logging.info("\tDIR_PATH_2 >>>\t" + str(dir_path_2))
    test_str_1 = generate_naming_convention(dir_path_1)
    test_str_2 = generate_naming_convention(dir_path_2)
    # CHECK IF EITHER EXIST (1 def should!)
    """
    if os.path.exists(dir_path_1) is True: #{
        print("CREATED IN F DRIVE")
    #}
    elif os.path.exists(dir_path_2) is True: #{
        print("CREATED IN G DRIVE")
    #}
    else: #{
        print("NOT CREATED IN NEITHER!")
    #}
    """
#}
# Out:
# 2019-09-09-151051 :
# 			FILE >>>	393210201@0006481960.pdf
# 2019-09-09-151051 : 	DIR_PATH_1 >>>	F:/APPS/CofA/393210201@0006481960.pdf
# 2019-09-09-151051 : 	DIR_PATH_2 >>>	G:/C of A's/Agilent/393210201@0006481960.pdf
# 2019-09-09-151051 : 	FILE NAME >>> 393210201@0006481960.pdf
# 2019-09-09-151051 : 	>>> NEW NAME == 0201@0006481960.p@93210201@0006481960.pdf
# 2019-09-09-151051 : 	FILE NAME >>> 393210201@0006481960.pdf
# 2019-09-09-151051 : 	>>> NEW NAME == 0201@0006481960.p@93210201@0006481960.pdf
# 2019-09-09-151051 :
# 			FILE >>>	AGI-P03-3@0006481524.pdf
# 2019-09-09-151051 : 	DIR_PATH_1 >>>	F:/APPS/CofA/AGI-P03-3@0006481524.pdf
# 2019-09-09-151051 : 	DIR_PATH_2 >>>	G:/C of A's/Agilent/AGI-P03-3@0006481524.pdf
# 2019-09-09-151051 : 	FILE NAME >>> AGI-P03-3@0006481524.pdf
# 2019-09-09-151051 : 	>>> NEW NAME == 03-3@0006481524.p@GI-P03-3@0006481524.pdf
# 2019-09-09-151051 : 	FILE NAME >>> AGI-P03-3@0006481524.pdf
# ...
