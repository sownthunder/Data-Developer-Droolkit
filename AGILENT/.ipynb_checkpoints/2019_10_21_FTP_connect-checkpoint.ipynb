# %% [markdown]
# `ftp://ftp.ncbi.nlm.nih.gov/pubchem/Compound/`

# %%
from ftplib import FTP

# %%
ftp = FTP('ftp.ncbi.nlm.nih.gov')

# %%
ftp.login()
# Out:
# '230 Anonymous access granted, restrictions apply'

# %%
ftp.dir()
# Out:
# dr-xr-xr-x   4 ftp      anonymous     4096 Oct 21 02:48 1000genomes
# -r--r--r--   1 ftp      anonymous 10738466816 Mar  7  2018 10GB
# -r--r--r--   1 ftp      anonymous 1074790400 Mar  7  2018 1GB
# -r--r--r--   1 ftp      anonymous 53688139776 Mar  7  2018 50GB
# -r--r--r--   1 ftp      anonymous 5369757696 Mar  7  2018 5GB
# -r--r--r--   1 ftp      anonymous     2037 Feb 28  2018 README.ftp
# dr-xr-xr-x 1073741824 ftp      anonymous       40 Oct 15 21:40 ReferenceSamples
# dr-xr-xr-x   8 ftp      anonymous     4096 Feb  8  2016 SampleData
# lr--r--r--   1 ftp      anonymous       29 Feb 28  2018 asn1-converters -> toolbox/ncbi_tools/converters
# dr-xr-xr-x  12 ftp      anonymous   184320 Nov 22  2014 bigwig
# dr-xr-xr-x   5 ftp      anonymous     4096 Oct 21 09:00 bioproject
# dr-xr-xr-x   2 ftp      anonymous     4096 Oct 21 09:18 biosample
# dr-xr-xr-x  10 ftp      anonymous     4096 Oct 21 02:48 blast
# dr-xr-xr-x   3 ftp      anonymous     4096 Sep 13  2004 cgap
# ...

# %%
ftp.cwd('pubchem/Compound/')
# Out:
# '250 CWD command successful'

# %%
ftp.dir()
# Out:
# dr-xr-xr-x   5 ftp      anonymous     4096 Jul 12 09:13 CURRENT-Full
# dr-xr-xr-x  10 ftp      anonymous     4096 Oct 20 16:09 Daily
# dr-xr-xr-x   2 ftp      anonymous     4096 Apr 17  2019 Extras
# dr-xr-xr-x   6 ftp      anonymous     4096 Oct  1 17:43 Monthly
# -r--r--r--   1 ftp      anonymous     4247 Oct 19  2013 README
# dr-xr-xr-x   7 ftp      anonymous     4096 Oct 20 16:09 Weekly

# %%
ftp.cwd('CURRENT-Full/SDF')
# Out:
# '250 CWD command successful'

# %%
ftp.dir()
# Out:
# -r--r--r--   1 ftp      anonymous 15601064 Oct  5 15:45 Compound_000000001_000025000.sdf.gz
# -r--r--r--   1 ftp      anonymous 14916612 Sep 27 12:59 Compound_000025001_000050000.sdf.gz
# -r--r--r--   1 ftp      anonymous 15991024 Sep 27 12:59 Compound_000050001_000075000.sdf.gz
# -r--r--r--   1 ftp      anonymous 15271545 Oct 13 14:45 Compound_000075001_000100000.sdf.gz
# -r--r--r--   1 ftp      anonymous 18050296 Sep 27 13:05 Compound_000100001_000125000.sdf.gz
# -r--r--r--   1 ftp      anonymous 16497489 Oct  3 12:19 Compound_000125001_000150000.sdf.gz
# -r--r--r--   1 ftp      anonymous 19841151 Oct  2 16:34 Compound_000150001_000175000.sdf.gz
# -r--r--r--   1 ftp      anonymous 19251656 Oct  3 12:20 Compound_000175001_000200000.sdf.gz
# -r--r--r--   1 ftp      anonymous 15564445 Sep 27 13:01 Compound_000200001_000225000.sdf.gz
# -r--r--r--   1 ftp      anonymous 14910270 Sep 27 13:04 Compound_000225001_000250000.sdf.gz
# ...

# %%
ftp.nlst()
# Out:
# ['Compound_000050001_000075000.sdf.gz',
#  'Compound_000025001_000050000.sdf.gz',
#  'Compound_000125001_000150000.sdf.gz',
#  'Compound_000100001_000125000.sdf.gz',
#  'Compound_000150001_000175000.sdf.gz',
#  'Compound_000075001_000100000.sdf.gz',
#  'Compound_000000001_000025000.sdf.gz',
#  'Compound_000175001_000200000.sdf.gz',
#  'Compound_000250001_000275000.sdf.gz',
#  'Compound_000200001_000225000.sdf.gz',
#  'Compound_000225001_000250000.sdf.gz',
#  'Compound_000275001_000300000.sdf.gz',
#  'Compound_000300001_000325000.sdf.gz',
#  'Compound_000325001_000350000.sdf.gz',
#  'Compound_000375001_000400000.sdf.gz',
#  'Compound_000400001_000425000.sdf.gz',
#  'Compound_000350001_000375000.sdf.gz',
#  'Compound_000425001_000450000.sdf.gz',
#  'Compound_000475001_000500000.sdf.gz',
#  'Compound_000450001_000475000.sdf.gz',
#  'Compound_000500001_000525000.sdf.gz',
#  'Compound_000525001_000550000.sdf.gz',
#  'Compound_000550001_000575000.sdf.gz',
# ...
