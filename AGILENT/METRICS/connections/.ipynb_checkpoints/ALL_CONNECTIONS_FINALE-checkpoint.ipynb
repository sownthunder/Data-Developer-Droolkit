# %%
# IMPORT THE GOODS
import os, sys, time
from time import sleep
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import pyodbc
from sqlalchemy.inspection import inspect

# %%
conn_str = str(
    r'DRIVER={ODBC Driver 17 for SQL Server};'
    r'SERVER=wtkngappflow1.is.agilent.net;'
    r'DATABASE=ProdFlow;'
    r'Trusted_Connection=yes;'
)

# %%
try: #{
    # Use connection strings for all these drivers
    cnxn = pyodbc.connect(conn_str)
    crsr = cnxn.cursor()
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# FIN...

# %%
"""
: param : CUSTOM SQL QUERY AS STRING
: return: Dataframe object containing SQL_EXPRESS data
"""
def read_sql_query_from_sqlexpress(theQuery, theConn): #{
    """Import data from SQL_EXPRESS; clean & merge dataframes"""
    # try the following
    try: #{
        df = pd.read_sql_query(
            sql=(str(theQuery)),
            con=(theConn))
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
        print("\n" + typeE + 
              "\n" + fileE + 
              "\n" + lineE + 
              "\n" + messageE)
    #}
    else: #{
        print("FIN...")
        return df
    #}
#}

# %% [markdown]
# ---
# # TABLE SCHEMAS

# %%
sql_query = cnxn.execute("select * FROM INFORMATION_SCHEMA.TABLES;")
for row in sql_query: # {
    print(str(row))
# }
# Out:
# ('Prodflow', 'dbo', 'tblSysUnitsOfMeasure', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysValidationTypes', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblCtrlItem', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblCtrlNote', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysVolumes', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblProdflow', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblRmNeatBottles', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblCtrlBottle', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblPfNotebookStocks', 'BASE TABLE')
# ('Prodflow', 'dbo', 'InventoryScanning', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblPfNotebookTargets', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblPfNotebookWIP', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblPfNotebook', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblRmNeatAssays', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblRmNeatLots', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblMgtChgValidations', 'BASE TABLE')
# ('Prodflow', 'dbo', 'vwNeatLots', 'VIEW')
# ('Prodflow', 'dbo', 'vwProdflowReport', 'VIEW')
# ('Prodflow', 'dbo', 'vwPfNotebookReport', 'VIEW')
# ('Prodflow', 'dbo', 'vwCrossRmNeatLot', 'VIEW')
# ('Prodflow', 'dbo', 'vwPfNotebookReportInorg', 'VIEW')
# ('Prodflow', 'dbo', 'tblPfNotebook_Backup', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblMgtChangeLog', 'BASE TABLE')
# ('Prodflow', 'dbo', 'vw_AmpCatCost', 'VIEW')
# ('Prodflow', 'dbo', 'vw_AgiKitCost', 'VIEW')
# ('Prodflow', 'dbo', 'vw_AgiCatCost', 'VIEW')
# ('Prodflow', 'dbo', 'vwTblPfNotebook_LastYear2018', 'VIEW')
# ('Prodflow', 'dbo', 'vw_tblPfNotebook_History', 'VIEW')
# ('Prodflow', 'dbo', 'tblPfNotebook_Backup2', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblCtrlJournal', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblProdflow_Backup04052019', 'BASE TABLE')
# ('Prodflow', 'dbo', 'Qry_tblAssays_Trimmed', 'VIEW')
# ('Prodflow', 'dbo', 'vw_tblProdflow', 'VIEW')
# ('Prodflow', 'dbo', 'tblEqGlassware_test', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblEqGlassware', 'BASE TABLE')
# ('Prodflow', 'dbo', 'HistoricalControlData', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblPrdInstructions', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSMLots', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblAppHelp', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblEqBalances', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSMBottles', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblMgtPersonnel', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSMAssays', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblRmManufacturers', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblRmMfrQuals', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysCofAHeaders', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysConstants', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysMfrQCCodes', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysMfrQualTypes', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysMgtPersLevels', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysObjTypes', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysProductLines', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysQCSource Priority', 'BASE TABLE')
# ('Prodflow', 'dbo', 'tblSysStorageTypes', 'BASE TABLE')

# %% [markdown]
# ---
# ## tblProdflow

# %%
df_tblProdflow = read_sql_query_from_sqlexpress(
    "select * FROM [tblProdflow]", cnxn
)
# Out:
# FIN...

# %%
df_tblProdflow.sample(25)
# Out:
#         PfIDNo PfBatchID      ProductNo    OrdID     QuoteNo PfSentTo  \
# 46135    11554  NC011186      IST-341-1      NaN  Prodflow I     done
# 81922   125737   NW13968  G1969-85026-X  78348.0  Stock Item     done
# 100031  142650   NZ06356   BULK-PE-1012  96235.0  Stock Item     done
# 95359   139219   NZ02925      PAH-630-1  92435.0  Stock Item     done
# 47426    10585  NC010216       CUS-3614      NaN  Prodflow I     done
# 102269  144640  NAA00222  G3440-85009-1  98201.0  Stock Item     done
# 30145    28978   NH03846      DWM-583-1  12024.0  Stock Item     done
# 62280   104934   NR00547      PPS-430-1  55593.0  Stock Item     done
# 94841   138955   NZ02661      CUS-10858  92288.0  101116-268    Scrap
# 34863    22061   NG00830       CUS-7420   7178.0   101105-59     done
# 95618   139476   NZ03182      ICUS-1855  92987.0  050218-975     done
# 33218    24309   NG03078     CUS-7968-5   9423.0  082306-251     done
# 51455     6399  NB981772    WAT042881-7      NaN  Prodflow I     done
# 84460   128345   NY00095      CUS-15706  81034.0  010417-949     done
# 66728   110340   NU05953      ICUS-1877  61819.0  111212-199     done
# 58257   102040   NP41103      STK-01475  51943.0  Stock Item    stock
# 84518   130322   NY02072      STK-00818  83530.0  Stock Item    stock
# 717      56187   NN01694      STK-00057  42245.0  Stock Item     done
# 44569    12205  NC020093       CUS-3973      NaN  Prodflow I     done
# 13247    47474   NL04497       CUS-8324  33183.0  092410-508     done
# 82323   126419   NW14650       CICM-240  79070.0  Stock Item     done
# 44325    13519  NC021407       CUS-4321      NaN  Prodflow I     done
# 42150    15267  NC031414       CUS-2179      NaN  Prodflow I     done
# 60212   108179   NU03792     EPA-1212-1  59468.0  Stock Item     done
# 22910    36595   NK00326   PST-1475K100  22225.0  110507-038     done
#
#          PrepDate  PrepVolume PrepUnit  PrepVessel  ... QCValidation  \
# 46135  2001-09-11       250.0       mL         1.0  ...          2.0
# 81922  2016-08-29     20000.0       mL         3.0  ...          2.0
# 100031 2018-10-15      6000.0       mL         1.0  ...          2.0
# 95359  2018-04-27        50.0       mL         1.0  ...          2.0
# 47426  2001-02-14       100.0       mL         1.0  ...          1.0
# 102269 2019-01-14       100.0       mL         1.0  ...          2.0
# 30145  2007-10-11      1000.0       mL         1.0  ...          2.0
# 62280  2014-02-04        50.0       mL         1.0  ...          2.0
# 94841  2018-04-20        50.0       mL         1.0  ...          1.0
# 34863  2006-03-15      1000.0       mL         1.0  ...          1.0
# 95618  2018-05-07      4000.0       mL         1.0  ...          1.0
# 33218  2006-09-28       100.0       mL         1.0  ...          1.0
# 51455  1998-11-19      4000.0       mL         1.0  ...          1.0
# 84460  2017-01-13        50.0       mL         1.0  ...          1.0
# 66728  2014-10-29      2000.0       mL         1.0  ...          1.0
# 58257  2013-07-31       100.0       mL         1.0  ...          1.0
# 84518  2017-04-12       100.0       mL         1.0  ...          1.0
# 717    2010-02-25       100.0       mL         1.0  ...          0.0
# 44569  2002-01-17       100.0       mL         1.0  ...          1.0
# 13247  2010-09-30        50.0       mL         1.0  ...          1.0
# 82323  2016-09-29      4000.0       mL         1.0  ...          2.0
# 44325  2002-10-10        50.0       mL         1.0  ...          1.0
# 42150  2003-08-12       100.0       mL         1.0  ...          1.0
# 60212  2014-07-18        50.0       mL         1.0  ...          2.0
# 22910  2009-01-20        50.0       mL         1.0  ...          1.0
#
#        FgInvCount            FgAccpacNote CofAHeaderNo QCChromatogram Correct  \
# 46135         NaN                    None          2.0           None   False
# 81922         0.0                    None          2.0           None   False
# 100031     6000.0                    None          2.0           None   False
# 95359        27.0                    None          2.0           None   False
# 47426         NaN                    None          1.0           None   False
# 102269       65.0                    None          2.0           None   False
# 30145       738.0                 back up          2.0           None   False
# 62280        26.0                    None          2.0           None   False
# 94841         NaN                    None          1.0           None   False
# 34863        12.0  Approx. 100 mL in bulk          1.0           None   False
# 95618         6.0                    None          1.0           None   False
# 33218        45.0                 current          1.0           None   False
# 51455         NaN                    None          2.0           None   False
# 84460        31.0                    None          1.0           None   False
# 66728         4.0                    None          1.0           None   False
# 58257         NaN                    None         14.0           None    True
# 84518         NaN                    None         14.0           None    True
# 717           0.0                    None          2.0           None   False
# 44569         NaN                    None          1.0           None   False
# 13247        33.0   zero out ce-3674 (17)          1.0           None   False
# 82323        29.0                    None          2.0           None   False
# 44325         NaN                    None          1.0           None   False
# 42150         NaN                    None          1.0           None   False
# 60212        31.0                    None          2.0           None   False
# 22910        49.0                1 x 1 mL          1.0           None   False
#
#        DoNotCorrect DensityUnit DensityTemp recipeid
# 46135          True        None        None     None
# 81922          True        None        None     None
# 100031         True        None        None     None
# 95359         False        None        None     None
# 47426          True        None        None     None
# 102269        False        None        None     None
# 30145          True        None        None     None
# 62280         False        None        None     None
# 94841         False        None        None     None
# 34863          True        None        None     None
# 95618         False        None        None     None
# 33218          True        None        None     None
# 51455          True        None        None     None
# 84460         False        None        None     None
# 66728         False        None        None     None
# 58257         False        None        None     None
# 84518         False        None        None     None
# 717            True        None        None     None
# 44569          True        None        None     None
# 13247          True        None        None     None
# 82323         False        None        None     None
# 44325          True        None        None     None
# 42150          True        None        None     None
# 60212         False        None        None     None
# 22910          True        None        None     None
#
# [25 rows x 53 columns]
