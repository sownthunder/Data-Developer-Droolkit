# %% [markdown]
# # Ample Unitizing
#
# ## [selecting_rows_based_on_conditions](https://chrisalbon.com/python/data_wrangling/pandas_select_rows_multiple_filters/)
#
# ---

# %%
import os, sys, time
from time import sleep
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import pyodbc
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %% [raw]
# [x for x in pyodbc.drivers() if x.startswith('Microsoft Access Driver')]

# %% [raw]
# try: #{
#     conn_str = (
#         r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
#         r'DBQ=C:\Users\derbates\OneDrive - Agilent Technologies\Desktop\Offline Prodflow II\Custom Quotes_fe.accdb;'
#     )
# #}
# except: #{
#     errorMessage = str(sys.exc_info()[0]) + "\n"
#     errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
#     errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
#     exc_type, exc_obj, exc_tb = sys.exc_info()
#     fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
#     typeE = str("TYPE : " + str(exc_type))
#     fileE = str("FILE : " + str(fname))
#     lineE = str("LINE : " + str(exc_tb.tb_lineno))
#     messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
#     print("\n" + typeE +
#           "\n" + fileE +
#           "\n" + lineE +
#           "\n" + messageE)
# #}
# else: #{
#     print("FIN...")
# #}

# %%
todays_date = pd.Timestamp.now()
today_str = str(todays_date)[:10]

# %% [markdown]
# ## *Prodflow* database in *SQL_SERVER*

# %%
# CREATE CONNECTION STRING FOR SQL SERVER
conn_str = str(
    r'DRIVER={ODBC Driver 17 for SQL Server};'
    r'SERVER=wtkngappflow1.is.agilent.net;'
    r'DATABASE=ProdFlow;'
    r'Trusted_Connection=yes;'
)

# %%
try: #{
    cnxn = pyodbc.connect(conn_str)
    crsr = cnxn.cursor()
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# FIN...

# %% [markdown]
# ## tblProdflow

# %%
# TRY THE FOLLOWING
try: # {
    df_tblProdflow = pd.read_sql_query(sql='SELECT * FROM tblProdflow', 
                                       parse_dates=['AmpDate'],
                                       con=cnxn)
# }
except: # {
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
# }
else: # {
    print("Operation Completed Successfully...")
    print(df_tblProdflow.info())
# }
# Out:
# Operation Completed Successfully...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108597 entries, 0 to 108596
# Data columns (total 53 columns):
# PfIDNo              108597 non-null int64
# PfBatchID           108597 non-null object
# ProductNo           108578 non-null object
# OrdID               92465 non-null float64
# QuoteNo             108561 non-null object
# PfSentTo            108532 non-null object
# PrepDate            107583 non-null datetime64[ns]
# PrepVolume          108552 non-null float64
# PrepUnit            108521 non-null object
# PrepVessel          108518 non-null float64
# PrepVBarcode        57912 non-null object
# PrdSaleUnit         89377 non-null object
# PrepMatrixNo        108522 non-null object
# PrepMatrixLot       107655 non-null object
# PrepInits           107414 non-null object
# PrepMemo            61210 non-null object
# PrepNotebookRef     48969 non-null object
# BulkQCStatus        24 non-null object
# BulkQCDate          74962 non-null datetime64[ns]
# BulkPassFail        74068 non-null object
# BulkQCInits         74946 non-null object
# BulkQCMemo          2111 non-null object
# BulkLotNo           73322 non-null object
# AmpRetains          51836 non-null float64
# AmpDate             92700 non-null datetime64[ns]
# AmpPreLabel         108597 non-null bool
# AmpNumberGood       93026 non-null float64
# AmpNumberBad        77453 non-null float64
# AmpBulkRemain       4103 non-null float64
# AmpTimeIn           92456 non-null datetime64[ns]
# AmpTimeOut          92456 non-null datetime64[ns]
# AmpInits            92664 non-null object
# QCStatus            573 non-null object
# QCDate              103140 non-null datetime64[ns]
# QCPassFail          103330 non-null object
# QCAuthInits         103129 non-null object
# QCMemo              55342 non-null object
# QCMethod            1193 non-null object
# LotNo               100429 non-null object
# QCExpMonth          93239 non-null float64
# QCExpDate           91725 non-null datetime64[ns]
# QCSellBy            0 non-null object
# QCFullValidation    108597 non-null bool
# QCValidation        108563 non-null float64
# FgInvCount          77893 non-null float64
# FgAccpacNote        19523 non-null object
# CofAHeaderNo        108565 non-null float64
# QCChromatogram      0 non-null object
# Correct             108597 non-null bool
# DoNotCorrect        108597 non-null bool
# DensityUnit         0 non-null object
# DensityTemp         0 non-null object
# recipeid            1 non-null object
# dtypes: bool(4), datetime64[ns](7), float64(11), int64(1), object(30)
# memory usage: 41.0+ MB
# None

# %%
df_tblProdflow.set_index(['AmpDate'], inplace=True)

# %% [raw]
# df_tblProdflow.T.to_csv("c:/data/outbound/metrics/tblProdflow_PIVOT.csv", index=True)

# %% [markdown]
# ### Rename `AmpBulkRemain` column in table

# %%
df_tblProdflow.rename(columns={'AmpBulkRemain': 'Daily Yield'}, inplace=True)

# %% [markdown]
# ### Get only rows from `TODAY`

# %%
df_todaysAmples = df_tblProdflow[today_str]

# %%
df_todaysAmples.T
# Out:
# AmpDate                     2020-02-26  \
# PfIDNo                          152970
# PfBatchID                     NAB00813
# ProductNo                 BULK-ICC-015
# OrdID                           107735
# QuoteNo                     Stock Item
# PfSentTo                          done
# PrepDate           2020-02-13 00:00:00
# PrepVolume                        1000
# PrepUnit                            mL
# PrepVessel                           1
# PrepVBarcode                      1572
# PrdSaleUnit                       None
# PrepMatrixNo                   JHP-040
# PrepMatrixLot              RM16106-001
# PrepInits                         LP01
# PrepMemo                          None
# PrepNotebookRef                   None
# BulkQCStatus                      None
# BulkQCDate         2020-02-25 00:00:00
# BulkPassFail                      Pass
# BulkQCInits                        PMM
# BulkQCMemo                        None
# BulkLotNo                   0006520497
# AmpRetains                         NaN
# AmpPreLabel                      False
# AmpNumberGood                      950
# AmpNumberBad                       NaN
# Daily Yield                        NaN
# AmpTimeIn          1899-12-30 00:00:00
# AmpTimeOut         1899-12-30 00:01:00
# AmpInits                           rlm
# QCStatus                          None
# QCDate             2020-02-26 00:00:00
# QCPassFail                        Pass
# QCAuthInits                        PMM
# QCMemo                    OFFLINE CofA
# QCMethod                          None
# LotNo                       0006520497
# QCExpMonth                          48
# QCExpDate          2024-03-31 00:00:00
# QCSellBy                          None
# QCFullValidation                 False
# QCValidation                         1
# FgInvCount                         950
# FgAccpacNote      Done by DJ 2/26/2020
# CofAHeaderNo                         1
# QCChromatogram                    None
# Correct                          False
# DoNotCorrect                     False
# DensityUnit                       None
# DensityTemp                       None
# recipeid                          None
#
# AmpDate                                               2020-02-26  \
# PfIDNo                                                    153098
# PfBatchID                                               NAB00941
# ProductNo                                              AGI-P03-1
# OrdID                                                     107500
# QuoteNo                                               Stock Item
# PfSentTo                                                    done
# PrepDate                                     2020-02-19 00:00:00
# PrepVolume                                                   200
# PrepUnit                                                      mL
# PrepVessel                                                     1
# PrepVBarcode                                         F200-000490
# PrdSaleUnit                            1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                             JHP-003
# PrepMatrixLot                                         RM16129-07
# PrepInits                                                   AJP1
# PrepMemo          Sonicated in unit 48.  Solution appears dusty.
# PrepNotebookRef                                             None
# BulkQCStatus                                                None
# BulkQCDate                                   2020-02-26 00:00:00
# BulkPassFail                                                Pass
# BulkQCInits                                                  PMM
# BulkQCMemo                                                  None
# BulkLotNo                                             0006518943
# AmpRetains                                                   NaN
# AmpPreLabel                                                False
# AmpNumberGood                                                149
# AmpNumberBad                                                   5
# Daily Yield                                                  NaN
# AmpTimeIn                                    1899-12-30 12:50:00
# AmpTimeOut                                   1899-12-30 13:25:00
# AmpInits                                                     dak
# QCStatus                                                    None
# QCDate                                       2020-02-26 00:00:00
# QCPassFail                                                  Pass
# QCAuthInits                                                  PMM
# QCMemo                                                      None
# QCMethod                                                    None
# LotNo                                                 0006518943
# QCExpMonth                                                    18
# QCExpDate                                    2021-09-30 00:00:00
# QCSellBy                                                    None
# QCFullValidation                                           False
# QCValidation                                                   1
# FgInvCount                                                   149
# FgAccpacNote                                                None
# CofAHeaderNo                                                   1
# QCChromatogram                                              None
# Correct                                                    False
# DoNotCorrect                                               False
# DensityUnit                                                 None
# DensityTemp                                                 None
# recipeid                                                    None
#
# AmpDate                                                  2020-02-26  \
# PfIDNo                                                       153161
# PfBatchID                                                  NAB01004
# ProductNo                                                 QRR010934
# OrdID                                                        107407
# QuoteNo                                                  Stock Item
# PfSentTo                                                       done
# PrepDate                                        2020-02-24 00:00:00
# PrepVolume                                                    2e+06
# PrepUnit                                                          g
# PrepVessel                                                        4
# PrepVBarcode                                                    N/A
# PrdSaleUnit                                                    None
# PrepMatrixNo                                                JHP-035
# PrepMatrixLot                                                  none
# PrepInits                                                      DRL1
# PrepMemo          Actual:\r\nHCl - 44.8 grams\r\n\r\nAdd:\r\nH2O...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-25 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     DRD
# BulkQCMemo                                             OFFLINE CofA
# BulkLotNo                                                0006518208
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                   100
# AmpNumberBad                                                    NaN
# Daily Yield                                                     NaN
# AmpTimeIn                                       1899-12-30 07:45:00
# AmpTimeOut                                      1899-12-30 10:30:00
# AmpInits                                                         bs
# QCStatus                                                       None
# QCDate                                          2020-02-26 00:00:00
# QCPassFail                                                     Pass
# QCAuthInits                                                     PMM
# QCMemo                                                 OFFLINE CofA
# QCMethod                                                       None
# LotNo                                                    0006518208
# QCExpMonth                                                       24
# QCExpDate                                       2022-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                      100
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                          2020-02-26                 2020-02-26  \
# PfIDNo                               153190                     153167
# PfBatchID                          NAB01033                   NAB01010
# ProductNo                         AGI-T04-8                  AGI-P03-3
# OrdID                                107519                     107503
# QuoteNo                          Stock Item                 Stock Item
# PfSentTo                               done                       done
# PrepDate                2020-02-25 00:00:00        2020-02-24 00:00:00
# PrepVolume                               50                        200
# PrepUnit                                 mL                         mL
# PrepVessel                                1                          1
# PrepVBarcode                    F050-000042                F200-000493
# PrdSaleUnit       1 mL in 2 mL Amber Ampule  1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-003                    JHP-003
# PrepMatrixLot                    RM15706-16                 RM15706-15
# PrepInits                              KAW1                       SMG1
# PrepMemo               sonicated in unit 48       Sonicated in unit 48
# PrepNotebookRef                        None                       None
# BulkQCStatus                           None                       None
# BulkQCDate              2020-02-25 00:00:00        2020-02-26 00:00:00
# BulkPassFail                           Pass                       Pass
# BulkQCInits                             PMM                        PMM
# BulkQCMemo                             None                       None
# BulkLotNo                        0006518965                 0006518946
# AmpRetains                              NaN                        NaN
# AmpPreLabel                           False                      False
# AmpNumberGood                            32                        151
# AmpNumberBad                              5                          5
# Daily Yield                             NaN                        NaN
# AmpTimeIn               1899-12-30 09:00:00        1899-12-30 10:25:00
# AmpTimeOut              1899-12-30 09:10:00        1899-12-30 11:10:00
# AmpInits                                dak                        dak
# QCStatus                               None                       None
# QCDate                  2020-02-26 00:00:00        2020-02-26 00:00:00
# QCPassFail                             Pass                       Pass
# QCAuthInits                             PMM                        PMM
# QCMemo                                 None                       None
# QCMethod                               None                       None
# LotNo                            0006518965                 0006518946
# QCExpMonth                               18                         18
# QCExpDate               2021-09-30 00:00:00        2021-09-30 00:00:00
# QCSellBy                               None                       None
# QCFullValidation                      False                      False
# QCValidation                              1                          1
# FgInvCount                               32                        151
# FgAccpacNote                           None                       None
# CofAHeaderNo                              1                          1
# QCChromatogram                         None                       None
# Correct                               False                      False
# DoNotCorrect                          False                      False
# DensityUnit                            None                       None
# DensityTemp                            None                       None
# recipeid                               None                       None
#
# AmpDate                          2020-02-26                 2020-02-26  \
# PfIDNo                               153172                     153178
# PfBatchID                          NAB01015                   NAB01021
# ProductNo                         AGI-P03-9                  AGI-P03-7
# OrdID                                107507                     107505
# QuoteNo                          Stock Item                 Stock Item
# PfSentTo                               done                       done
# PrepDate                2020-02-24 00:00:00        2020-02-24 00:00:00
# PrepVolume                              200                        200
# PrepUnit                                 mL                         mL
# PrepVessel                                1                          1
# PrepVBarcode                    F200-000605                F200-000119
# PrdSaleUnit       1 mL in 2 mL Amber Ampule  1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-003                    JHP-003
# PrepMatrixLot                    RM16129-08                 RM16129-06
# PrepInits                              SMM1                       DRL1
# PrepMemo          DW. Sonicated in unit 48.       Sonicated in unit 48
# PrepNotebookRef                        None                       None
# BulkQCStatus                           None                       None
# BulkQCDate              2020-02-26 00:00:00        2020-02-25 00:00:00
# BulkPassFail                           Pass                       Pass
# BulkQCInits                             PMM                        PMM
# BulkQCMemo                             None                       None
# BulkLotNo                        0006518950                 0006518948
# AmpRetains                              NaN                        NaN
# AmpPreLabel                           False                      False
# AmpNumberGood                           150                        146
# AmpNumberBad                              5                          5
# Daily Yield                             NaN                        NaN
# AmpTimeIn               1899-12-30 11:10:00        1899-12-30 08:15:00
# AmpTimeOut              1899-12-30 11:45:00        1899-12-30 08:45:00
# AmpInits                                dak                        dak
# QCStatus                               None                       None
# QCDate                  2020-02-26 00:00:00        2020-02-26 00:00:00
# QCPassFail                             Pass                       Pass
# QCAuthInits                             PMM                        PMM
# QCMemo                                 None                       None
# QCMethod                               None                       None
# LotNo                            0006518950                 0006518948
# QCExpMonth                               18                         18
# QCExpDate               2021-09-30 00:00:00        2021-09-30 00:00:00
# QCSellBy                               None                       None
# QCFullValidation                      False                      False
# QCValidation                              1                          1
# FgInvCount                              150                        146
# FgAccpacNote                           None                       None
# CofAHeaderNo                              1                          1
# QCChromatogram                         None                       None
# Correct                               False                      False
# DoNotCorrect                          False                      False
# DensityUnit                            None                       None
# DensityTemp                            None                       None
# recipeid                               None                       None
#
# AmpDate                          2020-02-26  \
# PfIDNo                               153179
# PfBatchID                          NAB01022
# ProductNo                         AGI-P03-8
# OrdID                                107506
# QuoteNo                          Stock Item
# PfSentTo                               done
# PrepDate                2020-02-24 00:00:00
# PrepVolume                              200
# PrepUnit                                 mL
# PrepVessel                                1
# PrepVBarcode                    F200-000133
# PrdSaleUnit       1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-003
# PrepMatrixLot                    RM15706-23
# PrepInits                              RAA1
# PrepMemo               Sonicated in Unit 48
# PrepNotebookRef                        None
# BulkQCStatus                           None
# BulkQCDate              2020-02-26 00:00:00
# BulkPassFail                           Pass
# BulkQCInits                             PMM
# BulkQCMemo                             None
# BulkLotNo                        0006518949
# AmpRetains                              NaN
# AmpPreLabel                           False
# AmpNumberGood                           151
# AmpNumberBad                              5
# Daily Yield                             NaN
# AmpTimeIn               1899-12-30 13:50:00
# AmpTimeOut              1899-12-30 14:25:00
# AmpInits                                dak
# QCStatus                               None
# QCDate                  2020-02-26 00:00:00
# QCPassFail                             Pass
# QCAuthInits                             PMM
# QCMemo                                 None
# QCMethod                               None
# LotNo                            0006518949
# QCExpMonth                               18
# QCExpDate               2021-09-30 00:00:00
# QCSellBy                               None
# QCFullValidation                      False
# QCValidation                              1
# FgInvCount                              151
# FgAccpacNote                           None
# CofAHeaderNo                              1
# QCChromatogram                         None
# Correct                               False
# DoNotCorrect                          False
# DensityUnit                            None
# DensityTemp                            None
# recipeid                               None
#
# AmpDate                                                  2020-02-26  \
# PfIDNo                                                       153180
# PfBatchID                                                  NAB01023
# ProductNo                                                 DWM-580-1
# OrdID                                                        107740
# QuoteNo                                                  Stock Item
# PfSentTo                                                         QC
# PrepDate                                        2020-02-24 00:00:00
# PrepVolume                                                      500
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F500-000079
# PrdSaleUnit                               1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                                JHP-021
# PrepMatrixLot                                           RM15622-017
# PrepInits                                                      CAD1
# PrepMemo          DW AND REG. AND GAS DILUTIONS ON ICE ADDED 10%...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-24 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006520481
# AmpRetains                                                        5
# AmpPreLabel                                                    True
# AmpNumberGood                                                   345
# AmpNumberBad                                                     10
# Daily Yield                                                     NaN
# AmpTimeIn                                       1899-12-30 07:30:00
# AmpTimeOut                                      1899-12-30 09:20:00
# AmpInits                                                      lusbi
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       24
# QCExpDate                                       2022-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                      345
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                          2020-02-26                 2020-02-26  \
# PfIDNo                               153195                     153200
# PfBatchID                          NAB01038                   NAB01043
# ProductNo                         AGI-T04-9                  AGI-T03-1
# OrdID                                107520                     107510
# QuoteNo                          Stock Item                 Stock Item
# PfSentTo                               done                       done
# PrepDate                2020-02-25 00:00:00        2020-02-25 00:00:00
# PrepVolume                               50                         50
# PrepUnit                                 mL                         mL
# PrepVessel                                1                          1
# PrepVBarcode                    F050-000586                F050-000591
# PrdSaleUnit       1 mL in 2 mL Amber Ampule  1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-003                    JHP-003
# PrepMatrixLot                    RM15706-16                 RM16129-03
# PrepInits                              KAW1                       KAW1
# PrepMemo                               None       sonicated in unit 48
# PrepNotebookRef                        None                       None
# BulkQCStatus                           None                       None
# BulkQCDate              2020-02-25 00:00:00        2020-02-26 00:00:00
# BulkPassFail                           Pass                       Pass
# BulkQCInits                             PMM                        PMM
# BulkQCMemo                             None                       None
# BulkLotNo                        0006518966                 0006518955
# AmpRetains                              NaN                        NaN
# AmpPreLabel                           False                      False
# AmpNumberGood                            32                         31
# AmpNumberBad                              5                          5
# Daily Yield                             NaN                        NaN
# AmpTimeIn               1899-12-30 09:20:00        1899-12-30 15:45:00
# AmpTimeOut              1899-12-30 09:30:00        1899-12-30 15:55:00
# AmpInits                                dak                        DAK
# QCStatus                               None                       None
# QCDate                  2020-02-26 00:00:00        2020-02-26 00:00:00
# QCPassFail                             Pass                       Pass
# QCAuthInits                             PMM                        PMM
# QCMemo                                 None                       None
# QCMethod                               None                       None
# LotNo                            0006518966                 0006518955
# QCExpMonth                               18                         18
# QCExpDate               2021-09-30 00:00:00        2021-09-30 00:00:00
# QCSellBy                               None                       None
# QCFullValidation                      False                      False
# QCValidation                              1                          1
# FgInvCount                               32                         31
# FgAccpacNote                           None                       None
# CofAHeaderNo                              1                          1
# QCChromatogram                         None                       None
# Correct                               False                      False
# DoNotCorrect                          False                      False
# DensityUnit                            None                       None
# DensityTemp                            None                       None
# recipeid                               None                       None
#
# AmpDate                          2020-02-26  \
# PfIDNo                               153217
# PfBatchID                          NAB01060
# ProductNo                            CS1100
# OrdID                                107856
# QuoteNo                          Stock Item
# PfSentTo                               done
# PrepDate                2020-02-26 00:00:00
# PrepVolume                              100
# PrepUnit                                 mL
# PrepVessel                                1
# PrepVBarcode                    F100-000162
# PrdSaleUnit       1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-021
# PrepMatrixLot                   RM15273-001
# PrepInits                              RAA1
# PrepMemo               Sonicated in Unit 48
# PrepNotebookRef                        None
# BulkQCStatus                           None
# BulkQCDate              2020-02-26 00:00:00
# BulkPassFail                           Pass
# BulkQCInits                             PMM
# BulkQCMemo                             None
# BulkLotNo                        0006521735
# AmpRetains                              NaN
# AmpPreLabel                           False
# AmpNumberGood                            66
# AmpNumberBad                              5
# Daily Yield                             NaN
# AmpTimeIn               1899-12-30 12:20:00
# AmpTimeOut              1899-12-30 12:40:00
# AmpInits                                dak
# QCStatus                               None
# QCDate                  2020-02-26 00:00:00
# QCPassFail                             Pass
# QCAuthInits                             PMM
# QCMemo                                 None
# QCMethod                               None
# LotNo                            0006521735
# QCExpMonth                               12
# QCExpDate               2021-03-31 00:00:00
# QCSellBy                               None
# QCFullValidation                      False
# QCValidation                              1
# FgInvCount                               66
# FgAccpacNote                           None
# CofAHeaderNo                              1
# QCChromatogram                         None
# Correct                               False
# DoNotCorrect                          False
# DensityUnit                            None
# DensityTemp                            None
# recipeid                               None
#
# AmpDate                                                  2020-02-26  \
# PfIDNo                                                       153212
# PfBatchID                                                  NAB01055
# ProductNo                                                 ICUS-7374
# OrdID                                                        107822
# QuoteNo                                                  Stock Item
# PfSentTo                                                       done
# PrepDate                                        2020-02-26 00:00:00
# PrepVolume                                                      200
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                                   1354
# PrdSaleUnit       125 mL in 125 ML (4 oz) NM Clear LDPE Bos Rnd ...
# PrepMatrixNo                                                JHP-338
# PrepMatrixLot                                            with batch
# PrepInits                                                      LP01
# PrepMemo          Hydrofluoric acid (0.2 ml) was not added; adde...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-26 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006521382
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                     1
# AmpNumberBad                                                    NaN
# Daily Yield                                                     NaN
# AmpTimeIn                                       1899-12-30 16:06:00
# AmpTimeOut                                      1899-12-30 16:07:00
# AmpInits                                                         SS
# QCStatus                                                       None
# QCDate                                          2020-02-26 00:00:00
# QCPassFail                                                     Pass
# QCAuthInits                                                     PMM
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                    0006521382
# QCExpMonth                                                       24
# QCExpDate                                       2022-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                        1
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                                  2020-02-26  \
# PfIDNo                                                       153218
# PfBatchID                                                  NAB01061
# ProductNo                                              ICUS-0000106
# OrdID                                                        107880
# QuoteNo                                                     3154284
# PfSentTo                                                   ampuling
# PrepDate                                        2020-02-26 00:00:00
# PrepVolume                                                     4000
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                                   1453
# PrdSaleUnit       480 mL in 500mL Nalgene Narrow-Mouth HDPE Economy
# PrepMatrixNo                                                JHP-377
# PrepMatrixLot                                            with batch
# PrepInits                                                      LP01
# PrepMemo          Hydrofluoric acid ( 4 ml ) was not added; adde...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-26 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006522033
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                   NaN
# AmpNumberBad                                                    NaN
# Daily Yield                                                     NaN
# AmpTimeIn                                                       NaT
# AmpTimeOut                                                      NaT
# AmpInits                                                       None
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       12
# QCExpDate                                       2021-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                      NaN
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                                  2020-02-26  \
# PfIDNo                                                       153132
# PfBatchID                                                  NAB00975
# ProductNo                                             G1946-85021-1
# OrdID                                                        107596
# QuoteNo                                                  Stock Item
# PfSentTo                                                         QC
# PrepDate                                        2020-02-20 00:00:00
# PrepVolume                                                     6000
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                             F6K-000116
# PrdSaleUnit                             2.2 mL in 2 mL Amber Ampule
# PrepMatrixNo                                                JHP-040
# PrepMatrixLot                                           RM15055-001
# PrepInits                                                      LFM1
# PrepMemo          dw. swirled into solution. let come to room te...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-21 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006518450
# AmpRetains                                                        5
# AmpPreLabel                                                    True
# AmpNumberGood                                                  2413
# AmpNumberBad                                                     10
# Daily Yield                                                     NaN
# AmpTimeIn                                       1899-12-30 10:00:00
# AmpTimeOut                                      1899-12-30 13:10:00
# AmpInits                                                      lusbi
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       12
# QCExpDate                                       2021-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                     2413
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                 2020-02-26
# PfIDNo                                      153203
# PfBatchID                                 NAB01046
# ProductNo                                QRR010933
# OrdID                                       107549
# QuoteNo                                 Stock Item
# PfSentTo                                  ampuling
# PrepDate                       2020-02-26 00:00:00
# PrepVolume                                  700000
# PrepUnit                                         g
# PrepVessel                                       4
# PrepVBarcode                                   N/A
# PrdSaleUnit       5 L in 5 L Clear plastic bladder
# PrepMatrixNo                               JHP-035
# PrepMatrixLot                                 none
# PrepInits                                     DRL1
# PrepMemo                                      None
# PrepNotebookRef                               None
# BulkQCStatus                                  None
# BulkQCDate                     2020-02-26 00:00:00
# BulkPassFail                                  Pass
# BulkQCInits                                    PMM
# BulkQCMemo                                    None
# BulkLotNo                               0006519330
# AmpRetains                                     NaN
# AmpPreLabel                                  False
# AmpNumberGood                                  NaN
# AmpNumberBad                                   NaN
# Daily Yield                                    NaN
# AmpTimeIn                                      NaT
# AmpTimeOut                                     NaT
# AmpInits                                      None
# QCStatus                                      None
# QCDate                                         NaT
# QCPassFail                                    None
# QCAuthInits                                   None
# QCMemo                                        None
# QCMethod                                      None
# LotNo                                         None
# QCExpMonth                                      36
# QCExpDate                      2023-03-31 00:00:00
# QCSellBy                                      None
# QCFullValidation                             False
# QCValidation                                     1
# FgInvCount                                     NaN
# FgAccpacNote                                  None
# CofAHeaderNo                                     1
# QCChromatogram                                None
# Correct                                      False
# DoNotCorrect                                 False
# DensityUnit                                   None
# DensityTemp                                   None
# recipeid                                      None

# %% [markdown]
# ### Create EMPTY DataFrame to hold Metrics

# %%
df_Metrics = pd.DataFrame(data=None)

# %% [raw]
# #### Get all `AmpNumberGood` number and their time `in/out`

# %% [raw]
# # SELECT ROWS OF THE DATAFRAME WHERE df.AmpNumberGood is greater than or equal to 1
# df_AmpNumberGood = df_todaysAmples[(df_tblProdflow['AmpNumberGood'] >= 1)]

# %%
# CREATE COLUMN TO hold PfID
df_Metrics["ID"] = df_todaysAmples['PfIDNo']

# %%
# CREATE COLUMN TO hold PfBatchID
df_Metrics['PfBatchID'] = df_todaysAmples['PfBatchID']

# %%
# CREATE column to hold number of GOOD AMPS
df_Metrics['AmpNumberGood'] = df_todaysAmples['AmpNumberGood']

# %% [raw]
# # CREATE COLUMN TO HOLD TIME IN
# df_Metrics['Time-In'] = df_todaysAmples['AmpTimeIn'].dt.time

# %% [raw]
# # CREATE COLUMN TO HOLD AN TIME OUT
# df_Metrics['Time-Out'] = df_todaysAmples['AmpTimeOut'].dt.time

# %%
# CHANGE TIME OUT AND TIME IN COLUMNS TO BE DATETIME
df_Metrics['Time-In'] = pd.to_datetime(df_todaysAmples['AmpTimeIn'])
df_Metrics['Time-Out'] = pd.to_datetime(df_todaysAmples['AmpTimeOut'])

# %%
df_Metrics['time_diff'] = df_Metrics['Time-Out'] - df_Metrics['Time-In']

# %%
# CHANGE TIME OUT AND TIME OUT BACK TO TIMEDELTAS
df_Metrics['Time-In'] = df_todaysAmples['AmpTimeIn'].dt.time
df_Metrics['Time-Out'] = df_todaysAmples['AmpTimeOut'].dt.time

# %%
df_Metrics["AmpRetains"] = df_todaysAmples["AmpRetains"]

# %%
df_Metrics["Volume"] = df_todaysAmples["PrepVolume"]

# %%
# FILL EMPTY CELLS WITH 0
df_Metrics.fillna(value=0, inplace=True)
# Out:
# C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.

# %%
df_Metrics["Daily Yield"] = df_Metrics["Volume"] * df_Metrics['AmpRetains']

# %%
df_Metrics["Unit"] = df_todaysAmples["PrepUnit"]

# %% [raw]
# #### determine time in/out of `AmpNumberGood`

# %%
df_Metrics
# Out:
#                 ID PfBatchID  AmpNumberGood   Time-In  Time-Out time_diff  \
# AmpDate
# 2020-02-26  152970  NAB00813          950.0  00:00:00  00:01:00  00:01:00
# 2020-02-26  153098  NAB00941          149.0  12:50:00  13:25:00  00:35:00
# 2020-02-26  153161  NAB01004          100.0  07:45:00  10:30:00  02:45:00
# 2020-02-26  153190  NAB01033           32.0  09:00:00  09:10:00  00:10:00
# 2020-02-26  153167  NAB01010          151.0  10:25:00  11:10:00  00:45:00
# 2020-02-26  153172  NAB01015          150.0  11:10:00  11:45:00  00:35:00
# 2020-02-26  153178  NAB01021          146.0  08:15:00  08:45:00  00:30:00
# 2020-02-26  153179  NAB01022          151.0  13:50:00  14:25:00  00:35:00
# 2020-02-26  153180  NAB01023          345.0  07:30:00  09:20:00  01:50:00
# 2020-02-26  153195  NAB01038           32.0  09:20:00  09:30:00  00:10:00
# 2020-02-26  153200  NAB01043           31.0  15:45:00  15:55:00  00:10:00
# 2020-02-26  153217  NAB01060           66.0  12:20:00  12:40:00  00:20:00
# 2020-02-26  153212  NAB01055            1.0  16:06:00  16:07:00  00:01:00
# 2020-02-26  153218  NAB01061            0.0         0         0  00:00:00
# 2020-02-26  153132  NAB00975         2413.0  10:00:00  13:10:00  03:10:00
# 2020-02-26  153203  NAB01046            0.0         0         0  00:00:00
#
#             AmpRetains     Volume  Daily Yield Unit
# AmpDate
# 2020-02-26         0.0     1000.0          0.0   mL
# 2020-02-26         0.0      200.0          0.0   mL
# 2020-02-26         0.0  2000000.0          0.0    g
# 2020-02-26         0.0       50.0          0.0   mL
# 2020-02-26         0.0      200.0          0.0   mL
# 2020-02-26         0.0      200.0          0.0   mL
# 2020-02-26         0.0      200.0          0.0   mL
# 2020-02-26         0.0      200.0          0.0   mL
# 2020-02-26         5.0      500.0       2500.0   mL
# 2020-02-26         0.0       50.0          0.0   mL
# 2020-02-26         0.0       50.0          0.0   mL
# 2020-02-26         0.0      100.0          0.0   mL
# 2020-02-26         0.0      200.0          0.0   mL
# 2020-02-26         0.0     4000.0          0.0   mL
# 2020-02-26         5.0     6000.0      30000.0   mL
# 2020-02-26         0.0   700000.0          0.0    g

# %% [raw]
# df_TodaysGoodAmples = df_AmpNumberGood[today_str][['AmpTimeIn'], ['AmpTimeOut']]

# %%
df_Metrics.to_excel("c:/data/outbound/Metrics/" + today_str + "_ampule_METRICS.xlsx", index=True)

# %%
df_Metrics.to_csv("c:/data/outbound/Metrics/" + today_str + "_ampule_METRICS.csv", index=True)

# %% [raw]
# ts_str = str(pd.Timestamp.now())[:10]
# filename_str = str("Ampule_metrics_test_" + ts_str + ".xlsx")

# %% [raw]
# df_Metrics.to_excel("C:/data/outbound/Metrics/" + filename_str)
