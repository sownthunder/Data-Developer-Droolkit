# %% [markdown]
# # Ample Unitizing
#
# ## [selecting_rows_based_on_conditions](https://chrisalbon.com/python/data_wrangling/pandas_select_rows_multiple_filters/)
#
# ---

# %%
import os, sys, time
from time import sleep
from pathlib import Path
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import pyodbc
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# %% [raw]
# [x for x in pyodbc.drivers() if x.startswith('Microsoft Access Driver')]

# %% [raw]
# try: #{
#     conn_str = (
#         r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
#         r'DBQ=C:\Users\derbates\OneDrive - Agilent Technologies\Desktop\Offline Prodflow II\Custom Quotes_fe.accdb;'
#     )
# #}
# except: #{
#     errorMessage = str(sys.exc_info()[0]) + "\n"
#     errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
#     errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
#     exc_type, exc_obj, exc_tb = sys.exc_info()
#     fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
#     typeE = str("TYPE : " + str(exc_type))
#     fileE = str("FILE : " + str(fname))
#     lineE = str("LINE : " + str(exc_tb.tb_lineno))
#     messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
#     print("\n" + typeE +
#           "\n" + fileE +
#           "\n" + lineE +
#           "\n" + messageE)
# #}
# else: #{
#     print("FIN...")
# #}

# %%
todays_date = pd.Timestamp.now()
today_str = str(todays_date)[:10]

# %% [markdown]
# ## *Prodflow* database in *SQL_SERVER*

# %%
# CREATE CONNECTION STRING FOR SQL SERVER
conn_str = str(
    r'DRIVER={ODBC Driver 17 for SQL Server};'
    r'SERVER=wtkngappflow1.is.agilent.net;'
    r'DATABASE=ProdFlow;'
    r'Trusted_Connection=yes;'
)

# %%
try: #{
    cnxn = pyodbc.connect(conn_str)
    crsr = cnxn.cursor()
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# FIN...

# %% [markdown]
# ## tblProdflow

# %%
# TRY THE FOLLOWING
try: # {
    df_tblProdflow = pd.read_sql_query(sql='SELECT * FROM tblProdflow', 
                                       parse_dates=['AmpDate'],
                                       con=cnxn)
# }
except: # {
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
# }
else: # {
    print("Operation Completed Successfully...")
    print(df_tblProdflow.info())
# }
# Out:
# Operation Completed Successfully...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108628 entries, 0 to 108627
# Data columns (total 53 columns):
# PfIDNo              108628 non-null int64
# PfBatchID           108628 non-null object
# ProductNo           108609 non-null object
# OrdID               92496 non-null float64
# QuoteNo             108592 non-null object
# PfSentTo            108563 non-null object
# PrepDate            107614 non-null datetime64[ns]
# PrepVolume          108583 non-null float64
# PrepUnit            108552 non-null object
# PrepVessel          108549 non-null float64
# PrepVBarcode        57942 non-null object
# PrdSaleUnit         89403 non-null object
# PrepMatrixNo        108553 non-null object
# PrepMatrixLot       107685 non-null object
# PrepInits           107444 non-null object
# PrepMemo            61238 non-null object
# PrepNotebookRef     48969 non-null object
# BulkQCStatus        24 non-null object
# BulkQCDate          74985 non-null datetime64[ns]
# BulkPassFail        74091 non-null object
# BulkQCInits         74969 non-null object
# BulkQCMemo          2111 non-null object
# BulkLotNo           73345 non-null object
# AmpRetains          51843 non-null float64
# AmpDate             92728 non-null datetime64[ns]
# AmpPreLabel         108628 non-null bool
# AmpNumberGood       93055 non-null float64
# AmpNumberBad        77472 non-null float64
# AmpBulkRemain       4121 non-null float64
# AmpTimeIn           92485 non-null datetime64[ns]
# AmpTimeOut          92485 non-null datetime64[ns]
# AmpInits            92693 non-null object
# QCStatus            573 non-null object
# QCDate              103169 non-null datetime64[ns]
# QCPassFail          103359 non-null object
# QCAuthInits         103158 non-null object
# QCMemo              55355 non-null object
# QCMethod            1195 non-null object
# LotNo               100455 non-null object
# QCExpMonth          93270 non-null float64
# QCExpDate           91752 non-null datetime64[ns]
# QCSellBy            0 non-null object
# QCFullValidation    108628 non-null bool
# QCValidation        108594 non-null float64
# FgInvCount          77922 non-null float64
# FgAccpacNote        19548 non-null object
# CofAHeaderNo        108596 non-null float64
# QCChromatogram      0 non-null object
# Correct             108628 non-null bool
# DoNotCorrect        108628 non-null bool
# DensityUnit         0 non-null object
# DensityTemp         0 non-null object
# recipeid            1 non-null object
# dtypes: bool(4), datetime64[ns](7), float64(11), int64(1), object(30)
# memory usage: 41.0+ MB
# None

# %%
df_tblProdflow.set_index(['AmpDate'], inplace=True)

# %% [raw]
# df_tblProdflow.T.to_csv("c:/data/outbound/metrics/tblProdflow_PIVOT.csv", index=True)

# %% [markdown]
# ### Rename `AmpBulkRemain` column in table

# %%
df_tblProdflow.rename(columns={'AmpBulkRemain': 'Daily Yield'}, inplace=True)

# %% [markdown]
# ### Get only rows from `TODAY`

# %%
df_todaysAmples = df_tblProdflow[today_str]

# %%
df_todaysAmples.T
# Out:
# AmpDate                                     2020-02-27  \
# PfIDNo                                          153080
# PfBatchID                                     NAB00923
# ProductNo                                    CUS-25143
# OrdID                                           107724
# QuoteNo                                     Stock Item
# PfSentTo                                          done
# PrepDate                           2020-02-18 00:00:00
# PrepVolume                                         100
# PrepUnit                                            mL
# PrepVessel                                           1
# PrepVBarcode                               F100-000564
# PrdSaleUnit                  1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                   JHP-335
# PrepMatrixLot                                AMX-00801
# PrepInits                                         MHD1
# PrepMemo          Sonicated in unit 48. MD (2/25/2020)
# PrepNotebookRef                                   None
# BulkQCStatus                                      None
# BulkQCDate                         2020-02-26 00:00:00
# BulkPassFail                                      Pass
# BulkQCInits                                        PMM
# BulkQCMemo                                        None
# BulkLotNo                                   0006520474
# AmpRetains                                         NaN
# AmpPreLabel                                      False
# AmpNumberGood                                        5
# AmpNumberBad                                         5
# Daily Yield                                         80
# AmpTimeIn                          1899-12-30 07:35:00
# AmpTimeOut                         1899-12-30 07:40:00
# AmpInits                                          dakl
# QCStatus                                          None
# QCDate                             2020-02-27 00:00:00
# QCPassFail                                        Pass
# QCAuthInits                                        PMM
# QCMemo                                            None
# QCMethod                                          None
# LotNo                                       0006520474
# QCExpMonth                                          24
# QCExpDate                          2022-03-31 00:00:00
# QCSellBy                                          None
# QCFullValidation                                 False
# QCValidation                                         1
# FgInvCount                                           5
# FgAccpacNote                                      None
# CofAHeaderNo                                         1
# QCChromatogram                                    None
# Correct                                          False
# DoNotCorrect                                     False
# DensityUnit                                       None
# DensityTemp                                       None
# recipeid                                          None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153202
# PfBatchID                                                  NAB01045
# ProductNo                                             G1969-85026-X
# OrdID                                                        107672
# QuoteNo                                                  Stock Item
# PfSentTo                                                       done
# PrepDate                                        2020-02-25 00:00:00
# PrepVolume                                                    20000
# PrepUnit                                                         mL
# PrepVessel                                                        3
# PrepVBarcode                                                    N/A
# PrdSaleUnit        500 mL in 500 mL (16 oz) NM Amber Glass Bottl...
# PrepMatrixNo                                                JHP-035
# PrepMatrixLot                                                  none
# PrepInits                                                      KAW1
# PrepMemo                                                      lot#1
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-26 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006519816
# AmpRetains                                                      NaN
# AmpPreLabel                                                    True
# AmpNumberGood                                                    42
# AmpNumberBad                                                      0
# Daily Yield                                                     NaN
# AmpTimeIn                                       1899-12-30 01:15:00
# AmpTimeOut                                      1899-12-30 11:00:00
# AmpInits                                                      lusbi
# QCStatus                                                       None
# QCDate                                          2020-02-27 00:00:00
# QCPassFail                                                     Pass
# QCAuthInits                                                     PMM
# QCMemo                                                 OFFLINE CofA
# QCMethod                                                       None
# LotNo                                                    0006519816
# QCExpMonth                                                       48
# QCExpDate                                       2024-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                       42
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                   True
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                          2020-02-27  \
# PfIDNo                               153248
# PfBatchID                          NAB01091
# ProductNo                      CUS-00002458
# OrdID                                107956
# QuoteNo                             3122444
# PfSentTo                                 QC
# PrepDate                2020-02-27 00:00:00
# PrepVolume                              100
# PrepUnit                                 mL
# PrepVessel                                1
# PrepVBarcode                    F100-000163
# PrdSaleUnit       1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-021
# PrepMatrixLot                   RM15273-001
# PrepInits                              RAA1
# PrepMemo                               None
# PrepNotebookRef                        None
# BulkQCStatus                           None
# BulkQCDate              2020-02-27 00:00:00
# BulkPassFail                           Pass
# BulkQCInits                             PMM
# BulkQCMemo                             None
# BulkLotNo                        0006522600
# AmpRetains                              NaN
# AmpPreLabel                           False
# AmpNumberGood                            10
# AmpNumberBad                              5
# Daily Yield                              75
# AmpTimeIn               1899-12-30 15:35:00
# AmpTimeOut              1899-12-30 15:40:00
# AmpInits                                DAK
# QCStatus                               None
# QCDate                                  NaT
# QCPassFail                             None
# QCAuthInits                            None
# QCMemo                                 None
# QCMethod                               None
# LotNo                                  None
# QCExpMonth                               24
# QCExpDate               2022-03-31 00:00:00
# QCSellBy                               None
# QCFullValidation                      False
# QCValidation                              1
# FgInvCount                               10
# FgAccpacNote                           None
# CofAHeaderNo                              1
# QCChromatogram                         None
# Correct                               False
# DoNotCorrect                          False
# DensityUnit                            None
# DensityTemp                            None
# recipeid                               None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153188
# PfBatchID                                                  NAB01031
# ProductNo                                               5190-6902-1
# OrdID                                                        107905
# QuoteNo                                                  Stock Item
# PfSentTo                                                         QC
# PrepDate                                        2020-02-25 00:00:00
# PrepVolume                                                       50
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F050-000017
# PrdSaleUnit       1 mg in 1.5 mL amber vial w/30 uL reservoir w/...
# PrepMatrixNo                                                JHP-597
# PrepMatrixLot                                             AMX-00803
# PrepInits                                                      RAA1
# PrepMemo          Did not use the 50 ml flask as indicated. The ...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-27 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006521771
# AmpRetains                                                        5
# AmpPreLabel                                                   False
# AmpNumberGood                                                    55
# AmpNumberBad                                                      3
# Daily Yield                                                       0
# AmpTimeIn                                       1899-12-30 12:00:00
# AmpTimeOut                                      1899-12-30 12:01:00
# AmpInits                                                        RAA
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       36
# QCExpDate                                       2023-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                       55
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                          2020-02-27  \
# PfIDNo                               153215
# PfBatchID                          NAB01058
# ProductNo                         CUS-15271
# OrdID                                107930
# QuoteNo                          Stock Item
# PfSentTo                               done
# PrepDate                2020-02-26 00:00:00
# PrepVolume                               25
# PrepUnit                                 mL
# PrepVessel                                1
# PrepVBarcode                    F025-000649
# PrdSaleUnit       1 mL in 2 mL Amber Ampule
# PrepMatrixNo                        JHP-021
# PrepMatrixLot                    RM15622-16
# PrepInits                              SMM1
# PrepMemo          DW. Sonicated in unit 48.
# PrepNotebookRef                        None
# BulkQCStatus                           None
# BulkQCDate              2020-02-26 00:00:00
# BulkPassFail                           Pass
# BulkQCInits                             PMM
# BulkQCMemo                             None
# BulkLotNo                        0006522309
# AmpRetains                              NaN
# AmpPreLabel                           False
# AmpNumberGood                             5
# AmpNumberBad                              5
# Daily Yield                               8
# AmpTimeIn               1899-12-30 12:50:00
# AmpTimeOut              1899-12-30 12:55:00
# AmpInits                                dak
# QCStatus                               None
# QCDate                  2020-02-27 00:00:00
# QCPassFail                             Pass
# QCAuthInits                             PMM
# QCMemo                                 None
# QCMethod                               None
# LotNo                            0006522309
# QCExpMonth                               12
# QCExpDate               2021-03-31 00:00:00
# QCSellBy                               None
# QCFullValidation                      False
# QCValidation                              1
# FgInvCount                                5
# FgAccpacNote                           None
# CofAHeaderNo                              1
# QCChromatogram                         None
# Correct                               False
# DoNotCorrect                          False
# DensityUnit                            None
# DensityTemp                            None
# recipeid                               None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153222
# PfBatchID                                                  NAB01065
# ProductNo                                                 CUS-24433
# OrdID                                                        107887
# QuoteNo                                                  Stock Item
# PfSentTo                                                       done
# PrepDate                                        2020-02-26 00:00:00
# PrepVolume                                                       50
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F050-000138
# PrdSaleUnit                               1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                                JHP-003
# PrepMatrixLot                                            RM16129-06
# PrepInits                                                      DRL1
# PrepMemo          DW's and Dilution (STK-03088)\r\nSonicated in ...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-26 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006522036
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                     5
# AmpNumberBad                                                      5
# Daily Yield                                                      30
# AmpTimeIn                                       1899-12-30 13:00:00
# AmpTimeOut                                      1899-12-30 13:05:00
# AmpInits                                                        dak
# QCStatus                                                       None
# QCDate                                          2020-02-27 00:00:00
# QCPassFail                                                     Pass
# QCAuthInits                                                     PMM
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                    0006522036
# QCExpMonth                                                       24
# QCExpDate                                       2022-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                        5
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                       2020-02-27           2020-02-27  \
# PfIDNo                                            153225               153239
# PfBatchID                                       NAB01068             NAB01082
# ProductNo                                   BULK-PE-1027         BULK-PE-1001
# OrdID                                             107928               107772
# QuoteNo                                       Stock Item           Stock Item
# PfSentTo                                            done                 done
# PrepDate                             2020-02-26 00:00:00  2020-02-27 00:00:00
# PrepVolume                                           500                 1000
# PrepUnit                                              mL                   mL
# PrepVessel                                             1                    1
# PrepVBarcode                                 F500-000081           F1K-000100
# PrdSaleUnit                                         None                 None
# PrepMatrixNo                                     JHP-027              JHP-536
# PrepMatrixLot                                  AMX-00796            AMX-00780
# PrepInits                                           RAA1                 RAA1
# PrepMemo          DW's and 1 stock. Packaged in Nalgene.        Brown Nalgene
# PrepNotebookRef                                     None                 None
# BulkQCStatus                                        None                 None
# BulkQCDate                           2020-02-26 00:00:00  2020-02-27 00:00:00
# BulkPassFail                                        Pass                 Pass
# BulkQCInits                                          PMM                  PMM
# BulkQCMemo                                          None                 None
# BulkLotNo                                     0006522212           0006520985
# AmpRetains                                           NaN                  NaN
# AmpPreLabel                                        False                False
# AmpNumberGood                                        450                  950
# AmpNumberBad                                         NaN                  NaN
# Daily Yield                                          NaN                  NaN
# AmpTimeIn                            1899-12-30 00:04:00  1899-12-30 00:01:00
# AmpTimeOut                           1899-12-30 00:05:00  1899-12-30 00:02:00
# AmpInits                                             rlm                  sal
# QCStatus                                            None                 None
# QCDate                               2020-02-27 00:00:00  2020-02-27 00:00:00
# QCPassFail                                          Pass                 Pass
# QCAuthInits                                          PMM                  PMM
# QCMemo                                              None         OFFLINE CofA
# QCMethod                                            None                 None
# LotNo                                         0006522212           0006520985
# QCExpMonth                                            12                    3
# QCExpDate                            2021-03-31 00:00:00  2020-06-30 00:00:00
# QCSellBy                                            None                 None
# QCFullValidation                                   False                False
# QCValidation                                           1                    1
# FgInvCount                                           450                  950
# FgAccpacNote                        Done by SL 2/27/2020  Done by D 2/27/2020
# CofAHeaderNo                                           1                    1
# QCChromatogram                                      None                 None
# Correct                                            False                False
# DoNotCorrect                                       False                False
# DensityUnit                                         None                 None
# DensityTemp                                         None                 None
# recipeid                                            None                 None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153182
# PfBatchID                                                  NAB01025
# ProductNo                                                 CUS-29771
# OrdID                                                        107820
# QuoteNo                                                  Stock Item
# PfSentTo                                                       done
# PrepDate                                        2020-02-25 00:00:00
# PrepVolume                                                      100
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F100-000511
# PrdSaleUnit                               1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                                JHP-021
# PrepMatrixLot                                            RM15622-04
# PrepInits                                                      AJP1
# PrepMemo          DW all solids and some liquids on the first da...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-26 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006521378
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                    10
# AmpNumberBad                                                      5
# Daily Yield                                                      70
# AmpTimeIn                                       1899-12-30 07:35:00
# AmpTimeOut                                      1899-12-30 08:00:00
# AmpInits                                                        dak
# QCStatus                                                       None
# QCDate                                          2020-02-27 00:00:00
# QCPassFail                                                     Pass
# QCAuthInits                                                     PMM
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                    0006521378
# QCExpMonth                                                       12
# QCExpDate                                       2021-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                       10
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                                  2020-02-27  ...  \
# PfIDNo                                                       153185  ...
# PfBatchID                                                  NAB01028  ...
# ProductNo                                                  CUS-6143  ...
# OrdID                                                        107860  ...
# QuoteNo                                                  Stock Item  ...
# PfSentTo                                                       done  ...
# PrepDate                                        2020-02-25 00:00:00  ...
# PrepVolume                                                      100  ...
# PrepUnit                                                         mL  ...
# PrepVessel                                                        1  ...
# PrepVBarcode                                            F100-000052  ...
# PrdSaleUnit                               2 mL in 2 mL Amber Ampule  ...
# PrepMatrixNo                                                JHP-169  ...
# PrepMatrixLot                                            with batch  ...
# PrepInits                                                      CAD1  ...
# PrepMemo          BUILD W/BATCH PIPPETTED 15ML OF HYDROCHLORIC A...  ...
# PrepNotebookRef                                                None  ...
# BulkQCStatus                                                   None  ...
# BulkQCDate                                      2020-02-25 00:00:00  ...
# BulkPassFail                                                   Pass  ...
# BulkQCInits                                                     PMM  ...
# BulkQCMemo                                                     None  ...
# BulkLotNo                                                0006521725  ...
# AmpRetains                                                      NaN  ...
# AmpPreLabel                                                   False  ...
# AmpNumberGood                                                    10  ...
# AmpNumberBad                                                      5  ...
# Daily Yield                                                      55  ...
# AmpTimeIn                                       1899-12-30 13:20:00  ...
# AmpTimeOut                                      1899-12-30 13:30:00  ...
# AmpInits                                                        dak  ...
# QCStatus                                                       None  ...
# QCDate                                          2020-02-27 00:00:00  ...
# QCPassFail                                                     Pass  ...
# QCAuthInits                                                     PMM  ...
# QCMemo                                                         None  ...
# QCMethod                                                       None  ...
# LotNo                                                    0006521725  ...
# QCExpMonth                                                       12  ...
# QCExpDate                                       2021-03-31 00:00:00  ...
# QCSellBy                                                       None  ...
# QCFullValidation                                              False  ...
# QCValidation                                                      1  ...
# FgInvCount                                                       10  ...
# FgAccpacNote                                                   None  ...
# CofAHeaderNo                                                      1  ...
# QCChromatogram                                                 None  ...
# Correct                                                       False  ...
# DoNotCorrect                                                  False  ...
# DensityUnit                                                    None  ...
# DensityTemp                                                    None  ...
# recipeid                                                       None  ...
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153143
# PfBatchID                                                  NAB00986
# ProductNo                                                 CUS-28148
# OrdID                                                        107838
# QuoteNo                                                  Stock Item
# PfSentTo                                                         QC
# PrepDate                                        2020-02-21 00:00:00
# PrepVolume                                                     1000
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                             F1K-000088
# PrdSaleUnit                               1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                                JHP-021
# PrepMatrixLot                                           RM15622-014
# PrepInits                                                      CAD1
# PrepMemo          dw and reg. and gas dilutions on ice   added 1...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-21 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                   ISO 34
# BulkLotNo                                                0006521386
# AmpRetains                                                        5
# AmpPreLabel                                                   False
# AmpNumberGood                                                    10
# AmpNumberBad                                                     40
# Daily Yield                                                     900
# AmpTimeIn                                       1899-12-30 08:10:00
# AmpTimeOut                                      1899-12-30 08:40:00
# AmpInits                                                        dak
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo                                                       ISO 34
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       24
# QCExpDate                                       2022-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                       10
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                             2020-02-27                   2020-02-27  \
# PfIDNo                                  153232                       153233
# PfBatchID                             NAB01075                     NAB01076
# ProductNo                             PP-220-1                     PP-220-1
# OrdID                                   107646                       107647
# QuoteNo                             Stock Item                   Stock Item
# PfSentTo                                    QC                           QC
# PrepDate                   2020-02-26 00:00:00          2020-02-27 00:00:00
# PrepVolume                                 100                          100
# PrepUnit                                    mL                           mL
# PrepVessel                                   1                            1
# PrepVBarcode                       F100-000578                  F100-000170
# PrdSaleUnit          1 mL in 2 mL Amber Ampule    1 mL in 2 mL Amber Ampule
# PrepMatrixNo                           JHP-021                      JHP-021
# PrepMatrixLot                      RM15622-017                  RM15622-017
# PrepInits                                 KAW1                         KAW1
# PrepMemo          sonicated in unit 48, lot #1  sonicated in unit 48, lot#2
# PrepNotebookRef                           None                         None
# BulkQCStatus                              None                         None
# BulkQCDate                 2020-02-27 00:00:00          2020-02-27 00:00:00
# BulkPassFail                              Pass                         Pass
# BulkQCInits                                PMM                          PMM
# BulkQCMemo                                None                         None
# BulkLotNo                           0006519595                   0006519596
# AmpRetains                                   5                            5
# AmpPreLabel                              False                        False
# AmpNumberGood                               50                           50
# AmpNumberBad                                10                           10
# Daily Yield                                 15                           15
# AmpTimeIn                  1899-12-30 11:20:00          1899-12-30 11:00:00
# AmpTimeOut                 1899-12-30 11:40:00          1899-12-30 11:20:00
# AmpInits                                   dak                          dak
# QCStatus                                  None                         None
# QCDate                                     NaT                          NaT
# QCPassFail                                None                         None
# QCAuthInits                               None                         None
# QCMemo                                    None                         None
# QCMethod                                  None                         None
# LotNo                                     None                         None
# QCExpMonth                                  36                           36
# QCExpDate                  2023-03-31 00:00:00          2023-03-31 00:00:00
# QCSellBy                                  None                         None
# QCFullValidation                         False                        False
# QCValidation                                 1                            1
# FgInvCount                                  50                           50
# FgAccpacNote                              None                         None
# CofAHeaderNo                                 1                            1
# QCChromatogram                            None                         None
# Correct                                  False                        False
# DoNotCorrect                             False                        False
# DensityUnit                               None                         None
# DensityTemp                               None                         None
# recipeid                                  None                         None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153016
# PfBatchID                                                  NAB00859
# ProductNo                                                80-6002-80
# OrdID                                                        107322
# QuoteNo                                                  Stock Item
# PfSentTo                                                         QC
# PrepDate                                        2020-02-14 00:00:00
# PrepVolume                                                      200
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F200-000494
# PrdSaleUnit                       5 mL in 8 mL Amber Screw Cap Vial
# PrepMatrixNo                                                JHP-443
# PrepMatrixLot                                             AMX-00649
# PrepInits                                                      RAA1
# PrepMemo          SOL-4213 New Lot used.\r\nSOL-4196 also\r\nDid...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-27 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006517125
# AmpRetains                                                        5
# AmpPreLabel                                                   False
# AmpNumberGood                                                    30
# AmpNumberBad                                                      5
# Daily Yield                                                       0
# AmpTimeIn                                       1899-12-30 13:50:00
# AmpTimeOut                                      1899-12-30 14:20:00
# AmpInits                                                        dak
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       36
# QCExpDate                                       2023-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                       30
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153183
# PfBatchID                                                  NAB01026
# ProductNo                                                 ICUS-2734
# OrdID                                                        107769
# QuoteNo                                                  Stock Item
# PfSentTo                                                       done
# PrepDate                                        2020-02-25 00:00:00
# PrepVolume                                                      500
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F500-000198
# PrdSaleUnit       480 mL in 500mL Nalgene Narrow-Mouth HDPE Economy
# PrepMatrixNo                                                JHP-040
# PrepMatrixLot                                           RM15918-001
# PrepInits                                                      MHD1
# PrepMemo                                                       None
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-26 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006520899
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                     1
# AmpNumberBad                                                    NaN
# Daily Yield                                                     NaN
# AmpTimeIn                                       1899-12-30 07:27:00
# AmpTimeOut                                      1899-12-30 07:29:00
# AmpInits                                                        rlm
# QCStatus                                                       None
# QCDate                                          2020-02-27 00:00:00
# QCPassFail                                                     Pass
# QCAuthInits                                                     PMM
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                    0006520899
# QCExpMonth                                                       24
# QCExpDate                                       2022-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                        1
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                      2020-02-27  \
# PfIDNo                                           153224
# PfBatchID                                      NAB01067
# ProductNo                                  BULK-PE-1026
# OrdID                                            107927
# QuoteNo                                      Stock Item
# PfSentTo                                           done
# PrepDate                            2020-02-26 00:00:00
# PrepVolume                                          500
# PrepUnit                                             mL
# PrepVessel                                            1
# PrepVBarcode                                F500-000081
# PrdSaleUnit                                        None
# PrepMatrixNo                                    JHP-027
# PrepMatrixLot                                 AMX-00796
# PrepInits                                          RAA1
# PrepMemo          DW's and 1 stock. Packaged in plastic
# PrepNotebookRef                                    None
# BulkQCStatus                                       None
# BulkQCDate                          2020-02-26 00:00:00
# BulkPassFail                                       Pass
# BulkQCInits                                         PMM
# BulkQCMemo                                         None
# BulkLotNo                                    0006522211
# AmpRetains                                          NaN
# AmpPreLabel                                       False
# AmpNumberGood                                       450
# AmpNumberBad                                        NaN
# Daily Yield                                         NaN
# AmpTimeIn                           1899-12-30 00:03:00
# AmpTimeOut                          1899-12-30 00:04:00
# AmpInits                                            rlm
# QCStatus                                           None
# QCDate                              2020-02-27 00:00:00
# QCPassFail                                         Pass
# QCAuthInits                                         PMM
# QCMemo                                             None
# QCMethod                                           None
# LotNo                                        0006522211
# QCExpMonth                                           12
# QCExpDate                           2021-03-31 00:00:00
# QCSellBy                                           None
# QCFullValidation                                  False
# QCValidation                                          1
# FgInvCount                                          450
# FgAccpacNote                       Done by SL 2/27/2020
# CofAHeaderNo                                          1
# QCChromatogram                                     None
# Correct                                           False
# DoNotCorrect                                      False
# DensityUnit                                        None
# DensityTemp                                        None
# recipeid                                           None
#
# AmpDate                                     2020-02-27  \
# PfIDNo                                          153234
# PfBatchID                                     NAB01077
# ProductNo                                G3440-85027-1
# OrdID                                           107939
# QuoteNo                                     Stock Item
# PfSentTo                                            QC
# PrepDate                           2020-02-27 00:00:00
# PrepVolume                                          50
# PrepUnit                                            mL
# PrepVessel                                           1
# PrepVBarcode                               F050-000015
# PrdSaleUnit                  1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                   JHP-038
# PrepMatrixLot                              RM12707-001
# PrepInits                                         AJP1
# PrepMemo          Sonicated in unit 48 for <5 minutes.
# PrepNotebookRef                                   None
# BulkQCStatus                                      None
# BulkQCDate                         2020-02-27 00:00:00
# BulkPassFail                                      Pass
# BulkQCInits                                        PMM
# BulkQCMemo                                        None
# BulkLotNo                                   0006522333
# AmpRetains                                           5
# AmpPreLabel                                      False
# AmpNumberGood                                       15
# AmpNumberBad                                        10
# Daily Yield                                         15
# AmpTimeIn                          1899-12-30 09:50:00
# AmpTimeOut                         1899-12-30 10:00:00
# AmpInits                                           dak
# QCStatus                                          None
# QCDate                                             NaT
# QCPassFail                                        None
# QCAuthInits                                       None
# QCMemo                                            None
# QCMethod                                          None
# LotNo                                             None
# QCExpMonth                                          12
# QCExpDate                          2021-03-31 00:00:00
# QCSellBy                                          None
# QCFullValidation                                 False
# QCValidation                                         1
# FgInvCount                                          15
# FgAccpacNote                                      None
# CofAHeaderNo                                         1
# QCChromatogram                                    None
# Correct                                          False
# DoNotCorrect                                     False
# DensityUnit                                       None
# DensityTemp                                       None
# recipeid                                          None
#
# AmpDate                                                  2020-02-27  \
# PfIDNo                                                       153244
# PfBatchID                                                  NAB01087
# ProductNo                                                 CUS-18906
# OrdID                                                        108040
# QuoteNo                                                  Stock Item
# PfSentTo                                                   ampuling
# PrepDate                                        2020-02-27 00:00:00
# PrepVolume                                                      100
# PrepUnit                                                         mL
# PrepVessel                                                        1
# PrepVBarcode                                            F100-000577
# PrdSaleUnit                               1 mL in 2 mL Amber Ampule
# PrepMatrixNo                                                JHP-256
# PrepMatrixLot                                            with batch
# PrepInits                                                      SMG1
# PrepMemo          5mL acetone from STK-03010. Filled to mark wit...
# PrepNotebookRef                                                None
# BulkQCStatus                                                   None
# BulkQCDate                                      2020-02-27 00:00:00
# BulkPassFail                                                   Pass
# BulkQCInits                                                     PMM
# BulkQCMemo                                                     None
# BulkLotNo                                                0006521385
# AmpRetains                                                      NaN
# AmpPreLabel                                                   False
# AmpNumberGood                                                   NaN
# AmpNumberBad                                                    NaN
# Daily Yield                                                     NaN
# AmpTimeIn                                                       NaT
# AmpTimeOut                                                      NaT
# AmpInits                                                       None
# QCStatus                                                       None
# QCDate                                                          NaT
# QCPassFail                                                     None
# QCAuthInits                                                    None
# QCMemo                                                         None
# QCMethod                                                       None
# LotNo                                                          None
# QCExpMonth                                                       12
# QCExpDate                                       2021-03-31 00:00:00
# QCSellBy                                                       None
# QCFullValidation                                              False
# QCValidation                                                      1
# FgInvCount                                                      NaN
# FgAccpacNote                                                   None
# CofAHeaderNo                                                      1
# QCChromatogram                                                 None
# Correct                                                       False
# DoNotCorrect                                                  False
# DensityUnit                                                    None
# DensityTemp                                                    None
# recipeid                                                       None
#
# AmpDate                                 2020-02-27  \
# PfIDNo                                      153203
# PfBatchID                                 NAB01046
# ProductNo                                QRR010933
# OrdID                                       107549
# QuoteNo                                 Stock Item
# PfSentTo                                      done
# PrepDate                       2020-02-26 00:00:00
# PrepVolume                                  700000
# PrepUnit                                         g
# PrepVessel                                       4
# PrepVBarcode                                   N/A
# PrdSaleUnit       5 L in 5 L Clear plastic bladder
# PrepMatrixNo                               JHP-035
# PrepMatrixLot                                 none
# PrepInits                                     DRL1
# PrepMemo                                      None
# PrepNotebookRef                               None
# BulkQCStatus                                  None
# BulkQCDate                     2020-02-26 00:00:00
# BulkPassFail                                  Pass
# BulkQCInits                                    PMM
# BulkQCMemo                                    None
# BulkLotNo                               0006519330
# AmpRetains                                     NaN
# AmpPreLabel                                  False
# AmpNumberGood                                  132
# AmpNumberBad                                   NaN
# Daily Yield                                    NaN
# AmpTimeIn                      1899-12-30 07:45:00
# AmpTimeOut                     1899-12-30 02:00:00
# AmpInits                                        bs
# QCStatus                                      None
# QCDate                         2020-02-27 00:00:00
# QCPassFail                                    Pass
# QCAuthInits                                    PMM
# QCMemo                                OFFLINE CofA
# QCMethod                                      None
# LotNo                                   0006519330
# QCExpMonth                                      36
# QCExpDate                      2023-03-31 00:00:00
# QCSellBy                                      None
# QCFullValidation                             False
# QCValidation                                     1
# FgInvCount                                     132
# FgAccpacNote                                  None
# CofAHeaderNo                                     1
# QCChromatogram                                None
# Correct                                      False
# DoNotCorrect                                 False
# DensityUnit                                   None
# DensityTemp                                   None
# recipeid                                      None
#
# AmpDate                                          2020-02-27
# PfIDNo                                               153211
# PfBatchID                                          NAB01054
# ProductNo                                      CUS-00002168
# OrdID                                                107955
# QuoteNo                                             3047490
# PfSentTo                                               done
# PrepDate                                2020-02-26 00:00:00
# PrepVolume                                              100
# PrepUnit                                                 mL
# PrepVessel                                                1
# PrepVBarcode                                    F100-000154
# PrdSaleUnit       1 mL in 2 mL Flame-Sealed Amber Ampule(s)
# PrepMatrixNo                                        JHP-021
# PrepMatrixLot                                    RM15622-16
# PrepInits                                              SMM1
# PrepMemo                          DW. Sonicated in unit 48.
# PrepNotebookRef                                        None
# BulkQCStatus                                           None
# BulkQCDate                              2020-02-26 00:00:00
# BulkPassFail                                           Pass
# BulkQCInits                                             PMM
# BulkQCMemo                                             None
# BulkLotNo                                        0006522596
# AmpRetains                                              NaN
# AmpPreLabel                                           False
# AmpNumberGood                                             5
# AmpNumberBad                                              5
# Daily Yield                                              80
# AmpTimeIn                               1899-12-30 12:40:00
# AmpTimeOut                              1899-12-30 12:45:00
# AmpInits                                                dak
# QCStatus                                               None
# QCDate                                  2020-02-27 00:00:00
# QCPassFail                                             Pass
# QCAuthInits                                             PMM
# QCMemo                                                 None
# QCMethod                                               None
# LotNo                                            0006522596
# QCExpMonth                                               24
# QCExpDate                               2022-03-31 00:00:00
# QCSellBy                                               None
# QCFullValidation                                      False
# QCValidation                                              1
# FgInvCount                                                5
# FgAccpacNote                                           None
# CofAHeaderNo                                              1
# QCChromatogram                                         None
# Correct                                               False
# DoNotCorrect                                          False
# DensityUnit                                            None
# DensityTemp                                            None
# recipeid                                               None
#
# [52 rows x 27 columns]

# %% [markdown]
# ### Create EMPTY DataFrame to hold Metrics

# %%
df_Metrics = pd.DataFrame(data=None)

# %% [raw]
# #### Get all `AmpNumberGood` number and their time `in/out`

# %% [raw]
# # SELECT ROWS OF THE DATAFRAME WHERE df.AmpNumberGood is greater than or equal to 1
# df_AmpNumberGood = df_todaysAmples[(df_tblProdflow['AmpNumberGood'] >= 1)]

# %%
# CREATE COLUMN TO hold PfID
df_Metrics["ID"] = df_todaysAmples['PfIDNo']

# %%
# CREATE COLUMN TO hold PfBatchID
df_Metrics['PfBatchID'] = df_todaysAmples['PfBatchID']

# %%
# CREATE column to hold number of GOOD AMPS
df_Metrics['GoodNo'] = df_todaysAmples['AmpNumberGood']

# %% [raw]
# # CREATE COLUMN TO HOLD TIME IN
# df_Metrics['Time-In'] = df_todaysAmples['AmpTimeIn'].dt.time

# %% [raw]
# # CREATE COLUMN TO HOLD AN TIME OUT
# df_Metrics['Time-Out'] = df_todaysAmples['AmpTimeOut'].dt.time

# %%
# CHANGE TIME OUT AND TIME IN COLUMNS TO BE DATETIME
df_Metrics['Time-In'] = pd.to_datetime(df_todaysAmples['AmpTimeIn'])
df_Metrics['Time-Out'] = pd.to_datetime(df_todaysAmples['AmpTimeOut'])

# %% [raw]
# # CHECK IF 'TimeOut' is INCORRECTLY entered (in regards to Military Time)
# for row in df_Metrics.itertuples(index=False): # {
#     # GET/ SET time/out values
#     time_in = row[3]
#     time_out = row[4]
#     print("TIME IN == " + str(time_in))
#     print("TIME OUT == " + str(time_out))
#     if time_out <= time_in: # {
#         print("ERROR!")
#         # [2020-02-27]\\hours = pd.Timedelta(value=12, unit='hours')
#         # [2020-02-27]\\print(timedelta(hours = 12))
#         # add 12 hours to time_out
#         time_out = pd.Timestamp(ts_input=str(time_out)) - timedelta(hours = 12)
#         print("TIME OUT == " + str(time_out))
#     # }
#     else: # {
#         print("FINE!")
#     # }
# # }

# %% [raw]
# print(df_Metrics.iloc[21, 5])

# %%
df_Metrics['elapsed_time'] = df_Metrics['Time-Out'] - df_Metrics['Time-In']

# %%
# CHANGE TIME OUT AND TIME OUT BACK TO datetime.timedelta
df_Metrics['Time-In'] = df_todaysAmples['AmpTimeIn'].dt.time
df_Metrics['Time-Out'] = df_todaysAmples['AmpTimeOut'].dt.time

# %%
df_Metrics["RetainsNo"] = df_todaysAmples["AmpRetains"]

# %%
df_Metrics["Volume"] = df_todaysAmples["PrepVolume"]

# %%
# FILL EMPTY CELLS WITH 0
df_Metrics.fillna(value=0, inplace=True)
# Out:
# C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Passing integers to fillna is deprecated, will raise a TypeError in a future version.  To retain the old behavior, pass pd.Timedelta(seconds=n) instead.

# %%
df_Metrics["Daily Yield"] = df_Metrics["Volume"] * df_Metrics['RetainsNo']

# %%
df_Metrics["Unit"] = df_todaysAmples["PrepUnit"]

# %% [raw]
# #### determine time in/out of `AmpNumberGood`

# %%
df_Metrics
# Out:
#                 ID PfBatchID  GoodNo   Time-In  Time-Out      elapsed_time  \
# AmpDate
# 2020-02-27  153080  NAB00923     5.0  07:35:00  07:40:00          00:05:00
# 2020-02-27  153202  NAB01045    42.0  01:15:00  11:00:00          09:45:00
# 2020-02-27  153248  NAB01091    10.0  15:35:00  15:40:00          00:05:00
# 2020-02-27  153188  NAB01031    55.0  12:00:00  12:01:00          00:01:00
# 2020-02-27  153215  NAB01058     5.0  12:50:00  12:55:00          00:05:00
# 2020-02-27  153222  NAB01065     5.0  13:00:00  13:05:00          00:05:00
# 2020-02-27  153225  NAB01068   450.0  00:04:00  00:05:00          00:01:00
# 2020-02-27  153239  NAB01082   950.0  00:01:00  00:02:00          00:01:00
# 2020-02-27  153182  NAB01025    10.0  07:35:00  08:00:00          00:25:00
# 2020-02-27  153185  NAB01028    10.0  13:20:00  13:30:00          00:10:00
# 2020-02-27  153205  NAB01048    42.0  11:00:00  14:00:00          03:00:00
# 2020-02-27  153214  NAB01057  1950.0  00:01:00  00:02:00          00:01:00
# 2020-02-27  153219  NAB01062   450.0  00:02:00  00:03:00          00:01:00
# 2020-02-27  153221  NAB01064    10.0  09:30:00  09:40:00          00:10:00
# 2020-02-27  153230  NAB01073    62.0  09:00:00  09:20:00          00:20:00
# 2020-02-27  153231  NAB01074    26.0  10:30:00  10:40:00          00:10:00
# 2020-02-27  153124  NAB00967  1950.0  00:00:00  00:01:00          00:01:00
# 2020-02-27  153143  NAB00986    10.0  08:10:00  08:40:00          00:30:00
# 2020-02-27  153232  NAB01075    50.0  11:20:00  11:40:00          00:20:00
# 2020-02-27  153233  NAB01076    50.0  11:00:00  11:20:00          00:20:00
# 2020-02-27  153016  NAB00859    30.0  13:50:00  14:20:00          00:30:00
# 2020-02-27  153183  NAB01026     1.0  07:27:00  07:29:00          00:02:00
# 2020-02-27  153224  NAB01067   450.0  00:03:00  00:04:00          00:01:00
# 2020-02-27  153234  NAB01077    15.0  09:50:00  10:00:00          00:10:00
# 2020-02-27  153244  NAB01087     0.0         0         0          00:00:00
# 2020-02-27  153203  NAB01046   132.0  07:45:00  02:00:00 -1 days +18:15:00
# 2020-02-27  153211  NAB01054     5.0  12:40:00  12:45:00          00:05:00
#
#             RetainsNo    Volume  Daily Yield Unit
# AmpDate
# 2020-02-27        0.0     100.0          0.0   mL
# 2020-02-27        0.0   20000.0          0.0   mL
# 2020-02-27        0.0     100.0          0.0   mL
# 2020-02-27        5.0      50.0        250.0   mL
# 2020-02-27        0.0      25.0          0.0   mL
# 2020-02-27        0.0      50.0          0.0   mL
# 2020-02-27        0.0     500.0          0.0   mL
# 2020-02-27        0.0    1000.0          0.0   mL
# 2020-02-27        0.0     100.0          0.0   mL
# 2020-02-27        0.0     100.0          0.0   mL
# 2020-02-27        0.0   20000.0          0.0   mL
# 2020-02-27        0.0    2000.0          0.0   mL
# 2020-02-27        0.0     500.0          0.0   mL
# 2020-02-27        0.0     100.0          0.0   mL
# 2020-02-27        5.0     100.0        500.0   mL
# 2020-02-27        5.0      50.0        250.0   mL
# 2020-02-27        0.0    2000.0          0.0   mL
# 2020-02-27        5.0    1000.0       5000.0   mL
# 2020-02-27        5.0     100.0        500.0   mL
# 2020-02-27        5.0     100.0        500.0   mL
# 2020-02-27        5.0     200.0       1000.0   mL
# 2020-02-27        0.0     500.0          0.0   mL
# 2020-02-27        0.0     500.0          0.0   mL
# 2020-02-27        5.0      50.0        250.0   mL
# 2020-02-27        0.0     100.0          0.0   mL
# 2020-02-27        0.0  700000.0          0.0    g
# 2020-02-27        0.0     100.0          0.0   mL

# %% [raw]
# df_TodaysGoodAmples = df_AmpNumberGood[today_str][['AmpTimeIn'], ['AmpTimeOut']]

# %%
df_Metrics.to_excel("c:/data/outbound/Metrics/" + today_str + "_ampule_METRICS.xlsx", index=True)

# %%
df_Metrics.to_csv("c:/data/outbound/Metrics/" + today_str + "_ampule_METRICS.csv", index=True)

# %% [raw]
# ts_str = str(pd.Timestamp.now())[:10]
# filename_str = str("Ampule_metrics_test_" + ts_str + ".xlsx")

# %% [raw]
# df_Metrics.to_excel("C:/data/outbound/Metrics/" + filename_str)
