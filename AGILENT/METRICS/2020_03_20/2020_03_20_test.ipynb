# %%
import os, sys, time
from time import sleep
from pathlib import Path
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df_metrics_data = pd.read_csv("C:/data/inbound/2020-03-20/metric_data.csv")
# Out:
# C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,9,12,20,25,30,31,59,74,79,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# CHANGE 'PfBatchID' to STRING
# Change data type of column 'Age' from int64 to string i.e. object type
df_metrics_data['PfBatchID'] = df_metrics_data['PfBatchID'].astype('object')
df_metrics_data['ProductID'] = df_metrics_data['ProductID'].astype('object')

# %%
df_metrics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85104 entries, 0 to 85103
# Data columns (total 95 columns):
# Unnamed: 0          85104 non-null int64
# ProductID           85104 non-null object
# ProductNo           85104 non-null object
# ProductName         85096 non-null object
# LineID              85104 non-null float64
# Description         21554 non-null object
# Specials            5731 non-null object
# OriginationDate     84931 non-null object
# EntryDate           85104 non-null object
# Status              22416 non-null object
# MatrixNumber        85104 non-null object
# Components          85104 non-null float64
# Availability        18098 non-null object
# EquivalentSoln      0 non-null float64
# EquivalentNeat      0 non-null float64
# Packaging           84050 non-null object
# Storage             84928 non-null object
# ExpirationDate      85104 non-null float64
# ShipType            80418 non-null object
# UN#                 73535 non-null object
# ShipClass           72390 non-null object
# PackGrp             72058 non-null object
# ShipSpecial         70294 non-null object
# Hazard1             11465 non-null object
# Hazard2             19531 non-null object
# Hazard3             208 non-null object
# Prop65              21387 non-null float64
# MSDS                21362 non-null object
# Analysis            18765 non-null object
# CofAHeader          78580 non-null float64
# Agilent#            5204 non-null object
# Tedia#              16949 non-null object
# ProdNotes           47769 non-null object
# MatrixNotes         5645 non-null object
# RecipeId            79441 non-null object
# RushPriority        85104 non-null bool
# IsVoided            45890 non-null object
# SagePartNumber      82834 non-null object
# ProductLevel        85104 non-null float64
# DateInserted        0 non-null float64
# CofATemplate        60360 non-null object
# UniqueRequestID     0 non-null float64
# Test_Timestamp      85104 non-null object
# PfIDNo              85104 non-null int64
# PfBatchID           85104 non-null object
# OrdID               76010 non-null float64
# QuoteNo             85102 non-null object
# PfSentTo            85102 non-null object
# PrepDate            85090 non-null object
# PrepVolume          85103 non-null float64
# PrepUnit            85052 non-null object
# PrepVessel          85049 non-null float64
# PrepVBarcode        41140 non-null object
# PrdSaleUnit         77172 non-null object
# PrepMatrixNo        85102 non-null object
# PrepMatrixLot       84326 non-null object
# PrepInits           84952 non-null object
# PrepMemo            46686 non-null object
# PrepNotebookRef     40020 non-null object
# BulkQCStatus        3 non-null object
# BulkQCDate          70799 non-null object
# BulkPassFail        70792 non-null object
# BulkQCInits         70797 non-null object
# BulkQCMemo          1094 non-null object
# BulkLotNo           70269 non-null object
# AmpRetains          49932 non-null float64
# AmpDate             82768 non-null object
# AmpPreLabel         85104 non-null bool
# AmpNumberGood       82934 non-null float64
# AmpNumberBad        68023 non-null float64
# AmpBulkRemain       4063 non-null float64
# AmpTimeIn           82658 non-null object
# AmpTimeOut          82658 non-null object
# AmpInits            82761 non-null object
# QCStatus            564 non-null object
# QCDate              85104 non-null object
# QCPassFail          85098 non-null object
# QCAuthInits         85092 non-null object
# QCMemo              40537 non-null object
# QCMethod            1192 non-null object
# LotNo               82849 non-null object
# QCExpMonth          76792 non-null float64
# QCExpDate           78758 non-null object
# QCSellBy            0 non-null float64
# QCFullValidation    85104 non-null bool
# QCValidation        85102 non-null float64
# FgInvCount          74450 non-null float64
# FgAccpacNote        17953 non-null object
# CofAHeaderNo        85104 non-null float64
# QCChromatogram      0 non-null float64
# Correct             85104 non-null bool
# DoNotCorrect        85104 non-null bool
# DensityUnit         0 non-null float64
# DensityTemp         0 non-null float64
# recipeid            1 non-null object
# dtypes: bool(5), float64(25), int64(2), object(63)
# memory usage: 58.8+ MB

# %%
# << set column to datetime >>
df_metrics_data['QCDate'] = pd.to_datetime(df_metrics_data['QCDate'])

# %%
# << set column to datetime >>
df_metrics_data['AmpDate'] = pd.to_datetime(df_metrics_data['AmpDate'])
df_metrics_data['OriginationDate'] = pd.to_datetime(df_metrics_data['OriginationDate'])
df_metrics_data['EntryDate'] = pd.to_datetime(df_metrics_data["EntryDate"])

# %% [markdown]
# ### only look at data for `specific time range`

# %%
# Select observations between two datetimes
# 2020-01-01
# to:
# 2020-03-01
df_metrics_obv = df_metrics_data[(df_metrics_data['QCDate'] > '2020-01-01') & (df_metrics_data['QCDate'] <= '2020-03-01')]

# %% [markdown]
# ### Determine `days in QC`

# %%
df_days_in_QC = pd.DataFrame(data=df_metrics_obv['PfBatchID'])

# %%
# CREATE new DATAFRAME with just PFBatchID numbers
#df_days_in_QC = pd.DataFrame(data=df_metrics_obv['PfBatchID'])

# %%
calculation = df_metrics_obv['QCDate'] - df_metrics_obv['AmpDate']

# %%
df_days_in_QC['time-in-QC'] = calculation

# %%
df_days_in_QC
# Out:
#       PfBatchID time-in-QC
# 69     NAB00352     0 days
# 115    NAB00632    14 days
# 159    NAB00648     2 days
# 482    NAB00812     4 days
# 511    NAB00101     3 days
# ...         ...        ...
# 83960  NAB00646     2 days
# 83996  NAB00881     1 days
# 84021  NAB00022     2 days
# 84112  NAB00465     2 days
# 84148  NAB00122     1 days
#
# [1024 rows x 2 columns]

# %%
df_days_in_QC.to_csv("C:/data/Outbound/2020-03-22/" + str(pd.Timestamp.now())[:10] + "-days-in-QC.csv")

# %%
# GROUPBY TEST?
df_metrics_obv.groupby(['QCDate', 'ProductLevel'])['PfBatchID'].count()
# Out:
# QCDate      ProductLevel
# 2020-01-02  1.0              6
#             2.0             19
# 2020-01-03  1.0              9
#             2.0              6
#             3.0              9
#                             ..
# 2020-02-27  1.0             19
#             2.0              6
# 2020-02-28  0.0              1
#             1.0             20
#             2.0              7
# Name: PfBatchID, Length: 116, dtype: int64

# %% [raw]
# df_metrics_obv_dt = df_metrics_obv.set_index(['QCDate'])

# %% [raw]
# df_metrics_obv_dt.resample('D').count()

# %% [markdown]
# ### How many `PfBatchID`, per `ProductLevel`, per `QCDate`?

# %%
df_metrics_obv.groupby(['QCDate', 'ProductLevel'])[['PfBatchID']].count()
# Out:
#                          PfBatchID
# QCDate     ProductLevel
# 2020-01-02 1.0                   6
#            2.0                  19
# 2020-01-03 1.0                   9
#            2.0                   6
#            3.0                   9
# ...                            ...
# 2020-02-27 1.0                  19
#            2.0                   6
# 2020-02-28 0.0                   1
#            1.0                  20
#            2.0                   7
#
# [116 rows x 1 columns]

# %%
df_metrics_obv.groupby(['QCDate', 'ProductLevel'])[['PfBatchID']].count().to_csv("C:/data/outbound/2020-03-22/df-obversation-groupby-" 
                                                                                 + str(pd.Timestamp.now())[:10]
                                                                                 + ".csv")

# %%
df_metrics_obv.groupby(['QCDate', 'ProductLevel'])[['PfBatchID']].sum()
# Out:
#                                                                  PfBatchID
# QCDate     ProductLevel
# 2020-01-02 1.0            NAA07703NAA07672NAA07686NAB00004NAA07723NAA07721
#            2.0           NAA07676NAA07677NAA07678NAA07679NAA07606NAA075...
# 2020-01-03 1.0           NAB00009NAA07670NAA07673NAA07682NAA07704NAA035...
#            2.0            NAA07576NAA07523NAA07539NAA07684NAA07689NAA07717
#            3.0           NAA07484NAA07460NAA07453NAA07450NAA07451NAA074...
# ...                                                                    ...
# 2020-02-27 1.0           NAB01057NAB01062NAB01067NAB01068NAB01044NAB010...
#            2.0            NAB00967NAB01082NAB01020NAB01023NAB01019NAB01046
# 2020-02-28 0.0                                                    NAB01115
#            1.0           NAB01085NAB01130NAB01132NAB01134NAB01121NAB010...
#            2.0           NAB01074NAB01073NAB00975NAB01077NAB01075NAB010...
#
# [116 rows x 1 columns]

# %% [raw]
# df_metrics_data.groupby(['QCDate', 'ProductLevel'])[['PfBatchID']].sum()

# %%
# set index
df_metrics_test = df_metrics_data.set_index(['QCDate', 'ProductLevel'])

# %%
df_metrics_test
# Out:
#                          Unnamed: 0 ProductID      ProductNo  \
# QCDate     ProductLevel
# 2012-09-05 2.0                    5      5420    01080-68703
# 2013-10-31 2.0                    6      5420    01080-68703
# 2012-04-26 2.0                    7      5420    01080-68703
#            2.0                    8      5420    01080-68703
# 2009-12-04 2.0                    9      5420    01080-68703
# ...                             ...       ...            ...
# 2012-01-17 2.0               104249     50108  ZX-TESTMIX-01
# 2016-03-11 2.0               104250     50108  ZX-TESTMIX-01
# 2018-02-20 2.0               104253     50108  ZX-TESTMIX-01
#            2.0               104254     50108  ZX-TESTMIX-01
# 2019-06-10 2.0               104255     50108  ZX-TESTMIX-01
#
#                                       ProductName  LineID Description  \
# QCDate     ProductLevel
# 2012-09-05 2.0                    Gradient Sample     7.0         NaN
# 2013-10-31 2.0                    Gradient Sample     7.0         NaN
# 2012-04-26 2.0                    Gradient Sample     7.0         NaN
#            2.0                    Gradient Sample     7.0         NaN
# 2009-12-04 2.0                    Gradient Sample     7.0         NaN
# ...                                           ...     ...         ...
# 2012-01-17 2.0           GC x GC Testing Solution     7.0         NaN
# 2016-03-11 2.0           GC x GC Testing Solution     7.0         NaN
# 2018-02-20 2.0           GC x GC Testing Solution     7.0         NaN
#            2.0           GC x GC Testing Solution     7.0         NaN
# 2019-06-10 2.0           GC x GC Testing Solution     7.0         NaN
#
#                             Specials OriginationDate  EntryDate Status  ...  \
# QCDate     ProductLevel                                                 ...
# 2012-09-05 2.0           01080-68703      1998-02-04 2011-05-09    oem  ...
# 2013-10-31 2.0           01080-68703      1998-02-04 2011-05-09    oem  ...
# 2012-04-26 2.0           01080-68703      1998-02-04 2011-05-09    oem  ...
#            2.0           01080-68703      1998-02-04 2011-05-09    oem  ...
# 2009-12-04 2.0           01080-68703      1998-02-04 2011-05-09    oem  ...
# ...                              ...             ...        ...    ...  ...
# 2012-01-17 2.0                   NaN      2011-04-19 2011-05-09    NaN  ...
# 2016-03-11 2.0                   NaN      2011-04-19 2011-05-09    NaN  ...
# 2018-02-20 2.0                   NaN      2011-04-19 2011-05-09    NaN  ...
#            2.0                   NaN      2011-04-19 2011-05-09    NaN  ...
# 2019-06-10 2.0                   NaN      2011-04-19 2011-05-09    NaN  ...
#
#                         QCValidation  FgInvCount  \
# QCDate     ProductLevel
# 2012-09-05 2.0                   2.0      2600.0
# 2013-10-31 2.0                   2.0      2123.0
# 2012-04-26 2.0                   2.0      3400.0
#            2.0                   2.0      1563.0
# 2009-12-04 2.0                   2.0      1156.0
# ...                              ...         ...
# 2012-01-17 2.0                   2.0       129.0
# 2016-03-11 2.0                   2.0       602.0
# 2018-02-20 2.0                   2.0       366.0
#            2.0                   2.0       320.0
# 2019-06-10 2.0                   2.0       320.0
#
#                                                    FgAccpacNote  CofAHeaderNo  \
# QCDate     ProductLevel
# 2012-09-05 2.0                                              NaN           2.0
# 2013-10-31 2.0                                              NaN           2.0
# 2012-04-26 2.0                                              NaN           2.0
#            2.0                                          back up           2.0
# 2009-12-04 2.0                zero out ce-3778 (1390) stability           2.0
# ...                                                         ...           ...
# 2012-01-17 2.0                                              NaN           2.0
# 2016-03-11 2.0                                              NaN           2.0
# 2018-02-20 2.0                                              NaN           2.0
#            2.0                                              NaN           2.0
# 2019-06-10 2.0           purge cs-0774 (70) cp-1554a (5) retain           2.0
#
#                          QCChromatogram Correct DoNotCorrect  DensityUnit  \
# QCDate     ProductLevel
# 2012-09-05 2.0                      NaN   False        False          NaN
# 2013-10-31 2.0                      NaN   False        False          NaN
# 2012-04-26 2.0                      NaN   False         True          NaN
#            2.0                      NaN   False         True          NaN
# 2009-12-04 2.0                      NaN   False         True          NaN
# ...                                 ...     ...          ...          ...
# 2012-01-17 2.0                      NaN   False         True          NaN
# 2016-03-11 2.0                      NaN   False        False          NaN
# 2018-02-20 2.0                      NaN   False        False          NaN
#            2.0                      NaN   False        False          NaN
# 2019-06-10 2.0                      NaN   False        False          NaN
#
#                         DensityTemp recipeid
# QCDate     ProductLevel
# 2012-09-05 2.0                  NaN      NaN
# 2013-10-31 2.0                  NaN      NaN
# 2012-04-26 2.0                  NaN      NaN
#            2.0                  NaN      NaN
# 2009-12-04 2.0                  NaN      NaN
# ...                             ...      ...
# 2012-01-17 2.0                  NaN      NaN
# 2016-03-11 2.0                  NaN      NaN
# 2018-02-20 2.0                  NaN      NaN
#            2.0                  NaN      NaN
# 2019-06-10 2.0                  NaN      NaN
#
# [85104 rows x 93 columns]

# %%
# check out multi-index?
df_metrics_test.index
# Out:
# MultiIndex([('2012-09-05', 2.0),
#             ('2013-10-31', 2.0),
#             ('2012-04-26', 2.0),
#             ('2012-04-26', 2.0),
#             ('2009-12-04', 2.0),
#             ('2008-07-02', 2.0),
#             ('2005-03-02', 2.0),
#             ('2003-08-21', 2.0),
#             ('2003-08-05', 2.0),
#             ('2002-08-12', 2.0),
#             ...
#             ('2018-04-06', 2.0),
#             ('2017-06-14', 1.0),
#             ('2017-07-03', 1.0),
#             ('2012-01-19', 2.0),
#             ('2013-10-17', 2.0),
#             ('2012-01-17', 2.0),
#             ('2016-03-11', 2.0),
#             ('2018-02-20', 2.0),
#             ('2018-02-20', 2.0),
#             ('2019-06-10', 2.0)],
#            names=['QCDate', 'ProductLevel'], length=85104)

# %%
# sort index
df_metrics_test.sort_index(inplace=True)

# %%
# check out columns son
for column in df_metrics_test.columns: # {
    print(column)
# }
# Out:
# Unnamed: 0
# ProductID
# ProductNo
# ProductName
# LineID
# Description
# Specials
# OriginationDate
# EntryDate
# Status
# MatrixNumber
# Components
# Availability
# EquivalentSoln
# EquivalentNeat
# Packaging
# Storage
# ExpirationDate
# ShipType
# UN#
# ShipClass
# PackGrp
# ShipSpecial
# Hazard1
# Hazard2
# Hazard3
# Prop65
# MSDS
# Analysis
# CofAHeader
# Agilent#
# Tedia#
# ProdNotes
# MatrixNotes
# RecipeId
# RushPriority
# IsVoided
# SagePartNumber
# DateInserted
# CofATemplate
# UniqueRequestID
# Test_Timestamp
# PfIDNo
# PfBatchID
# OrdID
# QuoteNo
# PfSentTo
# PrepDate
# PrepVolume
# PrepUnit
# PrepVessel
# PrepVBarcode
# PrdSaleUnit
# PrepMatrixNo
# PrepMatrixLot
# PrepInits
# PrepMemo
# PrepNotebookRef
# BulkQCStatus
# BulkQCDate
# BulkPassFail
# BulkQCInits
# BulkQCMemo
# BulkLotNo
# AmpRetains
# AmpDate
# AmpPreLabel
# AmpNumberGood
# AmpNumberBad
# AmpBulkRemain
# AmpTimeIn
# AmpTimeOut
# AmpInits
# QCStatus
# QCPassFail
# QCAuthInits
# QCMemo
# QCMethod
# LotNo
# QCExpMonth
# QCExpDate
# QCSellBy
# QCFullValidation
# QCValidation
# FgInvCount
# FgAccpacNote
# CofAHeaderNo
# QCChromatogram
# Correct
# DoNotCorrect
# DensityUnit
# DensityTemp
# recipeid

# %% [raw]
# df_metrics_test.resample('D').count()

# %% [markdown]
# ### groupBy `PfBatchID`

# %%
df_by_id = df_metrics_test.groupby('PfBatchID')

# %% [markdown]
# ---

# %%
# slice and dice your DataFrame
df_metrics_test.loc[('2020-02-14', 1.0)]
# Out:
#                          Unnamed: 0 ProductID      ProductNo  \
# QCDate     ProductLevel
# 2020-02-14 1.0                12224    108963   CUS-00000171
#            1.0                12688    113787   CUS-00002470
#            1.0                12690    113843   CUS-00002497
#            1.0                12704    113869   CUS-00002515
#            1.0                23094     55370      CUS-13853
#            1.0                24019     58659      CUS-14178
#            1.0                27116     71452      CUS-15490
#            1.0                29913     86059      CUS-19563
#            1.0                37079      1715       CUS-4698
#            1.0                56141      9212  G1969-85026-X
#            1.0                56148      9212  G1969-85026-X
#            1.0                59140    113789   ICUS-0000978
#            1.0                59903     25516      ICUS-2018
#            1.0                61355     56001      ICUS-3395
#            1.0                90422     98990      SOR-120-1
#
#                                           ProductName  LineID Description  \
# QCDate     ProductLevel
# 2020-02-14 1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                       Flushing Solvent    20.0         NaN
#            1.0                       Flushing Solvent    20.0         NaN
#            1.0                        Custom Standard     8.0         NaN
#            1.0                        Custom Standard     8.0         NaN
#            1.0                        Custom Standard     8.0         NaN
#            1.0           Oregon Pesticides Standard 3     7.0         NaN
#
#                         Specials OriginationDate                  EntryDate  \
# QCDate     ProductLevel
# 2020-02-14 1.0               NaN      2019-04-11 2019-04-11 00:00:00.000000
#            1.0               NaN      2020-01-17 2020-01-17 00:00:00.000000
#            1.0               NaN      2020-01-22 2020-01-22 00:00:00.000000
#            1.0               NaN      2020-01-23 2020-01-23 00:00:00.000000
#            1.0               NaN      2012-03-01 2012-03-01 00:00:00.000000
#            1.0               NaN      2012-07-18 2012-07-18 00:00:00.000000
#            1.0               NaN      2014-03-26 2014-03-26 00:00:00.000000
#            1.0               NaN      2016-02-11 2016-02-11 00:00:00.000000
#            1.0               NaN      2003-04-30 2003-04-30 00:00:00.000000
#            1.0               NaN      2004-07-12 2004-07-12 00:00:00.000000
#            1.0               NaN      2004-07-12 2004-07-12 00:00:00.000000
#            1.0               NaN      2020-01-17 2020-01-17 13:37:20.626666
#            1.0               NaN      2007-06-05 2009-04-30 00:00:00.000000
#            1.0               NaN      2012-04-03 2012-04-03 00:00:00.000000
#            1.0               NaN      2017-08-25 2017-08-25 00:00:00.000000
#
#                         Status  ... QCValidation  FgInvCount  \
# QCDate     ProductLevel         ...
# 2020-02-14 1.0             NaN  ...          1.0        10.0
#            1.0             NaN  ...          1.0        10.0
#            1.0             NaN  ...          1.0         5.0
#            1.0             NaN  ...          1.0         5.0
#            1.0             NaN  ...          1.0         6.0
#            1.0             NaN  ...          1.0         5.0
#            1.0             NaN  ...          1.0        32.0
#            1.0             NaN  ...          1.0         4.0
#            1.0             NaN  ...          1.0         5.0
#            1.0             NaN  ...          1.0        42.0
#            1.0             NaN  ...          1.0        42.0
#            1.0             NaN  ...          1.0         1.0
#            1.0             NaN  ...          1.0         2.0
#            1.0             NaN  ...          1.0         1.0
#            1.0             NaN  ...          1.0        10.0
#
#                                               FgAccpacNote  CofAHeaderNo  \
# QCDate     ProductLevel
# 2020-02-14 1.0           Quarantine 0006466600 [25] retain           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0              Quarantine cs-3140 [28] retain           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0                                         NaN           1.0
#            1.0           Quarantine 0006453114 [61] retain           1.0
#
#                          QCChromatogram Correct DoNotCorrect  DensityUnit  \
# QCDate     ProductLevel
# 2020-02-14 1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False         True          NaN
#            1.0                      NaN   False         True          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#            1.0                      NaN   False        False          NaN
#
#                         DensityTemp recipeid
# QCDate     ProductLevel
# 2020-02-14 1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#            1.0                  NaN      NaN
#
# [15 rows x 93 columns]

# %%
df_by_id.describe().head()
