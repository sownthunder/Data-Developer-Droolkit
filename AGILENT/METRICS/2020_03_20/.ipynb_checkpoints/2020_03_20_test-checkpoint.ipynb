# %%
import os, sys, time
from time import sleep
from pathlib import Path
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df_metrics_data = pd.read_csv("C:/data/inbound/2020-03-20/metric_data.csv")
# Out:
# C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,9,12,20,25,30,31,59,74,79,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_metrics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85104 entries, 0 to 85103
# Data columns (total 95 columns):
# Unnamed: 0          85104 non-null int64
# ProductID           85104 non-null float64
# ProductNo           85104 non-null object
# ProductName         85096 non-null object
# LineID              85104 non-null float64
# Description         21554 non-null object
# Specials            5731 non-null object
# OriginationDate     84931 non-null object
# EntryDate           85104 non-null object
# Status              22416 non-null object
# MatrixNumber        85104 non-null object
# Components          85104 non-null float64
# Availability        18098 non-null object
# EquivalentSoln      0 non-null float64
# EquivalentNeat      0 non-null float64
# Packaging           84050 non-null object
# Storage             84928 non-null object
# ExpirationDate      85104 non-null float64
# ShipType            80418 non-null object
# UN#                 73535 non-null object
# ShipClass           72390 non-null object
# PackGrp             72058 non-null object
# ShipSpecial         70294 non-null object
# Hazard1             11465 non-null object
# Hazard2             19531 non-null object
# Hazard3             208 non-null object
# Prop65              21387 non-null float64
# MSDS                21362 non-null object
# Analysis            18765 non-null object
# CofAHeader          78580 non-null float64
# Agilent#            5204 non-null object
# Tedia#              16949 non-null object
# ProdNotes           47769 non-null object
# MatrixNotes         5645 non-null object
# RecipeId            79441 non-null object
# RushPriority        85104 non-null bool
# IsVoided            45890 non-null object
# SagePartNumber      82834 non-null object
# ProductLevel        85104 non-null float64
# DateInserted        0 non-null float64
# CofATemplate        60360 non-null object
# UniqueRequestID     0 non-null float64
# Test_Timestamp      85104 non-null object
# PfIDNo              85104 non-null int64
# PfBatchID           85104 non-null object
# OrdID               76010 non-null float64
# QuoteNo             85102 non-null object
# PfSentTo            85102 non-null object
# PrepDate            85090 non-null object
# PrepVolume          85103 non-null float64
# PrepUnit            85052 non-null object
# PrepVessel          85049 non-null float64
# PrepVBarcode        41140 non-null object
# PrdSaleUnit         77172 non-null object
# PrepMatrixNo        85102 non-null object
# PrepMatrixLot       84326 non-null object
# PrepInits           84952 non-null object
# PrepMemo            46686 non-null object
# PrepNotebookRef     40020 non-null object
# BulkQCStatus        3 non-null object
# BulkQCDate          70799 non-null object
# BulkPassFail        70792 non-null object
# BulkQCInits         70797 non-null object
# BulkQCMemo          1094 non-null object
# BulkLotNo           70269 non-null object
# AmpRetains          49932 non-null float64
# AmpDate             82768 non-null object
# AmpPreLabel         85104 non-null bool
# AmpNumberGood       82934 non-null float64
# AmpNumberBad        68023 non-null float64
# AmpBulkRemain       4063 non-null float64
# AmpTimeIn           82658 non-null object
# AmpTimeOut          82658 non-null object
# AmpInits            82761 non-null object
# QCStatus            564 non-null object
# QCDate              85104 non-null object
# QCPassFail          85098 non-null object
# QCAuthInits         85092 non-null object
# QCMemo              40537 non-null object
# QCMethod            1192 non-null object
# LotNo               82849 non-null object
# QCExpMonth          76792 non-null float64
# QCExpDate           78758 non-null object
# QCSellBy            0 non-null float64
# QCFullValidation    85104 non-null bool
# QCValidation        85102 non-null float64
# FgInvCount          74450 non-null float64
# FgAccpacNote        17953 non-null object
# CofAHeaderNo        85104 non-null float64
# QCChromatogram      0 non-null float64
# Correct             85104 non-null bool
# DoNotCorrect        85104 non-null bool
# DensityUnit         0 non-null float64
# DensityTemp         0 non-null float64
# recipeid            1 non-null object
# dtypes: bool(5), float64(26), int64(2), object(62)
# memory usage: 58.8+ MB

# %%
# << set column to datetime >>
df_metrics_data['QCDate'] = pd.to_datetime(df_metrics_data['QCDate'])

# %%
# GROUPBY TEST?
df_metrics_data.groupby(['QCDate', 'ProductLevel'])['PfBatchID'].count()
# Out:
# QCDate      ProductLevel
# 1991-01-01  2.0              3
# 1992-01-01  2.0              3
# 1992-01-02  2.0              1
# 1992-04-07  2.0              1
# 1993-07-28  2.0              1
#                             ..
# 2020-03-19  1.0             10
#             2.0             12
#             3.0              2
# 2020-03-20  1.0              7
#             2.0             13
# Name: PfBatchID, Length: 10674, dtype: int64

# %%
df_metrics_data.groupby(['QCDate', 'ProductLevel'])[['PfBatchID']].count()
# Out:
#                          PfBatchID
# QCDate     ProductLevel
# 1991-01-01 2.0                   3
# 1992-01-01 2.0                   3
# 1992-01-02 2.0                   1
# 1992-04-07 2.0                   1
# 1993-07-28 2.0                   1
# ...                            ...
# 2020-03-19 1.0                  10
#            2.0                  12
#            3.0                   2
# 2020-03-20 1.0                   7
#            2.0                  13
#
# [10674 rows x 1 columns]

# %% [raw]
# df_metrics_data.groupby(['QCDate', 'ProductLevel'])[['PfBatchID']].sum()

# %%
# set index
df_metrics_test = df_metrics_data.set_index(['QCDate', 'ProductLevel'])

# %%
df_metrics_test
# Out:
#                          Unnamed: 0  ProductID      ProductNo  \
# QCDate     ProductLevel
# 2012-09-05 2.0                    5     5420.0    01080-68703
# 2013-10-31 2.0                    6     5420.0    01080-68703
# 2012-04-26 2.0                    7     5420.0    01080-68703
#            2.0                    8     5420.0    01080-68703
# 2009-12-04 2.0                    9     5420.0    01080-68703
# ...                             ...        ...            ...
# 2012-01-17 2.0               104249    50108.0  ZX-TESTMIX-01
# 2016-03-11 2.0               104250    50108.0  ZX-TESTMIX-01
# 2018-02-20 2.0               104253    50108.0  ZX-TESTMIX-01
#            2.0               104254    50108.0  ZX-TESTMIX-01
# 2019-06-10 2.0               104255    50108.0  ZX-TESTMIX-01
#
#                                       ProductName  LineID Description  \
# QCDate     ProductLevel
# 2012-09-05 2.0                    Gradient Sample     7.0         NaN
# 2013-10-31 2.0                    Gradient Sample     7.0         NaN
# 2012-04-26 2.0                    Gradient Sample     7.0         NaN
#            2.0                    Gradient Sample     7.0         NaN
# 2009-12-04 2.0                    Gradient Sample     7.0         NaN
# ...                                           ...     ...         ...
# 2012-01-17 2.0           GC x GC Testing Solution     7.0         NaN
# 2016-03-11 2.0           GC x GC Testing Solution     7.0         NaN
# 2018-02-20 2.0           GC x GC Testing Solution     7.0         NaN
#            2.0           GC x GC Testing Solution     7.0         NaN
# 2019-06-10 2.0           GC x GC Testing Solution     7.0         NaN
#
#                             Specials      OriginationDate  \
# QCDate     ProductLevel
# 2012-09-05 2.0           01080-68703  1998-02-04 00:00:00
# 2013-10-31 2.0           01080-68703  1998-02-04 00:00:00
# 2012-04-26 2.0           01080-68703  1998-02-04 00:00:00
#            2.0           01080-68703  1998-02-04 00:00:00
# 2009-12-04 2.0           01080-68703  1998-02-04 00:00:00
# ...                              ...                  ...
# 2012-01-17 2.0                   NaN  2011-04-19 00:00:00
# 2016-03-11 2.0                   NaN  2011-04-19 00:00:00
# 2018-02-20 2.0                   NaN  2011-04-19 00:00:00
#            2.0                   NaN  2011-04-19 00:00:00
# 2019-06-10 2.0                   NaN  2011-04-19 00:00:00
#
#                                    EntryDate Status  ... QCValidation  \
# QCDate     ProductLevel                              ...
# 2012-09-05 2.0           2011-05-09 00:00:00    oem  ...          2.0
# 2013-10-31 2.0           2011-05-09 00:00:00    oem  ...          2.0
# 2012-04-26 2.0           2011-05-09 00:00:00    oem  ...          2.0
#            2.0           2011-05-09 00:00:00    oem  ...          2.0
# 2009-12-04 2.0           2011-05-09 00:00:00    oem  ...          2.0
# ...                                      ...    ...  ...          ...
# 2012-01-17 2.0           2011-05-09 00:00:00    NaN  ...          2.0
# 2016-03-11 2.0           2011-05-09 00:00:00    NaN  ...          2.0
# 2018-02-20 2.0           2011-05-09 00:00:00    NaN  ...          2.0
#            2.0           2011-05-09 00:00:00    NaN  ...          2.0
# 2019-06-10 2.0           2011-05-09 00:00:00    NaN  ...          2.0
#
#                          FgInvCount                            FgAccpacNote  \
# QCDate     ProductLevel
# 2012-09-05 2.0               2600.0                                     NaN
# 2013-10-31 2.0               2123.0                                     NaN
# 2012-04-26 2.0               3400.0                                     NaN
#            2.0               1563.0                                 back up
# 2009-12-04 2.0               1156.0       zero out ce-3778 (1390) stability
# ...                             ...                                     ...
# 2012-01-17 2.0                129.0                                     NaN
# 2016-03-11 2.0                602.0                                     NaN
# 2018-02-20 2.0                366.0                                     NaN
#            2.0                320.0                                     NaN
# 2019-06-10 2.0                320.0  purge cs-0774 (70) cp-1554a (5) retain
#
#                          CofAHeaderNo  QCChromatogram Correct DoNotCorrect  \
# QCDate     ProductLevel
# 2012-09-05 2.0                    2.0             NaN   False        False
# 2013-10-31 2.0                    2.0             NaN   False        False
# 2012-04-26 2.0                    2.0             NaN   False         True
#            2.0                    2.0             NaN   False         True
# 2009-12-04 2.0                    2.0             NaN   False         True
# ...                               ...             ...     ...          ...
# 2012-01-17 2.0                    2.0             NaN   False         True
# 2016-03-11 2.0                    2.0             NaN   False        False
# 2018-02-20 2.0                    2.0             NaN   False        False
#            2.0                    2.0             NaN   False        False
# 2019-06-10 2.0                    2.0             NaN   False        False
#
#                          DensityUnit DensityTemp recipeid
# QCDate     ProductLevel
# 2012-09-05 2.0                   NaN         NaN      NaN
# 2013-10-31 2.0                   NaN         NaN      NaN
# 2012-04-26 2.0                   NaN         NaN      NaN
#            2.0                   NaN         NaN      NaN
# 2009-12-04 2.0                   NaN         NaN      NaN
# ...                              ...         ...      ...
# 2012-01-17 2.0                   NaN         NaN      NaN
# 2016-03-11 2.0                   NaN         NaN      NaN
# 2018-02-20 2.0                   NaN         NaN      NaN
#            2.0                   NaN         NaN      NaN
# 2019-06-10 2.0                   NaN         NaN      NaN
#
# [85104 rows x 93 columns]

# %%
# check out multi-index?
df_metrics_test.index
# Out:
# MultiIndex([('2012-09-05', 2.0),
#             ('2013-10-31', 2.0),
#             ('2012-04-26', 2.0),
#             ('2012-04-26', 2.0),
#             ('2009-12-04', 2.0),
#             ('2008-07-02', 2.0),
#             ('2005-03-02', 2.0),
#             ('2003-08-21', 2.0),
#             ('2003-08-05', 2.0),
#             ('2002-08-12', 2.0),
#             ...
#             ('2018-04-06', 2.0),
#             ('2017-06-14', 1.0),
#             ('2017-07-03', 1.0),
#             ('2012-01-19', 2.0),
#             ('2013-10-17', 2.0),
#             ('2012-01-17', 2.0),
#             ('2016-03-11', 2.0),
#             ('2018-02-20', 2.0),
#             ('2018-02-20', 2.0),
#             ('2019-06-10', 2.0)],
#            names=['QCDate', 'ProductLevel'], length=85104)

# %%
# sort index
df_metrics_test.sort_index(inplace=True)

# %%
# check out columns son
for column in df_metrics_test.columns: # {
    print(column)
# }
# Out:
# Unnamed: 0
# ProductID
# ProductNo
# ProductName
# LineID
# Description
# Specials
# OriginationDate
# EntryDate
# Status
# MatrixNumber
# Components
# Availability
# EquivalentSoln
# EquivalentNeat
# Packaging
# Storage
# ExpirationDate
# ShipType
# UN#
# ShipClass
# PackGrp
# ShipSpecial
# Hazard1
# Hazard2
# Hazard3
# Prop65
# MSDS
# Analysis
# CofAHeader
# Agilent#
# Tedia#
# ProdNotes
# MatrixNotes
# RecipeId
# RushPriority
# IsVoided
# SagePartNumber
# DateInserted
# CofATemplate
# UniqueRequestID
# Test_Timestamp
# PfIDNo
# PfBatchID
# OrdID
# QuoteNo
# PfSentTo
# PrepDate
# PrepVolume
# PrepUnit
# PrepVessel
# PrepVBarcode
# PrdSaleUnit
# PrepMatrixNo
# PrepMatrixLot
# PrepInits
# PrepMemo
# PrepNotebookRef
# BulkQCStatus
# BulkQCDate
# BulkPassFail
# BulkQCInits
# BulkQCMemo
# BulkLotNo
# AmpRetains
# AmpDate
# AmpPreLabel
# AmpNumberGood
# AmpNumberBad
# AmpBulkRemain
# AmpTimeIn
# AmpTimeOut
# AmpInits
# QCStatus
# QCPassFail
# QCAuthInits
# QCMemo
# QCMethod
# LotNo
# QCExpMonth
# QCExpDate
# QCSellBy
# QCFullValidation
# QCValidation
# FgInvCount
# FgAccpacNote
# CofAHeaderNo
# QCChromatogram
# Correct
# DoNotCorrect
# DensityUnit
# DensityTemp
# recipeid

# %% [markdown]
# ### groupBy `PfBatchID`

# %%
df_by_id = df_metrics_test.groupby('PfBatchID')

# %% [markdown]
# ---

# %%
# slice and dice your DataFrame
df_metrics_test.loc[('2020-02-14', 1.0)]
# Out:
#                          Unnamed: 0  ProductID      ProductNo  \
# QCDate     ProductLevel
# 2020-02-14 1.0                12224   108963.0   CUS-00000171
#            1.0                12688   113787.0   CUS-00002470
#            1.0                12690   113843.0   CUS-00002497
#            1.0                12704   113869.0   CUS-00002515
#            1.0                23094    55370.0      CUS-13853
#            1.0                24019    58659.0      CUS-14178
#            1.0                27116    71452.0      CUS-15490
#            1.0                29913    86059.0      CUS-19563
#            1.0                37079     1715.0       CUS-4698
#            1.0                56141     9212.0  G1969-85026-X
#            1.0                56148     9212.0  G1969-85026-X
#            1.0                59140   113789.0   ICUS-0000978
#            1.0                59903    25516.0      ICUS-2018
#            1.0                61355    56001.0      ICUS-3395
#            1.0                90422    98990.0      SOR-120-1
#
#                                           ProductName  LineID Description  \
# QCDate     ProductLevel
# 2020-02-14 1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                        Custom Standard     7.0         NaN
#            1.0                       Flushing Solvent    20.0         NaN
#            1.0                       Flushing Solvent    20.0         NaN
#            1.0                        Custom Standard     8.0         NaN
#            1.0                        Custom Standard     8.0         NaN
#            1.0                        Custom Standard     8.0         NaN
#            1.0           Oregon Pesticides Standard 3     7.0         NaN
#
#                         Specials             OriginationDate  \
# QCDate     ProductLevel
# 2020-02-14 1.0               NaN         2019-04-11 00:00:00
#            1.0               NaN  2020-01-17 00:00:00.000000
#            1.0               NaN  2020-01-22 00:00:00.000000
#            1.0               NaN  2020-01-23 00:00:00.000000
#            1.0               NaN         2012-03-01 00:00:00
#            1.0               NaN         2012-07-18 00:00:00
#            1.0               NaN         2014-03-26 00:00:00
#            1.0               NaN         2016-02-11 00:00:00
#            1.0               NaN         2003-04-30 00:00:00
#            1.0               NaN         2004-07-12 00:00:00
#            1.0               NaN         2004-07-12 00:00:00
#            1.0               NaN  2020-01-17 00:00:00.000000
#            1.0               NaN  2007-06-05 00:00:00.000000
#            1.0               NaN         2012-04-03 00:00:00
#            1.0               NaN  2017-08-25 00:00:00.000000
#
#                                           EntryDate Status  ... QCValidation  \
# QCDate     ProductLevel                                     ...
# 2020-02-14 1.0                  2019-04-11 00:00:00    NaN  ...          1.0
#            1.0           2020-01-17 00:00:00.000000    NaN  ...          1.0
#            1.0           2020-01-22 00:00:00.000000    NaN  ...          1.0
#            1.0           2020-01-23 00:00:00.000000    NaN  ...          1.0
#            1.0                  2012-03-01 00:00:00    NaN  ...          1.0
#            1.0                  2012-07-18 00:00:00    NaN  ...          1.0
#            1.0                  2014-03-26 00:00:00    NaN  ...          1.0
#            1.0                  2016-02-11 00:00:00    NaN  ...          1.0
#            1.0                  2003-04-30 00:00:00    NaN  ...          1.0
#            1.0                  2004-07-12 00:00:00    NaN  ...          1.0
#            1.0                  2004-07-12 00:00:00    NaN  ...          1.0
#            1.0           2020-01-17 13:37:20.626666    NaN  ...          1.0
#            1.0           2009-04-30 00:00:00.000000    NaN  ...          1.0
#            1.0                  2012-04-03 00:00:00    NaN  ...          1.0
#            1.0           2017-08-25 00:00:00.000000    NaN  ...          1.0
#
#                          FgInvCount                       FgAccpacNote  \
# QCDate     ProductLevel
# 2020-02-14 1.0                 10.0  Quarantine 0006466600 [25] retain
#            1.0                 10.0                                NaN
#            1.0                  5.0                                NaN
#            1.0                  5.0                                NaN
#            1.0                  6.0                                NaN
#            1.0                  5.0                                NaN
#            1.0                 32.0                                NaN
#            1.0                  4.0     Quarantine cs-3140 [28] retain
#            1.0                  5.0                                NaN
#            1.0                 42.0                                NaN
#            1.0                 42.0                                NaN
#            1.0                  1.0                                NaN
#            1.0                  2.0                                NaN
#            1.0                  1.0                                NaN
#            1.0                 10.0  Quarantine 0006453114 [61] retain
#
#                          CofAHeaderNo  QCChromatogram Correct DoNotCorrect  \
# QCDate     ProductLevel
# 2020-02-14 1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False         True
#            1.0                    1.0             NaN   False         True
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#            1.0                    1.0             NaN   False        False
#
#                          DensityUnit DensityTemp recipeid
# QCDate     ProductLevel
# 2020-02-14 1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#            1.0                   NaN         NaN      NaN
#
# [15 rows x 93 columns]

# %%
df_by_id.describe().head()
