# %% [markdown]
# # `MS ACCESS ODBC_select`
# *(Access >> data)*
#
# ---
#
# ## `ACCESS` connects via `pyodbc`
# ## and read into a `PANDAS DataFrame`
#
# ---

# %%
# import the goodies
import os, sys, time

# %%
import datetime

# %%
# CREATE TIME STAMP FOR FILE CREATION NAME
date_object = datetime.date.today()
time_object = str('{0:%m_%d_%Y-%H%M%S}'.format(datetime.datetime.now()))
print(str("file naming convention (today's example) :"), time_object)
# Out:
# file naming convention (today's example) : 05_23_2019-141814

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import pyodbc

# %% [markdown]
# ---

# %%
inDirectory = "C:/Temp/"

# %% [markdown]
# ##### Testing `ACCESS Driver`

# %%
[x for x in pyodbc.drivers() if x.startswith('Microsoft Access Driver')]
# Out:
# ['Microsoft Access Driver (*.mdb, *.accdb)']

# %% [markdown]
# ##### Create `CONNECTION STRING`

# %%
try: #{
    conn_str = (
        r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
        r'DBQ=E:\ACCDBUpgrade\Custom Quotes_fe.mdb;'
    )
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# FIN...

# %% [markdown]
# ##### Create `[cnxn]` from `[conn_str]`
#
# ##### Create `[crsr]` from `[cnxn]`

# %%
try: #{
    cnxn = pyodbc.connect(conn_str)
    crsr = cnxn.cursor()
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# FIN...

# %% [markdown]
# ---
# # `cnxn.execute()`
# ~~*(SinglesPests)*~~

# %%
try: #{
    # SQL COMMAND
    sql_query = cnxn.execute(
        "select * from [SinglePests]"
    )
    for row in sql_query: #{
        #print("CatalogNO:", row['Cat#'])
        print(str(row))
    #}
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
    print("\n" + typeE + 
          "\n" + fileE + 
          "\n" + lineE + 
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# (5, '000082-68-8', 'PST-770K1000')
# (6, '000122-39-4', 'PST-460K1000')
# (7, '000099-30-9', 'PST-190K1000')
# (8, '066332-96-5', 'PST-2365K1000')
# (9, '000058-89-9', 'PST-630K1000')
# (10, '000072-55-9', 'PST-250K1000')
# (11, '000072-54-8', 'PST-220K1000')
# (12, '096489-71-3', 'PST-2540K1000')
# (13, '000063-25-2', 'PST-100A1000')
# (14, '035367-38-5', 'PST-1400A1000')
# (15, '000527-20-8', 'PST-3610K1000')
# (16, '002439-01-2', 'PST-2845K1000')
# (17, '000957-51-7', 'PST-1405K1000')
# (18, '000114-26-1', 'PST-060A1000')
# (19, '016752-77-5', 'PST-680A1000')
# (20, '002032-65-7', 'PST-1525A1000')
# (21, '042874-03-3', 'PST-1590K1000')
# (22, '019666-30-9', 'PST-1575K1000')
# (23, '025311-71-1', 'PST-2690K1000')
# (24, '099387-89-0', 'PST-2635K1000')
# (25, '040487-42-1', 'PST-1600K1000')
# (26, '023103-98-2', 'PST-2505A1000')
# (27, '023135-22-0', 'PST-1580A1000')
# (28, '001563-66-2', 'PST-1295A1000')
# (29, '000950-37-8', 'PST-1520K1000')
# (30, '022781-23-3', 'PST-1235A1000')
# (31, '000101-21-3', 'PST-1345K1000')
# (32, '042576-02-3', 'PST-2805K1000')
# (33, '013171-21-6', 'PST-810K1000')
# (34, '002310-17-0', 'PST-2500K1000')
# (35, '007287-19-6', 'PST-840K1000')
# (36, '083657-24-3', 'PST-2215K1000')
# (37, '002104-64-5', 'PST-520K1000')
# (38, '000050-29-3', 'PST-260K1000')
# (39, '013194-48-4', 'PST-1425K1000')
# (40, '000886-50-0', 'PST-1710K1000')
# (41, '000072-20-8', 'PST-510K1000')
# (42, '000319-84-6', 'PST-071K1000')
# (43, '000116-29-0', 'PST-960K1000')
# (44, '002921-88-2', 'PST-480K1000')
# (45, '001582-09-8', 'PST-1740K1000')
# (46, '055283-68-6', 'PST-3015K1000')
# (47, '000148-79-8', 'PST-1720M1000')
# (48, '000121-75-5', 'PST-641K1000')
# (49, '028249-77-6', 'PST-1725K1000')
# (50, '015972-60-8', 'PST-625K1000')
# (51, '041198-08-7', 'PST-1635K1000')
# (52, '000330-54-1', 'PST-1415A1000')
# (53, '036734-19-7', 'PST-1985K1000')
# (54, '001897-45-6', 'PST-1340A1000')
# (55, '003766-81-2', 'PST-3435A1000')
# (56, '079983-71-4', 'PST-2385K1000')
# (57, '050471-44-8', 'PST-2050K1000')
# (58, '073250-68-7', 'PST-3525K1000')
# (59, '000298-04-4', 'PST-470K1000')
# (60, '000563-12-2', 'PST-530K1000')
# (61, '005598-13-0', 'PST-1350K1000')
# (62, '000789-02-6', 'PST-271K1000')
# (63, '000133-06-2', 'PST-090K1000')
# (64, '094361-06-5', 'PST-2150K1000')
# (65, '000786-19-6', 'PST-990K1000')
# (66, '000333-41-5', 'PST-320K1000')
# (67, '000055-38-9', 'PST-540K1000')
# (68, '057369-32-1', 'PST-3600A1000')
# (69, '001085-98-9', 'PST-2175K1000')
# (70, '076738-62-0', 'PST-2490K1000')
# (71, '023564-05-8', 'PST-1730A1000')
# (72, '057018-04-9', 'PST-2605K1000')
# (73, '003060-89-7', 'PST-3165K1000')
# (74, '000086-50-0', 'PST-1091K1000')
# (75, '000072-43-5', 'PST-691K1000')
# (76, '002631-40-5', 'PST-1470A1000')
# (77, '043121-43-3', 'PST-1830K1000')
# (78, '000076-44-8', 'PST-571K1000')
# (79, '000319-85-7', 'PST-072K1000')
# (80, '068359-37-5', 'PST-1910K1000')
# (81, '000122-34-9', 'PST-1130K1000')
# (82, '000510-15-6', 'PST-120K1000')
# (83, '038260-54-7', 'PST-2270K1000')
# (84, '121552-61-2', 'PST-2155K1000')
# (85, '000309-00-2', 'PST-010K1000')
# (86, '021087-64-9', 'PST-1535K1000')
# (87, '000959-98-8', 'PST-501K1000')
# (88, '065907-30-4', 'PST-3095K1000')
# (89, '000056-38-2', 'PST-761K1000')
# (90, '013071-79-9', 'PST-1700K1000')
# (91, '029973-13-5', 'PST-2240A1000')
# (92, '066841-25-6', 'PST-3320K1000')
# (93, '050512-35-1', 'PST-3510K1000')
# (94, '051338-27-3', 'PST-2955K1000')
# (95, '060207-90-1', 'PST-2040K1000')
# (96, '033213-65-9', 'PST-502K1000')
# (97, '029232-93-7', 'PST-1625K1000')
# (98, '051630-58-1', 'PST-1445K1000')
# (99, '027605-76-1', 'PST-3565K1000')
# (100, '015299-99-7', 'PST-1555K1000')
# (101, '000470-90-6', 'PST-1325K1000')
# (102, '023505-41-1', 'PST-2510K1000')
# (103, '000122-14-5', 'PST-1080K1000')
# (104, '000133-07-3', 'PST-550K1000')
# (105, '117718-60-2', 'PST-3640K1000')
# (106, '017109-49-8', 'PST-3000K1000')
# (107, '000060-57-1', 'PST-400K1000')
# (108, '063284-71-9', 'PST-2480K1000')
# (109, '052645-53-1', 'PST-1605K1000')
# (110, '110488-70-5', 'PST-2210A1000')
# (111, '018691-97-9', 'PST-2445K1000')
# (112, '000709-98-8', 'PST-1655K1000')
# (113, '000062-73-7', 'PST-380K1000')
# (114, '074115-24-5', 'PST-2145K1000')
# (115, '005915-41-3', 'PST-1705K1000')
# (116, '138261-41-3', 'PST-1980A1000')
# (117, '002212-67-1', 'PST-1540K1000')
# (118, '032809-16-8', 'PST-2520K1000')
# (119, '131860-33-8', 'PST-1905K1000')
# (120, '001024-57-3', 'PST-582K1000')
# (121, '067747-09-5', 'PST-2515K1000')
# (122, '083121-18-0', 'PST-3260A1000')
# (123, '000731-27-1', 'PST-2610K1000')
# (124, '007786-34-7', 'PST-3175K1000')
# (125, '101463-69-8', 'PST-2345K1000')
# (126, '026087-47-8', 'PST-3500K1000')
# (127, '018181-80-1', 'PST-2090K1000')
# (128, '055219-65-3', 'PST-2615K1000')
# (129, '001031-07-8', 'PST-503K1000')
# (130, '022224-92-6', 'PST-1435K1000')
# (131, '119446-68-3', 'PST-2190K1000')
# (132, '002593-15-9', 'PST-1770K1000')
# (133, '039515-41-8', 'PST-2310K1000')
# (134, '000060-51-5', 'PST-421K1000')
# (135, '051218-45-2', 'PST-1530K1000')
# (136, '086479-06-3', 'PST-3105A1000')
# (137, '005103-74-2', 'PST-112K1000')
# (138, '005103-71-9', 'PST-111K1000')
# (139, '000298-00-0', 'PST-700K1000')
# (140, '052918-63-5', 'PST-1385K1000')
# (141, '024151-93-7', 'PST-3560K1000')
# (142, '114369-43-6', 'PST-2290K1000')
# (143, '060168-88-9', 'PST-1775K1000')
# (144, '087130-20-9', 'PST-2185A1000')
# (145, '035554-44-0', 'PST-1970K1000')
# (146, '143390-89-0', 'PST-2405K1000')
# (147, '000119-12-0', 'PST-2545K1000')
# (148, '095737-68-1', 'PST-2560A1000')
# (149, '000115-32-2', 'PST-391A1000')
# (150, '148477-71-8', 'PST-3630A1000')
# (151, '066246-88-6', 'PST-2495K1000')
# (152, '001129-41-5', 'PST-3535A1000')
# (153, '069327-76-0', 'PST-2105K1000')
# (154, '000298-02-2', 'PST-800K1000')
# (155, '000116-06-3', 'PST-940A1000')
# (156, '131341-86-1', 'PST-2340K1000')
# (157, '064249-01-0', 'PST-3360K1000')
# (158, '105024-66-6', 'PST-3620A1000')
# (159, '122453-73-0', 'PST-2120K1000')
# (160, '096182-53-5', 'PST-3250K1000')
# (161, '041814-78-2', 'PST-1840A1000')
# (162, '001825-19-0', 'PST-3615K1000')
# (163, '161326-34-7', 'PST-2280K1000')
# (164, '057966-95-7', 'PST-2925A1000')
# (165, '057837-19-1', 'PST-2000K1000')
# (166, '120928-09-8', 'PST-2285K1000')
# (167, '175013-18-0', 'PST-3575A1000')
# (168, '002597-03-7', 'PST-2020K1000')
# (169, '111812-58-9', 'PST-3040A1000')
# (170, '052315-07-8', 'PST-1370K1000')
# (171, '144171-61-9', 'PST-2685K1000')
# (172, '034643-46-4', 'PST-1825K1000')
# (173, '002595-54-2', 'PST-2415K1000')
# (174, '103055-07-8', 'PST-3515K1000')
# (175, '140923-17-7', 'PST-3505K1000')
# (176, '023184-66-9', 'PST-1275K1000')
# (177, '064628-44-0', 'PST-3340K1000')
# (178, '070124-77-5', 'PST-2335K1000')
# (179, '024017-47-8', 'PST-2045K1000')
# (180, '055814-41-0', 'PST-2425K1000')
# (181, '059669-26-0', 'PST-3305A1000')
# (182, '010605-21-7', 'PST-1285E250')
# (183, '085509-19-9', 'PST-2360K1000')
# (184, '120116-88-3', 'PST-3400A1000')
# (185, '078587-05-0', 'PST-3110A1000')
# (186, '097886-45-8', 'PST-3425K1000')
# (187, '239110-15-7', 'PST-3470A1000')
# (188, '119168-77-3', 'PST-2585K1000')
# (189, '133220-30-1', 'PST-3495K1000')
# (190, '188425-85-6', 'PST-3365A1000')
# (191, '141517-21-7', 'PST-2630A1000')
# (192, '082657-04-3', 'PST-1915K1000')
# (193, '088671-89-0', 'PST-2470K1000')
# (194, '055179-31-2', 'PST-2070K1000')
# (195, '107534-96-3', 'PST-1955K1000')
# (196, '066063-05-6', 'PST-3555A1000')
# (197, '111988-49-9', 'PST-3285A1000')
# (198, '272451-65-7', 'PST-3460A1000')
# (199, '374726-62-2', 'PST-3520A1000')
# (200, '153719-23-4', 'PST-3290A1000')
# (201, '013457-18-6', 'PST-2530K1000')
# (202, '101007-06-1', 'PST-2060K1000')
# (203, '136426-54-5', 'PST-2355A1000')
# (204, '110235-47-7', 'PST-2420A1000')
# (205, '091465-08-6', 'PST-1990K1000')
# (206, '115852-48-7', 'PST-3445K1000')
# (207, '125116-23-6', 'PST-2440K1000')
# (208, '135410-20-7', 'PST-3355A1000')
# (209, '112281-77-3', 'PST-2595K1000')
# (210, '095465-99-9', 'PST-3375K1000')
# (211, '053112-28-0', 'PST-2555A1000')
# (212, '001014-70-6', 'PST-1805K1000')
# (213, '061432-55-1', 'PST-3415K1000')
# (214, '122008-85-9', 'PST-3410A1000')
# (215, '087674-68-8', 'PST-2205K1000')
# (216, '080844-07-1', 'PST-2260A1000')
# (217, '116714-46-6', 'PST-3540A1000')
# (218, '112410-23-8', 'PST-3245A1000')
# (219, '000319-86-8', 'PST-073K1000')
# (220, '058810-48-3', 'PST-3545K1000')
# (221, '120068-37-3', 'PST-1950K1000')
# (222, '210880-92-5', 'PST-3395A1000')
# (223, '500008-45-7', 'PST-3380A1000')
# (224, '161050-58-4', 'PST-3530A1000')
# (225, '074712-19-9', 'PST-3370K1000')
# (226, '283594-90-1', 'PST-3635A1000')
# (227, '156052-68-5', 'PST-3650K1000')
# (228, '179101-81-6', 'PST-3585K1000')
# (229, '085785-20-2', 'PST-3430K1000')
# (230, '002797-51-5', 'PST-3605A1000')
# (231, '079538-32-2', 'PST-2590K1000')
# (232, '077458-01-6', 'PST-3570K1000')
# (233, '153233-91-1', 'PST-2265K1000')
# (234, '149508-90-7', 'PST-3625K1000')
# (235, '229977-93-9', 'PST-3455A1000')
# (236, '062850-32-2', 'PST-3440K1000')
# (237, '143807-66-3', 'PST-3390A1000')
# (238, '071422-67-8', 'PST-3385K1000')
# (239, '130000-40-7', 'PST-3645K1000')
# (240, '068157-60-8', 'PST-3475A1000')
# (241, '089269-64-7', 'PST-3450A1000')
# (242, '180409-60-3', 'PST-3405K1000')
# (243, '103361-09-7', 'PST-3465A1000')
# (244, '002274-67-1', 'PST-3420A1000')
# (245, '098886-44-3', 'PST-3480K1000')
# (246, '088678-67-5', 'PST-3580A1000')
# (247, '086598-92-7', 'PST-3490A1000')
# (248, '105779-78-0', 'PST-3590K1000')
# (249, '147411-69-6', 'PST-3595K1000')
# (250, '153197-14-9', 'PST-3550A1000')
# (251, '027355-22-2', 'PST-3485K1000')
# FIN...

# %% [markdown]
# ---
# # `pandas.read_sql_query`

# %%
"""
: param : CUSTOM SQL QUERY AS STR
: return: Dataframe object containing ACCESS data
"""
def read_sql_query_from_access(theQuery, theConn): #{
    """Import data from ACCESS; clean & merge dataframes"""
    # try the following
    try: #{
        df = pd.read_sql_query(
            sql=(str(theQuery)),
            con=(theConn))
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
        print("\n" + typeE + 
              "\n" + fileE + 
              "\n" + lineE + 
              "\n" + messageE)
    #}
    else: #{
        print("FIN...")
    #}
    
    return df
#}

# %% [markdown]
# `"SELECT [ID], [CAS#], [Catalog#]`
#
# `FROM [SinglePests]"`

# %%
testDf = read_sql_query_from_access(
    "SELECT [MatrixNumber], [Matrix], [Density] FROM [Matrices]", cnxn
)
# Out:
# FIN...

# %%
testDf
# Out:
#     MatrixNumber                                             Matrix Density
# 0        JHP-001                                            acetone   0.791
# 1        JHP-002                   acetone/methylene chloride (2:1)   0.969
# 2        JHP-003                                       acetonitrile   0.786
# 3        JHP-004                         acetonitrile/acetone (9:1)   0.787
# 4        JHP-005               acetonitrile/acetone/toluene (6:3:1)   0.796
# 5        JHP-006                        acetonitrile/methanol (1:1)   0.789
# 6        JHP-007                        acetonitrile/methanol (9:1)   0.787
# 7        JHP-008                         acetonitrile/water (70:30)    0.85
# 8        JHP-009                   benzene/methylene chloride (4:1)   0.964
# 9        JHP-010    methylene chloride/benzene/acetonitrile (2:2:1)   1.037
# 10       JHP-011                          dimethyl sulfoxide (DMSO)   1.101
# 11       JHP-012                                           dodecane    0.75
# 12       JHP-013                                      ethyl acetate   0.902
# 13       JHP-014                                             hexane   0.659
# 14       JHP-015                               hexane/acetone (1:1)   0.725
# 15       JHP-016                                hexane/acetone (5%)   0.666
# 16       JHP-017                               hexane/toluene (1:1)   0.763
# 17       JHP-018                 isooctane (2,2,4-trimethylpentane)   0.692
# 18       JHP-019                            isooctane/toluene (1:1)   0.857
# 19       JHP-020                    isopropanol (isopropyl alcohol)   0.786
# 20       JHP-021                          methanol (methyl alcohol)   0.791
# 21       JHP-022  methanol/acetonitrile/water/acetic acid (42.4 ...   0.820
# 22       JHP-023                        methanol/acetonitrile (4:1)    0.79
# 23       JHP-024                            methanol/benzene (19:1)   0.795
# 24       JHP-025                        methanol/methylene chloride   1.059
# 25       JHP-026                  methanol/methylene chloride (1:1)   1.059
# 26       JHP-027                           methanol/water (1:1 V/V)   0.896
# 27       JHP-028                           methanol/water (3:2 V/V)   0.875
# 28       JHP-029                     methyl tert-butyl ether (MTBE)    0.74
# 29       JHP-030                   methyl tert-butyl ether/methanol   0.766
# ..           ...                                                ...     ...
# 637      JHP-638                        methanol with trace acetone       0
# 638      JHP-639                   ethyl acetate with trace acetone       0
# 639      JHP-641                                       Test On Live       1
# 640      JHP-642     water with trace nitric and hydrochloric acids       0
# 641      JHP-643          acetontrile/methanol/chloroform (85:14:1)       0
# 642      JHP-644                                        sec-butanol       0
# 643      JHP-645                                        sec-butanol       0
# 644      JHP-646              methanol/acetonitrile/water (36:56:8)       0
# 645      JHP-647              methanol/acetonitrile/water (36:56:8)       0
# 646      JHP-648  5% nitric acid in water with trace hydrochlori...       0
# 647      JHP-649                                                 10       0
# 648      JHP-650                   acetonitrile/acetone (70:30 v/v)       0
# 649      JHP-651                                      cyclohexanone       0
# 650      JHP-652                              ethanol/water (65:35)       0
# 651      JHP-653                   tetrahydrofuran (inhibitor free)       0
# 652      JHP-654                               pyridine/water (1:1)       0
# 653      JHP-655               methanol/water/acetic acid (59:40:1)       0
# 654      JHP-656                              2M potassium chloride       0
# 655      JHP-657                               2M hydrochloric acid       0
# 656      JHP-658                                   0.5M nitric acid       0
# 657      JHP-659              methyl tert-butyl ether/acetone (4:1)       0
# 658      JHP-660                       acetonitrile with 0.5% water       0
# 659      JHP-661                            toluene/ n-hexane (1:1)       0
# 660      JHP-662                             n-hexane/acetone (9:1)       0
# 661      JHP-663  2% hydrochloric acid with trace nitric acid in...       0
# 662      JHP-664                            toluene/isooctane (9:1)       0
# 663      JHP-665                            methanol with trace TEA       0
# 664      JHP-666                              ethanol/water (75:25)       0
# 665      JHP-667                         acetonitrile/acetone (3:2)       0
# 666      JHP-XXX         Check BellHawk Solvent!  Conversion issue!       0
#
# [667 rows x 3 columns]

# %%
testDf.to_csv(
    inDirectory
    + "_ACCESS_2_df"
    + str(time_object)
    + ".csv",
    index=False)

# %% [markdown]
# `WORKING IN PROGRESS: TO ACCEPT PARAMETERS`

# %%
def read_sql_query_from_access(theTable): #{
    """Import data from ACCESS; clean & merge dataframes"""
    # try the following
    try: #{
        df = pd.to_s
        df = pd.read_sql_query(
            sql=('SELECT [ID], [CAS#], [Catalog#] FROM [SinglePests] WHERE [ID]=%s' % theUser),
            con=(cnxn))
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
        print("\n" + typeE + 
              "\n" + fileE + 
              "\n" + lineE + 
              "\n" + messageE)
    #}
    else: #{
        print("FIN...")
    #}
#}

# %% [raw]
# """
# :param : Username as Str
# :return: DataFrame containing [ID], [Catalog#] of UserName
# """
# def pull_data_from_access(theUser): #{
#     # try the following
#     try: #{
#         df = pd.read_sql_table(
#         'SinglePests', con=cnxn, columns=['ID', 'Catalog#'])
#     #}
#     except: #{
#         errorMessage = str(sys.exc_info()[0]) + "\n"
#         errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
#         errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
#         exc_type, exc_obj, exc_tb = sys.exc_info()
#         fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
#         typeE = str("TYPE : " + str(exc_type))
#         fileE = str("FILE : " + str(fname))
#         lineE = str("LINE : " + str(exc_tb.tb_lineno))
#         messageE = str("MESG : " + "\n\n" + str(errorMessage) + "\n")
#         print("\n" + typeE +
#               "\n" + fileE +
#               "\n" + lineE +
#               "\n" + messageE)
#     #}
#     else: #{
#         print("FIN...")
#     #}
#     return df
# #}

# %% [raw]
# """
# : param : CUSTOM SQL QUERY AS STR
# : return: Dataframe object
# """
# def read_sql_query_from_access(theQuery, inputParam1): #{
#     """Import data from ACCESS; clean & merge dataframes"""
#     # try the following
#     try: #{
#         df = pd.read_sql_query(
#             sql=('SELECT [ID], [CAS#], [Catalog#] FROM [SinglePests] WHERE [ID]=%s' % inputParam1),
#             con=(cnxn))
#     #}
# #}
