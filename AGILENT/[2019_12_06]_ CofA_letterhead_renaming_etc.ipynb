# %% [markdown]
# ---

# %% [markdown]
# Happy Friday, Derek!
#
# I have another request for you.
#
# •	We need to add the CofA letterhead to all CofAs that’s saved at
# o	F:\APPS\CofA before 03/25/2019
# o	J:\controlled_docs\CofA
#
# •	These should NOT change the file name as we do for CofAs on or after 03/25/2019
#
# •	Can you please save the CofA with the background to G:\C of A's\#CofA with background for web
#
# If anything is not clear please let me know. Also you can do a few and let me know and I can confirm those are correct. Thanks so much!
#
# Best regards,
#
# Diluka

# %% [markdown]
# ---

# %% [markdown]
# The CofAs that are prior to 03/25/2019 that’s on the web already are without the letterhead. We need to replace those with the ones with letterhead. That location is ONLY for this project.
#
# All other CofAs where you change the name, apply the letterhead and save to email node and email daily, are to continue just the way you do right now without any changes.
#
# Best regards,
#
# Diluka

# %%
# IMPORT THE GOODS
import os, sys, time
from time import sleep
from pathlib import Path

# %%
from datetime import datetime
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
import logging
from PyPDF2 import PdfFileReader, PdfFileWriter

# %%
def setup_logger(): #{
    # TRY THE FOLLOWING
    try: #{
        logging.basicConfig(level=logging.INFO,
                            datefmt="%Y_%M_%d_%H%S%M",
                            filename="C:/data/Logs/CofA_renaming_etc.log",
                            filemode="a")
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        print("TYPE : " + str(exc_type) + "\n")
        print("FILE : " + str(fname) + "\n")
        print("LINE-NO : " + str(exc_tb.tb_lineno) + "\n")
        print("MESSAGE : \n" + str(errorMessage))
    #}
    else: #{
        print("[setup_logger] SUCCESS! VERY NICE!")
    #}
#}

# %%
def create_date_df(the_directory): #{
    # create list of directory
    dir_list = os.listdir(Path(the_directory))
    print("length of [dir_list]: \n" + str((len(dir_list))))
    logging.info("length of [dir_list]: \n" + str((len(dir_list))))
    # create series off list
    d1 = pd.Series(dir_list)
    d1.astype(dtype=np.str)
    # initialize empty DataFrame
    dates_df = pd.DataFrame(data=None, dtype=np.str)
    # assign dir_list to first column
    dates_df["File"] = d1
    # TRY THE FOLLOWING
    try: #{
        # create column var to store the data
        date_col = []
        # counter
        x = 0
        # for each row in the column
        for row in d1: #{
            the_str = str(row)
            the_path = os.path.join(the_directory, the_str)
            # GET MODIFIED TIME
            mtime = os.path.getmtime(the_path)
            # GET CREATE TIME
            ctime = os.path.getctime(the_path)
            # create date var
            # IF CREATE TIME IS OLDER...
            if ctime < mtime: #{
                date_str = str(datetime.fromtimestamp(ctime))
            #}
            else: #{
                date_str = str(datetime.fromtimestamp(mtime))
            #}
            print("CREATE_DATE == " + date_str)
            logging.info("CREATE_DATE == " + date_str)
            x += 1
        #}
        # Create column from list
        dates_df["Create-Date"] = date_col
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        logging.error("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[create_date_df] SUCCESS! VERY NICE!!")
        logging.info("[create_date_df] SUCCESS! VERY NICE!!")
    #}
    return dates_df
#}

# %%
def create_watermark(input_pdf, output, watermark): #{
    # TRY THE FOLLOWING
    try: #{
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)
        
        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()
        
        # WATERMARK ALL THE PAGES
        for page in range(pdf_reader.getNumPages()): #{
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        #}
        
        with open(output, 'wb') as out: #{
            pdf_writer.write(out)
        #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        logging.error("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[create_watermark] SUCCESS! VERY NICE!")
    #}
#}

# %%
def main(): #{
    check_date = pd.Timestamp('2019-03-25')
    # create TEST dataframe
    test_df = create_date_df(the_directory="F:/APPS/CofA/")
    # save to .csv
    test_df.to_csv("C:/data/Logs/TEST_" + str(pd.Timestamp.now())[:10] + ".csv")
    print(check_date)
#}

# %%
# MAIN BOILERPLATE
if __name__ == "__main__": #{
    setup_logger()
    # INSTANTIATE GLOBAL VARIABLES
    in_file = "C:/data/inbound/02OTHER_Rohde Island_Agilent Quality_Digital Letterhead.pdf"
    in_dir_1 = "F:/APPS/CofA/"
    in_dir_2 = "J:/controlled_docs/CofA"
    main()
#}
# Out:
# [setup_logger] SUCCESS! VERY NICE!
# length of [dir_list]:
# 65324
# CREATE_DATE == 2011-06-13 09:22:52.216886
# CREATE_DATE == 2012-05-14 12:48:11.532211
# CREATE_DATE == 2012-05-14 12:48:15.751096
# CREATE_DATE == 2017-06-07 12:18:11.043000
# CREATE_DATE == 2019-05-18 10:42:06.567331
# CREATE_DATE == 2019-08-16 07:03:37.980973
# CREATE_DATE == 2016-06-17 14:02:01.953726
# CREATE_DATE == 2017-01-31 12:51:01.238471
# CREATE_DATE == 2017-09-25 10:14:02.595503
# CREATE_DATE == 2017-05-02 10:43:17.283286
# CREATE_DATE == 2017-06-20 15:38:48.935122
# CREATE_DATE == 2017-06-20 15:39:07.904236
# CREATE_DATE == 2018-01-18 14:08:08.669407
# CREATE_DATE == 2018-01-22 10:59:08.185077
# CREATE_DATE == 2019-05-18 10:42:09.520494
# CREATE_DATE == 2019-08-16 07:03:40.637257
# CREATE_DATE == 2017-01-31 12:51:19.885671
# CREATE_DATE == 2017-05-02 15:17:04.321674
# CREATE_DATE == 2017-06-20 15:38:58.872812
# CREATE_DATE == 2017-06-20 15:39:15.029372
# CREATE_DATE == 2018-01-18 14:08:33.248004
# CREATE_DATE == 2018-01-22 10:59:30.982390
# CREATE_DATE == 2015-07-07 16:56:35.276138
# CREATE_DATE == 2018-04-13 13:36:53.397692
# CREATE_DATE == 2019-08-27 16:42:24.544047
# CREATE_DATE == 2012-03-15 14:01:38.029368
# CREATE_DATE == 2015-06-24 15:17:54.048533
# CREATE_DATE == 2010-06-29 10:37:49.527615
# CREATE_DATE == 2013-12-06 06:26:36.415420
# CREATE_DATE == 2013-12-06 06:26:36.399795
# CREATE_DATE == 2015-04-17 12:59:13.946911
# CREATE_DATE == 2018-01-15 06:57:03.444002
# CREATE_DATE == 2010-06-28 09:10:30.536408
# CREATE_DATE == 2014-07-01 15:58:51.290517
# CREATE_DATE == 2015-08-13 08:57:41.914678
# CREATE_DATE == 2019-03-10 13:24:33.204000
# CREATE_DATE == 2008-06-24 08:37:29.850000
# CREATE_DATE == 2015-03-11 11:31:36.361262
# CREATE_DATE == 2010-06-22 13:08:48.600408
# CREATE_DATE == 2018-02-06 07:49:42.344577
# CREATE_DATE == 2012-03-15 14:11:10.689683
# CREATE_DATE == 2017-04-04 11:39:05.126266
# CREATE_DATE == 2012-03-15 14:11:15.158548
# CREATE_DATE == 2017-04-04 11:39:13.548302
# CREATE_DATE == 2010-07-21 08:16:40.502741
# CREATE_DATE == 2012-11-01 13:24:09.351288
# CREATE_DATE == 2011-05-03 15:56:43.118465
# CREATE_DATE == 2010-10-01 09:05:57.279563
# CREATE_DATE == 2014-04-28 11:27:29.302921
# CREATE_DATE == 2015-12-21 08:00:20.630020
# CREATE_DATE == 2018-01-15 06:56:59.662679
# CREATE_DATE == 2010-08-04 08:32:35.547046
# CREATE_DATE == 2012-11-01 13:24:13.726456
# CREATE_DATE == 2015-01-22 09:28:57.028357
# CREATE_DATE == 2012-03-26 13:48:15.449102
# CREATE_DATE == 2011-05-11 10:51:48.386192
# CREATE_DATE == 2010-10-01 09:06:31.827322
# CREATE_DATE == 2015-02-20 13:14:34.340942
# CREATE_DATE == 2018-04-25 08:16:06.099212
# CREATE_DATE == 2008-12-04 17:04:52.128000
# CREATE_DATE == 2015-03-11 11:27:57.344236
# CREATE_DATE == 2010-06-23 11:24:45.085155
# CREATE_DATE == 2016-03-31 14:00:12.573816
# CREATE_DATE == 2012-11-01 13:23:03.489384
# CREATE_DATE == 2017-12-27 16:40:17.061807
# CREATE_DATE == 2015-01-16 11:19:48.880706
# CREATE_DATE == 2012-11-01 13:23:43.037778
# CREATE_DATE == 2017-12-27 16:40:02.905285
# CREATE_DATE == 2015-03-02 13:21:15.785239
# CREATE_DATE == 2012-11-01 13:25:15.408492
# CREATE_DATE == 2015-09-22 07:50:17.097262
# CREATE_DATE == 2012-03-15 14:01:42.748239
# CREATE_DATE == 2008-11-14 17:07:21.872538
# CREATE_DATE == 2010-06-22 13:04:59.889964
# CREATE_DATE == 2010-10-19 11:33:17.648014
# CREATE_DATE == 2018-05-09 08:20:22.277623
# CREATE_DATE == 2015-10-20 09:29:40.315815
# CREATE_DATE == 2012-05-31 11:08:00.563756
# CREATE_DATE == 2018-05-03 17:20:57.975728
# CREATE_DATE == 2015-10-20 09:29:44.472917
# CREATE_DATE == 2012-05-31 11:08:05.001398
# CREATE_DATE == 2008-05-22 08:54:20.967000
# CREATE_DATE == 2010-09-09 08:29:50.851505
# CREATE_DATE == 2015-07-06 15:48:34.927819
# CREATE_DATE == 2017-05-05 17:06:47.999742
# CREATE_DATE == 2010-07-07 08:04:24.652183
# CREATE_DATE == 2010-06-23 11:23:24.332572
# CREATE_DATE == 2017-12-27 16:39:38.342313
# CREATE_DATE == 2017-08-28 08:25:03.034767
# CREATE_DATE == 2010-08-10 09:37:08.649623
# CREATE_DATE == 2010-06-22 09:48:43.502848
# CREATE_DATE == 2017-06-02 15:13:07.790196
# CREATE_DATE == 2019-08-27 06:36:28.729932
# CREATE_DATE == 2008-06-24 08:38:08.880000
# CREATE_DATE == 2010-06-22 13:07:57.551899
# CREATE_DATE == 2015-08-20 09:33:13.547000
# CREATE_DATE == 2015-08-20 09:33:31.086000
# CREATE_DATE == 2008-01-15 10:18:08.350000
# CREATE_DATE == 2010-07-21 08:17:10.440816
# CREATE_DATE == 2012-12-04 09:51:07.904267
# CREATE_DATE == 2017-04-19 16:28:56.919924
# CREATE_DATE == 2008-09-23 11:17:58.880315
# CREATE_DATE == 2010-07-07 08:05:09.402183
# CREATE_DATE == 2010-11-10 11:44:41.899855
# CREATE_DATE == 2017-02-15 13:02:59.606855
# CREATE_DATE == 2009-10-14 11:57:29.882506
# CREATE_DATE == 2010-08-10 09:36:24.554462
# CREATE_DATE == 2012-09-25 07:34:03.817594
# CREATE_DATE == 2015-07-28 14:44:35.019362
# CREATE_DATE == 2016-01-07 09:19:51.057332
# CREATE_DATE == 2016-05-19 08:26:53.654824
# CREATE_DATE == 2015-09-22 07:50:21.022274
# CREATE_DATE == 2012-03-15 14:01:47.451485
# CREATE_DATE == 2018-01-15 06:55:27.895292
# CREATE_DATE == 2014-12-10 09:25:35.920032
# CREATE_DATE == 2017-04-05 13:59:31.162430
# CREATE_DATE == 2017-06-06 07:37:13.873602
# CREATE_DATE == 2018-12-17 17:14:45.546594
# CREATE_DATE == 2019-08-02 16:35:59.654550
# CREATE_DATE == 2010-06-14 11:03:29.920685
# CREATE_DATE == 2012-03-20 08:08:58.737606
# CREATE_DATE == 2015-04-27 13:46:49.419000
# CREATE_DATE == 2016-11-18 08:34:36.985580
# CREATE_DATE == 2018-10-25 17:13:44.770278
# CREATE_DATE == 2017-12-01 07:56:14.839104
# CREATE_DATE == 2019-10-25 16:15:33.353567
# CREATE_DATE == 2018-03-28 16:46:26.683443
# CREATE_DATE == 2019-04-29 12:39:02.343741
# CREATE_DATE == 2019-06-08 09:00:30.071000
# CREATE_DATE == 2019-06-08 09:01:01.176000
# CREATE_DATE == 2019-07-30 07:02:46.541996
# CREATE_DATE == 2019-09-10 11:16:58.369251
# CREATE_DATE == 2019-04-29 12:39:02.374991
# CREATE_DATE == 2019-05-18 11:06:48.039418
# CREATE_DATE == 2019-07-02 10:30:06.199235
# CREATE_DATE == 2019-08-06 07:20:03.179621
# CREATE_DATE == 2019-09-25 06:51:51.330655
# CREATE_DATE == 2018-09-14 12:07:34.942323
# CREATE_DATE == 2018-11-06 11:12:55.699826
# CREATE_DATE == 2018-12-10 12:17:55.984941
# CREATE_DATE == 2018-12-13 10:06:45.404277
# CREATE_DATE == 2018-12-27 15:36:00.949741
# CREATE_DATE == 2019-03-05 12:18:50.360203
# CREATE_DATE == 2019-03-08 10:30:12.598049
# CREATE_DATE == 2019-11-19 16:24:09.994083
# CREATE_DATE == 2010-08-05 17:18:50.260430
# CREATE_DATE == 2012-11-21 08:51:18.760546
# CREATE_DATE == 2015-04-22 16:02:43.214000
# CREATE_DATE == 2017-10-13 06:43:42.244623
# CREATE_DATE == 2010-09-08 16:34:31.936587
# CREATE_DATE == 2010-09-08 16:35:11.701957
# CREATE_DATE == 2010-09-08 16:35:55.967299
# CREATE_DATE == 2010-09-08 16:36:37.482658
# CREATE_DATE == 2010-09-08 16:37:24.310483
# CREATE_DATE == 2010-09-08 16:38:00.294628
# CREATE_DATE == 2010-09-08 16:39:30.684675
# CREATE_DATE == 2010-09-08 16:40:43.856081
# CREATE_DATE == 2010-09-08 16:41:26.637057
# CREATE_DATE == 2019-10-04 10:19:54.160736
# CREATE_DATE == 2019-10-10 12:26:20.438723
# CREATE_DATE == 2019-11-04 15:22:40.652966
# CREATE_DATE == 2019-11-15 07:50:21.279383
# CREATE_DATE == 2019-10-23 07:32:53.757940
# CREATE_DATE == 2019-09-27 07:20:29.160259
# CREATE_DATE == 2019-11-07 14:21:17.273129
# CREATE_DATE == 2019-11-13 07:23:42.766743
# CREATE_DATE == 2019-10-29 08:03:39.196290
# CREATE_DATE == 2019-11-22 16:28:32.063863
# CREATE_DATE == 2019-11-14 07:08:09.479369
# CREATE_DATE == 2019-01-29 11:18:05.776238
# CREATE_DATE == 2019-11-22 16:30:50.846889
# CREATE_DATE == 2019-10-31 07:43:51.123026
# CREATE_DATE == 2019-10-31 08:05:04.858079
# CREATE_DATE == 2019-10-04 16:10:55.419376
# CREATE_DATE == 2019-11-01 09:44:12.578737
# CREATE_DATE == 2018-11-16 09:46:21.587649
# CREATE_DATE == 2018-11-16 09:46:42.681804
# CREATE_DATE == 2018-11-19 09:10:03.528676
# CREATE_DATE == 2018-11-16 09:47:40.120407
# CREATE_DATE == 2019-11-22 16:23:06.910055
# CREATE_DATE == 2019-06-05 16:56:09.759203
# CREATE_DATE == 2010-06-16 12:06:24.540131
# CREATE_DATE == 2011-06-07 11:59:19.381043
# CREATE_DATE == 2013-06-10 08:10:14.665111
# CREATE_DATE == 2015-04-17 15:16:10.038000
# CREATE_DATE == 2015-08-12 16:20:02.044000
# CREATE_DATE == 2015-08-04 16:25:31.300494
# CREATE_DATE == 2016-05-26 12:35:24.333227
# CREATE_DATE == 2017-05-01 17:19:41.575045
# CREATE_DATE == 2018-05-08 07:15:23.582462
# CREATE_DATE == 2018-02-21 08:15:20.930007
# CREATE_DATE == 2018-12-04 17:57:05.368067
# CREATE_DATE == 2016-11-09 17:10:08.328944
# CREATE_DATE == 2017-01-04 10:04:19.339895
# CREATE_DATE == 2010-06-23 08:42:54.159457
# CREATE_DATE == 2010-07-22 08:58:51.084955
# CREATE_DATE == 2011-06-29 09:00:45.679923
# CREATE_DATE == 2019-02-23 09:57:22.262000
# CREATE_DATE == 2015-04-28 23:08:43.062886
# CREATE_DATE == 2016-03-22 08:27:21.907157
# CREATE_DATE == 2017-10-27 07:42:47.212388
# CREATE_DATE == 2010-06-23 08:43:22.019724
# CREATE_DATE == 2010-07-22 15:49:56.616139
# CREATE_DATE == 2011-12-16 17:13:53.602019
# CREATE_DATE == 2019-07-10 16:30:52.713197
# CREATE_DATE == 2012-04-30 09:37:48.176909
# CREATE_DATE == 2015-04-29 10:06:16.726546
# CREATE_DATE == 2017-02-24 11:54:04.075804
# CREATE_DATE == 2010-09-08 13:58:48.817949
# CREATE_DATE == 2010-10-07 15:05:37.931437
# CREATE_DATE == 2011-12-02 08:54:31.192477
# CREATE_DATE == 2013-02-06 17:26:55.524311
# CREATE_DATE == 2014-04-09 07:32:50.664685
# CREATE_DATE == 2016-01-06 14:59:36.844008
# CREATE_DATE == 2019-04-04 09:51:03.595000
# CREATE_DATE == 2019-06-11 07:27:16.911546
# CREATE_DATE == 2019-08-13 16:16:30.687075
# CREATE_DATE == 2019-10-30 16:27:10.669439
# CREATE_DATE == 2010-07-19 09:05:57.539097
# CREATE_DATE == 2010-11-10 11:39:08.495739
# CREATE_DATE == 2011-01-05 08:56:57.612783
# CREATE_DATE == 2011-05-03 08:24:58.282776
# CREATE_DATE == 2011-08-09 09:17:57.569052
# CREATE_DATE == 2011-12-01 13:21:25.642171
# CREATE_DATE == 2012-05-01 07:46:57.001415
# CREATE_DATE == 2012-09-24 09:25:41.107714
# CREATE_DATE == 2012-11-06 10:57:41.358584
# CREATE_DATE == 2015-04-29 10:08:52.476546
# CREATE_DATE == 2015-06-05 13:54:04.857831
# CREATE_DATE == 2015-10-23 16:48:38.658423
# CREATE_DATE == 2015-12-16 15:01:55.741868
# CREATE_DATE == 2016-02-18 12:29:34.511384
# CREATE_DATE == 2016-04-18 12:06:50.719883
# CREATE_DATE == 2016-06-24 09:12:01.236142
# CREATE_DATE == 2016-09-09 14:05:46.754248
# CREATE_DATE == 2017-02-01 10:42:34.640764
# CREATE_DATE == 2017-03-20 13:23:38.678945
# CREATE_DATE == 2017-06-16 15:42:24.546405
# CREATE_DATE == 2017-08-22 16:43:16.710155
# CREATE_DATE == 2017-12-04 07:38:18.936621
# CREATE_DATE == 2018-03-28 08:32:12.603521
# CREATE_DATE == 2018-09-24 06:41:27.713953
# CREATE_DATE == 2019-10-17 16:21:37.866526
# CREATE_DATE == 2010-11-10 11:38:45.542760
# CREATE_DATE == 2011-07-11 12:54:06.372368
# CREATE_DATE == 2012-05-01 07:46:52.142156
# CREATE_DATE == 2015-04-20 14:29:59.964000
# CREATE_DATE == 2015-12-17 08:39:12.684060
# CREATE_DATE == 2016-10-07 09:27:27.797303
# CREATE_DATE == 2017-08-29 12:06:40.915000
# CREATE_DATE == 2018-05-03 06:55:39.690627
# CREATE_DATE == 2019-03-07 08:36:24.899000
# CREATE_DATE == 2010-06-18 15:03:44.476758
# CREATE_DATE == 2011-03-31 09:08:12.337836
# CREATE_DATE == 2011-11-11 08:44:42.291783
# CREATE_DATE == 2015-04-28 10:59:02.730801
# CREATE_DATE == 2015-05-19 11:17:54.799000
# CREATE_DATE == 2017-06-17 12:41:24.656020
# CREATE_DATE == 2018-12-18 17:17:45.707854
# CREATE_DATE == 2019-01-03 17:21:41.390659
# CREATE_DATE == 2010-07-02 09:03:13.222603
# CREATE_DATE == 2012-08-21 08:35:31.086082
# CREATE_DATE == 2015-04-29 10:10:35.085921
# CREATE_DATE == 2016-09-26 09:08:16.459713
# CREATE_DATE == 2010-07-27 13:39:04.351461
# CREATE_DATE == 2011-12-15 16:39:29.293957
# CREATE_DATE == 2015-04-29 10:10:45.898421
# CREATE_DATE == 2018-01-09 06:58:19.310870
# CREATE_DATE == 2019-04-23 09:01:43.637713
# CREATE_DATE == 2019-05-28 16:27:01.017074
# CREATE_DATE == 2019-06-24 16:47:06.596066
# CREATE_DATE == 2019-07-26 16:45:55.593385
# CREATE_DATE == 2019-08-23 16:35:42.018438
# CREATE_DATE == 2019-09-23 16:42:15.977595
# CREATE_DATE == 2019-10-24 16:20:50.692841
# CREATE_DATE == 2019-11-21 16:17:46.607098
# CREATE_DATE == 2015-04-01 12:09:11.486419
# CREATE_DATE == 2011-04-20 09:55:15.218338
# CREATE_DATE == 2011-06-30 09:03:17.739158
# CREATE_DATE == 2011-08-24 08:48:21.307134
# CREATE_DATE == 2010-06-15 11:56:19.502609
# CREATE_DATE == 2010-06-29 10:39:40.564550
# CREATE_DATE == 2010-08-03 16:24:08.046686
# CREATE_DATE == 2010-08-30 15:18:54.373320
# CREATE_DATE == 2010-09-29 11:53:35.500761
# CREATE_DATE == 2010-10-29 14:52:53.803594
# CREATE_DATE == 2010-12-01 11:18:44.164484
# CREATE_DATE == 2010-12-29 10:33:37.066283
# CREATE_DATE == 2011-02-02 10:00:23.184966
# CREATE_DATE == 2011-02-28 13:23:05.013680
# CREATE_DATE == 2011-03-29 09:10:16.083756
# CREATE_DATE == 2011-04-27 09:08:34.556930
# CREATE_DATE == 2011-05-31 09:16:21.599298
# CREATE_DATE == 2011-06-24 09:12:00.578422
# CREATE_DATE == 2011-08-01 08:06:23.151051
# CREATE_DATE == 2011-09-02 09:08:57.575452
# CREATE_DATE == 2011-09-30 09:17:19.167333
# CREATE_DATE == 2011-10-28 09:10:57.720566
# CREATE_DATE == 2011-12-05 09:02:58.713539
# CREATE_DATE == 2012-01-06 08:54:05.822445
# CREATE_DATE == 2012-02-01 09:11:11.189577
# CREATE_DATE == 2012-03-05 08:06:13.650924
# CREATE_DATE == 2012-04-03 11:01:18.547845
# CREATE_DATE == 2012-04-03 11:43:59.470239
# CREATE_DATE == 2012-05-07 08:41:37.890141
# CREATE_DATE == 2012-05-25 07:47:43.173155
# CREATE_DATE == 2012-06-21 11:11:59.775779
# CREATE_DATE == 2012-07-02 08:36:27.145017
# CREATE_DATE == 2012-08-27 08:12:35.549705
# CREATE_DATE == 2012-09-27 07:27:37.378006
# CREATE_DATE == 2012-11-07 07:28:14.190731
# CREATE_DATE == 2012-11-29 07:36:33.447472
# CREATE_DATE == 2013-01-07 07:52:49.366668
# CREATE_DATE == 2013-06-24 08:28:39.321219
# CREATE_DATE == 2014-01-17 15:30:09.648410
# CREATE_DATE == 2015-04-29 11:10:49.757796
# CREATE_DATE == 2015-04-29 11:10:58.335921
# CREATE_DATE == 2015-04-29 11:11:00.554671
# CREATE_DATE == 2015-05-01 08:57:34.255000
# CREATE_DATE == 2015-06-01 11:36:17.824000
# CREATE_DATE == 2015-06-30 12:25:29.592199
# CREATE_DATE == 2015-07-29 09:23:25.992877
# CREATE_DATE == 2015-08-27 09:20:37.938570
# CREATE_DATE == 2015-09-25 08:49:25.457213
# CREATE_DATE == 2015-11-02 09:14:56.282815
# CREATE_DATE == 2015-12-01 09:33:50.836144
# CREATE_DATE == 2015-12-29 12:05:24.265688
# CREATE_DATE == 2016-01-27 12:37:59.810581
# CREATE_DATE == 2016-02-25 08:44:33.892247
# CREATE_DATE == 2016-03-28 09:26:07.529545
# CREATE_DATE == 2016-04-27 11:48:59.127812
# CREATE_DATE == 2016-05-27 12:14:48.771675
# CREATE_DATE == 2016-07-05 09:25:21.260399
# CREATE_DATE == 2016-07-28 08:28:51.838356
# CREATE_DATE == 2016-08-24 07:58:48.208226
# CREATE_DATE == 2016-09-26 14:49:57.472123
# CREATE_DATE == 2016-10-24 13:20:43.884896
# CREATE_DATE == 2016-11-23 13:41:05.568958
# CREATE_DATE == 2016-12-20 17:09:00.385707
# CREATE_DATE == 2017-01-31 14:26:00.088200
# CREATE_DATE == 2017-02-27 13:25:40.250011
# CREATE_DATE == 2017-03-29 13:34:34.911774
# CREATE_DATE == 2017-04-27 17:29:51.497073
# CREATE_DATE == 2017-06-01 07:39:26.603969
# CREATE_DATE == 2017-06-29 09:34:17.070328
# CREATE_DATE == 2017-07-28 17:04:53.950768
# CREATE_DATE == 2017-08-31 08:50:22.836691
# CREATE_DATE == 2017-10-03 06:43:34.228446
# CREATE_DATE == 2017-11-02 08:05:50.685262
# CREATE_DATE == 2017-12-01 09:02:49.765381
# CREATE_DATE == 2018-01-03 08:44:17.666805
# CREATE_DATE == 2018-01-29 06:54:49.552513
# CREATE_DATE == 2018-03-03 07:41:40.635523
# CREATE_DATE == 2018-03-30 07:52:44.914130
# CREATE_DATE == 2018-05-03 17:22:35.867605
# CREATE_DATE == 2018-06-05 07:31:40.852810
# CREATE_DATE == 2018-07-09 17:03:45.154992
# CREATE_DATE == 2018-08-02 08:10:39.482707
# CREATE_DATE == 2018-09-07 08:12:03.374652
# CREATE_DATE == 2018-10-04 08:53:27.387526
# CREATE_DATE == 2018-11-09 07:30:09.967337
# CREATE_DATE == 2018-12-17 17:15:35.875363
# CREATE_DATE == 2019-01-07 17:41:01.058908
# CREATE_DATE == 2019-02-05 13:39:49.150000
# CREATE_DATE == 2019-03-08 08:08:21.630000
# CREATE_DATE == 2019-04-23 09:01:46.747128
# CREATE_DATE == 2019-06-10 06:25:12.666449
# CREATE_DATE == 2019-06-25 16:42:46.741373
# CREATE_DATE == 2019-07-26 16:45:52.890225
# CREATE_DATE == 2019-08-23 16:35:39.268402
# CREATE_DATE == 2019-09-23 16:42:18.852632
# CREATE_DATE == 2019-10-24 16:20:42.536487
# CREATE_DATE == 2019-11-21 16:18:00.216647
# CREATE_DATE == 2018-01-03 08:44:24.698190
# CREATE_DATE == 2018-01-29 06:53:02.441081
# CREATE_DATE == 2018-03-03 07:41:16.416308
# CREATE_DATE == 2018-03-30 07:52:52.211099
# CREATE_DATE == 2018-05-03 17:22:43.664580
# CREATE_DATE == 2018-06-05 07:31:26.462000
# CREATE_DATE == 2018-07-09 17:03:52.373834
# CREATE_DATE == 2018-08-02 08:10:48.279695
# CREATE_DATE == 2018-09-07 08:12:35.687773
# CREATE_DATE == 2018-10-04 08:53:21.309284
# CREATE_DATE == 2018-11-09 07:30:30.545725
# CREATE_DATE == 2018-12-17 17:15:23.250202
# CREATE_DATE == 2019-01-07 17:41:43.231322
# CREATE_DATE == 2019-02-14 18:19:37.864000
# CREATE_DATE == 2019-03-08 13:40:16.321000
# CREATE_DATE == 2017-06-22 16:56:49.579746
# CREATE_DATE == 2017-08-31 08:50:10.242699
# CREATE_DATE == 2017-10-11 07:24:17.527232
# CREATE_DATE == 2017-11-02 08:05:42.232029
# CREATE_DATE == 2017-12-01 08:06:15.926424
# CREATE_DATE == 2019-04-23 09:01:49.731541
# CREATE_DATE == 2019-06-10 06:25:09.853913
# CREATE_DATE == 2019-06-24 16:47:03.189773
# CREATE_DATE == 2019-07-26 16:45:50.124565
# CREATE_DATE == 2019-08-23 16:35:36.471492
# CREATE_DATE == 2019-09-23 16:42:21.790169
# CREATE_DATE == 2019-10-24 16:20:34.630136
# CREATE_DATE == 2019-11-21 16:18:14.560581
# CREATE_DATE == 2018-01-05 07:20:06.183211
# CREATE_DATE == 2018-01-29 06:53:10.675614
# CREATE_DATE == 2018-03-06 06:38:36.154850
# CREATE_DATE == 2018-04-03 07:29:30.098750
# CREATE_DATE == 2018-05-07 08:01:54.168950
# CREATE_DATE == 2018-06-05 07:30:45.195847
# CREATE_DATE == 2018-07-09 17:04:22.561721
# CREATE_DATE == 2018-08-02 08:10:21.169973
# CREATE_DATE == 2018-09-07 08:13:43.814080
# CREATE_DATE == 2018-10-04 16:32:12.398046
# CREATE_DATE == 2018-11-09 07:30:39.311462
# CREATE_DATE == 2018-12-17 17:15:01.187419
# CREATE_DATE == 2019-01-07 17:41:28.387382
# CREATE_DATE == 2019-02-05 13:33:25.598000
# CREATE_DATE == 2017-11-03 06:57:24.727602
# CREATE_DATE == 2017-12-01 09:10:47.121000
# CREATE_DATE == 2019-03-08 08:07:37.955000
# CREATE_DATE == 2010-06-30 14:15:02.794855
# CREATE_DATE == 2012-05-23 09:48:18.308487
# CREATE_DATE == 2015-04-21 10:24:04.705241
# CREATE_DATE == 2016-04-27 11:47:45.579525
# CREATE_DATE == 2018-01-16 07:05:12.103603
# CREATE_DATE == 2019-11-21 16:20:09.671429
# CREATE_DATE == 2018-06-11 17:44:54.981297
# CREATE_DATE == 2017-01-31 16:18:30.418644
# CREATE_DATE == 2017-01-31 16:18:06.277555
# CREATE_DATE == 2010-12-27 14:54:08.375632
# CREATE_DATE == 2011-11-30 09:52:21.354908
# CREATE_DATE == 2015-04-29 11:11:05.601546
# CREATE_DATE == 2018-03-08 07:22:51.315849
# CREATE_DATE == 2010-06-15 17:01:42.348341
# CREATE_DATE == 2015-04-29 11:11:09.726546
# CREATE_DATE == 2017-07-14 08:13:12.142560
# CREATE_DATE == 2011-06-17 09:25:21.092985
# CREATE_DATE == 2015-04-29 11:11:18.492171
# CREATE_DATE == 2015-08-17 08:27:08.188307
# CREATE_DATE == 2019-06-12 16:47:11.419738
# CREATE_DATE == 2010-08-18 16:09:53.674604
# CREATE_DATE == 2010-11-29 10:10:47.575596
# CREATE_DATE == 2015-04-20 08:47:12.259000
# CREATE_DATE == 2015-10-16 10:02:55.283126
# CREATE_DATE == 2016-03-30 06:57:45.586824
# CREATE_DATE == 2018-03-08 07:22:58.956620
# CREATE_DATE == 2019-05-04 08:44:27.376451
# CREATE_DATE == 2011-02-17 08:40:15.682888
# CREATE_DATE == 2015-05-07 14:18:59.733000
# CREATE_DATE == 2010-11-08 08:27:16.222780
# CREATE_DATE == 2012-02-22 17:34:34.816564
# CREATE_DATE == 2015-04-29 11:11:27.023421
# CREATE_DATE == 2018-03-08 07:22:42.253175
# CREATE_DATE == 2019-06-11 16:27:41.874632
# CREATE_DATE == 2010-06-15 12:30:36.463516
# CREATE_DATE == 2011-03-10 09:05:52.502106
# CREATE_DATE == 2012-04-09 08:13:39.670247
# CREATE_DATE == 2015-04-29 11:11:35.445296
# CREATE_DATE == 2016-03-30 06:57:50.465242
# CREATE_DATE == 2019-09-17 16:33:23.357888
# CREATE_DATE == 2010-07-09 14:58:33.528066
# CREATE_DATE == 2011-12-12 11:46:28.894024
# CREATE_DATE == 2015-04-29 11:11:43.960921
# CREATE_DATE == 2017-07-05 07:46:01.935594
# CREATE_DATE == 2010-07-09 14:59:02.857130
# CREATE_DATE == 2011-08-16 08:45:13.879208
# CREATE_DATE == 2012-03-07 08:01:30.825141
# CREATE_DATE == 2015-04-28 12:49:53.760000
# CREATE_DATE == 2017-07-06 07:33:23.732238
# CREATE_DATE == 2010-06-23 08:08:25.057163
# CREATE_DATE == 2011-12-16 08:11:02.655242
# CREATE_DATE == 2015-04-15 21:37:14.642000
# CREATE_DATE == 2018-10-15 17:14:31.506087
# CREATE_DATE == 2010-06-23 08:08:01.087646
# CREATE_DATE == 2011-12-16 08:11:12.171172
# CREATE_DATE == 2015-04-29 11:11:52.460921
# CREATE_DATE == 2015-12-08 11:54:34.464398
# CREATE_DATE == 2018-01-09 06:58:10.529452
# CREATE_DATE == 2019-09-10 16:45:36.989878
# CREATE_DATE == 2010-06-23 08:08:50.026712
# CREATE_DATE == 2011-06-17 09:24:46.591660
# CREATE_DATE == 2015-04-29 11:12:01.054671
# CREATE_DATE == 2015-07-30 13:10:35.208381
# CREATE_DATE == 2018-12-26 17:30:03.463187
# CREATE_DATE == 2015-04-17 08:33:16.872000
# CREATE_DATE == 2019-09-13 16:31:49.103026
# CREATE_DATE == 2017-02-02 15:49:20.941139
# CREATE_DATE == 2017-02-02 15:49:42.894685
# CREATE_DATE == 2010-09-10 08:25:10.673811
# CREATE_DATE == 2012-05-23 09:48:09.401952
# CREATE_DATE == 2015-04-29 11:12:09.945296
# CREATE_DATE == 2015-08-25 09:47:33.782587
# CREATE_DATE == 2016-07-01 12:14:40.228882
# CREATE_DATE == 2016-08-18 10:56:58.779224
# CREATE_DATE == 2019-03-14 15:15:34.571113
# CREATE_DATE == 2018-03-16 07:23:20.498140
# CREATE_DATE == 2017-02-02 15:50:04.473224
# CREATE_DATE == 2018-10-17 17:03:18.274204
# CREATE_DATE == 2017-02-02 15:50:45.583389
# CREATE_DATE == 2010-06-29 13:58:26.303781
# CREATE_DATE == 2011-04-27 10:18:36.450258
# CREATE_DATE == 2012-03-30 08:50:31.622346
# CREATE_DATE == 2015-04-29 11:12:18.851546
# CREATE_DATE == 2015-06-10 14:52:26.629000
# CREATE_DATE == 2015-06-17 08:31:58.401578
# CREATE_DATE == 2017-09-20 13:06:18.224201
# CREATE_DATE == 2019-09-13 16:31:53.181203
# CREATE_DATE == 2010-06-14 12:15:47.458410
# CREATE_DATE == 2011-07-18 09:02:49.139814
# CREATE_DATE == 2015-04-29 11:12:27.710921
# CREATE_DATE == 2016-05-26 09:00:22.677800
# CREATE_DATE == 2017-06-15 07:25:41.006641
# CREATE_DATE == 2019-09-13 16:31:57.025002
# CREATE_DATE == 2010-06-30 10:08:30.840420
# CREATE_DATE == 2010-07-20 12:48:38.542398
# CREATE_DATE == 2012-08-22 13:32:21.074171
# CREATE_DATE == 2015-04-29 11:12:36.460921
# CREATE_DATE == 2015-07-07 08:19:56.155478
# CREATE_DATE == 2017-10-31 14:52:55.148097
# CREATE_DATE == 2010-06-30 16:07:56.603872
# CREATE_DATE == 2019-04-23 09:01:52.950332
# CREATE_DATE == 2019-06-11 07:26:28.504676
# CREATE_DATE == 2019-06-25 16:42:52.678949
# CREATE_DATE == 2019-07-26 16:46:04.202870
# CREATE_DATE == 2019-08-23 16:35:56.456122
# CREATE_DATE == 2019-09-23 16:42:24.805833
# CREATE_DATE == 2019-10-24 16:21:25.630788
# CREATE_DATE == 2019-11-21 16:18:26.670111
# CREATE_DATE == 2010-07-14 11:42:51.662386
# CREATE_DATE == 2010-06-29 10:39:05.547132
# CREATE_DATE == 2010-07-28 08:53:26.351118
# CREATE_DATE == 2010-08-30 15:19:28.671073
# CREATE_DATE == 2010-09-01 08:25:11.969937
# CREATE_DATE == 2010-09-27 15:53:24.600658
# CREATE_DATE == 2010-10-29 14:54:23.834324
# CREATE_DATE == 2010-12-01 11:19:12.102520
# CREATE_DATE == 2010-12-29 10:33:59.082049
# CREATE_DATE == 2011-02-02 10:00:50.294862
# CREATE_DATE == 2011-03-01 08:40:13.556734
# CREATE_DATE == 2011-03-29 09:10:21.318165
# CREATE_DATE == 2011-04-27 09:08:39.869566
# CREATE_DATE == 2011-05-31 09:16:26.365106
# CREATE_DATE == 2011-06-24 09:12:05.516112
# CREATE_DATE == 2011-08-01 08:06:27.963736
# CREATE_DATE == 2011-09-02 09:09:03.012987
# CREATE_DATE == 2011-09-30 09:17:24.667545
# CREATE_DATE == 2011-10-28 09:11:03.205116
# CREATE_DATE == 2011-12-05 09:03:03.135527
# CREATE_DATE == 2012-01-06 08:54:11.135115
# CREATE_DATE == 2012-02-01 09:08:26.282272
# CREATE_DATE == 2012-03-05 08:06:18.979118
# CREATE_DATE == 2012-04-03 10:59:53.952636
# CREATE_DATE == 2012-05-02 11:32:12.597782
# CREATE_DATE == 2012-05-25 07:47:12.001542
# CREATE_DATE == 2012-07-02 08:36:31.535867
# CREATE_DATE == 2012-08-27 08:12:42.784407
# CREATE_DATE == 2012-09-26 07:41:13.572222
# CREATE_DATE == 2012-11-08 14:54:50.271195
# CREATE_DATE == 2012-11-29 07:36:37.728886
# CREATE_DATE == 2013-01-07 07:52:53.616831
# CREATE_DATE == 2013-09-19 11:18:13.989951
# CREATE_DATE == 2015-04-23 13:59:41.123000
# CREATE_DATE == 2015-05-01 10:51:47.634000
# CREATE_DATE == 2015-06-01 11:36:44.639000
# CREATE_DATE == 2015-06-30 12:26:07.362175
# CREATE_DATE == 2015-07-29 09:23:30.367905
# CREATE_DATE == 2015-08-27 10:34:44.029525
# CREATE_DATE == 2015-09-25 08:49:30.301522
# CREATE_DATE == 2015-11-02 08:31:01.515953
# CREATE_DATE == 2015-12-01 09:33:54.851795
# CREATE_DATE == 2015-12-29 12:05:28.515716
# CREATE_DATE == 2016-01-27 12:37:55.529331
# CREATE_DATE == 2016-02-25 08:44:38.687679
# CREATE_DATE == 2016-03-28 09:26:01.531514
# CREATE_DATE == 2016-04-27 11:48:52.737064
# CREATE_DATE == 2016-05-27 12:14:55.348588
# CREATE_DATE == 2016-07-05 09:25:26.385464
# CREATE_DATE == 2016-07-28 08:28:46.400751
# CREATE_DATE == 2016-08-24 07:58:15.301555
# CREATE_DATE == 2016-09-26 14:50:03.675327
# CREATE_DATE == 2016-10-24 13:18:19.945554
# CREATE_DATE == 2016-11-23 13:41:13.256556
# CREATE_DATE == 2016-12-21 09:17:44.623000
# CREATE_DATE == 2017-01-31 16:17:00.338789
# CREATE_DATE == 2017-02-27 13:27:56.268248
# CREATE_DATE == 2017-03-29 13:34:42.646298
# CREATE_DATE == 2017-04-27 17:29:59.950414
# CREATE_DATE == 2017-06-01 07:39:34.369693
# CREATE_DATE == 2017-06-29 09:34:23.523536
# CREATE_DATE == 2017-07-31 08:19:07.416722
# CREATE_DATE == 2017-08-31 08:50:34.290036
# CREATE_DATE == 2017-10-03 06:43:37.931643
# CREATE_DATE == 2017-11-02 08:05:46.903964
# CREATE_DATE == 2017-12-01 08:04:42.770897
# CREATE_DATE == 2018-01-03 08:44:29.292028
# CREATE_DATE == 2018-01-29 06:53:14.675691
# CREATE_DATE == 2018-03-03 07:41:20.478886
# CREATE_DATE == 2018-03-30 07:52:56.226775
# CREATE_DATE == 2018-05-03 17:22:28.117506
# CREATE_DATE == 2018-06-05 07:30:38.102006
# CREATE_DATE == 2018-07-09 17:03:56.936393
# CREATE_DATE == 2018-08-02 08:10:54.123519
# CREATE_DATE == 2018-09-07 08:12:09.437268
# CREATE_DATE == 2018-10-04 08:52:59.324487
# CREATE_DATE == 2018-11-12 07:46:13.156973
# CREATE_DATE == 2018-12-17 17:15:29.531532
# CREATE_DATE == 2019-01-07 17:41:07.168361
# CREATE_DATE == 2019-02-05 13:39:07.172000
# CREATE_DATE == 2019-03-08 08:39:24.394000
# CREATE_DATE == 2019-04-23 09:01:55.700367
# CREATE_DATE == 2019-06-05 16:55:57.852801
# CREATE_DATE == 2019-06-24 16:47:10.221113
# CREATE_DATE == 2019-07-26 16:46:01.218457
# CREATE_DATE == 2019-08-23 16:35:53.565460
# CREATE_DATE == 2019-09-26 16:13:16.241346
# CREATE_DATE == 2019-10-30 16:27:53.513737
# CREATE_DATE == 2019-11-21 16:18:38.873392
# CREATE_DATE == 2010-06-17 11:01:26.456757
# CREATE_DATE == 2010-06-29 12:04:06.275760
# CREATE_DATE == 2010-08-30 15:21:40.815081
# CREATE_DATE == 2010-09-29 11:54:51.501734
# CREATE_DATE == 2010-11-03 09:05:40.996615
# CREATE_DATE == 2010-12-01 11:24:28.483594
# CREATE_DATE == 2010-12-29 10:35:12.754396
# CREATE_DATE == 2011-02-03 13:34:10.370602
# CREATE_DATE == 2011-03-02 09:41:56.040731
# CREATE_DATE == 2011-04-04 08:30:43.083190
# CREATE_DATE == 2011-04-27 09:09:00.541970
# CREATE_DATE == 2011-05-31 09:16:49.522245
# CREATE_DATE == 2011-07-05 08:42:09.544688
# CREATE_DATE == 2011-08-03 08:41:20.127160
# CREATE_DATE == 2011-09-02 09:08:52.247293
# CREATE_DATE == 2011-10-06 08:48:09.922299
# CREATE_DATE == 2011-10-28 09:11:24.908936
# CREATE_DATE == 2011-12-05 09:03:11.917001
# CREATE_DATE == 2012-01-09 14:38:40.752804
# CREATE_DATE == 2012-02-01 09:08:47.360532
# CREATE_DATE == 2012-03-05 08:06:40.166889
# CREATE_DATE == 2012-04-04 08:54:39.625609
# CREATE_DATE == 2012-05-03 07:44:17.379592
# CREATE_DATE == 2012-05-25 07:47:07.532649
# CREATE_DATE == 2012-07-05 07:42:01.531585
# CREATE_DATE == 2012-08-27 08:13:01.175973
# CREATE_DATE == 2012-09-26 07:40:15.725510
# CREATE_DATE == 2012-11-09 08:55:27.642942
# CREATE_DATE == 2012-12-04 10:22:35.336630
# CREATE_DATE == 2013-01-08 08:23:49.624056
# CREATE_DATE == 2015-04-17 14:37:06.451000
# CREATE_DATE == 2015-05-29 14:13:01.695000
# CREATE_DATE == 2015-06-30 12:22:55.277549
# CREATE_DATE == 2015-07-29 09:23:47.711766
# CREATE_DATE == 2015-08-27 10:34:52.592080
# CREATE_DATE == 2015-09-25 08:49:47.459748
# CREATE_DATE == 2015-11-02 08:30:57.594053
# CREATE_DATE == 2015-12-01 09:33:58.836195
# CREATE_DATE == 2015-12-30 11:22:49.516000
# CREATE_DATE == 2016-01-28 08:59:24.874001
# CREATE_DATE == 2016-02-25 08:46:17.985926
# CREATE_DATE == 2016-03-29 09:44:09.285874
# CREATE_DATE == 2016-04-27 11:47:52.017148
# CREATE_DATE == 2016-05-27 12:15:14.829962
# CREATE_DATE == 2016-07-05 09:25:43.541934
# CREATE_DATE == 2016-07-28 08:32:29.373782
# CREATE_DATE == 2016-08-24 15:22:04.156296
# CREATE_DATE == 2016-09-26 13:07:00.924314
# CREATE_DATE == 2016-10-27 08:55:18.113206
# CREATE_DATE == 2016-12-01 06:28:57.296906
# CREATE_DATE == 2016-12-21 16:39:55.027641
# CREATE_DATE == 2017-01-31 16:17:33.870683
# CREATE_DATE == 2017-02-28 12:05:17.376815
# CREATE_DATE == 2017-03-29 17:09:06.243706
# CREATE_DATE == 2017-04-28 16:49:58.510529
# CREATE_DATE == 2017-06-01 07:39:02.134906
# CREATE_DATE == 2017-06-29 09:35:06.258458
# CREATE_DATE == 2017-07-31 08:19:26.463840
# CREATE_DATE == 2017-08-31 08:50:14.649034
# CREATE_DATE == 2017-10-03 06:43:56.275745
# CREATE_DATE == 2017-11-03 06:57:45.477867
# CREATE_DATE == 2017-12-01 08:47:06.716025
# CREATE_DATE == 2018-01-05 07:20:11.527063
# CREATE_DATE == 2018-01-29 06:55:05.974703
# CREATE_DATE == 2018-03-06 06:38:25.170264
# CREATE_DATE == 2018-04-03 07:29:33.989425
# CREATE_DATE == 2018-05-07 08:01:58.465879
# CREATE_DATE == 2018-06-05 07:30:49.117772
# CREATE_DATE == 2018-07-09 17:04:15.624132
# CREATE_DATE == 2018-08-02 08:10:27.216925
# CREATE_DATE == 2018-09-07 08:12:53.953748
# CREATE_DATE == 2018-10-04 16:32:03.726005
# CREATE_DATE == 2018-11-09 07:31:00.186730
# CREATE_DATE == 2018-12-17 17:15:07.546876
# CREATE_DATE == 2019-01-07 17:41:34.528086
# CREATE_DATE == 2019-02-25 13:01:43.297000
# CREATE_DATE == 2019-03-08 08:40:28.679000
# CREATE_DATE == 2016-11-01 13:30:46.493000
# CREATE_DATE == 2016-12-21 09:17:08.511000
# CREATE_DATE == 2017-07-31 08:25:48.703108
# CREATE_DATE == 2017-08-31 09:05:55.010838
# CREATE_DATE == 2017-10-03 06:43:45.103655
# CREATE_DATE == 2017-11-02 08:31:11.470353
# CREATE_DATE == 2017-12-01 08:44:30.869282
# CREATE_DATE == 2018-01-03 08:51:52.831794
# CREATE_DATE == 2018-01-29 06:53:23.753990
# CREATE_DATE == 2018-03-06 06:36:53.137247
# CREATE_DATE == 2019-04-22 11:49:08.357308
# CREATE_DATE == 2019-04-22 11:49:10.872966
# CREATE_DATE == 2019-06-05 16:55:51.868349
# CREATE_DATE == 2019-06-05 16:55:54.805887
# CREATE_DATE == 2019-06-25 16:43:10.429176
# CREATE_DATE == 2019-06-25 16:43:13.397964
# CREATE_DATE == 2019-07-26 16:46:07.093532
# CREATE_DATE == 2019-07-26 16:46:09.968569
# CREATE_DATE == 2019-08-23 16:35:47.752886
# CREATE_DATE == 2019-08-23 16:35:50.659173
# CREATE_DATE == 2019-09-23 16:42:27.555868
# CREATE_DATE == 2019-09-23 16:42:30.352779
# CREATE_DATE == 2019-10-24 16:21:06.114913
# CREATE_DATE == 2019-10-24 16:21:15.333781
# CREATE_DATE == 2019-11-21 16:18:51.092298
# CREATE_DATE == 2019-11-21 16:19:03.451832
# CREATE_DATE == 2010-09-29 11:57:38.706999
# CREATE_DATE == 2010-06-15 11:24:49.327909
# CREATE_DATE == 2010-06-29 10:40:15.238200
# CREATE_DATE == 2010-06-29 10:42:25.197978
# CREATE_DATE == 2010-06-29 12:04:39.668095
# CREATE_DATE == 2010-07-28 13:33:00.194806
# CREATE_DATE == 2010-07-28 08:03:29.719351
# CREATE_DATE == 2010-08-30 15:19:59.718743
# CREATE_DATE == 2010-08-30 15:20:39.563513
# CREATE_DATE == 2010-09-29 11:56:10.909000
# CREATE_DATE == 2010-10-04 08:56:02.470114
# CREATE_DATE == 2010-10-29 14:54:56.068493
# CREATE_DATE == 2010-10-29 14:55:26.943295
# CREATE_DATE == 2010-12-01 11:20:17.760031
# CREATE_DATE == 2010-12-01 11:19:51.134519
# CREATE_DATE == 2010-12-29 10:34:16.504036
# CREATE_DATE == 2010-12-29 10:34:34.504151
# CREATE_DATE == 2011-02-01 15:44:07.742912
# CREATE_DATE == 2011-02-02 10:02:12.405813
# CREATE_DATE == 2011-03-01 08:41:15.323545
# CREATE_DATE == 2011-03-01 08:41:50.730475
# CREATE_DATE == 2011-03-29 09:20:21.228254
# CREATE_DATE == 2011-03-29 09:20:26.493913
# CREATE_DATE == 2011-04-27 09:08:45.010323
# CREATE_DATE == 2011-04-27 09:08:50.166705
# CREATE_DATE == 2011-05-31 09:16:31.037161
# CREATE_DATE == 2011-05-31 09:16:35.834220
# CREATE_DATE == 2011-06-24 09:12:10.813190
# CREATE_DATE == 2011-06-24 09:12:16.094643
# CREATE_DATE == 2011-08-01 08:06:38.432888
# CREATE_DATE == 2011-08-01 08:06:33.213938
# CREATE_DATE == 2011-09-01 14:57:45.216501
# CREATE_DATE == 2011-09-02 09:08:46.841008
# CREATE_DATE == 2011-09-30 09:17:29.995874
# CREATE_DATE == 2011-09-30 09:17:35.355455
# CREATE_DATE == 2011-10-28 09:11:08.549037
# CREATE_DATE == 2011-10-28 09:11:13.892958
# CREATE_DATE == 2011-12-05 09:03:07.510639
# CREATE_DATE == 2011-12-05 09:03:42.589662
# CREATE_DATE == 2012-01-06 08:53:59.525369
# CREATE_DATE == 2012-01-04 16:00:36.876322
# CREATE_DATE == 2012-02-01 09:08:36.876090
# CREATE_DATE == 2012-02-01 09:08:31.532305
# CREATE_DATE == 2012-03-05 08:06:24.244810
# CREATE_DATE == 2012-03-05 08:06:29.479252
# CREATE_DATE == 2012-04-03 11:02:19.674532
# CREATE_DATE == 2012-04-03 11:04:22.803472
# CREATE_DATE == 2012-05-02 11:30:43.001165
# CREATE_DATE == 2012-05-02 11:30:48.016950
# CREATE_DATE == 2012-05-25 07:47:03.063756
# CREATE_DATE == 2012-05-25 07:47:16.392307
# CREATE_DATE == 2012-07-02 08:36:35.942343
# CREATE_DATE == 2012-07-05 07:42:10.766433
# CREATE_DATE == 2012-08-27 08:12:47.972172
# CREATE_DATE == 2012-08-27 08:12:56.550737
# CREATE_DATE == 2012-09-26 07:40:51.992992
# CREATE_DATE == 2012-09-26 07:41:04.837399
# CREATE_DATE == 2012-11-06 16:38:48.779934
# CREATE_DATE == 2012-11-06 16:38:53.092600
# CREATE_DATE == 2012-11-29 07:36:42.025926
# CREATE_DATE == 2012-11-29 07:36:51.026272
# CREATE_DATE == 2013-01-07 07:52:57.882619
# CREATE_DATE == 2013-01-07 07:53:02.164034
# CREATE_DATE == 2013-06-10 10:39:40.660304
# CREATE_DATE == 2013-07-12 10:25:29.754501
# CREATE_DATE == 2013-09-30 10:24:27.385399
# CREATE_DATE == 2013-10-10 09:52:32.367710
# CREATE_DATE == 2015-04-29 11:12:44.898421
# CREATE_DATE == 2015-04-17 14:31:54.435000
# CREATE_DATE == 2015-04-17 08:34:13.925000
# CREATE_DATE == 2015-04-28 10:02:28.857000
# CREATE_DATE == 2015-05-04 10:30:27.470000
# CREATE_DATE == 2015-06-01 11:35:44.476000
# CREATE_DATE == 2015-06-01 11:36:02.739000
# CREATE_DATE == 2015-06-30 12:24:52.025372
# CREATE_DATE == 2015-06-30 12:24:17.286995
# CREATE_DATE == 2015-07-29 09:23:38.977335
# CREATE_DATE == 2015-07-29 09:23:34.711682
# CREATE_DATE == 2015-08-27 09:20:42.251098
# CREATE_DATE == 2015-08-27 10:34:48.185802
# CREATE_DATE == 2015-09-25 08:49:43.131124
# CREATE_DATE == 2015-09-25 08:49:34.692652
# CREATE_DATE == 2015-11-02 08:30:49.672127
# CREATE_DATE == 2015-11-02 08:30:53.640903
# CREATE_DATE == 2015-12-01 09:34:06.726871
# CREATE_DATE == 2015-12-01 09:33:46.304865
# CREATE_DATE == 2015-12-29 12:05:32.781368
# CREATE_DATE == 2015-12-29 12:05:37.015770
# CREATE_DATE == 2016-01-27 12:37:46.466831
# CREATE_DATE == 2016-01-27 12:37:41.935581
# CREATE_DATE == 2016-02-25 08:44:48.325404
# CREATE_DATE == 2016-02-25 08:44:43.561213
# CREATE_DATE == 2016-03-28 09:24:50.672120
# CREATE_DATE == 2016-03-28 09:25:55.456977
# CREATE_DATE == 2016-04-27 11:48:46.236939
# CREATE_DATE == 2016-04-27 11:48:39.830566
# CREATE_DATE == 2016-05-27 12:15:08.393316
# CREATE_DATE == 2016-05-27 12:15:01.894329
# CREATE_DATE == 2016-07-05 09:25:31.541780
# CREATE_DATE == 2016-07-05 09:25:36.994975
# CREATE_DATE == 2016-07-28 08:28:39.916252
# CREATE_DATE == 2016-07-28 08:28:33.650506
# CREATE_DATE == 2016-08-24 07:58:19.770362
# CREATE_DATE == 2016-08-24 07:58:24.582924
# CREATE_DATE == 2016-09-26 14:49:46.003226
# CREATE_DATE == 2016-09-26 14:49:51.925177
# CREATE_DATE == 2016-10-24 13:18:06.851636
# CREATE_DATE == 2016-10-24 13:20:50.447480
# CREATE_DATE == 2016-11-23 13:41:34.600579
# CREATE_DATE == 2016-11-23 13:41:42.631932
# CREATE_DATE == 2016-12-20 17:09:27.636230
# CREATE_DATE == 2016-12-20 17:09:20.182962
# CREATE_DATE == 2017-01-31 16:17:22.354837
# CREATE_DATE == 2017-01-31 16:17:12.089015
# CREATE_DATE == 2017-02-27 13:28:06.096561
# CREATE_DATE == 2017-02-27 13:28:16.096754
# CREATE_DATE == 2017-03-29 13:34:50.380821
# CREATE_DATE == 2017-03-29 13:35:25.568997
# CREATE_DATE == 2017-04-27 17:30:21.810349
# CREATE_DATE == 2017-04-27 17:33:41.704833
# CREATE_DATE == 2017-06-01 07:39:56.448101
# CREATE_DATE == 2017-06-01 07:40:03.760695
# CREATE_DATE == 2017-06-29 09:35:28.649369
# CREATE_DATE == 2017-06-29 09:35:35.258829
# CREATE_DATE == 2017-07-31 08:19:20.838768
# CREATE_DATE == 2017-07-31 08:19:15.885580
# CREATE_DATE == 2017-08-31 08:50:42.180812
# CREATE_DATE == 2017-08-31 08:50:46.821526
# CREATE_DATE == 2017-10-03 06:43:48.853727
# CREATE_DATE == 2017-10-03 06:43:52.556923
# CREATE_DATE == 2017-11-02 08:05:58.841617
# CREATE_DATE == 2017-11-02 08:06:03.544802
# CREATE_DATE == 2017-12-01 08:05:14.447839
# CREATE_DATE == 2017-12-01 08:05:44.046324
# CREATE_DATE == 2018-01-03 08:44:00.744605
# CREATE_DATE == 2018-01-03 08:44:04.588429
# CREATE_DATE == 2018-01-29 06:53:40.598064
# CREATE_DATE == 2018-01-29 06:53:44.379386
# CREATE_DATE == 2018-03-03 07:41:24.557089
# CREATE_DATE == 2018-03-03 07:41:28.650918
# CREATE_DATE == 2018-03-30 07:53:00.289327
# CREATE_DATE == 2018-03-30 07:51:20.866179
# CREATE_DATE == 2018-05-07 08:00:55.465073
# CREATE_DATE == 2018-05-07 08:00:59.871380
# CREATE_DATE == 2018-06-05 07:30:29.914402
# CREATE_DATE == 2018-06-05 07:30:34.086330
# CREATE_DATE == 2018-07-09 17:04:01.561452
# CREATE_DATE == 2018-07-09 17:04:06.264637
# CREATE_DATE == 2018-08-02 08:11:00.232973
# CREATE_DATE == 2018-08-02 08:11:06.279925
# CREATE_DATE == 2018-09-07 08:12:41.625386
# CREATE_DATE == 2018-09-07 08:12:48.000509
# CREATE_DATE == 2018-10-04 08:53:11.668474
# CREATE_DATE == 2018-10-04 08:53:05.527731
# CREATE_DATE == 2018-11-09 07:30:22.061242
# CREATE_DATE == 2018-11-09 07:30:16.029914
# CREATE_DATE == 2018-12-17 17:14:51.921676
# CREATE_DATE == 2018-12-17 17:15:13.734455
# CREATE_DATE == 2019-01-07 17:41:13.309064
# CREATE_DATE == 2019-01-07 17:41:49.340775
# CREATE_DATE == 2019-02-05 13:31:33.052000
# CREATE_DATE == 2019-02-05 13:32:37.148000
# CREATE_DATE == 2019-03-07 08:35:15.322000
# CREATE_DATE == 2019-03-07 08:34:41.436000
# CREATE_DATE == 2019-04-23 09:01:10.277911
# CREATE_DATE == 2019-06-05 16:55:48.540181
# CREATE_DATE == 2019-06-25 16:42:49.632035
# CREATE_DATE == 2019-07-26 16:45:58.421546
# CREATE_DATE == 2019-08-23 16:35:44.924725
# CREATE_DATE == 2019-09-23 16:42:33.290316
# CREATE_DATE == 2019-10-24 16:20:58.208562
# CREATE_DATE == 2019-11-21 16:19:16.811378
# CREATE_DATE == 2010-06-24 13:27:57.897628
# CREATE_DATE == 2010-06-29 12:03:35.133541
# CREATE_DATE == 2010-07-30 16:08:12.524674
# CREATE_DATE == 2010-08-30 15:22:12.456516
# CREATE_DATE == 2010-09-29 11:58:34.051458
# CREATE_DATE == 2010-10-29 14:56:03.458687
# CREATE_DATE == 2010-12-01 11:23:50.560991
# CREATE_DATE == 2010-12-29 10:34:54.176152
# CREATE_DATE == 2011-02-04 09:43:33.086596
# CREATE_DATE == 2011-03-01 08:42:33.825052
# CREATE_DATE == 2011-03-29 09:20:31.603321
# CREATE_DATE == 2011-04-27 09:08:55.307462
# CREATE_DATE == 2011-05-31 09:16:44.897068
# CREATE_DATE == 2011-06-24 09:12:21.329219
# CREATE_DATE == 2011-08-03 08:41:15.548859
# CREATE_DATE == 2011-09-06 09:03:32.560935
# CREATE_DATE == 2011-10-13 15:42:50.324616
# CREATE_DATE == 2011-10-28 09:11:19.393134
# CREATE_DATE == 2011-12-05 09:03:46.980399
# CREATE_DATE == 2012-01-11 08:56:35.432003
# CREATE_DATE == 2012-02-01 09:08:42.094873
# CREATE_DATE == 2012-03-05 08:06:34.823071
# CREATE_DATE == 2012-04-04 08:54:34.641075
# CREATE_DATE == 2012-05-03 09:17:48.425030
# CREATE_DATE == 2012-05-25 07:47:20.829949
# CREATE_DATE == 2012-07-05 07:41:57.296993
# CREATE_DATE == 2012-08-27 08:13:08.910744
# CREATE_DATE == 2012-09-26 07:40:24.897855
# CREATE_DATE == 2012-11-09 08:55:32.018110
# CREATE_DATE == 2012-12-04 10:22:48.508926
# CREATE_DATE == 2013-01-08 08:23:54.108603
# CREATE_DATE == 2015-04-21 10:25:49.357689
# CREATE_DATE == 2015-04-28 15:01:19.590000
# CREATE_DATE == 2015-05-29 14:13:22.192000
# CREATE_DATE == 2015-06-30 12:23:34.922740
# CREATE_DATE == 2015-07-29 09:23:52.024293
# CREATE_DATE == 2015-08-27 10:34:56.888982
# CREATE_DATE == 2015-09-25 08:49:51.835252
# CREATE_DATE == 2015-11-02 08:31:05.422228
# CREATE_DATE == 2015-12-01 09:34:02.742471
# CREATE_DATE == 2015-12-30 11:22:54.062904
# CREATE_DATE == 2016-01-28 08:59:29.202126
# CREATE_DATE == 2016-02-25 08:46:22.687637
# CREATE_DATE == 2016-03-29 09:48:18.297397
# CREATE_DATE == 2016-04-27 11:47:58.439147
# CREATE_DATE == 2016-05-27 12:15:22.092619
# CREATE_DATE == 2016-07-05 09:25:16.041582
# CREATE_DATE == 2016-07-28 08:32:35.655153
# CREATE_DATE == 2016-08-24 15:22:09.062608
# CREATE_DATE == 2016-09-26 13:07:07.158769
# CREATE_DATE == 2016-10-27 08:55:24.363286
# CREATE_DATE == 2016-12-07 08:05:40.925145
# CREATE_DATE == 2016-12-21 16:39:44.761818
# CREATE_DATE == 2017-01-31 16:17:43.480242
# CREATE_DATE == 2017-02-28 12:05:09.001654
# CREATE_DATE == 2017-03-29 17:08:58.946690
# CREATE_DATE == 2017-05-03 11:28:57.098000
# CREATE_DATE == 2017-06-01 07:40:29.354772
# CREATE_DATE == 2017-06-29 09:35:12.914793
# CREATE_DATE == 2017-07-31 08:19:36.667096
# CREATE_DATE == 2017-08-31 08:50:18.524108
# CREATE_DATE == 2017-10-03 06:43:59.932065
# CREATE_DATE == 2017-11-03 06:57:40.868433
# CREATE_DATE == 2017-12-01 08:48:38.311533
# CREATE_DATE == 2018-01-05 07:20:16.433407
# CREATE_DATE == 2018-01-29 06:55:10.756045
# CREATE_DATE == 2018-03-06 06:38:28.889086
# CREATE_DATE == 2018-04-03 07:29:38.520733
# CREATE_DATE == 2018-05-07 08:02:02.653433
# CREATE_DATE == 2018-06-05 07:31:30.555803
# CREATE_DATE == 2018-07-09 17:04:10.889696
# CREATE_DATE == 2018-08-02 08:10:33.232627
# CREATE_DATE == 2018-09-07 08:12:59.906987
# CREATE_DATE == 2018-10-04 16:32:18.507539
# CREATE_DATE == 2018-11-09 07:30:45.342790
# CREATE_DATE == 2019-01-07 17:41:19.418518
# CREATE_DATE == 2019-01-07 17:42:01.887811
# CREATE_DATE == 2019-02-05 13:38:20.389000
# CREATE_DATE == 2019-11-21 16:19:44.014851
# CREATE_DATE == 2011-05-31 09:16:40.225013
# CREATE_DATE == 2015-04-29 11:12:53.289046
# CREATE_DATE == 2015-08-24 15:21:28.107399
# CREATE_DATE == 2016-07-01 12:14:48.400861
# CREATE_DATE == 2017-10-26 07:22:54.238691
# CREATE_DATE == 2010-06-29 14:07:34.490441
# CREATE_DATE == 2019-06-11 07:26:39.473567
# CREATE_DATE == 2010-06-14 15:05:31.651108
# CREATE_DATE == 2011-12-02 08:54:57.583778
# CREATE_DATE == 2015-04-16 09:03:40.553000
# CREATE_DATE == 2015-12-14 16:30:49.649742
# CREATE_DATE == 2017-04-19 16:29:07.560753
# CREATE_DATE == 2019-05-28 17:24:37.748820
# CREATE_DATE == 2019-05-28 17:33:31.990033
# CREATE_DATE == 2013-06-20 13:00:38.521826
# CREATE_DATE == 2010-09-30 12:46:40.686618
# CREATE_DATE == 2011-05-09 08:56:52.189308
# CREATE_DATE == 2015-04-29 11:13:02.664046
# CREATE_DATE == 2016-04-07 12:27:22.001074
# CREATE_DATE == 2010-06-21 09:06:26.389160
# CREATE_DATE == 2015-04-29 11:13:11.710921
# CREATE_DATE == 2018-04-06 07:51:22.636550
# CREATE_DATE == 2012-05-09 12:08:18.088391
# CREATE_DATE == 2015-04-29 11:13:20.335921
# CREATE_DATE == 2016-06-01 08:36:02.756045
# CREATE_DATE == 2017-08-16 07:36:40.736086
# CREATE_DATE == 2019-08-12 16:37:50.703397
# CREATE_DATE == 2010-07-14 08:43:47.062363
# CREATE_DATE == 2011-12-15 06:57:29.400047
# CREATE_DATE == 2012-01-10 08:41:42.517759
# CREATE_DATE == 2012-06-19 11:16:06.876260
# CREATE_DATE == 2015-07-30 13:10:43.989687
# CREATE_DATE == 2016-06-07 11:06:53.678543
# CREATE_DATE == 2010-06-30 14:15:50.421379
# CREATE_DATE == 2011-10-26 09:04:16.101150
# CREATE_DATE == 2011-11-04 09:54:49.356565
# CREATE_DATE == 2015-04-21 08:48:42.298767
# CREATE_DATE == 2016-12-29 12:07:07.372737
# CREATE_DATE == 2010-06-14 11:01:50.620632
# CREATE_DATE == 2010-09-08 16:48:52.081010
# CREATE_DATE == 2012-03-01 17:53:42.785936
# CREATE_DATE == 2015-04-16 09:31:46.409000
# CREATE_DATE == 2015-08-13 16:53:38.145894
# CREATE_DATE == 2016-05-10 10:57:26.407610
# CREATE_DATE == 2016-10-26 13:34:39.155664
# CREATE_DATE == 2017-06-16 10:30:43.128496
# CREATE_DATE == 2019-06-14 16:57:17.492040
# CREATE_DATE == 2018-04-03 07:27:17.909558
# CREATE_DATE == 2017-02-06 13:14:51.406626
# CREATE_DATE == 2010-06-30 14:16:15.390928
# CREATE_DATE == 2010-08-20 13:53:41.652269
# CREATE_DATE == 2011-08-22 13:14:44.036206
# CREATE_DATE == 2015-04-29 11:13:28.929671
# CREATE_DATE == 2017-07-26 08:17:45.107376
# CREATE_DATE == 2018-05-12 07:19:50.545173
# CREATE_DATE == 2018-03-31 07:51:11.405518
# CREATE_DATE == 2017-02-08 12:25:33.537965
# CREATE_DATE == 2010-06-30 14:16:47.595083
# CREATE_DATE == 2011-05-06 13:46:28.795954
# CREATE_DATE == 2015-04-17 09:06:36.522000
# CREATE_DATE == 2016-09-20 13:33:46.455669
# CREATE_DATE == 2019-03-22 08:39:27.354000
# CREATE_DATE == 2010-06-18 09:44:24.488012
# CREATE_DATE == 2011-09-21 11:06:58.232914
# CREATE_DATE == 2015-04-29 11:13:37.335921
# CREATE_DATE == 2016-08-24 07:58:05.332677
# CREATE_DATE == 2017-10-18 06:55:41.452899
# CREATE_DATE == 2010-06-21 08:56:37.557818
# CREATE_DATE == 2010-07-02 09:06:07.525056
# CREATE_DATE == 2015-04-22 11:57:30.940000
# CREATE_DATE == 2017-07-26 08:17:50.029598
# CREATE_DATE == 2018-05-14 16:53:58.204251
# CREATE_DATE == 2010-06-17 13:23:41.185589
# CREATE_DATE == 2012-04-04 11:45:17.703659
# CREATE_DATE == 2012-10-17 16:41:30.757597
# CREATE_DATE == 2015-10-16 10:02:47.251825
# CREATE_DATE == 2017-08-02 09:00:19.893003
# CREATE_DATE == 2010-07-01 08:18:06.985381
# CREATE_DATE == 2011-06-09 08:47:19.180905
# CREATE_DATE == 2015-04-29 11:13:45.851546
# CREATE_DATE == 2017-10-16 07:07:51.595143
# CREATE_DATE == 2017-11-08 08:10:20.595591
# CREATE_DATE == 2017-02-06 13:14:30.374972
# CREATE_DATE == 2018-11-20 13:51:02.103000
# CREATE_DATE == 2010-07-01 15:50:43.852882
# CREATE_DATE == 2012-05-23 09:48:22.668001
# CREATE_DATE == 2016-05-31 13:10:31.357929
# CREATE_DATE == 2010-08-16 16:29:28.467433
# CREATE_DATE == 2010-10-06 08:03:38.134236
# CREATE_DATE == 2012-04-11 17:26:20.174333
# CREATE_DATE == 2015-04-29 11:13:54.320296
# CREATE_DATE == 2017-12-11 16:10:41.527386
# CREATE_DATE == 2017-12-21 07:18:31.928739
# CREATE_DATE == 2010-06-28 11:28:23.945874
# CREATE_DATE == 2011-03-10 09:05:38.705142
# CREATE_DATE == 2015-04-29 11:14:02.773421
# CREATE_DATE == 2017-08-25 07:12:52.829695
# CREATE_DATE == 2017-02-06 13:15:12.969540
# CREATE_DATE == 2011-02-14 15:31:35.854332
# CREATE_DATE == 2011-05-25 08:50:56.901101
# CREATE_DATE == 2015-04-29 11:14:11.195296
# CREATE_DATE == 2010-06-18 15:04:08.899414
# CREATE_DATE == 2015-04-29 11:14:19.992171
# CREATE_DATE == 2016-03-21 13:00:41.393992
# CREATE_DATE == 2018-03-08 07:21:22.345390
# CREATE_DATE == 2019-04-24 18:09:32.510874
# CREATE_DATE == 2010-06-28 12:55:41.147998
# CREATE_DATE == 2010-10-05 14:50:40.746523
# CREATE_DATE == 2011-02-22 09:24:27.284724
# CREATE_DATE == 2015-04-21 16:51:09.354000
# CREATE_DATE == 2015-06-04 13:23:06.038000
# CREATE_DATE == 2015-09-11 08:34:17.677813
# CREATE_DATE == 2016-04-22 14:19:25.966438
# CREATE_DATE == 2016-05-03 11:26:05.773932
# CREATE_DATE == 2016-10-25 08:36:43.976855
# CREATE_DATE == 2018-11-09 07:30:54.139777
# CREATE_DATE == 2017-02-08 12:25:52.475828
# CREATE_DATE == 2019-05-17 10:51:28.918216
# CREATE_DATE == 2012-11-20 13:30:59.604911
# CREATE_DATE == 2015-04-29 11:14:28.335921
# CREATE_DATE == 2018-09-26 07:39:58.622434
# CREATE_DATE == 2010-09-03 11:24:39.071459
# CREATE_DATE == 2012-11-06 08:45:30.955252
# CREATE_DATE == 2010-09-17 08:49:54.271486
# CREATE_DATE == 2010-10-05 09:39:36.360077
# CREATE_DATE == 2012-03-14 08:14:58.350178
# CREATE_DATE == 2015-04-16 09:04:00.014000
# CREATE_DATE == 2018-11-16 09:48:41.434084
# CREATE_DATE == 2012-02-02 10:25:40.375342
# CREATE_DATE == 2016-05-13 14:57:40.125720
# CREATE_DATE == 2012-05-14 10:34:00.083595
# CREATE_DATE == 2010-10-29 13:35:02.616274
# CREATE_DATE == 2015-04-15 21:40:39.966000
# CREATE_DATE == 2019-05-22 17:20:58.652060
# CREATE_DATE == 2010-07-30 09:27:31.661821
# CREATE_DATE == 2010-06-18 09:39:43.795521
# CREATE_DATE == 2012-03-28 12:09:09.009520
# CREATE_DATE == 2015-04-21 08:49:21.166551
# CREATE_DATE == 2017-02-07 06:39:32.388724
# CREATE_DATE == 2019-09-12 16:43:52.215834
# CREATE_DATE == 2010-07-23 08:52:22.111799
# CREATE_DATE == 2010-11-19 13:45:14.616536
# CREATE_DATE == 2011-05-12 08:26:21.820739
# CREATE_DATE == 2012-03-16 17:21:26.172043
# CREATE_DATE == 2015-04-29 11:14:36.945296
# CREATE_DATE == 2016-01-06 08:59:03.796986
# CREATE_DATE == 2016-05-03 08:25:23.720168
# CREATE_DATE == 2017-01-09 16:45:35.311371
# CREATE_DATE == 2017-08-24 07:47:59.170471
# CREATE_DATE == 2019-05-31 07:41:58.174176
# CREATE_DATE == 2010-06-21 08:10:05.828795
# CREATE_DATE == 2010-08-16 15:32:49.861483
# CREATE_DATE == 2010-08-30 12:35:44.629273
# CREATE_DATE == 2012-07-06 13:32:57.699902
# CREATE_DATE == 2012-08-13 08:05:03.425708
# CREATE_DATE == 2014-01-27 10:45:31.603180
# CREATE_DATE == 2016-01-22 11:06:46.094612
# CREATE_DATE == 2016-04-07 10:07:59.869432
# CREATE_DATE == 2018-03-08 07:23:03.097325
# CREATE_DATE == 2015-04-29 11:14:45.695296
# CREATE_DATE == 2018-01-17 13:46:34.998691
# CREATE_DATE == 2010-10-01 09:18:10.142858
# CREATE_DATE == 2010-06-11 15:15:00.095008
# CREATE_DATE == 2012-11-01 13:24:18.211003
# CREATE_DATE == 2010-06-29 13:04:14.603085
# CREATE_DATE == 2017-02-22 16:55:04.708655
# CREATE_DATE == 2010-07-06 14:46:30.426601
# CREATE_DATE == 2011-05-20 09:12:26.180654
# CREATE_DATE == 2015-04-21 12:02:16.825000
# CREATE_DATE == 2015-09-29 08:02:21.074722
# CREATE_DATE == 2019-01-03 17:23:13.719966
# CREATE_DATE == 2015-04-21 12:02:39.970000
# ...
# CREATE_DATE == 2019-05-18 11:50:23.666648
# CREATE_DATE == 2019-07-15 07:07:33.814897
# CREATE_DATE == 2019-11-20 07:20:51.605787
# CREATE_DATE == 2015-03-02 15:28:11.224167
# CREATE_DATE == 2015-07-07 16:47:15.198827
# CREATE_DATE == 2015-09-02 16:04:11.890673
# CREATE_DATE == 2016-03-10 11:48:53.306393
# CREATE_DATE == 2017-11-13 08:50:52.517533
# CREATE_DATE == 2018-12-20 10:07:05.325360
# CREATE_DATE == 2019-04-29 12:39:01.718733
# CREATE_DATE == 2019-05-18 11:50:23.791650
# CREATE_DATE == 2019-07-15 07:07:36.455556
# CREATE_DATE == 2019-09-04 07:44:19.028733
# CREATE_DATE == 2019-11-20 07:20:55.230833
# CREATE_DATE == 2015-03-02 15:29:36.518458
# CREATE_DATE == 2015-07-07 16:51:23.580435
# CREATE_DATE == 2015-09-02 16:14:30.289214
# CREATE_DATE == 2016-03-10 11:53:27.964652
# CREATE_DATE == 2017-11-13 09:07:42.599426
# CREATE_DATE == 2018-12-20 10:23:42.516380
# CREATE_DATE == 2015-03-03 11:33:55.590566
# CREATE_DATE == 2015-07-09 08:47:37.438025
# CREATE_DATE == 2015-09-08 08:35:02.487514
# CREATE_DATE == 2016-03-15 12:04:22.976309
# CREATE_DATE == 2015-03-03 11:33:57.543716
# CREATE_DATE == 2015-07-09 08:47:41.734927
# CREATE_DATE == 2015-09-08 08:34:52.909328
# CREATE_DATE == 2016-03-15 11:58:27.224032
# CREATE_DATE == 2015-03-03 10:11:25.357267
# CREATE_DATE == 2015-07-09 08:47:45.859954
# CREATE_DATE == 2016-03-15 11:58:32.833443
# CREATE_DATE == 2019-04-30 11:07:13.660078
# CREATE_DATE == 2017-04-18 11:03:23.701788
# CREATE_DATE == 2019-04-30 11:37:02.089220
# CREATE_DATE == 2017-04-18 11:12:32.634203
# CREATE_DATE == 2019-04-30 11:07:13.706954
# CREATE_DATE == 2017-04-18 11:16:44.592165
# CREATE_DATE == 2019-04-30 11:07:13.738204
# CREATE_DATE == 2017-04-18 11:42:16.918460
# CREATE_DATE == 2019-04-30 11:07:13.769455
# CREATE_DATE == 2017-04-18 11:48:43.496947
# CREATE_DATE == 2019-04-30 11:07:13.800705
# CREATE_DATE == 2017-04-18 11:53:16.298844
# CREATE_DATE == 2019-04-30 11:07:13.831955
# CREATE_DATE == 2017-04-18 12:00:36.052655
# CREATE_DATE == 2019-04-30 11:37:02.120470
# CREATE_DATE == 2017-04-18 12:07:48.318894
# CREATE_DATE == 2019-04-30 11:37:02.151721
# CREATE_DATE == 2017-04-18 12:20:32.040309
# CREATE_DATE == 2019-04-30 11:37:02.182971
# CREATE_DATE == 2017-04-18 12:27:48.236184
# CREATE_DATE == 2019-04-30 11:37:02.026719
# CREATE_DATE == 2019-10-18 07:05:22.449849
# CREATE_DATE == 2017-04-18 13:30:04.417292
# CREATE_DATE == 2019-04-30 11:37:02.214221
# CREATE_DATE == 2017-04-18 13:38:27.333198
# CREATE_DATE == 2019-04-30 11:37:02.245472
# CREATE_DATE == 2017-04-18 13:41:24.695978
# CREATE_DATE == 2015-06-23 14:19:51.254796
# CREATE_DATE == 2017-04-26 12:29:19.926901
# CREATE_DATE == 2017-06-29 10:34:34.711085
# CREATE_DATE == 2017-07-14 09:25:09.682741
# CREATE_DATE == 2017-04-26 12:35:51.325041
# CREATE_DATE == 2017-06-29 10:43:48.502967
# CREATE_DATE == 2017-07-14 09:30:09.532248
# CREATE_DATE == 2017-04-26 15:51:11.703001
# CREATE_DATE == 2017-06-29 10:59:11.192557
# CREATE_DATE == 2017-07-14 09:34:02.114839
# CREATE_DATE == 2017-04-26 16:05:46.172915
# CREATE_DATE == 2017-06-29 11:06:51.248265
# CREATE_DATE == 2017-07-14 09:40:07.199973
# CREATE_DATE == 2017-04-26 16:13:56.526080
# CREATE_DATE == 2017-06-29 11:14:56.648210
# CREATE_DATE == 2017-07-14 09:44:08.517106
# CREATE_DATE == 2017-04-27 09:28:18.800676
# CREATE_DATE == 2017-06-29 11:20:48.592467
# CREATE_DATE == 2017-07-14 09:49:11.272919
# CREATE_DATE == 2017-04-27 09:31:02.913202
# CREATE_DATE == 2017-06-29 11:30:07.353195
# CREATE_DATE == 2017-07-14 10:31:47.540749
# CREATE_DATE == 2017-04-27 09:32:15.398968
# CREATE_DATE == 2017-06-29 11:45:39.121085
# CREATE_DATE == 2017-07-14 10:36:45.390217
# CREATE_DATE == 2017-04-27 09:35:09.683564
# CREATE_DATE == 2017-06-29 11:57:12.134390
# CREATE_DATE == 2017-07-14 10:43:27.866694
# CREATE_DATE == 2017-04-27 09:38:22.781022
# CREATE_DATE == 2017-06-29 12:03:50.173282
# CREATE_DATE == 2017-07-14 10:48:39.732057
# CREATE_DATE == 2019-10-16 16:17:52.214380
# CREATE_DATE == 2019-09-18 08:35:49.823897
# CREATE_DATE == 2019-09-18 08:39:17.326553
# CREATE_DATE == 2019-09-18 09:28:49.786475
# CREATE_DATE == 2019-09-18 08:42:12.156916
# CREATE_DATE == 2019-09-18 08:46:55.863672
# CREATE_DATE == 2019-09-18 08:47:10.348233
# CREATE_DATE == 2019-09-18 09:56:59.417477
# CREATE_DATE == 2019-09-18 08:50:02.412935
# CREATE_DATE == 2019-09-18 08:55:21.463894
# CREATE_DATE == 2019-09-18 09:29:11.927383
# CREATE_DATE == 2019-09-18 09:29:14.771170
# CREATE_DATE == 2019-09-18 09:29:17.646207
# CREATE_DATE == 2019-09-18 09:29:20.427492
# CREATE_DATE == 2019-09-18 09:29:23.240028
# CREATE_DATE == 2016-03-07 15:10:07.380102
# CREATE_DATE == 2017-06-06 09:23:52.816826
# CREATE_DATE == 2019-10-04 06:47:13.778322
# CREATE_DATE == 2016-03-07 15:20:02.121689
# CREATE_DATE == 2017-06-05 10:30:47.101361
# CREATE_DATE == 2016-03-07 15:24:39.194828
# CREATE_DATE == 2017-06-05 10:40:25.924974
# CREATE_DATE == 2019-07-31 06:40:01.392648
# CREATE_DATE == 2016-03-07 15:57:23.020236
# CREATE_DATE == 2017-06-05 10:44:36.367283
# CREATE_DATE == 2016-03-07 16:00:18.620729
# CREATE_DATE == 2017-06-05 10:51:18.625006
# CREATE_DATE == 2016-03-08 09:16:43.278486
# CREATE_DATE == 2017-06-05 10:58:14.804871
# CREATE_DATE == 2016-03-07 16:18:47.663315
# CREATE_DATE == 2017-06-05 11:07:12.018311
# CREATE_DATE == 2016-03-07 16:24:45.317673
# CREATE_DATE == 2017-06-05 11:10:54.756962
# CREATE_DATE == 2016-03-07 16:28:26.560544
# CREATE_DATE == 2017-06-05 11:14:49.323966
# CREATE_DATE == 2016-03-08 08:19:46.178524
# CREATE_DATE == 2017-06-05 11:18:04.249583
# CREATE_DATE == 2016-03-07 16:32:45.179849
# CREATE_DATE == 2017-06-05 11:27:45.510743
# CREATE_DATE == 2016-03-08 08:24:52.065270
# CREATE_DATE == 2017-06-05 11:31:48.546659
# CREATE_DATE == 2019-05-18 11:05:12.272568
# CREATE_DATE == 2016-03-08 08:29:16.075408
# CREATE_DATE == 2017-06-05 11:34:52.300187
# CREATE_DATE == 2019-09-04 07:44:22.591279
# CREATE_DATE == 2016-03-07 16:37:13.940169
# CREATE_DATE == 2017-06-05 11:38:12.179025
# CREATE_DATE == 2016-03-07 16:43:12.625817
# CREATE_DATE == 2017-06-05 11:43:22.419357
# CREATE_DATE == 2019-09-17 16:24:03.881976
# CREATE_DATE == 2019-04-29 12:39:01.749984
# CREATE_DATE == 2017-04-13 09:07:18.544874
# CREATE_DATE == 2017-06-02 16:07:14.724495
# CREATE_DATE == 2019-04-29 12:39:01.796859
# CREATE_DATE == 2017-04-13 09:15:19.632683
# CREATE_DATE == 2017-06-02 16:08:11.506835
# CREATE_DATE == 2019-04-29 12:39:01.828110
# CREATE_DATE == 2017-04-13 09:19:48.312922
# CREATE_DATE == 2017-06-02 16:13:02.137415
# CREATE_DATE == 2019-04-29 12:39:01.859360
# CREATE_DATE == 2017-04-13 09:26:21.109255
# CREATE_DATE == 2017-06-02 16:14:18.326378
# CREATE_DATE == 2019-04-29 12:39:01.890610
# CREATE_DATE == 2017-04-13 09:32:30.666414
# CREATE_DATE == 2017-06-02 16:16:40.782238
# CREATE_DATE == 2019-04-29 12:39:01.906235
# CREATE_DATE == 2017-04-13 09:39:36.888835
# CREATE_DATE == 2017-06-02 16:17:46.330372
# CREATE_DATE == 2019-04-29 12:39:01.937486
# CREATE_DATE == 2017-04-13 09:46:10.358045
# CREATE_DATE == 2017-06-02 16:20:18.973927
# CREATE_DATE == 2019-04-29 12:39:01.968736
# CREATE_DATE == 2017-04-13 10:18:43.356865
# CREATE_DATE == 2017-06-02 16:21:18.740700
# CREATE_DATE == 2019-04-29 12:39:01.999987
# CREATE_DATE == 2017-04-13 10:25:27.067680
# CREATE_DATE == 2017-06-02 16:22:36.414066
# CREATE_DATE == 2019-04-29 12:39:02.031237
# CREATE_DATE == 2019-09-04 07:44:26.013198
# CREATE_DATE == 2017-04-13 10:32:42.068758
# CREATE_DATE == 2017-06-02 16:24:56.963640
# CREATE_DATE == 2019-04-29 12:39:02.062488
# CREATE_DATE == 2019-06-24 08:34:36.904158
# CREATE_DATE == 2017-04-13 10:42:36.046644
# CREATE_DATE == 2017-06-02 16:26:03.980551
# CREATE_DATE == 2019-04-29 12:39:02.093738
# CREATE_DATE == 2017-04-13 10:48:41.605603
# CREATE_DATE == 2017-06-02 16:27:37.341719
# CREATE_DATE == 2019-04-29 12:39:02.124988
# CREATE_DATE == 2019-09-04 07:44:29.325740
# CREATE_DATE == 2017-04-13 10:53:54.611763
# CREATE_DATE == 2017-06-02 16:29:00.765196
# CREATE_DATE == 2019-04-29 12:39:02.156239
# CREATE_DATE == 2017-04-13 10:59:44.513870
# CREATE_DATE == 2017-06-02 16:30:59.392473
# CREATE_DATE == 2019-04-29 12:39:02.187489
# CREATE_DATE == 2017-04-13 11:09:05.160398
# CREATE_DATE == 2017-06-02 16:32:13.050138
# CREATE_DATE == 2019-04-29 12:39:02.218740
# CREATE_DATE == 2019-09-04 07:44:32.685158
# CREATE_DATE == 2017-04-13 11:17:49.525259
# CREATE_DATE == 2017-06-02 16:33:53.036432
# CREATE_DATE == 2019-04-29 12:39:02.249990
# CREATE_DATE == 2017-04-13 11:25:59.965967
# CREATE_DATE == 2017-06-02 16:35:32.444591
# CREATE_DATE == 2019-04-29 12:39:02.281240
# CREATE_DATE == 2019-09-04 07:44:35.982075
# CREATE_DATE == 2017-04-13 11:30:51.709591
# CREATE_DATE == 2017-06-02 16:37:28.587446
# CREATE_DATE == 2019-04-29 12:39:02.312491
# CREATE_DATE == 2017-04-13 12:22:15.349483
# CREATE_DATE == 2017-06-05 12:13:45.157477
# CREATE_DATE == 2019-09-17 16:24:06.694512
# CREATE_DATE == 2019-09-17 16:24:09.600800
# CREATE_DATE == 2016-01-27 07:57:28.105428
# CREATE_DATE == 2016-04-18 11:10:15.607965
# CREATE_DATE == 2017-06-02 14:31:45.315774
# CREATE_DATE == 2017-11-07 10:38:16.653837
# CREATE_DATE == 2017-11-13 14:10:01.603331
# CREATE_DATE == 2018-06-07 15:18:21.344796
# CREATE_DATE == 2016-01-27 08:02:02.703863
# CREATE_DATE == 2016-04-18 11:14:10.582730
# CREATE_DATE == 2017-06-02 14:34:55.772556
# CREATE_DATE == 2017-11-07 10:43:05.893765
# CREATE_DATE == 2017-11-13 11:11:35.407822
# CREATE_DATE == 2018-06-07 15:27:24.007992
# CREATE_DATE == 2016-01-27 08:05:15.186840
# CREATE_DATE == 2016-04-18 11:17:29.244065
# CREATE_DATE == 2017-06-06 09:33:48.609515
# CREATE_DATE == 2017-11-07 10:50:17.964561
# CREATE_DATE == 2017-11-13 11:15:21.805691
# CREATE_DATE == 2018-06-07 15:34:45.107388
# CREATE_DATE == 2016-01-27 08:07:41.095763
# CREATE_DATE == 2016-04-18 11:22:10.127799
# CREATE_DATE == 2017-06-02 14:40:18.763132
# CREATE_DATE == 2017-11-07 11:08:18.172800
# CREATE_DATE == 2017-11-13 11:19:20.296552
# CREATE_DATE == 2018-06-07 15:42:08.519314
# CREATE_DATE == 2016-01-27 08:09:35.189011
# CREATE_DATE == 2016-04-18 11:30:20.252857
# CREATE_DATE == 2017-06-02 14:44:52.393386
# CREATE_DATE == 2017-11-07 11:12:07.442827
# CREATE_DATE == 2017-11-13 11:24:00.833963
# CREATE_DATE == 2018-06-07 15:52:26.605350
# CREATE_DATE == 2016-01-27 08:10:47.947664
# CREATE_DATE == 2016-04-18 11:40:18.709507
# CREATE_DATE == 2017-06-02 14:46:44.098656
# CREATE_DATE == 2017-11-07 11:25:43.927253
# CREATE_DATE == 2017-11-13 11:29:54.497003
# CREATE_DATE == 2018-06-07 15:55:46.545409
# CREATE_DATE == 2016-01-25 13:35:30.573969
# CREATE_DATE == 2016-01-27 08:11:48.486122
# CREATE_DATE == 2016-04-18 11:50:35.838630
# CREATE_DATE == 2017-06-02 14:48:01.584518
# CREATE_DATE == 2017-11-07 11:32:26.169351
# CREATE_DATE == 2017-11-13 11:41:23.166475
# CREATE_DATE == 2018-06-11 11:48:05.607121
# CREATE_DATE == 2016-01-25 13:38:30.926597
# CREATE_DATE == 2016-01-27 08:12:39.576951
# CREATE_DATE == 2016-04-18 11:59:58.512885
# CREATE_DATE == 2017-06-02 14:50:23.368490
# CREATE_DATE == 2017-11-07 11:43:49.948105
# CREATE_DATE == 2017-11-13 11:50:27.833183
# CREATE_DATE == 2018-06-07 15:58:55.485328
# CREATE_DATE == 2016-01-25 13:44:17.529750
# CREATE_DATE == 2016-01-27 08:13:23.972210
# CREATE_DATE == 2016-04-18 12:04:22.099444
# CREATE_DATE == 2017-06-02 14:51:51.838939
# CREATE_DATE == 2017-11-07 11:48:38.250515
# CREATE_DATE == 2017-11-13 11:56:24.652533
# CREATE_DATE == 2018-06-11 09:20:58.306633
# CREATE_DATE == 2016-01-25 13:46:52.717350
# CREATE_DATE == 2016-01-27 08:14:13.158669
# CREATE_DATE == 2016-04-18 15:07:47.514107
# CREATE_DATE == 2017-06-02 14:53:34.856542
# CREATE_DATE == 2017-11-07 11:54:51.304552
# CREATE_DATE == 2017-11-13 12:04:13.895918
# CREATE_DATE == 2018-06-13 10:53:22.323767
# CREATE_DATE == 2016-01-27 09:40:05.083932
# CREATE_DATE == 2016-04-18 12:10:40.986568
# CREATE_DATE == 2017-06-02 14:56:51.032183
# CREATE_DATE == 2017-11-07 11:57:33.292037
# CREATE_DATE == 2017-11-07 11:59:19.606579
# CREATE_DATE == 2017-11-13 12:10:44.356539
# CREATE_DATE == 2017-11-15 09:47:22.683357
# CREATE_DATE == 2018-06-07 16:16:26.186277
# CREATE_DATE == 2016-01-27 08:21:29.633697
# CREATE_DATE == 2016-04-18 12:24:39.247767
# CREATE_DATE == 2017-06-02 15:01:44.444067
# CREATE_DATE == 2017-11-07 12:10:13.572260
# CREATE_DATE == 2017-11-13 12:32:54.491452
# CREATE_DATE == 2018-06-07 16:22:03.846848
# CREATE_DATE == 2016-01-27 08:25:04.742711
# CREATE_DATE == 2016-04-18 12:29:03.146837
# CREATE_DATE == 2017-06-02 15:04:26.822185
# CREATE_DATE == 2017-11-07 12:19:40.020635
# CREATE_DATE == 2017-11-13 13:15:37.087528
# CREATE_DATE == 2018-06-11 09:18:22.023382
# CREATE_DATE == 2016-01-27 08:26:55.758967
# CREATE_DATE == 2016-04-18 13:09:16.989702
# CREATE_DATE == 2017-06-02 15:05:43.511157
# CREATE_DATE == 2017-11-07 12:28:36.765316
# CREATE_DATE == 2017-11-13 13:36:07.126770
# CREATE_DATE == 2018-06-07 16:33:36.902595
# CREATE_DATE == 2016-01-27 08:29:47.441331
# CREATE_DATE == 2016-04-18 13:13:08.918998
# CREATE_DATE == 2017-06-02 15:07:21.591165
# CREATE_DATE == 2017-11-07 13:25:07.705420
# CREATE_DATE == 2017-11-13 13:42:27.384070
# CREATE_DATE == 2018-06-08 08:55:12.169003
# CREATE_DATE == 2016-01-27 08:30:43.632175
# CREATE_DATE == 2016-04-18 13:20:05.932343
# CREATE_DATE == 2017-06-02 15:08:58.468025
# CREATE_DATE == 2017-11-07 13:43:33.507901
# CREATE_DATE == 2017-11-13 13:46:41.951458
# CREATE_DATE == 2018-06-08 09:00:00.188315
# CREATE_DATE == 2016-01-27 08:32:56.371669
# CREATE_DATE == 2016-04-18 13:29:37.341252
# CREATE_DATE == 2017-06-02 15:10:27.407233
# CREATE_DATE == 2017-11-07 13:50:02.124738
# CREATE_DATE == 2017-11-13 13:54:29.397933
# CREATE_DATE == 2018-06-08 09:04:17.769737
# CREATE_DATE == 2019-12-05 07:49:31.266124
# CREATE_DATE == 2016-01-27 08:35:31.944719
# CREATE_DATE == 2016-04-18 13:36:04.025501
# CREATE_DATE == 2017-06-02 15:20:17.043553
# CREATE_DATE == 2017-11-07 13:55:06.458706
# CREATE_DATE == 2017-11-13 13:58:54.856155
# CREATE_DATE == 2018-06-08 09:08:41.148108
# CREATE_DATE == 2016-01-27 08:36:35.992378
# CREATE_DATE == 2016-04-18 13:39:32.172786
# CREATE_DATE == 2017-06-02 15:22:08.931242
# CREATE_DATE == 2017-11-07 13:59:54.995496
# CREATE_DATE == 2017-11-13 14:04:36.331461
# CREATE_DATE == 2018-06-08 09:11:56.666236
# CREATE_DATE == 2019-10-29 06:49:55.406879
# CREATE_DATE == 2015-07-17 15:56:59.763600
# CREATE_DATE == 2015-07-17 15:58:05.961267
# CREATE_DATE == 2015-07-17 15:58:48.702206
# CREATE_DATE == 2015-07-17 15:59:43.601262
# CREATE_DATE == 2015-07-17 16:00:28.670683
# CREATE_DATE == 2015-07-17 16:02:01.417212
# CREATE_DATE == 2015-07-17 16:03:42.439302
# CREATE_DATE == 2015-07-17 16:05:55.463440
# CREATE_DATE == 2015-09-02 16:23:58.858991
# CREATE_DATE == 2015-09-02 16:28:00.158955
# CREATE_DATE == 2015-09-02 16:32:06.145806
# CREATE_DATE == 2015-09-02 16:35:46.559057
# CREATE_DATE == 2015-09-02 16:39:09.564049
# CREATE_DATE == 2015-09-02 16:41:36.400411
# CREATE_DATE == 2015-09-02 16:45:52.837256
# CREATE_DATE == 2016-05-25 08:14:29.590032
# CREATE_DATE == 2016-05-24 13:16:20.937892
# CREATE_DATE == 2016-06-17 09:19:35.127037
# CREATE_DATE == 2016-05-24 13:16:35.517424
# CREATE_DATE == 2016-06-17 09:19:20.455068
# CREATE_DATE == 2016-05-24 13:14:55.919144
# CREATE_DATE == 2016-05-24 13:14:41.681927
# CREATE_DATE == 2016-05-24 13:15:10.467557
# CREATE_DATE == 2019-01-08 08:20:44.207000
# CREATE_DATE == 2010-08-02 08:57:30.338228
# CREATE_DATE == 2010-10-21 16:50:11.360761
# CREATE_DATE == 2015-04-29 13:06:38.476546
# CREATE_DATE == 2015-10-13 11:32:00.499090
# CREATE_DATE == 2016-09-14 08:39:30.714043
# CREATE_DATE == 2017-12-22 06:51:22.198424
# CREATE_DATE == 2015-04-29 13:06:47.398421
# CREATE_DATE == 2017-02-07 06:39:27.169873
# CREATE_DATE == 2010-10-13 16:45:15.309734
# CREATE_DATE == 2016-06-22 11:45:04.100166
# CREATE_DATE == 2016-09-29 15:02:42.044640
# CREATE_DATE == 2010-10-06 08:06:08.325580
# CREATE_DATE == 2011-12-16 08:10:53.389321
# CREATE_DATE == 2015-04-29 13:06:56.257796
# CREATE_DATE == 2015-10-15 14:43:36.802150
# CREATE_DATE == 2016-09-20 13:33:56.705800
# CREATE_DATE == 2018-03-27 09:42:48.330791
# CREATE_DATE == 2015-06-23 10:15:33.650838
# CREATE_DATE == 2019-02-14 18:43:19.700000
# CREATE_DATE == 2012-03-15 14:04:23.939866
# CREATE_DATE == 2015-06-23 11:08:47.905656
# CREATE_DATE == 2015-06-23 15:16:22.551780
# CREATE_DATE == 2019-02-14 18:43:56.555000
# CREATE_DATE == 2012-03-15 14:03:47.688938
# CREATE_DATE == 2019-08-09 16:42:22.795594
# CREATE_DATE == 2018-04-16 06:47:49.931148
# CREATE_DATE == 2019-08-07 16:23:52.874005
# CREATE_DATE == 2018-02-27 08:35:41.481699
# CREATE_DATE == 2019-04-29 08:34:07.233288
# CREATE_DATE == 2019-06-03 08:12:10.036287
# CREATE_DATE == 2019-03-13 17:50:53.306000
# 2019-03-25 00:00:00
