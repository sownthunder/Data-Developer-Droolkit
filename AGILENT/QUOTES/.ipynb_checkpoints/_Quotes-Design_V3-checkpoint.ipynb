# %%
import os, sys, time
from time import sleep
from pathlib import Path

# %%
import tkinter as tk
from tkinter import ttk, filedialog, messagebox

# %%
import sqlite3, logging

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
class QuotesBook: #{
    
    db_filename = "test_quotes.db"
    
    def __init__(self, root): #{
        self.root = root
        self.root.title('AGILENT Quotes')
        self.root.resizable(width=False, height=False)
        self.root.minsize(height=1250)
        # SETUP GUI CALL
        self.create_gui()
    #}
    
    def execute_db_query(self, query, parameters=()): #{
        with sqlite3.connect(self.db_filename) as conn: #{
            cursor = conn.cursor()
            query_result = cursor.execute(query, parameters)
            conn.commit()
        #}
        return query_result
    #}
    
    #############################################################
    def create_gui(self): #{
        # [2019-11-13]\\self.create_tab_control()
        self.create_left_side()
        self.create_tab_control()
        self.create_lblframe_create()
        self.create_right_side()
        self.create_tree_view()
        self.view_records()
    #}
    #############################################################
    
    def create_paned_windows(self): #{
        self.test_frame = tk.LabelFrame(master = self.root, text = "Test Frame:")
        self.test_frame.pack()
        
        self.m1 = tk.PanedWindow(master = self.test_frame)
        self.m1.pack(fill = tk.BOTH, expand = 1)
        
        self.left = tk.Entry(master = self.m1, bd = 2)
        self.m1.add(self.left)
        
        self.m2 = tk.PanedWindow(master = self.m1, orient = tk.VERTICAL)
        self.m1.add(self.m2)
        
        self.top = tk.Scale(master = self.m2, orient = tk.HORIZONTAL)
        self.m2.add(self.top)
        
        self.bottom = ttk.Button(master = self.m2, text = "OK")
        self.m2.add(self.bottom)
    #}
    
    def create_left_side(self): #{
        # Create a Frame Container
        self.leftframe = tk.Frame(self.root)
        self.leftframe.pack(side = tk.LEFT, fill = tk.BOTH, expand = False)
    #}
    
    def create_tab_control(self): #{
        # NOTEBOOK WIDGET
        self.tab_control = ttk.Notebook(self.leftframe)
        
        # TAB-1
        self.tab1 = ttk.Frame(self.tab_control)
        self.tab_control.add(self.tab1, text = 'CREATE')
        self.tab_control.pack(expand = 2, fill = tk.BOTH)
        
        # TAB-2
        self.tab2 = ttk.Frame(self.tab_control)
        self.tab_control.add(self.tab2, text = 'READ')
        self.tab_control.pack(expand = 2, fill = tk.BOTH)
        
        # TAB-3
        self.tab3 = ttk.Frame(self.tab_control)
        self.tab_control.add(self.tab3, text = 'UPDATE')
        self.tab_control.pack(expand = 2, fill = tk.BOTH)
        
        # TAB-4
        self.tab4 = ttk.Frame(self.tab_control)
        self.tab_control.add(self.tab4, text = "DELETE")
        self.tab_control.pack(expand = 2, fill = tk.BOTH)
        
    #}
    
    def create_lblframe_create(self): #{
        # Create the Tab Container
        self.lblframe_create=tk.LabelFrame(master=self.tab1, text="")
        self.lblframe_create.pack(anchor=tk.CENTER, fill=tk.BOTH, expand=False)
        
        # Name Input
        ttk.Label(master = self.lblframe_create, text = 'Name: ').grid(row=0, column=0, padx=5,
                                                                       pady=5, sticky='w')
        self.name = tk.Entry(master = self.lblframe_create, borderwidth=3)
        self.name.grid(row = 0, column = 1, sticky = 'w', padx = 5, pady = 5)
        
        # xXxXxXxXxXxXxXxXx
        # Email Input
        ttk.Label(master=self.lblframe_create, text='Email: ').grid(row=1, column=0, padx=5,
                                                                    pady=5, sticky='w')
        self.email = tk.Entry(master=self.lblframe_create, borderwidth=3)
        self.email.grid(row=1, column=1, sticky='w', padx=5, pady=5)
        
        # xXxXxXxXxXxXxXxXx
        # Type Input
        ttk.Label(master=self.lblframe_create, text='Type: ').grid(row=2, column=0, padx=5,
                                                                   pady=5, sticky='w')
        ############################
        # RADIO-VARIABLE == STRING #
        self.radio_type_var = tk.StringVar(master=self.lblframe_create, value="email")
        ################################################################################
        self.radio_type_1 = tk.Radiobutton(master=self.lblframe_create, variable=self.radio_type_var,
                                          value="web", text="WEB", relief=tk.RIDGE, width=5)
        self.radio_type_1.grid(row=2, column=1, sticky='w', padx=5, pady=5)
        self.radio_type_2 = tk.Radiobutton(master=self.lblframe_create, variable=self.radio_type_var,
                                          value="email", text="EMAIL", relief=tk.RIDGE, width=5)
        self.radio_type_2.grid(row=2, column=1, sticky='e', padx=5, pady=5)
        
        # xXxXxXxXxXxXxXxXx
        # Sent Input
        ttk.Label(master=self.lblframe_create, text='Sent: ').grid(row=3, column=0, padx=5,
                                                                  pady=5, stick='w')
        ##########################
        # RADIO-VARIABLE == BOOL #
        self.radio_sent_var = tk.BooleanVar(master=self.lblframe_create, value=False)
        ################################################################################
        self.radio_sent_1 = tk.Radiobutton(master=self.lblframe_create, variable=self.radio_sent_var, 
                                           value=True, text="YES", relief=tk.RIDGE, width=5)
        self.radio_sent_1.grid(row=3, column=1, sticky='w', padx=5, pady=5)
        self.radio_sent_2 = tk.Radiobutton(master=self.lblframe_create, variable=self.radio_sent_var,
                                          value=False, text="NO", relief=tk.RIDGE, width = 5)
        self.radio_sent_2.grid(row=3, column=1, sticky='e', padx=5, pady=5)
        
        # xXxXxXxXxXxXxXxXx
        # Notes Section
        ttk.Label(master=self.lblframe_create, text='Notes: ').grid(row=4, column=0, padx=5,
                                                                    pady=5, sticky='w')
        self.notes = tk.Text(master=self.lblframe_create, width=15, height=14, borderwidth=3)
        self.notes.grid(row=5, column=1, padx=5, sticky='w')
        # row = 6, column = 0, columnspan = 2 AND NO STICK OR PADX
        
    #}
    
    def create_lblframe_read(self): #{
        # Create the Tab Container
        self.lblframe_read=tk.LabelFrame(master=self.tab2, text="")
        self.lblframe_read.pack(anchor=tk.CENTER, fill=tk.BOTH, expand=False)
        
        # Filter Input
        ttk.Label(master = self.lblframe_create, text = 'Filter: ').grid(row=0, column=0, padx=5,
                                                                         pady=5, sticky='w')
        #self.filter = ttk.Listbox(master=self.tab2, )
        self.spinval = tk.StringVar()
        self.s = ttk.Spinbox(self.tab2, from_=1.0, to=100.0, textvariable=self.spinval)
        self.s.grid(row=0, column=1, sticky='w', padx=5, pady=5)
    #}
    
    def create_tab_contents(self): #{
        pass
    #}
    
    def read_tab_contents(self): #{
        pass
    #}
    
    def update_tab_contents(self): #{
        pass
    #}
    
    def delete_tab_contents(self): #{
        pass
    #}
        
    def create_right_side(self): #{
        # Create a Frame Container
        self.rightframe = tk.Frame(master = self.root)
        self.rightframe.pack(side = tk.RIGHT, fill = tk.BOTH, expand = True)
    #}
    
    def create_tree_view(self): #{
        # TABLE
        self.tree = ttk. Treeview(master = self.rightframe, height = 20, columns = 8)
        self.tree["columns"] = ("one","two","three","four","five","six","seven")
        self.tree.column('#0', width=80, minwidth=80, stretch=tk.NO)
        self.tree.column("one", width=125, minwidth=125, stretch=tk.NO)
        self.tree.column("two", width=150, minwidth=150, stretch=tk.NO)
        self.tree.column("three", width=40, minwidth=40, stretch=tk.NO)
        self.tree.column("four", width=150, minwidth=150, stretch=tk.NO)
        self.tree.column("five", width=40, minwidth=35, stretch=tk.NO)
        self.tree.column("six", width=80, minwidth=75, stretch=tk.NO)
        self.tree.column("seven", width=80, minwidth=75, stretch=tk.NO)
        
        # Definitions of Headings
        self.tree.grid(row = 1, column = 0, columnspan = 8)
        self.tree.heading('#0', text = 'Tracking #', anchor = tk.CENTER)
        self.tree.heading('#1', text = 'Name', anchor = tk.CENTER)
        self.tree.heading('#2', text = 'Email', anchor = tk.CENTER)
        self.tree.heading('#3', text = 'Type', anchor = tk.CENTER)
        self.tree.heading('#4', text = 'Timestamp', anchor = tk.CENTER)
        self.tree.heading('#5', text = 'Sent', anchor = tk.CENTER)
        self.tree.heading('#6', text = 'Quote #', anchor = tk.CENTER)
        self.tree.heading('#7', text = 'Product #', anchor = tk.CENTER)
    #}
    
    def view_records(self): #{
        print("...BEGIN READING IN RECORDS...")
        # TRY THE FOLLOWING
        try: #{
            items = self.tree.get_children()
            for item in items: #{
                self.tree.delete(item)
            #}
            query = 'SELECT * FROM quotes ORDER BY NAME desc'
            quote_book_entries = self.execute_db_query(query)
            for row in quote_book_entries: #{
                logging.info("TRACKING # == " + str(row[0]))
                logging.info("NAME === " + str(row[1]))
                logging.info("Email == " + str(row[2]))
                logging.info("Type == " + str(row[3]))
                logging.info("Timestamp == " + str(row[4]))
                logging.info("Sent == " + str(row[5]))
                # CREATE LIST
                test_lst = [str(row[1]), str(row[2]), str(row[3]), str(row[4]), str(row[5])]
                # INSERT INTO TREE
                self.tree.insert('', 0, text=str(row[0]), values=test_lst)
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\t" + str(errorMessage) + "\n")
            logging.error("\n" + typeE +
                  "\n" + fileE +
                  "\n" + lineE +
                  "\n" + messageE)
        #}
        else: #{
            print("Operation done successfully")
        #}
    #} 
#}

# %%
def setup_logger(): #{
    # TRY THE FOLLOWING
    try: #{
        logging.basicConfig(level=logging.INFO,
                            format='%(asctime)s: %(message)s',
                            filemode='a')
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\t" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        pass
    #}
#}

# %%
if __name__ == "__main__": #{
    setup_logger()
    # TRY THE FOLLOWING
    try: #{
        window = tk.Tk()
        application = QuotesBook(window)
        window.mainloop()
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\t" + str(errorMessage) + "\n")
        logging.critical("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("Operation done successfully")
    #}
#}
# Out:
# 2019-11-15 16:43:44,477: TRACKING # == ABCDEF9
# 2019-11-15 16:43:44,482: NAME === vdfavfadv
# 2019-11-15 16:43:44,482: Email == dfvsdfvsdf
# 2019-11-15 16:43:44,483: Type == email
# 2019-11-15 16:43:44,484: Timestamp == 2019-10-29 16:12:30.709841
# 2019-11-15 16:43:44,485: Sent == False
# 2019-11-15 16:43:44,486: TRACKING # ==
# 2019-11-15 16:43:44,487: NAME === tootoot
# 2019-11-15 16:43:44,487: Email == gdfsljnsdjfkgb
# 2019-11-15 16:43:44,488: Type == email
# 2019-11-15 16:43:44,489: Timestamp == 2019-10-28 10:26:54.889358
# 2019-11-15 16:43:44,490: Sent == False
# 2019-11-15 16:43:44,492: TRACKING # ==
# 2019-11-15 16:43:44,493: NAME === tootoot
# 2019-11-15 16:43:44,493: Email == gdfsljnsdjfkgb
# 2019-11-15 16:43:44,495: Type == email
# 2019-11-15 16:43:44,495: Timestamp == 2019-10-28 10:26:54.889358
# 2019-11-15 16:43:44,496: Sent == False
# 2019-11-15 16:43:44,498: TRACKING # == ABCDEF19
# 2019-11-15 16:43:44,499: NAME === too many ppops
# 2019-11-15 16:43:44,499: Email == tom@myspace.com
# 2019-11-15 16:43:44,500: Type == web
# 2019-11-15 16:43:44,503: Timestamp == 2019-11-12 12:53:55.117293
# 2019-11-15 16:43:44,504: Sent == False
# 2019-11-15 16:43:44,506: TRACKING # ==
# 2019-11-15 16:43:44,507: NAME === tony the tiger
# 2019-11-15 16:43:44,508: Email == tony@tiger.com
# 2019-11-15 16:43:44,509: Type == email
# 2019-11-15 16:43:44,509: Timestamp == 2019-10-28 13:39:40.797271
# 2019-11-15 16:43:44,510: Sent == False
# 2019-11-15 16:43:44,511: TRACKING # ==
# 2019-11-15 16:43:44,512: NAME === tony the tiger
# 2019-11-15 16:43:44,512: Email == tony@tiger.com
# 2019-11-15 16:43:44,513: Type == email
# 2019-11-15 16:43:44,513: Timestamp == 2019-10-28 13:39:40.797271
# 2019-11-15 16:43:44,514: Sent == False
# 2019-11-15 16:43:44,515: TRACKING # == ABCDEF9
# 2019-11-15 16:43:44,516: NAME === tony the tiger
# 2019-11-15 16:43:44,516: Email == yourmom@myhouse.com
# 2019-11-15 16:43:44,517: Type == email
# 2019-11-15 16:43:44,518: Timestamp == 2019-10-29 10:24:53.472587
# 2019-11-15 16:43:44,519: Sent == False
# 2019-11-15 16:43:44,520: TRACKING # == ABCDEF24
# 2019-11-15 16:43:44,525: NAME === tjetujumm
# 2019-11-15 16:43:44,526: Email == myurmyrumuymuy
# 2019-11-15 16:43:44,527: Type == email
# 2019-11-15 16:43:44,528: Timestamp == 2019-10-28 14:45:49.351799
# 2019-11-15 16:43:44,530: Sent == False
# 2019-11-15 16:43:44,531: TRACKING # ==
# 2019-11-15 16:43:44,532: NAME === test test
# 2019-11-15 16:43:44,533: Email == test test
# 2019-11-15 16:43:44,535: Type == email
# 2019-11-15 16:43:44,536: Timestamp == 2019-10-28 13:38:43.883731
# 2019-11-15 16:43:44,536: Sent == False
# 2019-11-15 16:43:44,538: TRACKING # ==
# 2019-11-15 16:43:44,539: NAME === test name
# 2019-11-15 16:43:44,540: Email == test temail
# 2019-11-15 16:43:44,541: Type == email
# 2019-11-15 16:43:44,543: Timestamp == 2019-10-28 13:42:22.948644
# 2019-11-15 16:43:44,544: Sent == False
# 2019-11-15 16:43:44,545: TRACKING # ==
# 2019-11-15 16:43:44,545: NAME === test
# 2019-11-15 16:43:44,546: Email == test
# 2019-11-15 16:43:44,547: Type == email
# 2019-11-15 16:43:44,549: Timestamp == 2019-10-28 13:43:32.568266
# 2019-11-15 16:43:44,550: Sent == False
# 2019-11-15 16:43:44,552: TRACKING # == ABCDEF19
# 2019-11-15 16:43:44,553: NAME === svsdvksdbv
# 2019-11-15 16:43:44,554: Email == vsdfkvsdfv
# 2019-11-15 16:43:44,555: Type == web
# 2019-11-15 16:43:44,555: Timestamp == 2019-10-30 12:13:49.466213
# 2019-11-15 16:43:44,556: Sent == True
# 2019-11-15 16:43:44,558: TRACKING # == ABCDEF5
# 2019-11-15 16:43:44,559: NAME === sdfgasfg
# 2019-11-15 16:43:44,560: Email == dgasdfgfg
# 2019-11-15 16:43:44,561: Type == web
# 2019-11-15 16:43:44,562: Timestamp == 2019-10-30 12:12:13.344311
# 2019-11-15 16:43:44,563: Sent == True
# 2019-11-15 16:43:44,564: TRACKING # ==
# 2019-11-15 16:43:44,564: NAME === sdbdfgb
# 2019-11-15 16:43:44,565: Email == gbfgbfgb
# 2019-11-15 16:43:44,565: Type == email
# 2019-11-15 16:43:44,566: Timestamp == 2019-10-28 10:37:06.567168
# 2019-11-15 16:43:44,566: Sent == False
# 2019-11-15 16:43:44,568: TRACKING # == ABCDEF25
# 2019-11-15 16:43:44,570: NAME === ruykruyk
# 2019-11-15 16:43:44,572: Email == ryukryukryu
# 2019-11-15 16:43:44,573: Type == email
# 2019-11-15 16:43:44,574: Timestamp == 2019-10-28 14:47:13.358669
# 2019-11-15 16:43:44,576: Sent == False
# 2019-11-15 16:43:44,577: TRACKING # ==
# 2019-11-15 16:43:44,578: NAME === nhgndghn
# 2019-11-15 16:43:44,579: Email == nsfgnfsgn
# 2019-11-15 16:43:44,580: Type == email
# 2019-11-15 16:43:44,581: Timestamp == 2019-10-28 10:58:02.554249
# 2019-11-15 16:43:44,582: Sent == False
# 2019-11-15 16:43:44,584: TRACKING # ==
# 2019-11-15 16:43:44,585: NAME === howdy do
# 2019-11-15 16:43:44,586: Email == todd@twinkle.com
# 2019-11-15 16:43:44,587: Type == email
# 2019-11-15 16:43:44,588: Timestamp == 2019-10-25 16:10:05.098918
# 2019-11-15 16:43:44,589: Sent == False
# 2019-11-15 16:43:44,590: TRACKING # ==
# 2019-11-15 16:43:44,591: NAME === hghm
# 2019-11-15 16:43:44,592: Email == mmgh
# 2019-11-15 16:43:44,592: Type == email
# 2019-11-15 16:43:44,593: Timestamp == 2019-10-28 10:59:45.288851
# 2019-11-15 16:43:44,594: Sent == False
# 2019-11-15 16:43:44,595: TRACKING # == ABCDEF20
# 2019-11-15 16:43:44,596: NAME === heyheyey
# 2019-11-15 16:43:44,597: Email == whats@app.com
# 2019-11-15 16:43:44,598: Type == email
# 2019-11-15 16:43:44,599: Timestamp == 2019-10-29 10:20:47.931404
# 2019-11-15 16:43:44,600: Sent == False
# 2019-11-15 16:43:44,602: TRACKING # == ABCDEF1
# 2019-11-15 16:43:44,603: NAME === hey tehre
# 2019-11-15 16:43:44,604: Email == pop@head.com
# 2019-11-15 16:43:44,605: Type == email
# 2019-11-15 16:43:44,606: Timestamp == 2019-10-28 15:16:24.186292
# 2019-11-15 16:43:44,607: Sent == False
# 2019-11-15 16:43:44,608: TRACKING # == ABCDEF23
# 2019-11-15 16:43:44,609: NAME === gfhfgh
# 2019-11-15 16:43:44,610: Email == gfhdgfhdfgh
# 2019-11-15 16:43:44,610: Type == email
# 2019-11-15 16:43:44,611: Timestamp == 2019-10-28 13:54:04.207787
# 2019-11-15 16:43:44,612: Sent == False
# 2019-11-15 16:43:44,613: TRACKING # ==
# 2019-11-15 16:43:44,613: NAME === fvsfdbb
# 2019-11-15 16:43:44,614: Email == cvbvcxvb
# 2019-11-15 16:43:44,615: Type == email
# 2019-11-15 16:43:44,615: Timestamp == 2019-10-28 13:36:47.574676
# 2019-11-15 16:43:44,616: Sent == False
# 2019-11-15 16:43:44,617: TRACKING # == ABCDEF4
# 2019-11-15 16:43:44,618: NAME === fskdfasdbkvadv
# 2019-11-15 16:43:44,619: Email == sbgfbfgbdgfbgfdg
# 2019-11-15 16:43:44,619: Type == web
# 2019-11-15 16:43:44,620: Timestamp == 2019-10-30 12:09:56.146552
# 2019-11-15 16:43:44,621: Sent == True
# 2019-11-15 16:43:44,622: TRACKING # == ABCDEF4
# 2019-11-15 16:43:44,622: NAME === fskdfasdbkvadv
# 2019-11-15 16:43:44,623: Email == sbgfbfgbdgfbgfdg
# 2019-11-15 16:43:44,624: Type == web
# 2019-11-15 16:43:44,625: Timestamp == 2019-10-30 12:09:56.146552
# 2019-11-15 16:43:44,629: Sent == True
# 2019-11-15 16:43:44,631: TRACKING # == ABCDEF25
# 2019-11-15 16:43:44,632: NAME === fnfgndgh
# 2019-11-15 16:43:44,632: Email == gfndfgn
# 2019-11-15 16:43:44,634: Type == email
# 2019-11-15 16:43:44,635: Timestamp == 2019-10-28 14:46:25.687763
# 2019-11-15 16:43:44,636: Sent == False
# 2019-11-15 16:43:44,637: TRACKING # ==
# 2019-11-15 16:43:44,637: NAME === dsfadvxcvz
# 2019-11-15 16:43:44,638: Email == xzxcvbbvcb
# 2019-11-15 16:43:44,639: Type == email
# 2019-11-15 16:43:44,640: Timestamp == 2019-10-28 13:37:58.359884
# 2019-11-15 16:43:44,641: Sent == False
# 2019-11-15 16:43:44,643: TRACKING # ==
# 2019-11-15 16:43:44,643: NAME === dsafasdf
# 2019-11-15 16:43:44,644: Email == dassssssssss
# 2019-11-15 16:43:44,645: Type == email
# 2019-11-15 16:43:44,645: Timestamp == 2019-10-28 13:48:18.037284
# 2019-11-15 16:43:44,646: Sent == False
# 2019-11-15 16:43:44,646: TRACKING # == ABCDEF21
# 2019-11-15 16:43:44,647: NAME === dhgdhgm
# 2019-11-15 16:43:44,648: Email == hgmhmhg
# 2019-11-15 16:43:44,648: Type == email
# 2019-11-15 16:43:44,651: Timestamp == 2019-10-28 14:48:03.774191
# 2019-11-15 16:43:44,652: Sent == False
# 2019-11-15 16:43:44,653: TRACKING # == ABCDEF8
# 2019-11-15 16:43:44,653: NAME === dfgsdfb
# 2019-11-15 16:43:44,654: Email == sfdbsdfbsfgbfgb
# 2019-11-15 16:43:44,655: Type == web
# 2019-11-15 16:43:44,655: Timestamp == 2019-10-29 16:53:05.708864
# ...BEGIN READING IN RECORDS...
# 2019-11-15 16:43:44,656: Sent == True
# 2019-11-15 16:43:44,658: TRACKING # ==
# 2019-11-15 16:43:44,658: NAME === cvvvvvvvvv
# 2019-11-15 16:43:44,659: Email == zxcxcxcxcxcxcxcxcxcxcxc
# 2019-11-15 16:43:44,659: Type == email
# 2019-11-15 16:43:44,660: Timestamp == 2019-10-28 11:39:40.765884
# 2019-11-15 16:43:44,660: Sent == False
# 2019-11-15 16:43:44,661: TRACKING # == ABCDEF8
# 2019-11-15 16:43:44,661: NAME === bsfgbsgfb
# 2019-11-15 16:43:44,662: Email == fgbdfgbsfb
# 2019-11-15 16:43:44,663: Type == email
# 2019-11-15 16:43:44,663: Timestamp == 2019-10-28 15:10:12.450530
# 2019-11-15 16:43:44,664: Sent == False
# 2019-11-15 16:43:44,665: TRACKING # == ABCDEF12
# 2019-11-15 16:43:44,666: NAME === bfbsdfbsdfbfsdsfdb
# 2019-11-15 16:43:44,667: Email == bsf
# 2019-11-15 16:43:44,668: Type == email
# 2019-11-15 16:43:44,668: Timestamp == 2019-10-28 15:11:54.702331
# 2019-11-15 16:43:44,669: Sent == False
# 2019-11-15 16:43:44,673: TRACKING # == ABCDEF11
# 2019-11-15 16:43:44,674: NAME === avffadvadfv
# 2019-11-15 16:43:44,675: Email == fdvafdvadfvadfv
# 2019-11-15 16:43:44,675: Type == email
# 2019-11-15 16:43:44,676: Timestamp == 2019-10-28 15:13:56.412191
# 2019-11-15 16:43:44,677: Sent == False
# 2019-11-15 16:43:44,679: TRACKING # ==
# 2019-11-15 16:43:44,681: NAME === asdfsadfdsasd
# 2019-11-15 16:43:44,682: Email == asdfasdfasdf
# 2019-11-15 16:43:44,683: Type == email
# 2019-11-15 16:43:44,684: Timestamp == 2019-10-28 13:30:44.740606
# 2019-11-15 16:43:44,686: Sent == False
# 2019-11-15 16:43:44,687: TRACKING # ==
# 2019-11-15 16:43:44,689: NAME === asdfsadfdsasd
# 2019-11-15 16:43:44,690: Email == asdfasdfasdf
# 2019-11-15 16:43:44,691: Type == email
# 2019-11-15 16:43:44,692: Timestamp == 2019-10-28 13:30:44.740606
# 2019-11-15 16:43:44,694: Sent == False
# 2019-11-15 16:43:44,695: TRACKING # ==
# 2019-11-15 16:43:44,695: NAME === asdfsadf
# 2019-11-15 16:43:44,696: Email == asdfasdf
# 2019-11-15 16:43:44,697: Type == email
# 2019-11-15 16:43:44,698: Timestamp == 2019-10-28 13:30:44.740606
# 2019-11-15 16:43:44,699: Sent == False
# 2019-11-15 16:43:44,701: TRACKING # ==
# 2019-11-15 16:43:44,702: NAME === agdfg
# 2019-11-15 16:43:44,703: Email == dfdddddddddddd
# 2019-11-15 16:43:44,703: Type == email
# 2019-11-15 16:43:44,704: Timestamp == 2019-10-28 13:47:18.110692
# 2019-11-15 16:43:44,705: Sent == False
# 2019-11-15 16:43:44,706: TRACKING # ==
# 2019-11-15 16:43:44,708: NAME === Tony Saprano
# 2019-11-15 16:43:44,709: Email == tony@danza.com
# 2019-11-15 16:43:44,710: Type == email
# 2019-11-15 16:43:44,711: Timestamp == 2019-10-28 09:57:54.183824
# 2019-11-15 16:43:44,712: Sent == False
# 2019-11-15 16:43:44,714: TRACKING # == ABCDEF6
# 2019-11-15 16:43:44,715: NAME === Tony Danza
# 2019-11-15 16:43:44,716: Email == tony@donza.com
# 2019-11-15 16:43:44,716: Type == email
# 2019-11-15 16:43:44,717: Timestamp == 2019-10-28 15:14:56.566217
# 2019-11-15 16:43:44,718: Sent == False
# 2019-11-15 16:43:44,720: TRACKING # ==
# 2019-11-15 16:43:44,720: NAME === Todd Twinkle
# 2019-11-15 16:43:44,721: Email == todd@twinkle.com
# 2019-11-15 16:43:44,722: Type == email
# 2019-11-15 16:43:44,723: Timestamp == 2019-10-25 16:05:46.173234
# 2019-11-15 16:43:44,724: Sent == False
# 2019-11-15 16:43:44,724: TRACKING # ==
# 2019-11-15 16:43:44,725: NAME === TOdd Twinkle
# 2019-11-15 16:43:44,726: Email == hello
# 2019-11-15 16:43:44,726: Type == email
# 2019-11-15 16:43:44,727: Timestamp == 2019-10-25 16:07:29.596832
# 2019-11-15 16:43:44,728: Sent == False
# 2019-11-15 16:43:44,731: TRACKING # == ABCDEF18
# 2019-11-15 16:43:44,734: NAME === Michael Thomas
# 2019-11-15 16:43:44,735: Email == michael@thomas.com
# 2019-11-15 16:43:44,737: Type == web
# 2019-11-15 16:43:44,738: Timestamp == 2019-10-29 16:19:59.113876
# 2019-11-15 16:43:44,740: Sent == True
# 2019-11-15 16:43:44,741: TRACKING # == ABCDEF12
# 2019-11-15 16:43:44,743: NAME === Michael LeBerche
# 2019-11-15 16:43:44,744: Email == mike@ikes.com
# 2019-11-15 16:43:44,745: Type == email
# 2019-11-15 16:43:44,747: Timestamp == 2019-10-29 16:10:47.336806
# 2019-11-15 16:43:44,748: Sent == False
# 2019-11-15 16:43:44,750: TRACKING # == ABCDEF9
# 2019-11-15 16:43:44,751: NAME === Larry Fuckward
# 2019-11-15 16:43:44,752: Email == fuckward@larry.com
# 2019-11-15 16:43:44,753: Type == email
# 2019-11-15 16:43:44,753: Timestamp == 2019-10-28 15:17:37.794853
# 2019-11-15 16:43:44,754: Sent == False
# 2019-11-15 16:43:44,755: TRACKING # == ABCDEF21
# 2019-11-15 16:43:44,756: NAME === Bill Cosby
# 2019-11-15 16:43:44,756: Email == pudding@qualudes.net
# 2019-11-15 16:43:44,757: Type == web
# 2019-11-15 16:43:44,758: Timestamp == 2019-10-30 16:08:16.600020
# 2019-11-15 16:43:44,758: Sent == False
# 2019-11-15 16:43:44,759: TRACKING # == ABCDEF21
# 2019-11-15 16:43:44,759: NAME === Bill Cosby
# 2019-11-15 16:43:44,760: Email == pudding@qualudes.net
# 2019-11-15 16:43:44,760: Type == email
# 2019-11-15 16:43:44,761: Timestamp == 2019-10-30 16:08:16.600020
# 2019-11-15 16:43:44,761: Sent == True
# 2019-11-15 16:43:44,763: TRACKING # == ABCDEF15
# 2019-11-15 16:43:44,766: NAME ===
# 2019-11-15 16:43:44,766: Email ==
# 2019-11-15 16:43:44,767: Type == email
# 2019-11-15 16:43:44,769: Timestamp == 2019-10-28 14:59:09.534200
# 2019-11-15 16:43:44,769: Sent == False
# 2019-11-15 16:43:44,770: TRACKING # == ABCDEF7
# 2019-11-15 16:43:44,771: NAME ===
# 2019-11-15 16:43:44,772: Email ==
# 2019-11-15 16:43:44,772: Type == email
# 2019-11-15 16:43:44,773: Timestamp == 2019-11-05 14:03:18.202696
# 2019-11-15 16:43:44,774: Sent == False
# Operation done successfully
