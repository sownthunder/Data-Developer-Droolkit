# %%
import os, sys, time
from time import sleep
import email
import ssl, imaplib
from ssl import Purpose
import pprint
import configparser

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
try: #{
    imap_host = 'outlook.office365.com'  # WAS: 'imap.agilent.com'
    imap_user = 'derek.bates@non.agilent.com'
    imap_pass = '@hisBooty!23'
    
    # CONNECT TO HOST USING SSL
    imap = imaplib.IMAP4(imap_host, port=993)
    #imap.starttls()
    
    imap.login(imap_user, imap_pass)
    
    imap.select('inbox')
    
    tmp, data = imap.search(None, 'ALL')
    for num in data[0].split(): #{
        tmp, data = imap.fetch(num, '(RFC822)')
        print('Message: {0}\n'.format(num))
        pprint.pprint(data[0][1])
        break
    #}
    imap.close()
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
    print("\n" + typeE +
          "\n" + fileE +
          "\n" + lineE +
          "\n" + messageE)
#}
else: #{
    print("SUCCESS!! ")
#}
# Out:
# TYPE : <class 'imaplib.IMAP4.abort'>
# FILE : <ipython-input-3-588b55b822b4>
# LINE : 7
# MESG :
# <class 'imaplib.IMAP4.abort'>
# 		socket error: EOF
# 		<traceback object at 0x0000025BE7613708>

# %% [markdown]
# # SPACE BREAK

# %%
imap_host = 'outlook.office365.com'  # WAS: 'imap.agilent.com'
imap_user = 'derek.bates@non.agilent.com'
imap_pass = '@hisBooty!23'

use_tls = True

try: #{
    """
    # CONNECT TO HOST USING SSL
    imap = imaplib.IMAP4(imap_host, port=993)
    if use_tls: #{
        imap.starttls()
    #}
    """
    
    # CONNECT TO HOST USING SSL
    context = ssl.create_default_context(Purpose.CLIENT_AUTH)
    imap = imaplib.IMAP4_SSL(imap_host, port=993, ssl_context=context)
    
    ### LOGIN TO SERVER
    imap.login(imap_user, imap_pass)
    
    imap.select('Inbox')
    
    tmp, data = imap.search(None, 'ALL')
    for num in data[0].split(): #{
        tmp, data = imap.fetch(num, '(RFC822)')
        print('Message: {0}\n'.format(num))
        pprint.pprint(data[0][1])
        break
    #}
    imap.close()
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
    print("\n" + typeE +
          "\n" + fileE +
          "\n" + lineE +
          "\n" + messageE)
#}
else: #{
    print("SUCCESS!")
#}
# Out:
# TYPE : <class 'imaplib.IMAP4.error'>
# FILE : <ipython-input-4-226720ed8772>
# LINE : 21
# MESG :
# <class 'imaplib.IMAP4.error'>
# 		b'LOGIN failed.'
# 		<traceback object at 0x0000016BB48C9A88>

# %% [markdown]
# def read_email(username, password, server="imap.aggilent.com", port=993, use_tls=True): #{
#
#     imap_host = str(server)
#     imap_user = str(username)
#     imap_pass = str(password)
#
#     imap = imaplib.IMAP4(imap_host, port)
#     if use_tls: #{
#         imap.
#     #}
#
# #}

# %% [raw]
# def open_connection(verbose=False): #{
#     # READ THE CONFIG FILE
#     config = configparser.ConfigParser()
#     config.read([os.path.expanduser('~/.pymotw')])
#
#     # CONNECT TO THE SERVER
#     hostname = config.get('server', 'hostname')
#     if verbose: #{
#         print("connecting to", hostname)
#     #}
#     connection = imaplib.IMAP4_SSL(hostname)
#
#     # LOGIN TO OUR ACCOUNT
#     username = config.get('account', 'username')
#     password = config.get('account', 'password')
#     if verbose: #{
#         print("Logging in as", username)
#     #}
#     connection.login(username, password)
#     return connection
#
# #}

# %% [markdown]
# ---

# %%
df_test_quote_1 = pd.read_excel("C:/data/inbound/Quote Details_1569338365749.xlsx", sheet_name=0, dtype=np.str)

# %%
df_test_quote_1
# Out:
#   Unique Request ID    Product Name Product Type/Product Class  \
# 0     1569338365749  CustomStandard                       Neat
#
#                Origination Date Matrix Number/Matrix Name Component IDs  \
# 0  Tue Sep 24 15:19:26 UTC 2019                       NaN             1
#
#   Quantity Fill Size First Name Last Name Phone                      Email  \
# 0        1      1 mL    MICHIEL      MICA   NaN  michiel_mica3@agilent.com
#
#   Product Level
# 0       Level 1

# %%
print(df_test_quote_1["Origination Date"][0])
# Out:
# Tue Sep 24 15:19:26 UTC 2019

# %%
test_timestamp = pd.Timestamp(ts_input=df_test_quote_1["Origination Date"][0])

# %%
print(test_timestamp)
# Out:
# 2019-09-24 15:19:26+00:00

# %%
df_test_quote_2 = pd.read_excel("C:/data/inbound/Quote Details_1569338365749.xlsx", sheet_name=1, dtype=np.str)

# %%
df_test_quote_2
# Out:
#   Unique Request ID Component# Component ID
# 0     1569338365749          1    6982-25-8

# %%
df_inbox = pd.read_excel("C:/data/inbound/Inbox.xlsx", sheet_name=0, dtype=np.str)

# %%
df_inbox
# Out:
#      Importance      Icon Priority  \
# 0             1  IPM.Note        0
# 1             1  IPM.Note        0
# 2             1  IPM.Note        0
# 3             1  IPM.Note        0
# 4             1  IPM.Note        0
# ...         ...       ...      ...
# 7033          1  IPM.Note        0
# 7034          1  IPM.Note        0
# 7035          1  IPM.Note        0
# 7036          1  IPM.Note        0
# 7037          1  IPM.Note        0
#
#                                                 Subject  \
# 0                      Timekeeping Deadline Approaching
# 1                                       phone and email
# 2                                      RE: Import Files
# 3                                  Sending a test email
# 4                        Re: ULTRA Scientific - Go Live
# ...                                                 ...
# 7033              FW: CS Update for Rhode Island Office
# 7034                                                NaN
# 7035              RE: CS Update for Rhode Island Office
# 7036                                           Re: IMAP
# 7037  Action Required-Application Patches implementa...
#
#                                  From Message To Me Message CC to Me  \
# 0             eet_application@adp.com          True            False
# 1                         Don McGlory           NaN              NaN
# 2     ROMIG,LINDA (A-LittleFalls,ex1)          True            False
# 3                      Mayank Agrawal           NaN              NaN
# 4                      Mayank Agrawal           NaN              NaN
# ...                               ...           ...              ...
# 7033     SCHULTZ,JOANNE (Agilent USA)          True            False
# 7034   LABRECHE,MICHAEL (Agilent USA)          True            False
# 7035     SCHULTZ,JOANNE (Agilent USA)         False             True
# 7036     GONZALEZ,CESAR (Agilent USA)          True            False
# 7037             ISRM,APPSEC (Shared)           NaN              NaN
#
#                           Sender Name  \
# 0             eet_application@adp.com
# 1                         Don McGlory
# 2     ROMIG,LINDA (A-LittleFalls,ex1)
# 3                      Mayank Agrawal
# 4                      Mayank Agrawal
# ...                               ...
# 7033     SCHULTZ,JOANNE (Agilent USA)
# 7034   LABRECHE,MICHAEL (Agilent USA)
# 7035     SCHULTZ,JOANNE (Agilent USA)
# 7036     GONZALEZ,CESAR (Agilent USA)
# 7037             ISRM,APPSEC (Shared)
#
#                                                      CC  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Nicole Clauberg; Michael LaBreche; Govinda Ber...
# 4     Navyasheel Laxminarayan Chippa; Nicole Clauber...
# ...                                                 ...
# 7033  WONG,RICHARD (Agilent USA); TATMAN,PHYLLIS (Ag...
# 7034                                                NaN
# 7035  TATMAN,PHYLLIS (Agilent USA); LABRECHE,MICHAEL...
# 7036                                                NaN
# 7037                                                NaN
#
#                                                      To             Received  \
# 0                LABRECHE,MICHAEL (A-United States,ex1)  2018-09-25 04:19:21
# 1                                      Michael LaBreche  2018-09-25 08:40:41
# 2                LABRECHE,MICHAEL (A-United States,ex1)  2018-09-25 09:47:23
# 3     ny93u7n85jp@networksolutionsprivateregistratio...  2018-09-25 10:05:31
# 4                        DE-MELO,EDWARD (Non-A-USA,ex1)  2018-09-25 10:06:06
# ...                                                 ...                  ...
# 7033  LABRECHE,MICHAEL (Agilent USA); BATES,DEREK (N...  2019-09-25 09:35:25
# 7034                     LABRECHE,MICHAEL (Agilent USA)  2019-09-25 10:28:44
# 7035                         WONG,RICHARD (Agilent USA)  2019-09-25 11:18:06
# 7036                     LABRECHE,MICHAEL (Agilent USA)  2019-09-25 11:29:40
# 7037                                                NaN  2019-09-25 11:46:36
#
#      Message Size                                           Contents  \
# 0           56019  Reminder: The timekeeping deadline for the cur...
# 1           17592  Mike,\n\n \n\nI have a company issued phone th...
# 2           55428  Thanks!\n\n \n\nFrom: LABRECHE,MICHAEL (A-Unit...
# 3           43320  Please confirm who received this email. Please...
# 4           58814  Mike\n\nAs part of the Go Live, we need to mak...
# ...           ...                                                ...
# 7033        68184  Michael and Derek, \n\nPlease get the specs fo...
# 7034       312013                                                NaN
# 7035        61002  @WONG,RICHARD (Agilent USA) <mailto:richard.wo...
# 7036       104876  Hey Michael,\n\n                Take a look at...
# 7037       185769  Hi Team,\n\nDescription:\n\nNew ISRM Applicati...
#
#                   Created             Modified Subject Prefix Has Attachments  \
# 0     2018-09-25 04:19:20  2018-09-25 04:19:22            NaN           False
# 1     2019-01-07 09:30:09  2019-01-07 09:30:09            NaN           False
# 2     2018-09-25 09:47:23  2018-09-25 09:47:24            RE:            True
# 3     2019-01-07 09:30:08  2019-01-07 09:30:09            NaN           False
# 4     2019-01-07 09:30:08  2019-01-07 09:30:08            Re:           False
# ...                   ...                  ...            ...             ...
# 7033  2019-09-25 09:35:24  2019-09-25 09:38:19            FW:           False
# 7034  2019-09-25 10:28:44  2019-09-25 10:37:47            NaN            True
# 7035  2019-09-25 11:18:05  2019-09-25 11:18:06            RE:           False
# 7036  2019-09-25 11:29:40  2019-09-25 11:41:29            Re:            True
# 7037  2019-09-25 11:46:36  2019-09-25 11:46:37            NaN            True
#
#                                      Normalized Subject Object Type  \
# 0                      Timekeeping Deadline Approaching           5
# 1                                       phone and email           5
# 2                                          Import Files           5
# 3                                  Sending a test email           5
# 4                            ULTRA Scientific - Go Live           5
# ...                                                 ...         ...
# 7033                  CS Update for Rhode Island Office           5
# 7034                                                NaN           5
# 7035                  CS Update for Rhode Island Office           5
# 7036                                               IMAP           5
# 7037  Action Required-Application Patches implementa...           5
#
#      Content Unread
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 7033            NaN
# 7034            NaN
# 7035            NaN
# 7036            NaN
# 7037            NaN
#
# [7038 rows x 20 columns]

# %%
df_dedupped = df_inbox.drop_duplicates(subset=['Subject'])

# %%
df_dedupped
# Out:
#      Importance      Icon Priority  \
# 0             1  IPM.Note        0
# 1             1  IPM.Note        0
# 2             1  IPM.Note        0
# 3             1  IPM.Note        0
# 4             1  IPM.Note        0
# ...         ...       ...      ...
# 7029          1  IPM.Note        0
# 7030          1  IPM.Note        0
# 7033          1  IPM.Note        0
# 7035          1  IPM.Note        0
# 7036          1  IPM.Note        0
#
#                                                 Subject  \
# 0                      Timekeeping Deadline Approaching
# 1                                       phone and email
# 2                                      RE: Import Files
# 3                                  Sending a test email
# 4                        Re: ULTRA Scientific - Go Live
# ...                                                 ...
# 7029  Reminder: CSD Above and Beyond Nominations Due...
# 7030         New PC (PO 9200321262) Shipped from HP_APS
# 7033              FW: CS Update for Rhode Island Office
# 7035              RE: CS Update for Rhode Island Office
# 7036                                           Re: IMAP
#
#                                  From Message To Me Message CC to Me  \
# 0             eet_application@adp.com          True            False
# 1                         Don McGlory           NaN              NaN
# 2     ROMIG,LINDA (A-LittleFalls,ex1)          True            False
# 3                      Mayank Agrawal           NaN              NaN
# 4                      Mayank Agrawal           NaN              NaN
# ...                               ...           ...              ...
# 7029         MARR,MEGAN (Agilent USA)           NaN              NaN
# 7030            ORDERDESK,PC (Shared)          True            False
# 7033     SCHULTZ,JOANNE (Agilent USA)          True            False
# 7035     SCHULTZ,JOANNE (Agilent USA)         False             True
# 7036     GONZALEZ,CESAR (Agilent USA)          True            False
#
#                           Sender Name  \
# 0             eet_application@adp.com
# 1                         Don McGlory
# 2     ROMIG,LINDA (A-LittleFalls,ex1)
# 3                      Mayank Agrawal
# 4                      Mayank Agrawal
# ...                               ...
# 7029         MARR,MEGAN (Agilent USA)
# 7030            ORDERDESK,PC (Shared)
# 7033     SCHULTZ,JOANNE (Agilent USA)
# 7035     SCHULTZ,JOANNE (Agilent USA)
# 7036     GONZALEZ,CESAR (Agilent USA)
#
#                                                      CC  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Nicole Clauberg; Michael LaBreche; Govinda Ber...
# 4     Navyasheel Laxminarayan Chippa; Nicole Clauber...
# ...                                                 ...
# 7029                                                NaN
# 7030                                                NaN
# 7033  WONG,RICHARD (Agilent USA); TATMAN,PHYLLIS (Ag...
# 7035  TATMAN,PHYLLIS (Agilent USA); LABRECHE,MICHAEL...
# 7036                                                NaN
#
#                                                      To             Received  \
# 0                LABRECHE,MICHAEL (A-United States,ex1)  2018-09-25 04:19:21
# 1                                      Michael LaBreche  2018-09-25 08:40:41
# 2                LABRECHE,MICHAEL (A-United States,ex1)  2018-09-25 09:47:23
# 3     ny93u7n85jp@networksolutionsprivateregistratio...  2018-09-25 10:05:31
# 4                        DE-MELO,EDWARD (Non-A-USA,ex1)  2018-09-25 10:06:06
# ...                                                 ...                  ...
# 7029  PDL-CSS-COLUMNS-SUPPLIES (Distribution); PDL-A...  2019-09-25 08:45:05
# 7030                     LABRECHE,MICHAEL (Agilent USA)  2019-09-25 08:59:20
# 7033  LABRECHE,MICHAEL (Agilent USA); BATES,DEREK (N...  2019-09-25 09:35:25
# 7035                         WONG,RICHARD (Agilent USA)  2019-09-25 11:18:06
# 7036                     LABRECHE,MICHAEL (Agilent USA)  2019-09-25 11:29:40
#
#      Message Size                                           Contents  \
# 0           56019  Reminder: The timekeeping deadline for the cur...
# 1           17592  Mike,\n\n \n\nI have a company issued phone th...
# 2           55428  Thanks!\n\n \n\nFrom: LABRECHE,MICHAEL (A-Unit...
# 3           43320  Please confirm who received this email. Please...
# 4           58814  Mike\n\nAs part of the Go Live, we need to mak...
# ...           ...                                                ...
# 7029       127811  Above and Beyond Recognition Program\n\n \n\n ...
# 7030       100256  Your New PC Has Shipped from HP!\n\n\n\n \n\nI...
# 7033        68184  Michael and Derek, \n\nPlease get the specs fo...
# 7035        61002  @WONG,RICHARD (Agilent USA) <mailto:richard.wo...
# 7036       104876  Hey Michael,\n\n                Take a look at...
#
#                   Created             Modified Subject Prefix Has Attachments  \
# 0     2018-09-25 04:19:20  2018-09-25 04:19:22            NaN           False
# 1     2019-01-07 09:30:09  2019-01-07 09:30:09            NaN           False
# 2     2018-09-25 09:47:23  2018-09-25 09:47:24            RE:            True
# 3     2019-01-07 09:30:08  2019-01-07 09:30:09            NaN           False
# 4     2019-01-07 09:30:08  2019-01-07 09:30:08            Re:           False
# ...                   ...                  ...            ...             ...
# 7029  2019-09-25 08:45:05  2019-09-25 08:45:06            NaN            True
# 7030  2019-09-25 08:59:20  2019-09-25 08:59:21            NaN            True
# 7033  2019-09-25 09:35:24  2019-09-25 09:38:19            FW:           False
# 7035  2019-09-25 11:18:05  2019-09-25 11:18:06            RE:           False
# 7036  2019-09-25 11:29:40  2019-09-25 11:41:29            Re:            True
#
#                                      Normalized Subject Object Type  \
# 0                      Timekeeping Deadline Approaching           5
# 1                                       phone and email           5
# 2                                          Import Files           5
# 3                                  Sending a test email           5
# 4                            ULTRA Scientific - Go Live           5
# ...                                                 ...         ...
# 7029  Reminder: CSD Above and Beyond Nominations Due...           5
# 7030         New PC (PO 9200321262) Shipped from HP_APS           5
# 7033                  CS Update for Rhode Island Office           5
# 7035                  CS Update for Rhode Island Office           5
# 7036                                               IMAP           5
#
#      Content Unread
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 7029            NaN
# 7030            NaN
# 7033            NaN
# 7035            NaN
# 7036            NaN
#
# [3707 rows x 20 columns]

# %% [raw]
# username = 'derek.bates@non.agilent.com'
# password = input("enter password")

# %% [raw]
# try: #{
#     mail = imaplib.IMAP4(host="imap.agilent.com")
#     mail.login(username, password)
# #}
# except: #{
#     errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
#     errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
#     errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
#     exc_type, exc_obj, exc_tb = sys.exc_info()
#     fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
#     typeE = str("TYPE : " + str(exc_type))
#     fileE = str("FILE : " + str(fname))
#     lineE = str("LINE : " + str(exc_tb.tb_lineno))
#     messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
#     print("\n" + typeE +
#                   "\n" + fileE +
#                   "\n" + lineE +
#                   "\n" + messageE)
# #}
# else: #{
#     print("SUCCESS! VERY NICE!")
# #}
