# %%
import os, sys, time
from time import sleep
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import tkinter as tk
from tkinter import ttk, filedialog, messagebox

# %%
def test_command(): #{
    # RE-INSTANTIATE GLOBALS
    global x
    x += 1
    messagebox.showwarning(title="WARNING:", message="NOPE! \n" + str(x))
#}

# %%
def App(): #{
    # RE-INSTANTIATE GLOBALS
    global root
    # MAIN APP PROPERTIES
    root.title("CofA-Crate")
    root.geometry("365x140+250+250") # WAS 550x205+250+250
    root.minsize(width=350, height=105)
    root.maxsize(width=750, height=405)
    
    #######################################################
    # TOP FRAME
    topframe = tk.Frame(master=root)
    topframe.pack(anchor=tk.N, fill=tk.BOTH, expand=True)
    
    ######################
    # b1
    button1 = tk.Button(master=topframe, text="Batch-File:", font=("Copperplate Gothic Light", 12), 
                        background="#6699ff", command=test_command,
                        activebackground="#000000", activeforeground="#666666", 
                        disabledforeground="#012562")
    button1.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
    
    #######################
    # l1
    label1 = tk.Label(master=topframe, text="label1", font=("Sourcecode ExtraLight", 12),
                     background="#6699ff", )
    label1.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True)
    """
    # e1
    entry1 = tk.Entry(master=topframe, text="entry1", font=("Courier New", 14))
    entry1.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True)
    """
    
    #######################################################
    # MIDDLE FRAME
    middleframe = tk.Frame(master=root)
    middleframe.pack(anchor=tk.CENTER, fill=tk.BOTH, expand=True)
    
    #####################
    # b2
    button2 = tk.Button(master=middleframe, text="Zip-Output:", background="#ffff66",
                       activebackground="#000000", activeforeground="#666666",
                        disabledforeground="#012562", command=test_command)
    button2.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
    
    """
    TREEVIEW ATTEMPT BELOW:
    
    
    
    """
    
    # CREATE THE WIDGET
    tree=ttk.Treeview(master=root)
    tree["columns"]=("one","two","three")
    # DEFINITION OF THE COLUMNS
    tree.column("#0", width=270, minwidth=270, stretch=tk.NO)
    tree.column("one", width=150, minwidth=150, stretch=tk.NO)
    tree.column("two", width=400, minwidth=200)
    tree.column("three", width=80, minwidth=50, stretch=tk.NO)
    # DEFINITION OF THE HEADINGS
    tree.heading("#0",text="Name",anchor=tk.W)
    tree.heading("one", text="Date modified",anchor=tk.W)
    tree.heading("two", text="Type",anchor=tk.W)
    tree.heading("three", text="Size",anchor=tk.W)
    # INSERT SOME ROWS
    # Level 1
    folder1=tree.insert("", 1, "", text="Folder 1", values=("23-Jun-17 11:05","File folder",""))
    tree.insert("", 2, "", text="text_file.txt", values=("23-Jun-17 11:25","TXT file","1 KB"))
    # Level 2
    tree.insert(folder1, "end", "", text="photo1.png", values=("23-Jun-17 11:28","PNG file","2.6KB"))
    tree.insert(folder1, "end", "", text="photo2.png", values=("23-Jun-17 11:29","PNG file","3.2KB"))
    tree.insert(folder1, "end", "", text="photo3.png", values=("23-Jun-17 11:30","PNG file","3.1KB"))
    # PACKING
    
    """
    ######################
    # treeview
    tree = ttk.Treeview(master=middleframe)
    # DEFINE COLUMNS / ETC
    tree["columns"] = ("one","two","three")
    tree.column("#0", width=270, minwidth=270, stretch=tk.NO)
    tree.column("one", width=150, minwidth=150, stretch=tk.NO)
    tree.column("two", width=400, minwidth=200)
    tree.column("three", width=80, minwidth=50, stretch=tk.NO)
    # DEFINITION OF HEADINGS
    tree.heading("#0",text="Name",anchor=tk.W)
    tree.heading("one", text="Date modified",anchor=tk.W)
    tree.heading("two", text="Type",anchor=tk.W)
    tree.heading("three", text="Size",anchor=tk.W)
    # INSERT SOME ROWS
    # Level 1
    folder1=tree.insert("", 1, "", text="Folder 1", values=("23-Jun-17 11:05","File folder",""))
    tree.insert("", 2, "", text="text_file.txt", values=("23-Jun-17 11:25","TXT file","1 KB"))
    # Level 2
    tree.insert(folder1, "end", "", text="photo1.png", values=("23-Jun-17 11:28","PNG file","2.6 KB"))
    tree.insert(folder1, "end", "", text="photo2.png", values=("23-Jun-17 11:29","PNG file","3.2 KB"))
    tree.insert(folder1, "end", "", text="photo3.png", values=("23-Jun-17 11:30","PNG file","3.1 KB"))
    # PACK
    tree.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True)
    """
    
    """
    # e2
    entry2 = tk.Entry(master=middleframe, text="entry2", font=("Courier New", 14))
    entry2.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True)
    """
    
    #######################################################
    # BOTTOM FRAME
    bottomframe = tk.Frame(master=root)
    bottomframe.pack(anchor=tk.S, fill=tk.BOTH, expand=True)
    
    ########################################################
    
    # BOTTOM_LEFT
    bottomleft = tk.Frame(master=bottomframe)
    bottomleft.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
    
    # b3
    button3 = tk.Button(master=bottomleft, text="Confirm", background="#ffff66",
                       activebackground="#000000", activeforeground="#666666",
                        disabledforeground="#012562", state=tk.DISABLED)
    button3.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
    
    # b4
    button4 = tk.Button(master=bottomleft, text="Cancel", background="#ffff66",
                       activebackground="#000000", activeforeground="#666666",
                        disabledforeground="#012562")
    button4.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
    
    ########################################################
    
    # BOTTOM_RIGHT
    bottomright = tk.Frame(master=bottomframe)
    bottomright.pack(side=tk.RIGHT, fill=tk.BOTH, expand=True)
    
    # R1
    radio1 = tk.Radiobutton(master=bottomright, text="Current **ONLY** CofAs", background="#ffff66",
                           activebackground="#000000", activeforeground="#666666",
                           disabledforeground="#012562", value=1)
    radio1.pack(side=tk.TOP, fill=tk.BOTH, expand=True)
    
    # R@
    radio2 = tk.Radiobutton(master=bottomright, text="Return **ALL** CofAs", background="#fff666",
                           activebackground="#ffff66", activeforeground="#ff6666",
                           disabledforeground="#012562", value=2)
    radio2.pack(side=tk.BOTTOM, fill=tk.BOTH, expand=True)
    
    root.config()
    root.mainloop()
#}

# %%
if __name__ == "__main__": #{
    # INSTANTIATE GLOBAL VARIABLES
    x = 0
    root = tk.Tk()
    App()
#}
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-4-ce91491d10fc> in <module>
#       3     x = 0
#       4     root = tk.Tk()
# ----> 5     App()
#       6 #}
#
# <ipython-input-3-c618ec3a2e32> in App()
#      66     # INSERT SOME ROWS
#      67     # Level 1
# ---> 68     tree.insert("", 1, "", text="Folder 1", values=("23-Jun-17 11:05","File folder",""))
#      69     tree.insert("", 2, "", text="text_file.txt", values=("23-Jun-17 11:25","TXT file","1 KB"))
#      70     # Level 2
#
# ~\anaconda3\lib\tkinter\ttk.py in insert(self, parent, index, iid, **kw)
#    1366         if iid is not None:
#    1367             res = self.tk.call(self._w, "insert", parent, index,
# -> 1368                 "-id", iid, *opts)
#    1369         else:
#    1370             res = self.tk.call(self._w, "insert", parent, index, *opts)
#
# TclError: Item  already exists
