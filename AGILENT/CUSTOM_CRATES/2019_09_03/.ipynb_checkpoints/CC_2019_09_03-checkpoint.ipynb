# %%
import os, sys, time
from time import sleep
from datetime import datetime
from pathlib import Path
import fnmatch, glob, shutil
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import tempfile, logging
from zipfile import ZipFile

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader

# %%
# CREATE TIME STAMP FOR ZIP FOLDER
ts = pd.Timestamp.now()
ts_str = str(ts)[:10]
print(ts_str)
# Out:
# 2019-09-03

# %%
# DIRECTORIES TO SCAn
in_directory = "F:/APPS/CofA/"

# %%
out_directory = "."

# %%
zip_dir_path = os.path.join(out_directory, ts_str)

# %%
# if 'zip_folder' DOES NOT YET EXIST!
if not os.path.exists(zip_dir_path): #{
    # MAKE IT EXIST!
    os.makedirs(zip_dir_path)
#}

# %%
# RESET/RE-ESTABLISH 'out_directory'
out_directory = Path(zip_dir_path)

# %%
watermark = "C:/data/inbound/Agilent_CofA_Letterhead_03-21-19.pdf"

# %% [markdown]
# ### *DEFINE FUNCTIONS*

# %%
def create_watermark(input_pdf, output, watermark): #{
    try: #{
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)
        
        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()
        
        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()): #{
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        #}
        
        with open(output, 'wb') as out: #{
            pdf_writer.write(out)
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Watermark-PDF] FIN...")
    #}
    return
#}

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list
    file_paths = []
    
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths

#}

# %%
in_file = "batch_list_b.csv"

# %%
df_batch = pd.read_csv(in_file, header=None, names=['Lot_No'], engine='python')

# %%
df_batch.head(5)
# Out:
#      Lot_No
# 0   CP-0327
# 1   CR-0369
# 2  CP-5199A
# 3   CS-4899
# 4   CR-1057

# %%
test_glob = str(in_directory + "*")
print(test_glob)
# Out:
# F:/APPS/CofA/*

# %%
# counter
x = 0

for lot_no in df_batch.itertuples(): #{
    print("============== \n " + str(lot_no[1]) + "\n==============")
    # CHECK AND CREATE NEW DIR PATH
    new_dir_path = os.path.join(out_directory, str(lot_no[1]))
    # IF 'lot_no' DIRECTORY DOES NOT EXIST:
    if not os.path.exists(new_dir_path): #{
        # MAKE IT EXIST!
        os.makedirs(new_dir_path)
    #}
    # CREATE TEMP DIR/FOLDER TO WORK INSIDE OF:
    with tempfile.TemporaryDirectory() as directory_name: #{
        # was: most_recent = ""
        the_dir = Path(directory_name)
        print("TEMP_DIRECTORY == " + str(the_dir))
        # GLOB AND ITERATURE THROUGH EACH FILE MATCHING NAME ETC
        for name in sorted(glob.glob(in_directory 
                                     + "*" 
                                     + str(lot_no[1]) 
                                     "*")): #{
            #print(name)
            # CREAT PATH VARIABLE
            pdf_path = Path(str(name))
            print(os.path.exists(pdf_path))
            # GET BASE NAME (FILE NAME)
            file_name = os.path.basename(pdf_path)
            # CREATE TEMP PATH
            temp_path = os.path.join(the_dir, file_name)
            # COPY FILE TO NEW LOCATION
            shutil.copy2(pdf_path, temp_path)
            # CREATE WATERMARK ON NEW FILE
            # (OUTPUT == out_directory + str(lot_no[1]) + filename)
            create_watermark(input_pdf=temp_path,
                            output=os.path.join(new_dir_path, file_name),
                            watermark=watermark)
            # increase count
            x += 1
        #}
    #}
    print("count == " + (str(x)))
    print("Directory exists after?", str(the_dir.exists()))
    print("Contents after:", str(list(the_dir.glob("*"))))
    print("told you so")
#}
# Out:
# ==============
#  CP-0327
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpcn9x_4kt
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CR-0369
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpw3_irgg1
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# count == 4
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CP-5199A
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpnffrfkwf
# True
# [Watermark-PDF] FIN...
# count == 5
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CS-4899
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp7m289jo2
# True
# [Watermark-PDF] FIN...
# count == 6
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CR-1057
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpbs198jmb
# True
# [Watermark-PDF] FIN...
# count == 7
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CS-5422
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpl01eflj1
# True
# [Watermark-PDF] FIN...
# count == 8
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CR-4590
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp0rhfo6m_
# True
# [Watermark-PDF] FIN...
# count == 9
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CS-2779
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmppihjrnyu
# True
# [Watermark-PDF] FIN...
# count == 10
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CT-0177
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpy25_2j4k
# True
# [Watermark-PDF] FIN...
# count == 11
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CR-6033
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp6zf8wieg
# True
# [Watermark-PDF] FIN...
# count == 12
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CS-0874
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp3x440lxy
# True
# [Watermark-PDF] FIN...
# count == 13
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CR-0874
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp_bbj80n6
# count == 13
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CR-3809
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpl52i11pj
# True
# [Watermark-PDF] FIN...
# count == 14
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CP-6172
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpe161o_ba
# True
# [Watermark-PDF] FIN...
# count == 15
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CS-4734
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpj_v3nlbp
# True
# [Watermark-PDF] FIN...
# count == 16
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  CS-1770
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpuyd6jitk
# True
# [Watermark-PDF] FIN...
# count == 17
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  0006475713
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpd1gqctlo
# True
# [Watermark-PDF] FIN...
# count == 18
# Directory exists after? False
# Contents after: []
# told you so

# %%
# TRY AND ZIP FOLDER
try: #{
    # path to folder which needs to be zipped
    directory = zip_dir_path
    
    # calling function to get all file paths in the directory
    file_paths = get_all_file_paths(directory)
    
    # printing list of all files to be zipped
    print('Following files will be zipped:')
    for file_name in file_paths: #{
        print(file_name)
    #}
    
    zip_name = str(ts_str + ".zip")
    
    # writing files to a zipfile
    with ZipFile(zip_name, 'w') as zip: #{
        # writing each file one by one
        for file in file_paths: #{
            zip.write(file)
        #}
    #}
    
    print("All Files zipped successfully!")
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
    print("\n" + typeE +
                 "\n" + fileE +
                 "\n" + lineE +
                 "\n" + messageE)
#}
else: #{
    print("[zip-folder] FIN...")
#}
# Out:
# Following files will be zipped:
# .\2019-09-03\0006475713\PST-6580-250MG@0006475713.pdf
# .\2019-09-03\CP-0327\D471-E@CP-0327.PDF
# .\2019-09-03\CP-0327\D471-E@CP-0327A.PDF
# .\2019-09-03\CP-5199A\D471-F@CP-5199A.PDF
# .\2019-09-03\CP-6172\CFC-250@CP-6172.PDF
# .\2019-09-03\CR-0369\AM-181-1@CR-0369A.PDF
# .\2019-09-03\CR-0369\AM-181@CR-0369.PDF
# .\2019-09-03\CR-1057\STM-530@CR-1057.PDF
# .\2019-09-03\CR-3809\D471-G@CR-3809.PDF
# .\2019-09-03\CR-4590\PPM-471A@CR-4590.PDF
# .\2019-09-03\CR-6033\RBF-093S@CR-6033.PDF
# .\2019-09-03\CS-0874\ITA-40@CS-0874.PDF
# .\2019-09-03\CS-1770\CUS-15956@CS-1770.PDF
# .\2019-09-03\CS-2779\PPM-471A@CS-2779.PDF
# .\2019-09-03\CS-4734\CFC-250@CS-4734.PDF
# .\2019-09-03\CS-4899\D471-F@CS-4899.PDF
# .\2019-09-03\CS-5422\STM-520@CS-5422.PDF
# .\2019-09-03\CT-0177\PPM-471A@CT-0177.PDF
# All Files zipped successfully!
# [zip-folder] FIN...
