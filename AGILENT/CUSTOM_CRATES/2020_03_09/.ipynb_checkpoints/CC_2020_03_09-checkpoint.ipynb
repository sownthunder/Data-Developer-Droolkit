# %%
import os, sys, time
from time import sleep
from datetime import datetime
from pathlib import Path
import fnmatch, glob, shutil
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import tempfile, logging
from zipfile import ZipFile

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader

# %%
# CREATE TIME STAMP FOR ZIP FOLDER
ts = pd.Timestamp.now()
ts_str = str(ts)[:10]
print(ts_str)
# Out:
# 2019-11-05

# %%
# DIRECTORIES TO SCAn
in_directory = "F:/APPS/CofA/"
in_directory_2 = "G:/C of A's/Agilent/"

# %%
out_directory = "."

# %%
zip_dir_path = os.path.join(out_directory, ts_str)

# %%
# if 'zip_folder' DOES NOT YET EXIST!
if not os.path.exists(zip_dir_path): #{
    # MAKE IT EXIST!
    os.makedirs(zip_dir_path)
#}

# %%
# RESET/RE-ESTABLISH 'out_directory'
out_directory = Path(zip_dir_path)

# %%
watermark = "C:/data/inbound/Agilent_CofA_Letterhead_03-21-19.pdf"

# %% [markdown]
# ### *DEFINE FUNCTIONS*

# %%
def create_watermark(input_pdf, output, watermark): #{
    try: #{
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)
        
        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()
        
        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()): #{
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        #}
        
        with open(output, 'wb') as out: #{
            pdf_writer.write(out)
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Watermark-PDF] FIN...")
    #}
    return
#}

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list
    file_paths = []
    
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths

#}

# %%
in_file = "2020-03-04-batch-list.csv"

# %%
df_batch = pd.read_csv(in_file, header=None, names=['Lot_No'], engine='python')

# %%
df_batch.head(5)
# Out:
#       Lot_No
# 0  82572-J-G
# 1  82575-J-G
# 2    53000-P
# 3    82550-G
# 4    82510-G

# %%
test_glob = str(in_directory + "*")
print(test_glob)
# Out:
# F:/APPS/CofA/*

# %%
# counter
x = 0

for lot_no in df_batch.itertuples(): #{
    print("============== \n " + str(lot_no[1]) + "\n==============")
    # CHECK AND CREATE NEW DIR PATH
    new_dir_path = os.path.join(out_directory, str(lot_no[1]))
    # IF 'lot_no' DIRECTORY DOES NOT EXIST:
    if not os.path.exists(new_dir_path): #{
        # MAKE IT EXIST!
        os.makedirs(new_dir_path)
    #}
    # CREATE TEMP DIR/FOLDER TO WORK INSIDE OF:
    with tempfile.TemporaryDirectory() as directory_name: #{
        # was: most_recent = ""
        the_dir = Path(directory_name)
        print("TEMP_DIRECTORY == " + str(the_dir))
        # GLOB AND ITERATURE THROUGH EACH FILE MATCHING NAME ETC
        for name in sorted(glob.glob(in_directory 
                                     + "*" 
                                     + str(lot_no[1]) 
                                     + "*")): #{
            #print(name)
            # CREAT PATH VARIABLE
            pdf_path = Path(str(name))
            print(os.path.exists(pdf_path))
            # GET BASE NAME (FILE NAME)
            file_name = os.path.basename(pdf_path)
            # CREATE TEMP PATH
            temp_path = os.path.join(the_dir, file_name)
            # COPY FILE TO NEW LOCATION
            shutil.copy2(pdf_path, temp_path)
            # CREATE WATERMARK ON NEW FILE
            # (OUTPUT == out_directory + str(lot_no[1]) + filename)
            create_watermark(input_pdf=temp_path,
                            output=os.path.join(new_dir_path, file_name),
                            watermark=watermark)
            # increase count
            x += 1
        #}
    #}
    print("count == " + (str(x)))
    print("Directory exists after?", str(the_dir.exists()))
    print("Contents after:", str(list(the_dir.glob("*"))))
    print("told you so")
#}
# Out:
# ==============
#  82572-J-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpp3r2mych
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82575-J-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmptf5xx24b
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  53000-P
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpcaqp43r4
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82550-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp6a5ju7je
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82510-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpfxz6adpz
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82511-5G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpjlw8copd
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82507-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpy_uf3p8x
# count == 0
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51553
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpkq1dfasg
# True
# [Watermark-PDF] FIN...
# count == 1
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51023
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp_qnva2c9
# True
# [Watermark-PDF] FIN...
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51010-NA
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpm1zg5tjp
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  55555-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp8cst0739
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82510-5G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpb_9k66r4
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82511-5G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpma80gqi5
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82507-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpnfbg_klw
# count == 2
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51553
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpe26cl8yb
# True
# [Watermark-PDF] FIN...
# count == 3
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51550
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpf0kcj2ph
# True
# [Watermark-PDF] FIN...
# count == 4
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82552-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpdukftyhk
# count == 4
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82518-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpg056z555
# count == 4
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  52000
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpnoh5fkpd
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# True
# [Watermark-PDF] FIN...
# count == 10
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51333
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp248gfn1t
# True
# [Watermark-PDF] FIN...
# count == 11
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51010-K
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmp4wzjcc3z
# count == 11
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  55000-P
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpc7x46y35
# count == 11
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82570-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpe5a59xy_
# count == 11
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  82507-G
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmpdgibz40j
# count == 11
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51770
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmps38dtcbz
# True
# [Watermark-PDF] FIN...
# count == 12
# Directory exists after? False
# Contents after: []
# told you so
# ==============
#  51010-CA
# ==============
# TEMP_DIRECTORY == C:\Users\derbates\AppData\Local\Temp\tmptedhhnbo
# count == 12
# Directory exists after? False
# Contents after: []
# told you so

# %%
# TRY AND ZIP FOLDER
try: #{
    # path to folder which needs to be zipped
    directory = zip_dir_path
    
    # calling function to get all file paths in the directory
    file_paths = get_all_file_paths(directory)
    
    # printing list of all files to be zipped
    print('Following files will be zipped:')
    for file_name in file_paths: #{
        print(file_name)
    #}
    
    zip_name = str(ts_str + ".zip")
    
    # writing files to a zipfile
    with ZipFile(zip_name, 'w') as zip: #{
        # writing each file one by one
        for file in file_paths: #{
            zip.write(file)
        #}
    #}
    
    print("All Files zipped successfully!")
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
    print("\n" + typeE +
                 "\n" + fileE +
                 "\n" + lineE +
                 "\n" + messageE)
#}
else: #{
    print("[zip-folder] FIN...")
#}
# Out:
# Following files will be zipped:
# .\2019-11-05\51023\RCB-018@NT051023.pdf
# .\2019-11-05\51333\RAH-002@NT051333.pdf
# .\2019-11-05\51550\FRCK-014G@NT051550.pdf
# .\2019-11-05\51553\FRCK-014J@NT051553.pdf
# .\2019-11-05\51770\WRK-301M@NT051770.pdf
# .\2019-11-05\52000\52000@0006459935.pdf
# .\2019-11-05\52000\52000@0006464887.pdf
# .\2019-11-05\52000\52000@0006464888.pdf
# .\2019-11-05\52000\52000@0006481325.pdf
# .\2019-11-05\52000\52000@0006488080.pdf
# .\2019-11-05\52000\PST-1180@NT052000.pdf
# All Files zipped successfully!
# [zip-folder] FIN...
