# %%
import os, sys, time
from time import sleep
from datetime import *
from pathlib import Path
import fnmatch, glob, shutil
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import tempfile, logging
from zipfile import ZipFile

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader

# %% [raw]
# '%(asctime)s : \n\t\t\t [MESG] : %(message)s \n\t\t\t\t [LINE] : %(lineno)s'

# %%
# SETUP LOGGER
try: #{
    logging.basicConfig(level=logging.INFO,
                        format='%(asctime)s : %(message)s',
                        datefmt='%Y-%m-%d-%H%M%S',
                        filemode='a')
#}
except: #{
    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
    exc_type, exc_obj, exc_tb = sys.exc_info()
    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
    typeE = str("TYPE : " + str(exc_type))
    fileE = str("FILE : " + str(fname))
    lineE = str("LINE : " + str(exc_tb.tb_lineno))
    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
    print("\n" + typeE +
          "\n" + fileE +
          "\n" + lineE +
          "\n" + messageE)
#}
else: #{
    print("FIN...")
#}
# Out:
# FIN...

# %%
# CREATE TIME STAMP (string) FOR ZIP FOLDER
ts = pd.Timestamp.now()
ts_str = str(ts)
ts_str = ts_str[:10]
print(ts_str)
# Out:
# 2019-07-26

# %%
# DIRECTORIES TO SCAN
in_directory_1 = "F:/APPS/CofA/"
in_directory_2 = "G:/C of A's/#Email Node/"

# %%
out_directory = "."

# %%
zip_dir_path = os.path.join(out_directory, ts_str)
print(zip_dir_path)
# Out:
# .\2019-07-26

# %%
# if 'zip_folder' DOES NOT YET EXIST!
if not os.path.exists(zip_dir_path): #{
    # MAKE IT EXIST!
    os.makedirs(zip_dir_path)
#}

# %%
# RESET/RE-ESTABLISH 'out_directory'
out_directory = Path(zip_dir_path)

# %%
watermark = "C:/data/inbound/Agilent_CofA_Letterhead_03-21-19.pdf"

# %% [markdown]
# ## *DEFINE FUNCTIONS*

# %%
def create_watermark(input_pdf, output, watermark): #{
    try: #{
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)
        
        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()
        
        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()): #{
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        #}
        
        with open(output, 'wb') as out: #{
            pdf_writer.write(out)
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        logging.info("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        logging.info("[Watermark-PDF] FIN...")
    #}
    return
#}

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list
    file_paths = []
    
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths

#}

# %%
"""
TAKES IN THE PATH OF A FILE AND DETERMINES:
is modification or created date older? 
returns the more accurate information 
"""
def pull_creation_modification_date(the_file_path): #{
    # GET CREATION DATE
    file_date = os.path.getctime(pdf_path)
    # GET CREATION_DATE
    created = os.stat(pdf_path).st_ctime_ns
    # CONVERT CREATION_DATE TO PANDAS.TIMESTAMP
    c_stamp = pd.Timestamp(created)
    # GET MODIFICATION_TIME
    modified = os.stat(pdf_path).st_mtime_ns
    # CONVERT MODIFIED TIME TO PANDAS.TIMESTAMP
    m_stamp = pd.Timestamp(modified)
    #########################################3##
    # PANDAS.TIMEDELTA FOR SUBTRACTING DATES
    creation_delta = pd.Timedelta(created - modified)
    logging.debug("DELTA TIME (created - modified) >>> " + str(creation_delta))
    # CREATE CHECK DELTA TO USE 'AGAINST' CREATION_DELTA
    check_delta = pd.Timedelta(value=1, unit='min')
    # IF DELTA IS LESS THAN ONE-MINUTE (NEGATIVE)
    if (creation_delta <= check_delta): #{
        logging.debug("<< CREATION DATE IS OLDER >>")
        logging.debug("CREATED == " + str(c_stamp)) # WAS: logging.info
        logging.debug("MODIFIED == " + str(m_stamp))
        # SET STRING VAR FOR EMAIL OUTPUT
        date_str = str(c_stamp)
    #}
    # ELSE... DELTA IS GREATER THAN ONE-MINUTE
    else: #{
        logging.debug("<< MODIFIED DATE IS OLDER >>")
        logging.debug("MODIFIED == " + str(m_stamp)) # WAS: logging.info
        logging.debug("CREATED == " + str(c_stamp))
        # SET STRING VAR FOR EMAIL OUTPUT
        date_str = str(m_stamp)
    #}
    return date_str
#}

# %%
in_file = "batch_list.csv"

# %%
df_batch = pd.read_csv(in_file, header=None, names=['Lot_No'], engine='python')

# %%
df_batch.head(5)
# Out:
#       Lot_No
# 0   47995N-1
# 1  DWM-544-1
# 2  DWM-580-1
# 3  DWM-583-1
# 4  DWM-588-1

# %%
test_glob = str(in_directory_1 + "*")
print(test_glob)
# Out:
# F:/APPS/CofA/*

# %%
# TOTAL counter
x = 0

for lot_no in df_batch.itertuples(): #{
    logging.info("======== " + str(lot_no[1]) + " ========")
    # CHECK AND CREATE NEW DIR PATH
    new_dir_path = os.path.join(out_directory, str(lot_no[1]))
    # IF 'lot_no' DIRECTORY DOES NOT EXIST:
    if not os.path.exists(new_dir_path): #{
        # MAKE IT EXIST!
        os.makedirs(new_dir_path)
    #}
    # CREATE TEMP DIR/FOLDER TO WORK INSIDE OF:
    with tempfile.TemporaryDirectory() as directory_name: #{
        # LOCAL COUNTER
        j = 0
        the_dir = Path(directory_name)
        logging.info("TEMP_DIR== " + str(the_dir))
        # create variable to hold most recent DATETIME
        newest_date = pd.Timestamp.today()
        # create str to hold our most recent file (path)
        newest_cofa = ""
        # GLOB AND ITERATURE THROUGH EACH FILE MATCHING NAME ETC
        for name in sorted(glob.glob(in_directory_1 + "*" + str(lot_no[1]) + "*")): #{
            # CREATE PATH VARIABLE
            pdf_path = Path(str(name))
            ###########################################
            the_date_str = pull_creation_modification_date(pdf_path)
            """
            the_c_date = pd.Timedelta(the_date_str)
            if newest_date > the_c_date: #{
                # THE C_DATE IS OLDER
                newest_date = newest_date
            #}
            else: #{
                # THE "LAST" C_DATE IS OLDER
                # RESET 
                newest_date = the_c_date
            #}
            """
            #####################################################
            logging.info("FILE CREATED == " + the_date_str)
            logging.info("THE_FILE_PATH == " + str(pdf_path))
            logging.info("FILE_EXISTS == " + str(os.path.exists(pdf_path)))
            # GET BASE NAME (FILE NAME)
            file_name = os.path.basename(pdf_path)
            # CREATE TEMP PATH
            temp_path = os.path.join(the_dir, file_name)
            # COPY FILE TO NEW LOCATION
            shutil.copy2(pdf_path, temp_path)
            # CREATE WATERMARK ON NEW FILE
            # (OUTPUT == out_directory + str(lot_no[1]) + filename)
            create_watermark(input_pdf=temp_path,
                            output=os.path.join(new_dir_path, file_name),
                            watermark=watermark)
            # increase counts
            x += 1
            j += 1
            logging.info("LOCAL count == " + str(j))
        #}
    #}
    logging.info("TOTAL count == " + (str(x)))
    logging.info("Directory exists after? " + str(the_dir.exists()))
    logging.info("Contents after: " + str(list(the_dir.glob("*"))))
    logging.info("told you so")
#}
# Out:
# 2019-07-26-165521 : ======== 47995N-1 ========
# 2019-07-26-165521 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpuh4zc7kx
# 2019-07-26-165522 : TOTAL count == 0
# 2019-07-26-165522 : Directory exists after? False
# 2019-07-26-165522 : Contents after: []
# 2019-07-26-165522 : told you so
# 2019-07-26-165522 : ======== DWM-544-1 ========
# 2019-07-26-165522 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpu2bdwpfr
# 2019-07-26-165524 : FILE CREATED == 2019-04-17 15:45:44.568289900
# 2019-07-26-165524 : THE_FILE_PATH == F:\APPS\CofA\DWM-544-1@0006460286.pdf
# 2019-07-26-165524 : FILE_EXISTS == True
# 2019-07-26-165524 : [Watermark-PDF] FIN...
# 2019-07-26-165524 : LOCAL count == 1
# 2019-07-26-165524 : FILE CREATED == 2019-06-26 20:59:57.088455600
# 2019-07-26-165524 : THE_FILE_PATH == F:\APPS\CofA\DWM-544-1@0006476293.pdf
# 2019-07-26-165524 : FILE_EXISTS == True
# 2019-07-26-165524 : [Watermark-PDF] FIN...
# 2019-07-26-165524 : LOCAL count == 2
# 2019-07-26-165524 : TOTAL count == 2
# 2019-07-26-165524 : Directory exists after? False
# 2019-07-26-165524 : Contents after: []
# 2019-07-26-165524 : told you so
# 2019-07-26-165524 : ======== DWM-580-1 ========
# 2019-07-26-165524 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpl1rwm3u2
# 2019-07-26-165526 : FILE CREATED == 2019-06-10 10:25:56.167005600
# 2019-07-26-165526 : THE_FILE_PATH == F:\APPS\CofA\DWM-580-1@0006472370.pdf
# 2019-07-26-165526 : FILE_EXISTS == True
# 2019-07-26-165526 : [Watermark-PDF] FIN...
# 2019-07-26-165526 : LOCAL count == 1
# 2019-07-26-165526 : FILE CREATED == 2019-06-10 10:26:02.682714
# 2019-07-26-165526 : THE_FILE_PATH == F:\APPS\CofA\DWM-580-1@0006472371.pdf
# 2019-07-26-165526 : FILE_EXISTS == True
# 2019-07-26-165527 : [Watermark-PDF] FIN...
# 2019-07-26-165527 : LOCAL count == 2
# 2019-07-26-165527 : TOTAL count == 4
# 2019-07-26-165527 : Directory exists after? False
# 2019-07-26-165527 : Contents after: []
# 2019-07-26-165527 : told you so
# 2019-07-26-165527 : ======== DWM-583-1 ========
# 2019-07-26-165527 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpi8b_hy28
# 2019-07-26-165528 : FILE CREATED == 2010-12-21 19:30:59.128315800
# 2019-07-26-165528 : THE_FILE_PATH == F:\APPS\CofA\DWM-583-1@CG-3973.PDF
# 2019-07-26-165528 : FILE_EXISTS == True
# 2019-07-26-165528 : [Watermark-PDF] FIN...
# 2019-07-26-165528 : LOCAL count == 1
# 2019-07-26-165528 : TOTAL count == 5
# 2019-07-26-165528 : Directory exists after? False
# 2019-07-26-165528 : Contents after: []
# 2019-07-26-165528 : told you so
# 2019-07-26-165528 : ======== DWM-588-1 ========
# 2019-07-26-165528 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpaw3sv6h2
# 2019-07-26-165530 : TOTAL count == 5
# 2019-07-26-165530 : Directory exists after? False
# 2019-07-26-165530 : Contents after: []
# 2019-07-26-165530 : told you so
# 2019-07-26-165530 : ======== DWM-589N-1 ========
# 2019-07-26-165530 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpqvkfdcq_
# 2019-07-26-165531 : TOTAL count == 5
# 2019-07-26-165531 : Directory exists after? False
# 2019-07-26-165531 : Contents after: []
# 2019-07-26-165531 : told you so
# 2019-07-26-165531 : ======== EPA-1050-1 ========
# 2019-07-26-165531 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmphlzmw4bm
# 2019-07-26-165533 : TOTAL count == 5
# 2019-07-26-165533 : Directory exists after? False
# 2019-07-26-165533 : Contents after: []
# 2019-07-26-165533 : told you so
# 2019-07-26-165533 : ======== EPA-1105-1 ========
# 2019-07-26-165533 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpzdk5ouif
# 2019-07-26-165534 : TOTAL count == 5
# 2019-07-26-165534 : Directory exists after? False
# 2019-07-26-165534 : Contents after: []
# 2019-07-26-165534 : told you so
# 2019-07-26-165534 : ======== EPA-1125-1 ========
# 2019-07-26-165534 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp72atdgk6
# 2019-07-26-165536 : TOTAL count == 5
# 2019-07-26-165536 : Directory exists after? False
# 2019-07-26-165536 : Contents after: []
# 2019-07-26-165536 : told you so
# 2019-07-26-165536 : ======== EPA-1161-1 ========
# 2019-07-26-165536 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp2lnxpjxw
# 2019-07-26-165537 : TOTAL count == 5
# 2019-07-26-165537 : Directory exists after? False
# 2019-07-26-165537 : Contents after: []
# 2019-07-26-165537 : told you so
# 2019-07-26-165537 : ======== IBF-1245 ========
# 2019-07-26-165537 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpeaev_bgw
# 2019-07-26-165539 : FILE CREATED == 2015-03-31 13:06:37.919279500
# 2019-07-26-165539 : THE_FILE_PATH == F:\APPS\CofA\IBF-1245@
: THE_FILE_PATH == F:\APPS\CofA\IBF-1245@CR-5266.pdf
# 2019-07-26-165543 : FILE_EXISTS == True
# 2019-07-26-165544 : [Watermark-PDF] FIN...
# 2019-07-26-165544 : LOCAL count == 12
# 2019-07-26-165544 : FILE CREATED == 2018-01-03 16:21:00.901168300
# 2019-07-26-165544 : THE_FILE_PATH == F:\APPS\CofA\IBF-1245@CR-6109.pdf
# 2019-07-26-165544 : FILE_EXISTS == True
# 2019-07-26-165544 : [Watermark-PDF] FIN...
# 2019-07-26-165544 : LOCAL count == 13
# 2019-07-26-165544 : FILE CREATED == 2018-04-12 12:39:20.306152700
# 2019-07-26-165544 : THE_FILE_PATH == F:\APPS\CofA\IBF-1245@CS-1746.pdf
# 2019-07-26-165544 : FILE_EXISTS == True
# 2019-07-26-165545 : [Watermark-PDF] FIN...
# 2019-07-26-165545 : LOCAL count == 14
# 2019-07-26-165545 : FILE CREATED == 2018-11-19 11:57:13.659947800
# 2019-07-26-165545 : THE_FILE_PATH == F:\APPS\CofA\IBF-1245@CS-5595.pdf
# 2019-07-26-165545 : FILE_EXISTS == True
# 2019-07-26-165545 : [Watermark-PDF] FIN...
# 2019-07-26-165545 : LOCAL count == 15
# 2019-07-26-165545 : FILE CREATED == 2019-02-05 20:04:04.022969900
# 2019-07-26-165545 : THE_FILE_PATH == F:\APPS\CofA\IBF-1245@CT-0400.pdf
# 2019-07-26-165545 : FILE_EXISTS == True
# 2019-07-26-165545 : [Watermark-PDF] FIN...
# 2019-07-26-165545 : LOCAL count == 16
# 2019-07-26-165545 : FILE CREATED == 2019-03-12 12:52:34.773755500
# 2019-07-26-165545 : THE_FILE_PATH == F:\APPS\CofA\IBF-1245@CT-1199.pdf
# 2019-07-26-165545 : FILE_EXISTS == True
# 2019-07-26-165546 : [Watermark-PDF] FIN...
# 2019-07-26-165546 : LOCAL count == 17
# 2019-07-26-165546 : TOTAL count == 22
# 2019-07-26-165546 : Directory exists after? False
# 2019-07-26-165546 : Contents after: []
# 2019-07-26-165546 : told you so
# 2019-07-26-165546 : ======== ICP-042 ========
# 2019-07-26-165546 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpaipe8hlg
# 2019-07-26-165548 : FILE CREATED == 2015-03-17 15:28:52.008451600
# 2019-07-26-165548 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@CL-4904.pdf
# 2019-07-26-165548 : FILE_EXISTS == True
# 2019-07-26-165548 : [Watermark-PDF] FIN...
# 2019-07-26-165548 : LOCAL count == 1
# 2019-07-26-165548 : FILE CREATED == 2016-01-05 15:30:53.280903
# 2019-07-26-165548 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@CM-6402.pdf
# 2019-07-26-165548 : FILE_EXISTS == True
# 2019-07-26-165549 : [Watermark-PDF] FIN...
# 2019-07-26-165549 : LOCAL count == 2
# 2019-07-26-165549 : FILE CREATED == 2017-03-09 13:58:46.835031200
# 2019-07-26-165549 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@CR-1020.pdf
# 2019-07-26-165549 : FILE_EXISTS == True
# 2019-07-26-165549 : [Watermark-PDF] FIN...
# 2019-07-26-165549 : LOCAL count == 3
# 2019-07-26-165549 : FILE CREATED == 2018-02-15 13:51:17.200164800
# 2019-07-26-165549 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@CS-0671.pdf
# 2019-07-26-165549 : FILE_EXISTS == True
# 2019-07-26-165550 : [Watermark-PDF] FIN...
# 2019-07-26-165550 : LOCAL count == 4
# 2019-07-26-165550 : FILE CREATED == 2015-04-15 14:30:04.819054700
# 2019-07-26-165550 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@J00296.pdf
# 2019-07-26-165550 : FILE_EXISTS == True
# 2019-07-26-165550 : [Watermark-PDF] FIN...
# 2019-07-26-165550 : LOCAL count == 5
# 2019-07-26-165550 : FILE CREATED == 2015-04-15 14:30:43.896929600
# 2019-07-26-165550 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@K00988.pdf
# 2019-07-26-165550 : FILE_EXISTS == True
# 2019-07-26-165551 : [Watermark-PDF] FIN...
# 2019-07-26-165551 : LOCAL count == 6
# 2019-07-26-165551 : FILE CREATED == 2015-04-15 14:31:32.521618400
# 2019-07-26-165551 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@M00929.pdf
# 2019-07-26-165551 : FILE_EXISTS == True
# 2019-07-26-165551 : [Watermark-PDF] FIN...
# 2019-07-26-165551 : LOCAL count == 7
# 2019-07-26-165551 : FILE CREATED == 2015-04-15 14:28:28.522796
# 2019-07-26-165551 : THE_FILE_PATH == F:\APPS\CofA\ICP-042@R00415.pdf
# 2019-07-26-165551 : FILE_EXISTS == True
# 2019-07-26-165551 : [Watermark-PDF] FIN...
# 2019-07-26-165551 : LOCAL count == 8
# 2019-07-26-165551 : TOTAL count == 30
# 2019-07-26-165551 : Directory exists after? False
# 2019-07-26-165551 : Contents after: []
# 2019-07-26-165551 : told you so
# 2019-07-26-165551 : ======== ICP-048 ========
# 2019-07-26-165551 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmphxaq670j
# 2019-07-26-165553 : FILE CREATED == 2015-03-16 16:17:16.714212100
# 2019-07-26-165553 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@CL-2608.pdf
# 2019-07-26-165553 : FILE_EXISTS == True
# 2019-07-26-165553 : [Watermark-PDF] FIN...
# 2019-07-26-165553 : LOCAL count == 1
# 2019-07-26-165553 : FILE CREATED == 2016-10-25 10:50:05.473079700
# 2019-07-26-165553 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@CP-5285.pdf
# 2019-07-26-165553 : FILE_EXISTS == True
# 2019-07-26-165554 : [Watermark-PDF] FIN...
# 2019-07-26-165554 : LOCAL count == 2
# 2019-07-26-165554 : FILE CREATED == 2015-04-16 13:36:28.861185600
# 2019-07-26-165554 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@J00298.pdf
# 2019-07-26-165554 : FILE_EXISTS == True
# 2019-07-26-165554 : [Watermark-PDF] FIN...
# 2019-07-26-165554 : LOCAL count == 3
# 2019-07-26-165554 : FILE CREATED == 2015-04-16 13:37:06.189310600
# 2019-07-26-165554 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@K00951.pdf
# 2019-07-26-165554 : FILE_EXISTS == True
# 2019-07-26-165555 : [Watermark-PDF] FIN...
# 2019-07-26-165555 : LOCAL count == 4
# 2019-07-26-165555 : FILE CREATED == 2015-04-16 13:38:11.048685600
# 2019-07-26-165555 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@M00538.pdf
# 2019-07-26-165555 : FILE_EXISTS == True
# 2019-07-26-165555 : [Watermark-PDF] FIN...
# 2019-07-26-165555 : LOCAL count == 5
# 2019-07-26-165555 : FILE CREATED == 2015-04-16 13:38:50.533060600
# 2019-07-26-165555 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@M00538A.pdf
# 2019-07-26-165555 : FILE_EXISTS == True
# 2019-07-26-165556 : [Watermark-PDF] FIN...
# 2019-07-26-165556 : LOCAL count == 6
# 2019-07-26-165556 : FILE CREATED == 2015-04-16 13:34:41.095560600
# 2019-07-26-165556 : THE_FILE_PATH == F:\APPS\CofA\ICP-048@M00538B.pdf
# 2019-07-26-165556 : FILE_EXISTS == True
# 2019-07-26-165556 : [Watermark-PDF] FIN...
# 2019-07-26-165556 : LOCAL count == 7
# 2019-07-26-165556 : TOTAL count == 37
# 2019-07-26-165556 : Directory exists after? False
# 2019-07-26-165556 : Contents after: []
# 2019-07-26-165556 : told you so
# 2019-07-26-165556 : ======== ICP-049 ========
# 2019-07-26-165556 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp5zz2w5xu
# 2019-07-26-165557 : FILE CREATED == 2015-04-07 17:13:02.854092
# 2019-07-26-165557 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@CM-1655.pdf
# 2019-07-26-165557 : FILE_EXISTS == True
# 2019-07-26-165558 : [Watermark-PDF] FIN...
# 2019-07-26-165558 : LOCAL count == 1
# 2019-07-26-165558 : FILE CREATED == 2016-11-23 17:47:33.043462800
# 2019-07-26-165558 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@CP-5774.pdf
# 2019-07-26-165558 : FILE_EXISTS == True
# 2019-07-26-165558 : [Watermark-PDF] FIN...
# 2019-07-26-165558 : LOCAL count == 2
# 2019-07-26-165558 : FILE CREATED == 2017-08-22 13:17:42.165004200
# 2019-07-26-165558 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@CR-3812.pdf
# 2019-07-26-165558 : FILE_EXISTS == True
# 2019-07-26-165559 : [Watermark-PDF] FIN...
# 2019-07-26-165559 : LOCAL count == 3
# 2019-07-26-165559 : FILE CREATED == 2019-01-07 15:02:39.940410600
# 2019-07-26-165559 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@CS-6387.pdf
# 2019-07-26-165559 : FILE_EXISTS == True
# 2019-07-26-165600 : [Watermark-PDF] FIN...
# 2019-07-26-165600 : LOCAL count == 4
# 2019-07-26-165600 : FILE CREATED == 2015-04-17 12:40:30.751335600
# 2019-07-26-165600 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@G00049A.pdf
# 2019-07-26-165600 : FILE_EXISTS == True
# 2019-07-26-165600 : [Watermark-PDF] FIN...
# 2019-07-26-165600 : LOCAL count == 5
# 2019-07-26-165600 : FILE CREATED == 2015-04-16 14:27:51.802325600
# 2019-07-26-165600 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@J00597.pdf
# 2019-07-26-165600 : FILE_EXISTS == True
# 2019-07-26-165601 : [Watermark-PDF] FIN...
# 2019-07-26-165601 : LOCAL count == 6
# 2019-07-26-165601 : FILE CREATED == 2015-04-16 14:28:26.458575600
# 2019-07-26-165601 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@K00128.pdf
# 2019-07-26-165601 : FILE_EXISTS == True
# 2019-07-26-165601 : [Watermark-PDF] FIN...
# 2019-07-26-165601 : LOCAL count == 7
# 2019-07-26-165601 : FILE CREATED == 2015-04-16 14:28:54.161700600
# 2019-07-26-165601 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@K00919.pdf
# 2019-07-26-165601 : FILE_EXISTS == True
# 2019-07-26-165602 : [Watermark-PDF] FIN...
# 2019-07-26-165602 : LOCAL count == 8
# 2019-07-26-165602 : FILE CREATED == 2015-04-16 14:31:10.880450600
# 2019-07-26-165602 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@K01137.pdf
# 2019-07-26-165602 : FILE_EXISTS == True
# 2019-07-26-165602 : [Watermark-PDF] FIN...
# 2019-07-26-165602 : LOCAL count == 9
# 2019-07-26-165602 : FILE CREATED == 2015-04-16 14:32:47.692950600
# 2019-07-26-165602 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@L00990.pdf
# 2019-07-26-165602 : FILE_EXISTS == True
# 2019-07-26-165602 : [Watermark-PDF] FIN...
# 2019-07-26-165602 : LOCAL count == 10
# 2019-07-26-165602 : FILE CREATED == 2015-04-16 14:33:18.567950600
# 2019-07-26-165602 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@M00165.pdf
# 2019-07-26-165602 : FILE_EXISTS == True
# 2019-07-26-165603 : [Watermark-PDF] FIN...
# 2019-07-26-165603 : LOCAL count == 11
# 2019-07-26-165603 : FILE CREATED == 2015-03-11 19:01:58.692044800
# 2019-07-26-165603 : THE_FILE_PATH == F:\APPS\CofA\ICP-049@R00677.pdf
# 2019-07-26-165603 : FILE_EXISTS == True
# 2019-07-26-165603 : [Watermark-PDF] FIN...
# 2019-07-26-165603 : LOCAL count == 12
# 2019-07-26-165603 : TOTAL count == 49
# 2019-07-26-165603 : Directory exists after? False
# 2019-07-26-165603 : Contents after: []
# 2019-07-26-165603 : told you so
# 2019-07-26-165603 : ======== ICP-125 ========
# 2019-07-26-165603 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpzkkvjmar
# 2019-07-26-165605 : FILE CREATED == 2019-06-03 18:13:15.118574100
# 2019-07-26-165605 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@0006470502.pdf
# 2019-07-26-165605 : FILE_EXISTS == True
# 2019-07-26-165606 : [Watermark-PDF] FIN...
# 2019-07-26-165606 : LOCAL count == 1
# 2019-07-26-165606 : FILE CREATED == 2015-05-12 10:40:07.798819800
# 2019-07-26-165606 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@CM-2432.pdf
# 2019-07-26-165606 : FILE_EXISTS == True
# 2019-07-26-165606 : [Watermark-PDF] FIN...
# 2019-07-26-165606 : LOCAL count == 2
# 2019-07-26-165606 : FILE CREATED == 2018-04-09 16:23:45.626666300
# 2019-07-26-165606 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@CS-1643.pdf
# 2019-07-26-165606 : FILE_EXISTS == True
# 2019-07-26-165607 : [Watermark-PDF] FIN...
# 2019-07-26-165607 : LOCAL count == 3
# 2019-07-26-165607 : FILE CREATED == 2015-04-23 18:01:29.922400600
# 2019-07-26-165607 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@G00793A.pdf
# 2019-07-26-165607 : FILE_EXISTS == True
# 2019-07-26-165607 : [Watermark-PDF] FIN...
# 2019-07-26-165607 : LOCAL count == 4
# 2019-07-26-165607 : FILE CREATED == 2015-11-05 14:44:08.175142700
# 2019-07-26-165607 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@IH-0391.pdf
# 2019-07-26-165607 : FILE_EXISTS == True
# 2019-07-26-165607 : [Watermark-PDF] FIN...
# 2019-07-26-165607 : LOCAL count == 5
# 2019-07-26-165607 : FILE CREATED == 2015-04-23 18:18:52.813025600
# 2019-07-26-165607 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@J00797.pdf
# 2019-07-26-165607 : FILE_EXISTS == True
# 2019-07-26-165608 : [Watermark-PDF] FIN...
# 2019-07-26-165608 : LOCAL count == 6
# 2019-07-26-165608 : FILE CREATED == 2015-04-23 18:19:29.484900600
# 2019-07-26-165608 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@K00953.pdf
# 2019-07-26-165608 : FILE_EXISTS == True
# 2019-07-26-165608 : [Watermark-PDF] FIN...
# 2019-07-26-165608 : LOCAL count == 7
# 2019-07-26-165608 : FILE CREATED == 2015-03-25 20:06:45.482415400
# 2019-07-26-165608 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@M00276.pdf
# 2019-07-26-165608 : FILE_EXISTS == True
# 2019-07-26-165609 : [Watermark-PDF] FIN...
# 2019-07-26-165609 : LOCAL count == 8
# 2019-07-26-165609 : FILE CREATED == 2015-05-05 14:26:56.414485600
# 2019-07-26-165609 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@M00276B.pdf
# 2019-07-26-165609 : FILE_EXISTS == True
# 2019-07-26-165609 : [Watermark-PDF] FIN...
# 2019-07-26-165609 : LOCAL count == 9
# 2019-07-26-165609 : FILE CREATED == 2015-04-23 18:21:15.766150600
# 2019-07-26-165609 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@M00334.pdf
# 2019-07-26-165609 : FILE_EXISTS == True
# 2019-07-26-165609 : [Watermark-PDF] FIN...
# 2019-07-26-165609 : LOCAL count == 10
# 2019-07-26-165609 : FILE CREATED == 2017-12-22 15:22:57.899064700
# 2019-07-26-165609 : THE_FILE_PATH == F:\APPS\CofA\ICP-125@M00334A.pdf
# 2019-07-26-165609 : FILE_EXISTS == True
# 2019-07-26-165610 : [Watermark-PDF] FIN...
# 2019-07-26-165610 : LOCAL count == 11
# 2019-07-26-165610 : TOTAL count == 60
# 2019-07-26-165610 : Directory exists after? False
# 2019-07-26-165610 : Contents after: []
# 2019-07-26-165610 : told you so
# 2019-07-26-165610 : ======== ICP-126 ========
# 2019-07-26-165610 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp36gppjeh
# 2019-07-26-165611 : FILE CREATED == 2019-05-13 15:51:01.734496800
# 2019-07-26-165611 : THE_FILE_PATH == F:\APPS\CofA\ICP-126@0006465163.pdf
# 2019-07-26-165611 : FILE_EXISTS == True
# 2019-07-26-165612 : [Watermark-PDF] FIN...
# 2019-07-26-165612 : LOCAL count == 1
# 2019-07-26-165612 : FILE CREATED == 2015-04-09 18:38:12.135794800
# 2019-07-26-165612 : THE_FILE_PATH == F:\APPS\CofA\ICP-126
: TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp3uywxw9k
# 2019-07-26-165624 : FILE CREATED == 2015-03-30 11:47:51.073000
# 2019-07-26-165624 : THE_FILE_PATH == F:\APPS\CofA\ICP-356@AU-00033.pdf
# 2019-07-26-165624 : FILE_EXISTS == True
# 2019-07-26-165625 : [Watermark-PDF] FIN...
# 2019-07-26-165625 : LOCAL count == 1
# 2019-07-26-165625 : FILE CREATED == 2015-08-25 14:20:14.326384
# 2019-07-26-165625 : THE_FILE_PATH == F:\APPS\CofA\ICP-356@AU-00894.pdf
# 2019-07-26-165625 : FILE_EXISTS == True
# 2019-07-26-165625 : [Watermark-PDF] FIN...
# 2019-07-26-165625 : LOCAL count == 2
# 2019-07-26-165625 : FILE CREATED == 2016-10-11 20:54:08.262000
# 2019-07-26-165625 : THE_FILE_PATH == F:\APPS\CofA\ICP-356@AU-01069.pdf
# 2019-07-26-165625 : FILE_EXISTS == True
# PdfReadWarning: Superfluous whitespace found in object header b'51' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'50' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'49' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'54' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'53' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'48' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'52' b'0' [pdf.py:1666]
# 2019-07-26-165626 : [Watermark-PDF] FIN...
# 2019-07-26-165626 : LOCAL count == 3
# 2019-07-26-165626 : TOTAL count == 82
# 2019-07-26-165626 : Directory exists after? False
# 2019-07-26-165626 : Contents after: []
# 2019-07-26-165626 : told you so
# 2019-07-26-165626 : ======== IMK-109 ========
# 2019-07-26-165626 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpblmshjex
# 2019-07-26-165627 : TOTAL count == 82
# 2019-07-26-165627 : Directory exists after? False
# 2019-07-26-165627 : Contents after: []
# 2019-07-26-165627 : told you so
# 2019-07-26-165627 : ======== IMS-101 ========
# 2019-07-26-165627 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpn0msdtod
# 2019-07-26-165629 : FILE CREATED == 2017-03-24 16:46:02.409218300
# 2019-07-26-165629 : THE_FILE_PATH == F:\APPS\CofA\IMS-101@CR-1261.pdf
# 2019-07-26-165629 : FILE_EXISTS == True
# 2019-07-26-165629 : [Watermark-PDF] FIN...
# 2019-07-26-165629 : LOCAL count == 1
# 2019-07-26-165629 : FILE CREATED == 2015-03-30 11:51:23.558544700
# 2019-07-26-165629 : THE_FILE_PATH == F:\APPS\CofA\IMS-101@T00268.pdf
# 2019-07-26-165629 : FILE_EXISTS == True
# 2019-07-26-165629 : [Watermark-PDF] FIN...
# 2019-07-26-165629 : LOCAL count == 2
# 2019-07-26-165629 : TOTAL count == 84
# 2019-07-26-165629 : Directory exists after? False
# 2019-07-26-165629 : Contents after: []
# 2019-07-26-165629 : told you so
# 2019-07-26-165629 : ======== IMS-102 ========
# 2019-07-26-165629 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp6u97sogd
# 2019-07-26-165631 : FILE CREATED == 2015-05-14 17:29:32.549330800
# 2019-07-26-165631 : THE_FILE_PATH == F:\APPS\CofA\IMS-102@CL-4972.pdf
# 2019-07-26-165631 : FILE_EXISTS == True
# 2019-07-26-165631 : [Watermark-PDF] FIN...
# 2019-07-26-165631 : LOCAL count == 1
# 2019-07-26-165631 : FILE CREATED == 2015-02-10 18:58:20.092668500
# 2019-07-26-165631 : THE_FILE_PATH == F:\APPS\CofA\IMS-102@CL-4972A.pdf
: TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpb6z5z224
# 2019-07-26-165635 : FILE CREATED == 2019-05-16 16:46:49.858592400
# 2019-07-26-165635 : THE_FILE_PATH == F:\APPS\CofA\IMS-103@0006464679.pdf
# 2019-07-26-165635 : FILE_EXISTS == True
# 2019-07-26-165635 : [Watermark-PDF] FIN...
# 2019-07-26-165635 : LOCAL count == 1
# 2019-07-26-165635 : FILE CREATED == 2014-08-25 14:34:22.268923200
# 2019-07-26-165635 : THE_FILE_PATH == F:\APPS\CofA\IMS-103@CL-3346.pdf
# 2019-07-26-165635 : FILE_EXISTS == True
# 2019-07-26-165635 : [Watermark-PDF] FIN...
# 2019-07-26-165635 : LOCAL count == 2
# 2019-07-26-165635 : FILE CREATED == 2016-03-24 15:54:53.876800100
# 2019-07-26-165635 : THE_FILE_PATH == F:\APPS\CofA\IMS-103@CP-1324.pdf
# 2019-07-26-165635 : FILE_EXISTS == True
# 2019-07-26-165636 : [Watermark-PDF] FIN...
# 2019-07-26-165636 : LOCAL count == 3
# 2019-07-26-165636 : FILE CREATED == 2017-04-26 17:16:15.535500300
# 2019-07-26-165636 : THE_FILE_PATH == F:\APPS\CofA\IMS-103@CR-1846.pdf
# 2019-07-26-165636 : FILE_EXISTS == True
# 2019-07-26-165636 : [Watermark-PDF] FIN...
# 2019-07-26-165636 : LOCAL count == 4
# 2019-07-26-165636 : FILE CREATED == 2015-05-14 17:34:49.598234900
# 2019-07-26-165636 : THE_FILE_PATH == F:\APPS\CofA\IMS-103@M00713.pdf
# 2019-07-26-165636 : FILE_EXISTS == True
# 2019-07-26-165636 : [Watermark-PDF] FIN...
# 2019-07-26-165636 : LOCAL count == 5
# 2019-07-26-165636 : FILE CREATED == 2015-05-14 18:13:20.253648
# 2019-07-26-165636 : THE_FILE_PATH == F:\APPS\CofA\IMS-103@R00412.pdf
# 2019-07-26-165636 : FILE_EXISTS == True
# 2019-07-26-165636 : [Watermark-PDF] FIN...
# 2019-07-26-165636 : LOCAL count == 6
# 2019-07-26-165636 : TOTAL count == 99
# 2019-07-26-165636 : Directory exists after? False
# 2019-07-26-165636 : Contents after: []
# 2019-07-26-165636 : told you so
# 2019-07-26-165636 : ======== IMS-104 ========
# 2019-07-26-165636 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpw958bzaj
# 2019-07-26-165638 : FILE CREATED == 2016-01-04 14:50:29.413198300
# 2019-07-26-165638 : THE_FILE_PATH == F:\APPS\CofA\IMS-104@CM-6545.pdf
# 2019-07-26-165638 : FILE_EXISTS == True
# 2019-07-26-165638 : [Watermark-PDF] FIN...
# 2019-07-26-165638 : LOCAL count == 1
# 2019-07-26-165638 : FILE CREATED == 2017-07-31 17:21:03.411374700
# 2019-07-26-165638 : THE_FILE_PATH == F:\APPS\CofA\IMS-104@CR-3465.pdf
# 2019-07-26-165638 : FILE_EXISTS == True
# 2019-07-26-165638 : [Watermark-PDF] FIN...
# 2019-07-26-165638 : LOCAL count == 2
# 2019-07-26-165638 : FILE CREATED == 2019-02-27 15:04:50.059378700
# 2019-07-26-165638 : THE_FILE_PATH == F:\APPS\CofA\IMS-104@CT-0844.pdf
# 2019-07-26-165638 : FILE_EXISTS == True
# 2019-07-26-165639 : [Watermark-PDF] FIN...
# 2019-07-26-165639 : LOCAL count == 3
# 2019-07-26-165639 : FILE CREATED == 2015-05-14 18:16:23.411070200
# 2019-07-26-165639 : THE_FILE_PATH == F:\APPS\CofA\IMS-104@J00358A.pdf
# 2019-07-26-165639 : FILE_EXISTS == True
# 2019-07-26-165639 : [Watermark-PDF] FIN...
# 2019-07-26-165639 : LOCAL count == 4
# 2019-07-26-165639 : FILE CREATED == 2015-05-14 18:21:37.741206900
# 2019-07-26-165639 : THE_FILE_PATH == F:\APPS\CofA\IMS-104@P00340.pdf
# 2019-07-26-165639 : FILE_EXISTS == True
# 2019-07-26-165639 : [Watermark-PDF] FIN...
# 2019-07-26-165639 : LOCAL count == 5
# 2019-07-26-165639 : FILE CREATED == 2015-03-17 17:39:48.652086400
# 2019-07-26-165639 : THE_FILE_PATH == F:\APPS\CofA\IMS-104@T00344.pdf
# 2019-07-26-165639 : FILE_EXISTS == True
# 2019-07-26-165639 : [Watermark-PDF] FIN...
# 2019-07-26-165639 : LOCAL count == 6
# 2019-07-26-165639 : TOTAL count == 105
# 2019-07-26-165639 : Directory exists after? False
# 2019-07-26-165639 : Contents after: []
# 2019-07-26-165639 : told you so
# 2019-07-26-165639 : ======== IMS-105 ========
# 2019-07-26-165639 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpfqo_lzab
# 2019-07-26-165641 : FILE CREATED == 2019-03-29 13:27:58.815052600
# 2019-07-26-165641 : THE_FILE_PATH == F:\APPS\CofA\IMS-105@0006458210.pdf
# 2019-07-26-165641 : FILE_EXISTS == True
# 2019-07-26-165641 : [Watermark-PDF] FIN...
# 2019-07-26-165641 : LOCAL count == 1
# 2019-07-26-165641 : FILE CREATED == 2015-01-13 17:25:54.513292500
# 2019-07-26-165641 : THE_FILE_PATH == F:\APPS\CofA\IMS-105@CM-0087.pdf
# 2019-07-26-165641 : FILE_EXISTS == True
# 2019-07-26-165642 : [Watermark-PDF] FIN...
# 2019-07-26-165642 : LOCAL count == 2
# 2019-07-26-165642 : FILE CREATED == 2016-09-13 17:14:29.867334600
# 2019-07-26-165642 : THE_FILE_PATH == F:\APPS\CofA\IMS-105@CP-4641.pdf
# 2019-07-26-165642 : FILE_EXISTS == True
# 2019-07-26-165642 : [Watermark-PDF] FIN...
# 2019-07-26-165642 : LOCAL count == 3
# 2019-07-26-165642 : FILE CREATED == 2017-03-22 12:18:45.002649200
# 2019-07-26-165642 : THE_FILE_PATH == F:\APPS\CofA\IMS-105@CR-1154.pdf
# 2019-07-26-165642 : FILE_EXISTS == True
# 2019-07-26-165642 : [Watermark-PDF] FIN...
# 2019-07-26-165642 : LOCAL count == 4
# 2019-07-26-165642 : FILE CREATED == 2015-05-14 18:23:55.913966200
# 2019-07-26-165642 : THE_FILE_PATH == F:\APPS\CofA\IMS-105@P01307.pdf
# 2019-07-26-165642 : FILE_EXISTS == True
# 2019-07-26-165643 : [Watermark-PDF] FIN...
# 2019-07-26-165643 : LOCAL count == 5
# 2019-07-26-165643 : FILE CREATED == 2015-05-14 18:23:01.272991500
# 2019-07-26-165643 : THE_FILE_PATH == F:\APPS\CofA\IMS-105@R01235.pdf
# 2019-07-26-165643 : FILE_EXISTS == True
# 2019-07-26-165643 : [Watermark-PDF] FIN...
# 2019-07-26-165643 : LOCAL count == 6
# 2019-07-26-165643 : TOTAL count == 111
# 2019-07-26-165643 : Directory exists after? False
# 2019-07-26-165643 : Contents after: []
# 2019-07-26-165643 : told you so
# 2019-07-26-165643 : ======== ISM-287-1 ========
# 2019-07-26-165643 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmppla15b_h
# 2019-07-26-165645 : TOTAL count == 111
# 2019-07-26-165645 : Directory exists after? False
# 2019-07-26-165645 : Contents after: []
# 2019-07-26-165645 : told you so
# 2019-07-26-165645 : ======== ISM-331-1 ========
# 2019-07-26-165645 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpyxn7c2_7
# 2019-07-26-165646 : FILE CREATED == 2019-06-10 10:25:18.713401200
# 2019-07-26-165646 : THE_FILE_PATH == F:\APPS\CofA\ISM-331-1@0006469481.pdf
# 2019-07-26-165646 : FILE_EXISTS == True
# 2019-07-26-165646 : [Watermark-PDF] FIN...
# 2019-07-26-165646 : LOCAL count == 1
# 2019-07-26-165646 : FILE CREATED == 2018-02-27 13:35:58.450774300
# 2019-07-26-165646 : THE_FILE_PATH == F:\APPS\CofA\ISM-331-1@CS-0856.PDF
# 2019-07-26-165646 : FILE_EXISTS == True
# 2019-07-26-165647 : [Watermark-PDF] FIN...
# 2019-07-26-165647 : LOCAL count == 2
# 2019-07-26-165647 : TOTAL count == 113
# 2019-07-26-165647 : Directory exists after? False
# 2019-07-26-165647 : Contents after: []
# 2019-07-26-165647 : told you so
# 2019-07-26-165647 : ======== IST-630-1 ========
# 2019-07-26-165647 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp97q26g93
# 2019-07-26-165648 : FILE CREATED == 2019-06-11 20:28:43.531671600
# 2019-07-26-165648 : THE_FILE_PATH == F:\APPS\CofA\IST-630-1@0006472760.pdf
# 2019-07-26-165648 : FILE_EXISTS == True
# 2019-07-26-165649 : [Watermark-PDF] FIN...
# 2019-07-26-165649 : LOCAL count == 1
# 2019-07-26-165649 : TOTAL count == 114
# 2019-07-26-165649 : Directory exists after? False
# 2019-07-26-165649 : Contents after: []
# 2019-07-26-165649 : told you so
# 2019-07-26-165649 : ======== NVM-8115-1 ========
# 2019-07-26-165649 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpwhccb2zj
# 2019-07-26-165650 : TOTAL count == 114
# 2019-07-26-165650 : Directory exists after? False
# 2019-07-26-165651 : Contents after: []
# 2019-07-26-165651 : told you so
# 2019-07-26-165651 : ======== PFA-100-1 ========
# 2019-07-26-165651 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp6j90c0yc
# 2019-07-26-165652 : TOTAL count == 114
# 2019-07-26-165652 : Directory exists after? False
# 2019-07-26-165652 : Contents after: []
# 2019-07-26-165652 : told you so
# 2019-07-26-165652 : ======== PHM-565-1 ========
# 2019-07-26-165652 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmprvsip39i
# 2019-07-26-165654 : FILE CREATED == 2017-01-12 19:17:14.063127
# 2019-07-26-165654 : THE_FILE_PATH == F:\APPS\CofA\PHM-565-1@CR-0016.pdf
# 2019-07-26-165654 : FILE_EXISTS == True
# 2019-07-26-165654 : [Watermark-PDF] FIN...
# 2019-07-26-165654 : LOCAL count == 1
# 2019-07-26-165654 : FILE CREATED == 2018-04-18 11:23:10.113632600
# 2019-07-26-165654 : THE_FILE_PATH == F:\APPS\CofA\PHM-565-1@CS-1971.PDF
: TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpy2bc6h0e
# 2019-07-26-165707 : FILE CREATED == 2019-04-29 22:17:54.978252700
# 2019-07-26-165707 : THE_FILE_PATH == F:\APPS\CofA\PP-361-1@0006462134.pdf
# 2019-07-26-165707 : FILE_EXISTS == True
# 2019-07-26-165707 : [Watermark-PDF] FIN...
# 2019-07-26-165707 : LOCAL count == 1
# 2019-07-26-165707 : TOTAL count == 120
# 2019-07-26-165707 : Directory exists after? False
# 2019-07-26-165707 : Contents after: []
# 2019-07-26-165707 : told you so
# 2019-07-26-165707 : ======== PPM-530-1 ========
# 2019-07-26-165707 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpe2uluw29
# 2019-07-26-165709 : FILE CREATED == 2019-06-12 20:47:08.575951200
# 2019-07-26-165709 : THE_FILE_PATH == F:\APPS\CofA\PPM-530-1@0006471606.pdf
# 2019-07-26-165709 : FILE_EXISTS == True
# 2019-07-26-165710 : [Watermark-PDF] FIN...
# 2019-07-26-165710 : LOCAL count == 1
# 2019-07-26-165710 : TOTAL count == 121
# 2019-07-26-165710 : Directory exists after? False
# 2019-07-26-165710 : Contents after: []
# 2019-07-26-165710 : told you so
# 2019-07-26-165710 : ======== PPM-531-1 ========
# 2019-07-26-165710 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpqvycyhsu
# 2019-07-26-165712 : TOTAL count == 121
# 2019-07-26-165712 : Directory exists after? False
# 2019-07-26-165712 : Contents after: []
# 2019-07-26-165712 : told you so
# 2019-07-26-165712 : ======== PPM-549-1 ========
# 2019-07-26-165712 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpnh3smhba
# 2019-07-26-165713 : TOTAL count == 121
# 2019-07-26-165713 : Directory exists after? False
# 2019-07-26-165713 : Contents after: []
# 2019-07-26-165713 : told you so
# 2019-07-26-165713 : ======== PPM-808C-1 ========
# 2019-07-26-165713 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpd4uiofik
# 2019-07-26-165715 : FILE CREATED == 2019-05-23 22:29:13.245647500
# 2019-07-26-165715 : THE_FILE_PATH == F:\APPS\CofA\PPM-808C-1     @0006453059.pdf
# 2019-07-26-165715 : FILE_EXISTS == True
# 2019-07-26-165715 : [Watermark-PDF] FIN...
# 2019-07-26-165715 : LOCAL count == 1
# 2019-07-26-165715 : TOTAL count == 122
# 2019-07-26-165715 : Directory exists after? False
# 2019-07-26-165715 : Contents after: []
# 2019-07-26-165715 : told you so
# 2019-07-26-165715 : ======== PST-040 ========
# 2019-07-26-165715 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpfckye0_u
# 2019-07-26-165717 : FILE CREATED == 2015-06-29 17:25:10.446298
# 2019-07-26-165717 : THE_FILE_PATH == F:\APPS\CofA\PST-040-100MG@NT051529.pdf
# ...
# 2019-07-26-170033 : LOCAL count == 2
# 2019-07-26-170033 : TOTAL count == 487
# 2019-07-26-170033 : Directory exists after? False
# 2019-07-26-170033 : Contents after: []
# 2019-07-26-170033 : told you so
# 2019-07-26-170033 : ======== WRK-151K ========
# 2019-07-26-170033 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tm
: TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp2tdluutu
# 2019-07-26-170130 : TOTAL count == 498
# 2019-07-26-170130 : Directory exists after? False
# 2019-07-26-170130 : Contents after: []
# 2019-07-26-170130 : told you so
# 2019-07-26-170130 : ======== STS-440-1 ========
# 2019-07-26-170130 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmplavyrbf0
# 2019-07-26-170131 : TOTAL count == 498
# 2019-07-26-170131 : Directory exists after? False
# 2019-07-26-170131 : Contents after: []
# 2019-07-26-170131 : told you so
# 2019-07-26-170131 : ======== SVM-8270-1 ========
# 2019-07-26-170131 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpvel9c_dg
# 2019-07-26-170133 : TOTAL count == 498
# 2019-07-26-170133 : Directory exists after? False
# 2019-07-26-170133 : Contents after: []
# 2019-07-26-170133 : told you so
# 2019-07-26-170133 : ======== TCLP-512-1 ========
# 2019-07-26-170133 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp_wx7f5ey
# 2019-07-26-170134 : TOTAL count == 498
# 2019-07-26-170134 : Directory exists after? False
# 2019-07-26-170134 : Contents after: []
# 2019-07-26-170134 : told you so
# 2019-07-26-170134 : ======== US-105N-1 ========
# 2019-07-26-170134 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp5qs8u5ye
# 2019-07-26-170136 : TOTAL count == 498
# 2019-07-26-170136 : Directory exists after? False
# 2019-07-26-170136 : Contents after: []
# 2019-07-26-170136 : told you so
# 2019-07-26-170136 : ======== US-120AN-1 ========
# 2019-07-26-170136 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpu7hgnh7r
# 2019-07-26-170137 : TOTAL count == 498
# 2019-07-26-170137 : Directory exists after? False
# 2019-07-26-170137 : Contents after: []
# 2019-07-26-170137 : told you so
# 2019-07-26-170137 : ======== UST-200-1 ========
# 2019-07-26-170137 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpb9cjor12
# 2019-07-26-170139 : TOTAL count == 498
# 2019-07-26-170139 : Directory exists after? False
# 2019-07-26-170139 : Contents after: []
# 2019-07-26-170139 : told you so
# 2019-07-26-170139 : ======== WRK-151P ========
# 2019-07-26-170139 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpijv873pn
# 2019-07-26-170140 : TOTAL count == 498
# 2019-07-26-170140 : Directory exists after? False
# 2019-07-26-170140 : Contents after: []
# 2019-07-26-170140 : told you so
# 2019-07-26-170140 : ======== WRK-151Q ========
# 2019-07-26-170140 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmpapj07w13
# 2019-07-26-170142 : TOTAL count == 498
# 2019-07-26-170142 : Directory exists after? False
# 2019-07-26-170142 : Contents after: []
# 2019-07-26-170142 : told you so
# 2019-07-26-170142 : ======== WRK-151R ========
# 2019-07-26-170142 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmprxatgryu
# 2019-07-26-170143 : TOTAL count == 498
# 2019-07-26-170143 : Directory exists after? False
# 2019-07-26-170143 : Contents after: []
# 2019-07-26-170143 : told you so
# 2019-07-26-170143 : ======== WRK-151S ========
# 2019-07-26-170143 : TEMP_DIR== C:\Users\derbates\AppData\Local\Temp\tmp9y4ro4gr
# 2019-07-26-170145 : TOTAL count == 498
# 2019-07-26-170145 : Directory exists after? False
# 2019-07-26-170145 : Contents after: []
# 2019-07-26-170145 : told you so

# %% [markdown]
# ## *`os.walk()` thru WORKING DIRECTORY*
#
# ## and keep only **MOST RECENT** file
#
# ## `or`
#
# ## keep only **MOST OLDEST** file

# %%
most_recent = False

# %%
type(most_recent)
# Out:
# bool

# %%
if most_recent is True: #{
    print("true")
#}
else: #{
    print("false!")
#}
# Out:
# false!

# %%
in_directory = "."

# %%
# CREATE LIST VARIABLES THAT WILL BECOME COLS IN DATAFRAME
file_col = []
date_col = []

# %% [markdown]
# ---
# *PROCESS FOR RETURNING `MOST RECENT`*

# %%
# create LIST vars to hold all the most recent files/dates
recent_files = []
recent_dates = []

# %%
# iterate thru directory/directories 
for root, d_names, f_names in os.walk(in_directory): #{
    logging.info("===================== START ====================== \n")
    logging.info("\t *root* = " + str(root) + "\n") 
    logging.info("\t *dict* = " + str(d_names) + "\n")
    if len(f_names) >= 0: #{
        logging.info("\t *file(s)*: \n")
        # CREATE VARS for "most_recents"
        most_recent_date = pd.Timestamp(year=1999, month=12, day=31)
        most_recent_name = "NOT FOUND"
        # multiple file(s)
        for f in f_names: #{
            logging.info("\t FILE-NAME == " + str(f) + "\n")
            file_name = os.path.basename(f)
            # add **file NAME** to list
            file_col.append(file_name)
            # create variable for *ORIGINAL* file_path
            f_path = os.path.join("F:/APPS/CofA/", file_name)
            logging.info("\t F_PATH == " + str(f_path) + "\n")
            if os.path.exists(f_path): #{
                # create date var
                date = os.path.getctime(f_path)
                # FORMAT date var & SET AS str
                date_str = str(datetime.fromtimestamp(date))
                # set our date STR to a Pandas.TIMESTAMP var
                ts = pd.Timestamp(ts_input=date_str)
                logging.info("\t CREATE_DATE == " + str(ts) + "\n")
                ##################################################### 
                # CHECK IF MOST RECENT (if 'ts' is more recent...)
                if ts > most_recent_date: #{
                    # RE_ASSIGN 'most_recent_date'
                    most_recent_date = ts
                    most_recent_name = f_path
                    logging.info("\t most_recent_date == " + str(most_recent_date) + "\n")
                    logging.info("\t most_recent_name == " + str(most_recent_name) + "\n")
                #}
                else: #{
                    # keep "most_recent_date" the same
                    logging.info("\t most_recent_date == " + str(most_recent_date) + "\n")
                    logging.info("\t most_recent_name == " + str(most_recent_name) + "\n")
                #}
                #logging.info("\t ts == " + str(ts) + "\n")
                # add **file DATE** to list
                date_col.append(date_str)
            #}
            else: #{
                logging.info("\t CREATE_DATE == NaN (doesn't exist) \n")
            #}
        #}
    #}
    else: #{
        # no files
        logging.info("\t NO-FILES!")
    #}
    logging.info("=====================  END  ======================")
    recent_files.append(most_recent_name)
    recent_dates.append(most_recent_date)
#}
# Out:
# 2019-07-26-170145 : ===================== START ======================
#
# 2019-07-26-170145 : 	 *root* = .
#
# 2019-07-26-170145 : 	 *dict* = ['.ipynb_checkpoints', '2019-07-26']
#
# 2019-07-26-170145 : 	 *file(s)*:
#
# 2019-07-26-170145 : 	 FILE-NAME == .~lock.most_recent_test_1.csv#
#
# 2019-07-26-170145 : 	 F_PATH == F:/APPS/CofA/.~lock.most_recent_test_1.csv#
#
# 2019-07-26-170145 : 	 CREATE_DATE == NaN (doesn't exist)
#
# 2019-07-26-170145 : 	 FILE-NAME == batch_list.csv
#
# 2019-07-26-170145 : 	 F_PATH == F:/APPS/CofA/batch_list.csv
#
# 2019-07-26-170145 : 	 CREATE_DATE == NaN (doesn't exist)
#
# 2019-07-26-170145 : 	 FILE-NAME == CC_2019_07_26.ipynb
#
# 2019-07-26-170145 : 	 F_PATH == F:/APPS/CofA/CC_2019_07_26.ipynb
#
# 2019-07-26-170145 : 	 CREATE_DATE == NaN (doesn't exist)
#
# 2019-07-26-170145 : 	 FILE-NAME == most_recent_test_1.csv
#
# 2019-07-26-170145 : 	 F_PATH == F:/APPS/CofA
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/IMS-105@0006458210.pdf
#
# 2019-07-26-170147 : 	 FILE-NAME == IMS-105@CP-4641.pdf
#
# 2019-07-26-170147 : 	 F_PATH == F:/APPS/CofA/IMS-105@CP-4641.pdf
#
# 2019-07-26-170147 : 	 CREATE_DATE == 2016-09-13 13:14:29.867335
#
# 2019-07-26-170147 : 	 most_recent_date == 2019-03-29 10:17:07.169621
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/IMS-105@0006458210.pdf
#
# 2019-07-26-170147 : 	 FILE-NAME == IMS-105@CR-1154.pdf
#
# 2019-07-26-170147 : 	 F_PATH == F:/APPS/CofA/IMS-105@CR-1154.pdf
#
# 2019-07-26-170147 : 	 CREATE_DATE == 2017-03-22 08:18:45.002649
#
# 2019-07-26-170147 : 	 most_recent_date == 2019-03-29 10:17:07.169621
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/IMS-105@0006458210.pdf
#
# 2019-07-26-170147 : 	 FILE-NAME == IMS-105@P01307.pdf
#
# 2019-07-26-170147 : 	 F_PATH == F:/APPS/CofA/IMS-105@P01307.pdf
#
# 2019-07-26-170147 : 	 CREATE_DATE == 2015-05-14 14:23:55.913966
#
# 2019-07-26-170147 : 	 most_recent_date == 2019-03-29 10:17:07.169621
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/IMS-105@0006458210.pdf
#
# 2019-07-26-170147 : 	 FILE-NAME == IMS-105@R01235.pdf
#
# 2019-07-26-170147 : 	 F_PATH == F:/APPS/CofA/IMS-105@R01235.pdf
#
# 2019-07-26-170147 : 	 CREATE_DATE == 2015-05-14 14:23:01.272991
#
# 2019-07-26-170147 : 	 most_recent_date == 2019-03-29 10:17:07.169621
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/IMS-105@0006458210.pdf
#
# 2019-07-26-170147 : =====================  END  ======================
# 2019-07-26-170147 : ===================== START ======================
#
# 2019-07-26-170147 : 	 *root* = .\2019-07-26\ISM-287-1
#
# 2019-07-26-170147 : 	 *dict* = []
#
# 2019-07-26-170147 : 	 *file(s)*:
#
# 2019-07-26-170147 : =====================  END  ======================
# 2019-07-26-170147 : ===================== START ======================
#
# 2019-07-26-170147 : 	 *root* = .\2019-07-26\ISM-331-1
#
# 2019-07-26-170147 : 	 *dict* = []
#
# 2019-07-26-170147 : 	 *file(s)*:
#
# 2019-07-26-170147 : 	 FILE-NAME == ISM-331-1@0006469481.pdf
#
# 2019-07-26-170147 : 	 F_PATH == F:/APPS/CofA/ISM-331-1@0006469481.pdf
#
# 2019-07-26-170147 : 	 CREATE_DATE == 2019-06-10 06:25:18.713401
#
# 2019-07-26-170147 : 	 most_recent_date == 2019-06-10 06:25:18.713401
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/ISM-331-1@0006469481.pdf
#
# 2019-07-26-170147 : 	 FILE-NAME == ISM-331-1@CS-0856.PDF
#
# 2019-07-26-170147 : 	 F_PATH == F:/APPS/CofA/ISM-331-1@CS-0856.PDF
#
# 2019-07-26-170147 : 	 CREATE_DATE == 2018-02-27 08:35:58.450774
#
# 2019-07-26-170147 : 	 most_recent_date == 2019-06-10 06:25:18.713401
#
# 2019-07-26-170147 : 	 most_recent_name == F:/APPS/CofA/ISM-331-1@0006469481.pdf
#
# ...
#
# 2019-07-26-170152 : 	 F_PATH == F:/APPS/CofA/WRK-151O@NT057361.pdf
#
# 2019-07-26-170152 : 	 CREATE_DATE == 2019-05-28 09:54:42.775191
#
# 2019-07-26-170152 : 	 most_recent_date == 2019-05-28 10:03:49.204060
#
# 2019-07-26-170152 : 	 most_recent_name == F:/APPS/CofA/WRK-151A@NT053304.pdf
#
# 2019-07-26-170152 : =====================  END  ======================
# 2019-07-26-170152 : ===================== START ======================
#
# 2019-07-26-170152 : 	 *root* = .\2019-07-26\WRK-151A
#
# 2019-07-26-170152 : 	 *dict* = []
#
# 2019-07-26-170152 : 	 *file(s)*:
#
# 2019-07-26-170152 : 	 FILE-NAME == WRK-151A@NT053304.pdf
#
# 2019-07-26-170152 : 	 F_PATH == F:/APPS/CofA/WRK-151A@NT053304.pdf
#
# 2019-07-26-170152 : 	 CREATE_DATE == 2019-05-28 10:03:49.204060
#
# 2019-07-26-170152 : 	 most_recent_date == 2019-05-28 10:03:49.204060
#
# 2019-07-26-170152 : 	 most_recent_name == F:/APPS/CofA/WRK-151A@NT053304.pdf
#
# 2019-07-26-170152 : 	 FILE-NAME == WRK-151A@NT057373.pdf
#
# 2019-07-26-170152 : 	 F_PATH == F:/APPS/CofA/WRK-151A@NT057373.pdf
#
# 2019-07-26-170152 : 	 CREATE_DATE == 2019-05-28 09:54:42.087682
#
# 2019-07-26-170152 : 	 most_recent_date == 2019-05-28 10:03:49.204060
#
# 2019-07-26-170152 : 	 most_recent_name == F:/APPS/CofA/WRK-151A@NT053304.pdf
#
# 2019-07-26-170152 : =====================  END  ======================
# 2019-07-26-170152 : ===================== START ======================
#
# 2019-07-26-170152 : 	 *root* = .\2019-07-26\WRK-151B
#
# 2019-07-26-170152 : 	 *dict* = []
#
# 2019-07-26-170152 : 	 *file(s)*:
#
# 2019-07-26-170152 : 	 FILE-NAME == WRK-151B@NT053305.pdf
#
# 2019-07-26-170152 : 	 F_PATH == F:/APPS/CofA/WRK-151B@NT053305.pdf
#
# 2019-07-26-170152 : 	 CREATE_DATE == 2019-05-28 10:03:49.094684
#
# 2019-07-26-170152 : 	 most_recent_date == 2019-05-28 10:03:49.094684
#
# 2019-07-26-170152 : 	 most_recent_name == F:/APPS/CofA/WRK-151B@NT053305.pdf
#
# 2019-07-26-170152 : 	 FILE-NAME == WRK-151B@NT057348.pdf
#
# 2019-07-26-170152 : 	 F_PATH == F:/APPS/CofA/WRK-151B@NT057348.pdf
#
# 2019-07-26-170152 : 	 CREATE_DATE == 2019-05-28 09:54:44.259585
#
# 2019-07-26-170152 : 	 most_recent_date == 2019-05-28 10:03:49.094684
#
# 2019-07-26-170152 : 	 most_recent_name == F:/APPS/CofA/WRK-151B@NT053305.pdf
#
# 2019-07-26-170152 : =====================  END  ======================
# 2019-07-26-170152 : ===================== START ======================
#
# 2019-07-26-170152 : 	 *root* = .\2019-07-26\WRK-151C
#
# 2019-07-26-170152 : 	 *dict* = []
#
# 2019-07-26-170152 : 	 *file(s)*:
#
# 2019-07-26-170152 : 	 FILE-NAME == WRK-
#
# 2019-07-26-170153 : 	 FILE-NAME == WRK-151O@NT053315.pdf
# 2019-07-26-170153 : 	 F_PATH == F:/APPS/CofA/WRK-151O@NT053315.pdf
#
# 2019-07-26-170153 : 	 CREATE_DATE == 2019-05-28 10:03:47.938419
#
# 2019-07-26-170153 : 	 most_recent_date == 2019-05-28 10:03:47.938419
#
# 2019-07-26-170153 : 	 most_recent_name == F:/APPS/CofA/WRK-151O@NT053315.pdf
#
# 2019-07-26-170153 : 	 FILE-NAME == WRK-151O@NT057361.pdf
#
# 2019-07-26-170153 : 	 F_PATH == F:/APPS/CofA/WRK-151O@NT057361.pdf
#
# 2019-07-26-170153 : 	 CREATE_DATE == 2019-05-28 09:54:42.775191
#
# 2019-07-26-170153 : 	 most_recent_date == 2019-05-28 10:03:47.938419
#
# 2019-07-26-170153 : 	 most_recent_name == F:/APPS/CofA/WRK-151O@NT053315.pdf
#
# 2019-07-26-170153 : =====================  END  ======================
# 2019-07-26-170153 : ===================== START ======================
#
# 2019-07-26-170153 : 	 *root* = .\2019-07-26\WRK-151P
#
# 2019-07-26-170153 : 	 *dict* = []
#
# 2019-07-26-170153 : 	 *file(s)*:
#
# 2019-07-26-170153 : =====================  END  ======================
# 2019-07-26-170153 : ===================== START ======================
#
# 2019-07-26-170153 : 	 *root* = .\2019-07-26\WRK-151Q
#
# 2019-07-26-170153 : 	 *dict* = []
#
# 2019-07-26-170153 : 	 *file(s)*:
#
# 2019-07-26-170153 : =====================  END  ======================
# 2019-07-26-170153 : ===================== START ======================
#
# 2019-07-26-170153 : 	 *root* = .\2019-07-26\WRK-151R
#
# 2019-07-26-170153 : 	 *dict* = []
#
# 2019-07-26-170153 : 	 *file(s)*:
#
# 2019-07-26-170153 : =====================  END  ======================
# 2019-07-26-170153 : ===================== START ======================
#
# 2019-07-26-170153 : 	 *root* = .\2019-07-26\WRK-151S
#
# 2019-07-26-170153 : 	 *dict* = []
#
# 2019-07-26-170153 : 	 *file(s)*:
#
# 2019-07-26-170153 : =====================  END  ======================

# %%
# CREATE EMPTY DATAFRAME
df_dates = pd.DataFrame()

# %%
# CREATE SERIES OFF LIST
f1 = pd.Series(recent_files)

# %%
# CREATE SERIES OFF LIST
d1 = pd.Series(recent_dates)

# %%
df_dates['File'] = f1
df_dates['Time'] = d1

# %%
df_dates.head(10)
# Out:
#                                     File                       Time
# 0                              NOT FOUND 1999-12-31 00:00:00.000000
# 1                              NOT FOUND 1999-12-31 00:00:00.000000
# 2                              NOT FOUND 1999-12-31 00:00:00.000000
# 3                              NOT FOUND 1999-12-31 00:00:00.000000
# 4  F:/APPS/CofA/DWM-544-1@0006476293.pdf 2019-06-26 16:59:57.088456
# 5  F:/APPS/CofA/DWM-580-1@0006472371.pdf 2019-06-10 06:26:02.682714
# 6     F:/APPS/CofA/DWM-583-1@CG-3973.PDF 2010-12-21 14:30:59.128316
# 7                              NOT FOUND 1999-12-31 00:00:00.000000
# 8                              NOT FOUND 1999-12-31 00:00:00.000000
# 9                              NOT FOUND 1999-12-31 00:00:00.000000

# %%
df_dates.to_csv("most_recent_test.csv", index=False)

# %% [raw]
# df_dates['FileName'] = f1
# df_dates['CreateTime'] = d1

# %% [raw]
# df_dates.head(20)

# %% [raw]
# try: #{
#     # create column var to store the data
#     # date_col = []
#
#     # counter
#     x = 0
#
#     # create Series from column
#     d1
#
# #}
