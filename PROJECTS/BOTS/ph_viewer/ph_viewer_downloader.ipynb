# %%
import os, sys, time
from time import sleep
from pathlib import Path

# %%
import fnmatch, logging
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
from bs4 import BeautifulSoup
import requests
# IMPORT THE LIBRARY USED TO QUERY A WEBSITE
import urllib.request as urllib2
import wget

# %% [markdown]
# ## Setup LOGGER

# %%
def setup_logger(): #{
    # RE-INSTANTIATE GLOBAL
    global timestamp_str
    # TRY THE FOLLOWING
    try: #{
        logging.basicConfig(level=logging.INFO,
                           format="%(asctime)s:%(message)s",
                           filename="C:/data/Logs/PH-VIEWER-downloader" + timestamp_str + ".log",
                           filemode="a")
    #}
    except: #{
        print("failed setting up logger yo")
    #}
    else: #{
        print("SUCCESS! VERY NICE!")
    #}
#}

# %% [markdown]
# ## MAKE DIRECTORY FOR TODAYS DATE:

# %%
if __name__ == "__main__": #{
    # INSTANTIATE GLOBAL VARIABLES
    out_directory = "C:/data/outbound/ph_viewer"
    ts_date_str = str(pd.Timestamp.now())[:10]
    ts_time_str = str(pd.Timestamp.now())[11:19]
    ts_time_str = ts_time_str.replace(":","-")
    timestamp_str = ts_date_str + "_" + ts_time_str
    print(ts_date_str)
    print(ts_time_str)
    print(timestamp_str)
    ###########################################################
    setup_logger()
    #######################################################
    # CHECK AND CREATE NEW DIR PATH
    new_dir_path = os.path.join(out_directory, str(ts_date_str + "-" + str(ts_time_str)))
    # IF 'NEW DIR' DOES NOT EXIST (it wont)
    if not os.path.exists(new_dir_path): #{
        # MAKE IT EXIST!
        os.makedirs(new_dir_path)
    #}
    
    options = webdriver.ChromeOptions()
    options.add_argument('--ignore-certificate-errors')
    options.add_argument("--test-type")
    #options.binary_location = "/usr/bin/chromium/"
    driver = webdriver.Chrome(chrome_options=options)
    
    driver.get('https://pornhub.com/')
    
    images = driver.find_elements_by_tag_name('img')
    
    # COUNTER
    i = 1
    for image in images: #{
        logging.info(image.get_attribute('src'))
        print(str(image.get_attribute('src')))
        # GET IMAGE SOURCE
        src = image.get_attribute('src')
        # CHECK STRING OF "src"
        if str(src) != "None": #{
             # CREATE FILENAME
            file_name = ts_date_str + "-" + ts_time_str + str(i) + ".png"
            # CREATE FILE_PATH
            file_path = os.path.join(new_dir_path, file_name)
            print("FILEPATH WILL BE ===" + str(file_path))
            # TRY THE FOLLOWING
            try: #{
                # DOWNLOAD IMAGE
                urllib2.urlretrieve(str(src), file_path)
            #}
            except: #{
                # TRY DOWNLOADING VIA WGET
                wget.download(src, file_path)
            #}
            else: #{
                print("SUCCESSFULLY DOWNLOADED VIA urllib!")
            #}
            finally: #{
                pass    
            #}
        #}
        else: #{
            print("FAIL!")
        #}
        # INCREASE COUNT
        i += 1
        logging.info(str(i))
        print(str(i))
    #}
    # QUIT OUT OF DRIVER
    driver.quit()
    # END THE PROGRAM
    sys.exit(69)
#}
# Out:
# 2019-11-18
# 17-29-18
# 2019-11-18_17-29-18
# SUCCESS! VERY NICE!
# C:\Users\BabyPoopSoup\Miniconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning: use options instead of chrome_options
# None
# FAIL!
# 2
# None
# FAIL!
# 3
# None
# FAIL!
# 4
# None
# FAIL!
# 5
# None
# FAIL!
# 6
# None
# FAIL!
# 7
# None
# FAIL!
# 8
# https://ci.phncdn.com/www-static/images/pornhub_logo_straight.png?cache=2019111803
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-188.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 9
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-189.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 10
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1810.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 11
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1811.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 12
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1812.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 13
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1813.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 14
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1814.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 15
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1815.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 16
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1816.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 17
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1817.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 18
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1818.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 19
# None
# FAIL!
# 20
# None
# FAIL!
# 21
# None
# FAIL!
# 22
# None
# FAIL!
# 23
# None
# FAIL!
# 24
# None
# FAIL!
# 25
# None
# FAIL!
# 26
# None
# FAIL!
# 27
# None
# FAIL!
# 28
# None
# FAIL!
# 29
# None
# FAIL!
# 30
# None
# FAIL!
# 31
# None
# FAIL!
# 32
# None
# FAIL!
# 33
# None
# FAIL!
# 34
# None
# FAIL!
# 35
# None
# FAIL!
# 36
# None
# FAIL!
# 37
# None
# FAIL!
# 38
# None
# FAIL!
# 39
# None
# FAIL!
# 40
# None
# FAIL!
# 41
# None
# FAIL!
# 42
# None
# FAIL!
# 43
# None
# FAIL!
# 44
# None
# FAIL!
# 45
# None
# FAIL!
# 46
# None
# FAIL!
# 47
# None
# FAIL!
# 48
# None
# FAIL!
# 49
# None
# FAIL!
# 50
# https://ci.phncdn.com/videos/201909/20/249685031/thumbs_30/(m=eafTGgaaaa)(mh=61S9STBECv4i6YbS)15.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1850.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 51
# https://ci.phncdn.com/videos/201605/25/77576131/original/(m=eafTGgaaaa)(mh=g54cNiJ-reF8bSmB)7.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1851.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 52
# https://di.phncdn.com/videos/201909/18/249209301/original/(m=eafTGgaaaa)(mh=DyIt_nY8UUf5NBFm)4.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1852.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 53
# https://di.phncdn.com/videos/201910/15/255070541/original/(m=qI8TJ7UbeafTGgaaaa)(mh=jwOixmGN5nNcKc2f)0.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1853.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 54
# https://ci.phncdn.com/videos/201910/22/256555781/original/(m=qTNX_6UbeafTGgaaaa)(mh=qqbJS7a63XgQrp7w)0.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1854.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 55
# https://di.phncdn.com/videos/201910/12/254415651/original/(m=eafTGgaaaa)(mh=tehY03XU__-dLLwD)10.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1855.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 56
# https://ci.phncdn.com/videos/201812/05/195331791/thumbs_4/(m=eafTGgaaaa)(mh=4h65_zltIM_-AGIC)5.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1856.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 57
# https://di.phncdn.com/videos/201712/31/147916892/original/(m=eafTGgaaaa)(mh=lglOrNJmZ50NvJgl)12.jpg
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1857.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 58
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1858.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 59
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1859.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 60
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1860.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 61
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1861.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 62
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1862.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 63
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1863.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 64
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1864.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 65
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1865.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 66
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1866.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 67
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1867.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 68
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1868.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 69
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1869.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 70
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1870.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 71
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1871.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 72
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1872.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 73
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1873.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 74
# ...
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1874.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 75
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1875.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 76
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1876.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 77
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1877.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 78
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1878.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 79
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1879.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 80
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1880.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 81
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1881.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 82
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1882.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 83
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1883.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 84
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1884.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 85
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1885.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 86
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1886.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 87
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1887.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 88
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1888.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 89
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1889.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 90
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1890.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 91
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1891.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 92
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1892.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 93
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1893.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 94
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1894.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 95
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1895.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 96
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1896.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 97
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1897.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 98
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1898.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 99
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-1899.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 100
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18100.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 101
# https://ci.phncdn.com/www-static/images/rightArrow.png
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18101.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 102
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18102.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 103
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18103.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 104
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18104.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 105
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18105.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 106
# ...:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18106.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 107
# https://cdn1-smallimg.phncdn.com/n172nWs1UEcnquuObA5x52osw51230gH/rta-1.gif
# FILEPATH WILL BE ===C:/data/outbound/ph_viewer\2019-11-18-17-29-18\2019-11-18-17-29-18107.png
# SUCCESSFULLY DOWNLOADED VIA urllib!
# 108
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 69
# C:\Users\BabyPoopSoup\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
