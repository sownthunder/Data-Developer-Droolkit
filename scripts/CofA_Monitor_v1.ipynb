# %% [markdown]
# # `CofA` Daily_Launcher

# %% [markdown]
# ### 1) create `logger`
# ### 2) create global variables
# ### 3) using `watchdog` wait for file to come into:
#     - F:/Apps/CofA/
#
# ## save all created and modified files into the `df_save_list` datafeframe and then when `execute_staging()` is called:
#
# ***_ conpare the two dorectories and only watermark the DIFF***
# ***_ then FINALLY create that garbage temp dir and ZiP it***
# ***_ last but not least email that shit once and for good***

# %%
# IMPORT THE GOODIES
import os, sys, time
from time import sleep
from pathlib import Path
import fnmatch, glob, shutil
import wmi, psutil
import filecmp, tempfile, textwrap
from textwrap import wrap
from zipfile import ZipFile
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import email, smtplib, ssl
import os.path as op
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.utils import COMMASPACE, formatdate
import subprocess, threading, logging
from threading import Timer
from PyPDF2 import PdfFileReader, PdfFileWriter
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# %% [markdown]
# **CLASSES**

# %%
class CofA_Event_Handler(FileSystemEventHandler): #{
    
    def __init__(self, save_dataframe, in_directory, observer): #{
        
        self.save_dataframe = save_dataframe
        self.in_directory = in_directory
        self.observer = observer
        #self.out_directory = out_directory
    #}
    
    """
    # DISPATCH ALWAYS CALLED FIRST JUST DESCRIBE EVENT
    def dispatch(self, event): #{
        event_str = str(event.event_type)
        event_path = Path(event.src_path)
        print("**********************")
        print("EVENT >>> " + event_str)
        print("SRC_PATH >>> " + str(event_path))
        print("**********************")
        # SEND OFF TO PERFORM ACTIONS BASED ON EVENT
        #perform_event_actions(the_event_type=event_str, the_event_path=event_path)
    #}
    """
    
    def on_any_event(self,event): #{
        # RE-INSTANTIATE GLOBALS
        global isEOD, t
        global observer
        # TRY THE FOLLOWING
        print("\ne=" + str(event) + "\n")
        
        try: #{
            print(str(t))
            print("checking for isEOD...")
            if isEOD is True: #{
                # STOP OBSERVER
                observer.stop()
                print("TRUE! ENDING SCRIPT!")
                # QUIT SCRIPT
                sys.exit(69)
            #}
            else: #{
                print("FALSE! \n STILL RUNNING AT " 
                      + str(pd.Timestamp.now()) 
                      + "\n")
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("SUCCESS! VERY NICE!!")
        #}
        finally: #{
            print("[isEOD-check]FIN...")
        #}
    #}
    
    def on_created(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| CREATED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)  # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                """int
                # CREATE str TO HOLD FINAL COLUMN FOR TUPLE
                created_str = "Created"
                """
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  #WAS: (created_str)
                """
                # APPEND EVENT ITEM TO "save_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
                print(df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED AT " + str(ts))
            #}
            
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Created-Event] FIN..")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Created-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    
    def on_modified(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| MODIFIED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)   # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  # WAS: (modified_str)
                """
                # APPEND EVENT ITEM TO "Createed_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED ON " + str(ts))
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Modified-Event] VERY NICE GOOD JOB! ")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Modified-Event] >>> time_alloted: " + str(run_time))
        #}
    #}

#}

# %% [markdown]
# **FUNCTIONS**

# %%
"""
TAKES IN:
PDF TO WATERMARK,
"""
def create_watermark(input_pdf, output, watermark): # {
    try:  # {
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)

        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()

        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()):  # {
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        # }

        with open(output, 'wb') as out:  # {
            pdf_writer.write(out)
        # }
    # }
    except: # {
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
        # }
    else: # {
        print("\t\t[watermark-pdf] FIN...")
    # }
    finally: # {
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[watermark-pdf] >>> time_alloted: " + str(run_time))
    # }
    return
# }

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list 
    file_paths = [] 
    
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths
#}

# %%
"""
TAKES IN:
(1) path to pdf 
RETURNS: 
the STRING of that PDF to match the naming convention
in G:/C of A's/#Email Node/ from F:/APPS/CofA/
"""
def generate_naming_convention(the_pdf_path): #{
    # get/set filename to variable
    the_file_name = str(os.path.basename(the_pdf_path))
    # PERFORM STRING OPERATIONS
    #################################
    idx_mrk = the_file_name.rfind('@', 0, len(the_file_name))
    half1 = str(the_file_name[0:idx_mrk])
    half2 = str(the_file_name[idx_mrk + 1:len(the_file_name)])
    print("\t\t[*************************]")
    print("\t\t|>>> HALF 1 == " + half1)
    print("\t\t|>>> HALF 2 == " + half2)
    #  setup NEW FILE NAME (for copy)
    new_name = "part "
    new_name += str(half1)
    new_name += " CofA Lot# "
    new_name += str(half2)
    print("\t\t|>>> NEW NAME == " + str(new_name))
    print("\t\t[*************************]")
    #################################
    return str(new_name)
#}

# %%
"""
TAKES IN: 
(1) LIST-type obj containing:
    - basename (CofA etc)[*.pdf]
    - timestamp
    - "Created" **OR** "Modified category"
(2) DataFrame obj containing:
    - that the newest row will be appended too
RETURNS: 
DataFrame (not in-place) with newly
appended tuple row etc 
"""
def append_to_dataframe(the_event_list, dataframe_to_append): #{
    # TRY THE FOLLOWING
    try: #{
        # CHECK IF LIST
        if type(the_event_list) is list : #{  # WAS: (the_event_list is list)
            print("\t\tLIST check == PASS")
            # SEPERATE COLUMNS
            col_1 = str(the_event_list[0])
            col_2 = str(the_event_list[1])
            # CREATE APPENDAGE FRAME
            df_appendage = pd.DataFrame(data=[the_event_list], 
                                        columns=['CofA', 'Timestamp'])
            # CREATE INSTANCE OF DATAFRAME WE ARE RETURNING
            return_df = dataframe_to_append.append(df_appendage, ignore_index=True, sort=False)
            #OLD# print(return_df.tail(5))
        #}
        else: #{
            print("\t\tLIST check == FAIL")
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("\t\t[Append-2-DataFrame] FIN...")
        return return_df
    #}
    finally: #{
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[Append-2-DataFrame] >>> time_alloted: "+ str(run_time))
    #}
#}

# %% [raw]
# def extract_information(pdf_path): #{
#     with open(pdf_path, 'rb') as f: #{
#         pdf = PdfFileReader(f)
#         information = pdf.getDocumentInfo()
#         number_of_pages = pdf.getNumPages()
#     #}
#     txt = f"""
#     Information about {pdf_path}:
#
#     Author: {information.author}
#     Creator: {information.creator}
#     Producer: {information.producer}
#     Subject: {information.subject}
#     Title: {information.title}
#     Number of Pages: {number_of_pages}
#     """
#
#     print(txt)
#     return information
# #}

# %%
"""
TAKES IN:
(1) file_path to file 
RETURNS: 
The create time or modified time, whichever is older
"""
def pull_creation_timetamp(a_file_path): #{
    # FORCE PATH VARIABLE
    the_path = Path(a_file_path)
    # GET MODIFIED TIME
    mtime = os.path.getmtime(the_path)
    # GET CREATE TIME
    ctime = os.path.getctime(the_path)
    # CREATE DATE VAR
    # IF CREATE TIME IS OLDER...
    if ctime < mtime: #{
        # FORMAT DATE VAR as str
        date_str = str(datetime.fromtimestamp(ctime))
    #}
    # ELSE.... MODIFIED TIME IS OLDER...
    else: #{
        # FORMAT DATE VAR as str
        date_str = str(datetime.fromtimestamp(mtime))
    #}
    # RETURN THE DATE WE PULLED AS STRING
    return date_str
#}

# %%
#test_list = scan_directory("F:/APPS/CofA/")

# %%
#print(len(test_list))

# %% [raw]
# def display_pdf_text(pdf_path): #{
#     read_pdf = PyPDF2.PdfFileReader(pdf_path)
#
#     for i in range(read_pdf.getNumPages()): #{
#         page = read_pdf.getPage(i)
#         print("Page No - " + str(1+read_pdf.getPageNumber(page)))
#         page_content = page.extractText()
#         print(page_content)
#     #}
#
# #}

# %%
def send_mail(send_from, send_to, subject, message, files=[], 
              server="cos.smtp.agilent.com", port=587, use_tls=True): #{
    print("SENDING MAIL... DATE == " + str(pd.Timestamp.now())[:10])
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = COMMASPACE.join(send_to)
    msg['Date'] = formatdate(localtime=True)
    msg['Subject'] = subject
    
    msg.attach(MIMEText(message))
    
    for path in files: #{
        part = MIMEBase('application', "octet-stream")
        with open(path, 'rb') as file: #{
            part.set_payload(file.read())
        #}
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                       'attachment; filename="{}"'.format(op.basename(path)))
        msg.attach(part)
    #}
    
    smtp = smtplib.SMTP(server, port)
    if use_tls: #{
        smtp.starttls()
    #}
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
#}

# %% [markdown]
# ---
#
# # compare `F:/APPS/CofA/` scan of `TODAY`
# # to scan of `F:/APPS/CofA/` of `YESTERDAY`
#
# >>> `CREATE DIFF DATAFRAME`
# >>> `ITERATE THRU THAT`
#
# `OVERWRITE` PDFs when *watermarking*
#
# AND THEN `CREATE ZIP` AND *EMAIL THAT ZIP* IN THE TEMP FOLDER

# %%
"""
EXPORTS DATAFRAME
TAKES IN:
(1) DATAFRAME OBJECT THAT HAS BEEN CREATED VIA WATCHODG
"""
def execute_staging(): #{
    # RE-INSTANTIATE GLOBALS
    #OLD# global save_list
    global df_save_list
    global observer
    global in_directory
    global out_directory
    #OLD# global today_date_str
    global isEOD
    #OLD# print("DATAFRAME IS OF TYPE ==\n\t\t" + str(type(df_save_list)))
    #OLD# print("AND IS EMPTY !?!?!? == \n" + str(df_save_list))
    print("\n\n\n >>>>> BUT THAT SEXY save_list == \n" + str(df_save_list))
    print("of type =====================" + str(type(df_save_list)))
    """
    #################### CREATE [save_list] DATAFRAME #####################
    try: #{
        # WE HAVE THE SAVE_LIST, NOW WE NEED TO FILL THAT DATA IN
        # TO THE MAIN DATAFRAME THAT IT BELONG TO
        df_saveframe = pd.DataFrame(data=save_list, 
                                    columns=['CofA', 'Timestamp'], 
                                    dtype=np.str)
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-DataFrame] SUCCESS! VERY NICE!")
        print(str(df_saveframe))
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("[Create-DataFrame] RUN TIME == " + str(run_time))
    #}
    """
    #################################################
    try: #{
        print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #OLD# print("TODAYS (FAKE) DATE == " + today_date_str)
        ###########################################
        # CREATE TODAY AND YESTERDAY STR
        today_str = str(pd.Timestamp.now())[:10]
        print("TODAYS (REAL) DATE == " + today_str)
        ######################################################
        #time_now = pd.Timestamp(year=2019, month=8, day=14) #
        ######################################################
        time_now = pd.Timestamp.now()
        # CREATE SUTBRACTION DELTA 
        subtraction_delta = pd.Timedelta(value=1, unit='days')
        print("SUBTRACTION DELTA == " + str(subtraction_delta))
        # CREATE "yesterdays date" BY SUTBRACTING
        yesterstr = str(time_now - subtraction_delta)[:10]
        print("YESTERSTR == " + str(yesterstr))
        print("\nTEST GLOB-STRING == " + str("C:/CofA/log/lists/*_" 
                                             + yesterstr 
                                             + "_*"))
        ###########################################
        # BEGIN GLOBBING (WAS: C:/data/inbound/)
        glob_previous = sorted(glob.glob("CC:/CofA/log/lists/*_" 
                                         + yesterstr 
                                         + "_*"))
        print("\n\t GLOB_PREVIOUS >>> \n")
        for name in glob_previous: #{
            print(name)
        #}
        #####################################################################
        # < FOR RIGHT NOW WE IMPORT A .CSV FOR THE TODAY_FILE... 
        # THIS IS CREATED MANUALLY EVERY TIME BY CREATING A LIST OF 
        # "F:/APPS/CofA/" AND PUTTING INTO  A DATAFRAME
        # ==============[DIRECTORY CHANGE FOR FINAL VERISON]===========
        # "C:/data/inbound/*_" >>>> "C:/CofA/log/lists/*_"
        #####################################################################
        # RETURN LIST FROM FUNCTION
        #
        #OLD#glob_current = scan_directory("F:/APPS/CofA/")
        #
        ########################################################
        glob_current = sorted(glob.glob("C:/CofA/log/lists/*_" 
                                        + today_str 
                                        + "_*"))
        print("\n\t GLOB_CURRENT >>> \n")
        for name in glob_current: #{
            print(name)
        #}
        print("\n\n\n~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #################
        # SETUP IMPORTS #
        #################
        df1 = pd.read_csv(glob_previous[0])
        df2 = pd.read_csv(glob_current[0])
        """
        # we dont use indeces because of LIST
        df2 = pd.DataFrame() # EMPTY AT FIRST
        # ASSIGN COLUMN OF DATAFRAME FROM LIST
        df2['CofA File'] = glob_current
        """
        print("LEN_D1 == " + str(len(df1)))
        print("LEN_D2 == " + str(len(df2)))
        #OLD#print(df1.info)
        #OLD#print(df2.info)
        # SET DIFFERENCE OF TWO DATAFRAMES IN PANDAS PYTHON
        set_diff_df = pd.concat([df2, df1, df1]).drop_duplicates(keep=False)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("\n\tLENGTH OF DIFFERENCE == " + str(len(set_diff_df)))
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
        x = 0  # counter variable
        # CREATE TEMPORARY DIRECTORY (TO WORK INSIDE OF)
        ###################################################################
        with tempfile.TemporaryDirectory() as directory_name: #{
            the_dir = Path(directory_name)
            print("| TEMPORARY DIRECTORY >>> " + str(the_dir) + "\n")
            # ITERATE THRU TUPLES...
            for row in set_diff_df.itertuples(index=False, name="CofA"): #{
                # GET/CREATE BASE_NAME
                base_name = os.path.basename(str(row[0]))  # WAS: the_event_path
                # GET NEW FILE NAME CONVENTION
                file_name_conv = generate_naming_convention(base_name)
                # CREATE "temp_path"
                temp_path = os.path.join(the_dir, file_name_conv)
                # CREATE "dst_path"
                dst_path = os.path.join(out_directory, file_name_conv)
                # WATERMARK A COPY TO G_DRIVE **WITH CORRECT NE W FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=dst_path, watermark=in_file)
                # WATERMARK A COPY INTO TEMP FOLDER ** WITH CORRECT NEW FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=temp_path, watermark=in_file)
                # INCREASE COUNTER
                x += 1
                print("COUNT == " + str(x))
            #}
            ################################################################
            # ZIP THE CURRENT TEMP DIR (no need to create... just rename)
            try: #{
                print("\n\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
                print("\nWORKING DIRECTORY ---BEFORE--- ZIP == " + str(os.getcwd()))
                # path to folder
                directory = "." # (the_dir)
                # CHANGE WORKING DIRECTORY TO THE TEMPORARY DIR
                # (IN ORDER TO PROPERLY ZIP FILES/FOLDER)
                os.chdir(the_dir)   # WAS: "C:/"
                print("\nWORKING DIRECTORY ---DURING--- ZIP == " + str(os.getcwd()))
                # calling function to get all file paths in the directory
                file_paths = get_all_file_paths(the_dir)
                # printing the list of all files to be zipped 
                print('\nFollowing files will be zipped:') 
                for file_name in file_paths: #{
                    print(file_name) 
                #}
                # writing files to a zipfile 
                with ZipFile('CofA-' + str(pd.Timestamp.now())[:10] + ".zip",'w') as zip: #{
                    # writing each file one by one 
                    for file in file_paths: #{
                        zip.write(file) 
                    #}
                #}
                print('All files zipped successfully!\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' 
                      + 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX\n')
                ###################################################
                # ....NOW ZIP THE NEWLY MADE FOLDER INSIDE TEMP FOLDER...
                #WAS#zip_directory = "./" + str(today_date_str)
                """
                zip_dir = Path("/" + str(today_str))
                print("\n MAKE-SHIFT ZIPPY_DIR == " + str(zip_dir) + "\n")
                # CREATE ZIP_DIRECTORY PATH VARIABLE
                zip_directory = os.path.join(".", zip_dir)
                print("\n ZIP_DIRECTORY == " + str(zip_directory) + "\n")
                # calling function to get all file paths in directory
                file_paths = get_all_file_paths(zip_directory)
                # printing the list of all files to be zipped
                print('Following files will be zipped:') 
                """
            #}
            except: #{
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                      "\n" + fileE +
                      "\n" + lineE +
                      "\n" + messageE)
            #}
            else: #{
                print("ALL FILES SUCCESSFULLY ZIPPED!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Zip-Files] RUN TIME == " + str(run_time))
            #}
            # TRY TO FINISH THIS SHIT OFF
            try: #{
                print("\n\t\t\t GLOBBING FOR ZIP FILE !!!")
                for name in sorted(glob.glob(str(the_dir) + "/*.zip")): #{
                    print("NAME OF FILE == " 
                          + str(name))
                    #logging.info(name)
                    print("LENGTH OF GLOB == " 
                          + str(len(sorted(glob.glob(str(the_dir))))))
                    # GET&SET PATH NAME 
                    zip_path = Path(name)
                    print("ZIP_PATH == " 
                          + str(zip_path))
                #}
                """
                # CREATE ZIP_DRIECTORY OFF SINGLE_GLOB_STR
                zip_path = Path(sorted(glob.glob(str(the_dir) + "/*.zip"))[0])
                """
                # >>>>>>>>>>>>> EXPORT DATAFRAME <<<<<<<<<<<<<<<<<<< #
                ###################################################3
                # CREATE STR FOR PATH FOR SAVE_DIFF_DATAFRAME
                df_save_str = str("CofA-" 
                                  + str(pd.Timestamp.now())[:10] 
                                  + ".csv")
                df_save_path = os.path.join(the_dir, df_save_str)
                print("\n\n\tSAVE-PATH FOR DATAFRAME == " + str(df_save_path))
                # SORT THE DATAFRAME BEFORE EXPORTING
                df_save_frame_sorted = df_saveframe.sort_values(by='Timestamp')
                # DROP DUPLICATES BEFORE EXPORTING
                df_save_frame_sorted.drop_duplicates(subset='CofA', 
                                                     keep='last', 
                                                     inplace=True)
                df_save_frame_sorted.to_csv(str(df_save_path), index=False)
                #################### EXPORT DATAFRAME #####################
                # ZIP FILE HAS BEE CREATED NOW WE CAN EXPORT DATAFRAME
                # AND NOT WORRY ABOUT IT ALSO BEING INCLUDE IN ZIP
                #########################################################
                #OLD# df_saveframe.to_csv(str(df_save_path), index=False)
                ##################################################
                # EXPORT THE SET_DIFF_DF TO FILE  IN TEMP FOLDER IN ORDER TO EMAIL
                #set_diff_df.to_csv(str(df_save_path), index=False)
                # CREATE PATH VAR and "Popen" via SUBPROCESS
                print("Opening Explorer Window...")
                the_dir = Path(directory_name)
                # open temp_folder in a new EXPLORER WINDOW
                subprocess.Popen('explorer ' + str(the_dir))
                ###################################################
                # CREATE FILE_LIST VAR
                file_list = [str(zip_path), str(df_save_path)]
                print(">>> FILE LIST : \n\t" 
                      + str(file_list) 
                      + "\n")
                """
                break_input = input("Continue? Y\n")
                if str(break_input).lower() == "n": #{
                    sys.exit(69)
                #}
                elif str(break_input).lower() == "y": #{
                """
                print("CONT....")
                #####################################################
                # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                #####################################################
                try: #{
                    send_mail(send_from="derek.bates@non.agilent.com",
                              send_to="derek.bates@non.agilent.com", 
                              subject=str(pd.Timestamp.now())[:10],
                              message="See File(s) attached",
                              files=file_list)
                #}
                except: #{
                    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                    exc_type, exc_obj, exc_tb = sys.exc_info()
                    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                    typeE = str("TYPE : " + str(exc_type))
                    fileE = str("FILE : " + str(fname))
                    lineE = str("LINE : " + str(exc_tb.tb_lineno))
                    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                    print("\n" + typeE +
                                  "\n" + fileE +
                                  "\n" + lineE +
                                  "\n" + messageE)
                #}
                else: #{
                    print("EMAIL SUCCESSFULLY SENT! VERY NICE!")
                #}
            #}
            except: #{                
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                              "\n" + fileE +
                              "\n" + lineE +
                              "\n" + messageE)
            #}
            else: #{
                print("[Create-set_diff_df] SUCCESS! VERY NICE!!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Email-Files] FIN...")
                sys.exit(69)
            #}
        #}
        """
        print('Directory exists after?' + str(directory_name.exists()))
        print('Contents after:' + str(list(directory_name.glob('*'))))
        """
        ###################################################
        # OUTSIDE OF TEMP FOLDER
        # EXPORT THE .csv?
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        isEOD = True
        # BECAUSE WE SET "isEOD" TO TRUE IT WILL STOP WATCHDOG LISTENER, 
        # POST TIME STAMP, THEN EN
        observer.stop()
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("RUN TIME == " + str(run_time))
        print("LINE 352 EXECUTE STAGING()")
    #}
    
#}

# %% [markdown]
# ---

# %% [markdown]
# **OVERWRITE `.txt` FILE WITH DATAFRME**

# %% [raw]
# new_df.to_csv("CofA-backlog-test.txt", columns=None,
#               header=False, index=False, mode='w', escapechar='\r')

# %% [markdown]
# ---

# %% [raw]
# # INSTANTIATE GLOBAL VARIABLES
# in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
# in_file2 = "C:/data/inbound/02OTHER_Rohde Island_Agilent Quality_Digital Letterhead.pdf"
# #in_directory = "F:/APPS/CofA/"
# #out_directory = "G:/C of A's/#Email Node/"
# in_directory = "C:/Temp/F/APPS/CofA/"
# out_directory = "C:/Temp/G/C of A's/#Email Node/"
# save_list = []
# isEOD = False
# time_start = pd.Timestamp.now()
# df_save_list = pd.DataFrame(data=None, dtype=np.str)
# # FAKE VAR TO STAND FOR "todays date"
# today_date_str = "2019-08-14"

# %%
if __name__ == "__main__":
    # SETUP LOGGER
    try: #{
        logging.basicConfig(level=logging.INFO,
                            #stream=sys.stdout,
                            filename="C:/data/outbound/CofA_Daily_Launcher.log",
                            format='%(asctime)s:'
                            + '\n\t\t\t\t'
                            + '<MESG:%(message)s>'
                            + '\n\t\t\t\t'
                            + '<%(threadName)s-ID:%(thread)d>'
                            + '\n\t\t\t\t'
                            + '<%(processName)s-ID:%(process)d>'
                            + '\n\t\t\t\t'
                            + '<FUNC=%(funcName)s>'
                            + '\n\t\t\t\t'
                            + '<LINE:%(lineno)s>'
                            + '\n\t\t\t\t'
                            + '<PATH:%(pathname)s>'
                            + '\n\t\t\t\t'
                            + '<NAME:%(name)s>',
                            # format='%(asctime)s:%(message)s PROCESS=%(processName)s',
                            datefmt='%Y_%d_%m_%H%M%S',
                            filemode='a')
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-Logger] FIN...")
    #}
    ######################################
    # >>>>>>>> GLOBAL VARIABLES <<<<<<<< #
    ######################################
    in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
    #OLD# save_list = []
    df_save_list = pd.DataFrame(data=None, columns=['CofA', 'Timestamp'])
    # 'Created/Modified'
    isEOD = False
    in_directory = "F:/APPS/CofA/"  #"C:/Temp/F/APPS/CofA/"
    out_directory =  "G:/C of A's/#Email Node/"  #"C:/Temp/G/C of A's/#Email Node/"
    outbound_directory = "C:/Temp/G/C of A's/Agilent/"  #"G:/C of A's/Agilent/"
    to_email = "derek.bates@non.agilent.com"
    from_email = "derek.bates@non.agilemt.com"
    time_start = pd.Timestamp.now()
    # FAKE VAR TO STAND FOR "todays date"
    #OLD# today_date_str = "2019-08-24"  # WAS: 8/14
    ##########################################
    print("[=================================================]")
    print("| SCANNING DIRECTORY >>> " + str(in_directory))
    print("| STORING IN DATAFRAME >>> " + str(df_save_list))  # WAS: str(df_save_list.head()))
    print("[=================================================]")
    print("| Initializing Timer >>> " + str(pd.Timestamp.now()))
    print("[=================================================]\n\n\n")
    # CREATE TIMER VAR  // 12 HOURS... now 10.5 HOURS !! 08/07/2019
    # 37800 / USE == 54000
    t = Timer(28800, execute_staging) # WAS 2592000,3600,720,600,43200,300 & 120
    # START TIMER
    t.start()
    """
    print("\n\n<><><><><><><><><><>BEFORE HANDLER START<><><><><><><><><><><>\n")
    print("<><><><><> save_list == \n")
    # PRINT OUT EVERY ITEM & COUNT #
    len_count = len(df_save_list)
    for save in df_save_list: #{
        print("SAVE NAME === " + str(save))
        print("COUNT === " + str(len_count))
        # subtract one
        len_count -= 1
    #}
    #print("<><><><><> df_save_list == " + str(df_save_list))
    print("\n<><><><><><><><><><><><><><><><><><><><><><><><><><><>\n\n")
    """
    ###################
    # ALSO GLOBAL VAR # 
    ###################
    observer = Observer()
    # CREATE INSTANCE OF CUSTOM EVENT HANDLER
    event_handler = CofA_Event_Handler(df_save_list, in_directory, observer)
    #OLD# observer = Observer()
    observer.schedule(event_handler=event_handler,
                      path=in_directory,
                      recursive=True)
    observer.start()
    # TRY THE FOLLOWING
    try: #{
        while True: #{
            sleep(1)
        #}
    #}
    except KeyboardInterrupt: #{
        observer.stop()
    #}
    observer.join()
# Out:
# [Create-Logger] FIN...
# [=================================================]
# | SCANNING DIRECTORY >>> F:/APPS/CofA/
# | STORING IN DATAFRAME >>> Empty DataFrame
# Columns: [CofA, Timestamp]
# Index: []
# [=================================================]
# | Initializing Timer >>> 2019-08-26 14:00:47.373970
# [=================================================]
#
#
#
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/061496-2@0006484062.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:09:41.184524
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:09:41.184524
# 		[*************************]
# 		|>>> HALF 1 == 061496-2
# 		|>>> HALF 2 == 0006484062.pdf
# 		|>>> NEW NAME == part 061496-2 CofA Lot# 0006484062.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:08:53.816586
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:08:53.816586
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/061496-1@0006484061.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:09:41.998611
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:09:41.998611
# 		[*************************]
# 		|>>> HALF 1 == 061496-1
# 		|>>> HALF 2 == 0006484061.pdf
# 		|>>> NEW NAME == part 061496-1 CofA Lot# 0006484061.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:08:54.628672
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:08:54.628672
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/ICUS-2387@0006486113.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:19:54.810902
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:19:54.812875
# 		[*************************]
# 		|>>> HALF 1 == ICUS-2387
# 		|>>> HALF 2 == 0006486113.pdf
# 		|>>> NEW NAME == part ICUS-2387 CofA Lot# 0006486113.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:19:07.444929
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:19:07.444929
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/Thumbs.db'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:24:12.697284
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:24:12.697284
# NON-PDF CREATED ON 2019-08-26 14:24:12.697284
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:23:25.325346
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/US-105N@CT-0277.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:26:09.841705
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:26:09.842704
# 		[*************************]
# 		|>>> HALF 1 == US-105N
# 		|>>> HALF 2 == CT-0277.pdf
# 		|>>> NEW NAME == part US-105N CofA Lot# CT-0277.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:25:22.474324
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:25:22.474324
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Instruction Sheets'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.653655
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.653655
# NON-PDF CREATED ON 2019-08-26 14:29:24.653655
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.281717
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Instruction Sheets\\QCUS-QICUS'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.684654
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.685656
# NON-PDF CREATED ON 2019-08-26 14:29:24.685656
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.313718
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.763660
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.763660
# NON-PDF CREATED ON 2019-08-26 14:29:24.763660
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.391722
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\utils'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.783655
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.783655
# NON-PDF CREATED ON 2019-08-26 14:29:24.783655
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.411717
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\TEMP'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.790659
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.790659
# NON-PDF CREATED ON 2019-08-26 14:29:24.790659
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.418721
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\SQLQueries'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.821657
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.821657
# NON-PDF CREATED ON 2019-08-26 14:29:24.821657
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.449719
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\RecipeImport'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.879658
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.880658
# NON-PDF CREATED ON 2019-08-26 14:29:24.880658
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.508720
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\progs'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.903658
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.903658
# NON-PDF CREATED ON 2019-08-26 14:29:24.903658
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.532721
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\Menus'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.909660
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.909660
# NON-PDF CREATED ON 2019-08-26 14:29:24.909660
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.539724
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\libs'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:24.936674
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:24.936674
# NON-PDF CREATED ON 2019-08-26 14:29:24.936674
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.565724
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\ItemsConvert'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:25.027660
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:25.027660
# NON-PDF CREATED ON 2019-08-26 14:29:25.027660
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.656723
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\Forms'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:25.041659
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:25.041659
# NON-PDF CREATED ON 2019-08-26 14:29:25.041659
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:37.669721
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Archive ERR'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:25.686880
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:25.686880
# NON-PDF CREATED ON 2019-08-26 14:29:25.686880
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:38.315943
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Archive - For all archived CofA, see G CofA folder'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:25.697882
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:25.698882
# NON-PDF CREATED ON 2019-08-26 14:29:25.698882
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:28:38.327943
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/CLP-245@CT-0666.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:29:58.316686
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:29:58.316686
# 		[*************************]
# 		|>>> HALF 1 == CLP-245
# 		|>>> HALF 2 == CT-0666.pdf
# 		|>>> NEW NAME == part CLP-245 CofA Lot# CT-0666.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:29:10.945746
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:29:10.945746
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/ICP-026@CS-6257.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:34:49.513367
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:34:49.513367
# 		[*************************]
# 		|>>> HALF 1 == ICP-026
# 		|>>> HALF 2 == CS-6257.pdf
# 		|>>> NEW NAME == part ICP-026 CofA Lot# CS-6257.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:34:02.147422
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:34:02.151419
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/ICP-024A@CR-6004.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:38:32.145418
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:38:32.145418
# 		[*************************]
# 		|>>> HALF 1 == ICP-024A
# 		|>>> HALF 2 == CR-6004.pdf
# 		|>>> NEW NAME == part ICP-024A CofA Lot# CR-6004.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:37:44.775478
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:37:44.775478
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/ICUS-4493@0006485860.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:47:19.691835
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:47:19.691835
# 		[*************************]
# 		|>>> HALF 1 == ICUS-4493
# 		|>>> HALF 2 == 0006485860.pdf
# 		|>>> NEW NAME == part ICUS-4493 CofA Lot# 0006485860.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:46:32.323896
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:46:32.323896
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/IAA-216@CP-2216.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:50:11.209180
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:50:11.209180
# 		[*************************]
# 		|>>> HALF 1 == IAA-216
# 		|>>> HALF 2 == CP-2216.pdf
# 		|>>> NEW NAME == part IAA-216 CofA Lot# CP-2216.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:49:23.840243
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:49:23.841245
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/CUS-12992@0006486525.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:52:00.459214
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:52:00.459214
# 		[*************************]
# 		|>>> HALF 1 == CUS-12992
# 		|>>> HALF 2 == 0006486525.pdf
# 		|>>> NEW NAME == part CUS-12992 CofA Lot# 0006486525.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:51:13.091248
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:51:13.091248
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/DWM-588@CT-0288.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 14:55:36.384115
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 14:55:36.384115
# 		[*************************]
# 		|>>> HALF 1 == DWM-588
# 		|>>> HALF 2 == CT-0288.pdf
# 		|>>> NEW NAME == part DWM-588 CofA Lot# CT-0288.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:54:49.013197
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:54:49.013197
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/CUS-17268@0006466798.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:01:58.278931
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:01:58.278931
# 		[*************************]
# 		|>>> HALF 1 == CUS-17268
# 		|>>> HALF 2 == 0006466798.pdf
# 		|>>> NEW NAME == part CUS-17268 CofA Lot# 0006466798.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:01:10.909994
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:01:10.910994
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/PSM-525A@CS-4052.PDF'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:02:04.504617
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:02:04.504617
# 		[*************************]
# 		|>>> HALF 1 == PSM-525A
# 		|>>> HALF 2 == CS-4052.PDF
# 		|>>> NEW NAME == part PSM-525A CofA Lot# CS-4052.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:01:17.184678
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:01:17.184678
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/NPM-103@CS-0237.PDF'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:02:10.950052
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:02:10.951078
# 		[*************************]
# 		|>>> HALF 1 == NPM-103
# 		|>>> HALF 2 == CS-0237.PDF
# 		|>>> NEW NAME == part NPM-103 CofA Lot# CS-0237.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:01:23.580139
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:01:23.580139
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/PST-3390-10MG@0006485662.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:14:43.035035
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:14:43.035035
# 		[*************************]
# 		|>>> HALF 1 == PST-3390-10MG
# 		|>>> HALF 2 == 0006485662.pdf
# 		|>>> NEW NAME == part PST-3390-10MG CofA Lot# 0006485662.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:13:55.666098
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:13:55.666098
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/RGO-101X@0006478435.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:28:25.218310
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:28:25.218310
# 		[*************************]
# 		|>>> HALF 1 == RGO-101X
# 		|>>> HALF 2 == 0006478435.pdf
# 		|>>> NEW NAME == part RGO-101X CofA Lot# 0006478435.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:27:37.848408
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:27:37.849407
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/DWM-592-1@CR-6051.PDF'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:31:46.614163
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:31:46.614163
# 		[*************************]
# 		|>>> HALF 1 == DWM-592-1
# 		|>>> HALF 2 == CR-6051.PDF
# 		|>>> NEW NAME == part DWM-592-1 CofA Lot# CR-6051.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:30:59.243181
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:30:59.243181
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/DWM-592-1@CR-6050.PDF'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:31:54.760735
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:31:54.760735
# 		[*************************]
# 		|>>> HALF 1 == DWM-592-1
# 		|>>> HALF 2 == CR-6050.PDF
# 		|>>> NEW NAME == part DWM-592-1 CofA Lot# CR-6050.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:31:07.390794
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:31:07.390794
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/CUS-5463@0006486505.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:34:44.201233
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:34:44.204283
# 		[*************************]
# 		|>>> HALF 1 == CUS-5463
# 		|>>> HALF 2 == 0006486505.pdf
# 		|>>> NEW NAME == part CUS-5463 CofA Lot# 0006486505.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:33:56.840359
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:33:56.841347
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/CUS-4533@0006487237.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:38:11.330679
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:38:11.330679
# 		[*************************]
# 		|>>> HALF 1 == CUS-4533
# 		|>>> HALF 2 == 0006487237.pdf
# 		|>>> NEW NAME == part CUS-4533 CofA Lot# 0006487237.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:37:23.961776
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:37:23.961776
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/STM-320N@CP-4746A.PDF'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:46:30.091358
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:46:30.092409
# 		[*************************]
# 		|>>> HALF 1 == STM-320N
# 		|>>> HALF 2 == CP-4746A.PDF
# 		|>>> NEW NAME == part STM-320N CofA Lot# CP-4746A.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:45:42.724466
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:45:42.725459
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/PPM-8082@CM-5400A.PDF'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:48:21.125958
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:48:21.126961
# 		[*************************]
# 		|>>> HALF 1 == PPM-8082
# 		|>>> HALF 2 == CM-5400A.PDF
# 		|>>> NEW NAME == part PPM-8082 CofA Lot# CM-5400A.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:47:33.758023
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:47:33.758023
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/PPS-350-1@0006471975.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:49:23.559956
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:49:23.559956
# 		[*************************]
# 		|>>> HALF 1 == PPS-350-1
# 		|>>> HALF 2 == 0006471975.pdf
# 		|>>> NEW NAME == part PPS-350-1 CofA Lot# 0006471975.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:48:36.190016
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:48:36.190016
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/ISM-331-1@0006469481.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:49:29.784076
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:49:29.784076
# 		[*************************]
# 		|>>> HALF 1 == ISM-331-1
# 		|>>> HALF 2 == 0006469481.pdf
# 		|>>> NEW NAME == part ISM-331-1 CofA Lot# 0006469481.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:48:42.414105
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:48:42.414105
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/ISM-560-1@0006471679.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:49:36.264873
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:49:36.266870
# 		[*************************]
# 		|>>> HALF 1 == ISM-560-1
# 		|>>> HALF 2 == 0006471679.pdf
# 		|>>> NEW NAME == part ISM-560-1 CofA Lot# 0006471679.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:48:48.898932
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:48:48.898932
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/HBM-5156A@CT-0820.pdf'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 15:55:35.654418
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 15:55:35.654418
# 		[*************************]
# 		|>>> HALF 1 == HBM-5156A
# 		|>>> HALF 2 == CT-0820.pdf
# 		|>>> NEW NAME == part HBM-5156A CofA Lot# CT-0820.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:54:48.285479
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:54:48.286527
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1254TK-1@CE-3928.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:19.689902
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:19.690896
# NON-PDF CREATED ON 2019-08-26 16:08:19.690896
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:32.318958
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/Thumbs.db'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:26.485696
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:26.485696
# NON-PDF CREATED ON 2019-08-26 16:08:26.485696
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:39.113758
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Instruction Sheets'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.539977
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.539977
# NON-PDF CREATED ON 2019-08-26 16:08:32.539977
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.168039
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Instruction Sheets\\QCUS-QICUS'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.560983
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.561963
# NON-PDF CREATED ON 2019-08-26 16:08:32.561963
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.190025
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.783555
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.783555
# NON-PDF CREATED ON 2019-08-26 16:08:32.783555
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.411617
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\utils'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.805548
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.805548
# NON-PDF CREATED ON 2019-08-26 16:08:32.805548
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.433610
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\TEMP'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.811548
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.811548
# NON-PDF CREATED ON 2019-08-26 16:08:32.811548
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.439610
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\SQLQueries'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.829585
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.829585
# NON-PDF CREATED ON 2019-08-26 16:08:32.829585
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.458612
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\RecipeImport'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.876617
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.877552
# NON-PDF CREATED ON 2019-08-26 16:08:32.877552
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.505614
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\progs'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.888553
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.888553
# NON-PDF CREATED ON 2019-08-26 16:08:32.888553
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.516615
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\Menus'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.895554
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.895554
# NON-PDF CREATED ON 2019-08-26 16:08:32.895554
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.523616
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\libs'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.921553
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.921553
# NON-PDF CREATED ON 2019-08-26 16:08:32.921553
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.549615
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\ItemsConvert'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.945557
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.945557
# NON-PDF CREATED ON 2019-08-26 16:08:32.945557
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.573619
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Asap_dev\\Forms'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:32.987557
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:32.987557
# NON-PDF CREATED ON 2019-08-26 16:08:32.987557
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.615619
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Archive ERR'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:33.257564
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:33.257564
# NON-PDF CREATED ON 2019-08-26 16:08:33.257564
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.885626
# e=<DirModifiedEvent: src_path='F:/APPS/CofA/Archive - For all archived CofA, see G CofA folder'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:33.269565
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:33.270567
# NON-PDF CREATED ON 2019-08-26 16:08:33.270567
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:45.898629
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1242TK-1@CE-2173.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:37.804665
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:37.804665
# NON-PDF CREATED ON 2019-08-26 16:08:37.804665
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.432727
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1242TK@CE-4066.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:37.829670
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:37.829670
# NON-PDF CREATED ON 2019-08-26 16:08:37.829670
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.457732
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1254TK-B1@CE-1732.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:37.898680
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:37.898680
# NON-PDF CREATED ON 2019-08-26 16:08:37.898680
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.526742
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1260TK-1@CE-2174.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:37.934683
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:37.934683
# NON-PDF CREATED ON 2019-08-26 16:08:37.934683
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.563736
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1260TK-B1@CE-0102.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:37.981673
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:37.981673
# NON-PDF CREATED ON 2019-08-26 16:08:37.981673
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.609735
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1260TK-B2@CE-3370.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:38.011679
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:38.011679
# NON-PDF CREATED ON 2019-08-26 16:08:38.011679
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.639741
# e=<FileModifiedEvent: src_path='F:/APPS/CofA/1260TK@CF-4068.doc'>
# <Timer(Thread-6, started 47156)>
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 16:08:38.049725
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 16:08:38.049725
# NON-PDF CREATED ON 2019-08-26 16:08:38.049725
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:07:50.677787
