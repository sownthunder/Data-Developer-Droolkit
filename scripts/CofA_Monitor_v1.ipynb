# %% [markdown]
# # `CofA` Daily_Launcher

# %% [markdown]
# ### 1) create `logger`
# ### 2) create global variables
# ### 3) using `watchdog` wait for file to come into:
#     - F:/Apps/CofA/
#
# ## save all created and modified files into the `df_save_list` datafeframe and then when `execute_staging()` is called:
#
# ***_ conpare the two dorectories and only watermark the DIFF***
# ***_ then FINALLY create that garbage temp dir and ZiP it***
# ***_ last but not least email that shit once and for good***

# %%
# IMPORT THE GOODIES
import os, sys, time
from time import sleep
from pathlib import Path
import fnmatch, glob, shutil
import wmi, psutil
import filecmp, tempfile, textwrap
from textwrap import wrap
from zipfile import ZipFile
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import email, smtplib, ssl
import os.path as op
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.utils import COMMASPACE, formatdate
import subprocess, threading, logging
from threading import Timer
from PyPDF2 import PdfFileReader, PdfFileWriter
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# %% [markdown]
# **CLASSES**

# %%
class CofA_Event_Handler(FileSystemEventHandler): #{
    
    def __init__(self, save_list, in_directory, out_directory): #{
        self.save_list = save_list
        self.in_directory = in_directory
        self.out_directory = out_directory
    #}
    
    """
    # DISPATCH ALWAYS CALLED FIRST JUST DESCRIBE EVENT
    def dispatch(self, event): #{
        event_str = str(event.event_type)
        event_path = Path(event.src_path)
        print("**********************")
        print("EVENT >>> " + event_str)
        print("SRC_PATH >>> " + str(event_path))
        print("**********************")
        # SEND OFF TO PERFORM ACTIONS BASED ON EVENT
        #perform_event_actions(the_event_type=event_str, the_event_path=event_path)
    #}
    """
    
    def on_created(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| CREATED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)  # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                """
                # CREATE str TO HOLD FINAL COLUMN FOR TUPLE
                created_str = "Created"
                """
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  #WAS: (created_str)
                # APPEND EVENT ITEM TO "save_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
                """
            #}
            else: #{
                print("NON-PDF CREATED AT " + str(ts))
            #}
            
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            logging.error("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Created-Event] FIN..")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Created-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    
    def on_modified(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| MODIFIED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)   # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  # WAS: (modified_str)
                # APPEND EVENT ITEM TO "Createed_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
            #}
            else: #{
                print("NON-PDF CREATED ON " + str(ts))
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            logging.error("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Modified-Event] VERY NICE GOOD JOB! ")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Modified-Event] >>> time_alloted: " + str(run_time))
        #}
    #}

#}

# %% [markdown]
# **FUNCTIONS**

# %%
"""
TAKES IN:
PDF TO WATERMARK,
"""
def create_watermark(input_pdf, output, watermark): # {
    try:  # {
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)

        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()

        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()):  # {
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        # }

        with open(output, 'wb') as out:  # {
            pdf_writer.write(out)
        # }
    # }
    except: # {
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        logging.error("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
        # }
    else: # {
        print("\t\t[watermark-pdf] FIN...")
    # }
    finally: # {
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[watermark-pdf] >>> time_alloted: " + str(run_time))
    # }
    return
# }

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list 
    file_paths = [] 
    
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths
#}

# %%
"""
TAKES IN:
(1) path to pdf 
RETURNS: 
the STRING of that PDF to match the naming convention
in G:/C of A's/#Email Node/ from F:/APPS/CofA/
"""
def generate_naming_convention(the_pdf_path): #{
    # get/set filename to variable
    the_file_name = str(os.path.basename(the_pdf_path))
    # PERFORM STRING OPERATIONS
    #################################
    idx_mrk = the_file_name.rfind('@', 0, len(the_file_name))
    half1 = str(the_file_name[0:idx_mrk])
    half2 = str(the_file_name[idx_mrk + 1:len(the_file_name)])
    print("\t\t[*************************]")
    print("\t\t|>>> HALF 1 == " + half1)
    print("\t\t|>>> HALF 2 == " + half2)
    #  setup NEW FILE NAME (for copy)
    new_name = "part "
    new_name += str(half1)
    new_name += " CofA Lot# "
    new_name += str(half2)
    print("\t\t|>>> NEW NAME == " + str(new_name))
    print("\t\t[*************************]")
    #################################
    return str(new_name)
#}

# %%
"""
TAKES IN: 
(1) LIST-type obj containing:
    - basename (CofA etc)[*.pdf]
    - timestamp
    - "Created" **OR** "Modified category"
(2) DataFrame obj containing:
    - that the newest row will be appended too
RETURNS: 
DataFrame (not in-place) with newly
appended tuple row etc 
"""
def append_to_dataframe(the_event_list, dataframe_to_append): #{
    # TRY THE FOLLOWING
    try: #{
        # CHECK IF LIST
        if type(the_event_list) is list : #{  # WAS: (the_event_list is list)
            print("\t\tLIST check == PASS")
            # SEPERATE COLUMNS
            col_1 = str(the_event_list[0])
            col_2 = str(the_event_list[1])
            #col_3 = str(the_event_list[2])
            # CREATE APPENDAGE FRAME
            df_appendage = pd.DataFrame(data=[the_event_list], 
                                        columns=['CofA', 'Timestamp'])
            # CREATE INSTANCE OF DATAFRAME WE ARE RETURNING
            return_df = dataframe_to_append.append(df_appendage, ignore_index=True, sort=False)
            print(return_df.tail(5))
        #}
        else: #{
            print("\t\tLIST check == FAIL")
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        logging.error("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("\t\t[Append-2-DataFrame] FIN...")
        return return_df
    #}
    finally: #{
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[Append-2-DataFrame] >>> time_alloted: "+ str(run_time))
    #}
#}

# %% [raw]
# def extract_information(pdf_path): #{
#     with open(pdf_path, 'rb') as f: #{
#         pdf = PdfFileReader(f)
#         information = pdf.getDocumentInfo()
#         number_of_pages = pdf.getNumPages()
#     #}
#     txt = f"""
#     Information about {pdf_path}:
#
#     Author: {information.author}
#     Creator: {information.creator}
#     Producer: {information.producer}
#     Subject: {information.subject}
#     Title: {information.title}
#     Number of Pages: {number_of_pages}
#     """
#
#     print(txt)
#     return information
# #}

# %%
def extract_modified_time(the_path): #{
    print("extracting...")
#}

# %%
#test_list = scan_directory("F:/APPS/CofA/")

# %%
#print(len(test_list))

# %% [raw]
# def display_pdf_text(pdf_path): #{
#     read_pdf = PyPDF2.PdfFileReader(pdf_path)
#
#     for i in range(read_pdf.getNumPages()): #{
#         page = read_pdf.getPage(i)
#         print("Page No - " + str(1+read_pdf.getPageNumber(page)))
#         page_content = page.extractText()
#         print(page_content)
#     #}
#
# #}

# %%
def send_mail(send_from, send_to, subject, message, files=[], 
              server="cos.smtp.agilent.com", port=587, use_tls=True): #{
    print("SENDING MAIL... DATE == " + str(pd.Timestamp.now())[:10])
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = COMMASPACE.join(send_to)
    msg['Date'] = formatdate(localtime=True)
    msg['Subject'] = subject
    
    msg.attach(MIMEText(message))
    
    for path in files: #{
        part = MIMEBase('application', "octet-stream")
        with open(path, 'rb') as file: #{
            part.set_payload(file.read())
        #}
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                       'attachment; filename="{}"'.format(op.basename(path)))
        msg.attach(part)
    #}
    
    smtp = smtplib.SMTP(server, port)
    if use_tls: #{
        smtp.starttls()
    #}
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
#}

# %% [markdown]
# ---
#
# # compare `F:/APPS/CofA/` scan of `TODAY`
# # to scan of `F:/APPS/CofA/` of `YESTERDAY`
#
# >>> `CREATE DIFF DATAFRAME`
# >>> `ITERATE THRU THAT`
#
# `OVERWRITE` PDFs when *watermarking*
#
# AND THEN `CREATE ZIP` AND *EMAIL THAT ZIP* IN THE TEMP FOLDER

# %%
"""
EXPORTS DATAFRAME
TAKES IN:
(1) DATAFRAME OBJECT THAT HAS BEEN CREATED VIA WATCHODG
"""
def execute_staging(): #{
    # RE-INSTANTIATE GLOBALS
    global save_list
    #OLD# global df_save_list
    global observer
    global in_directory
    global out_directory
    global today_date_str
    global isEOD
    #OLD# print("DATAFRAME IS OF TYPE ==\n\t\t" + str(type(df_save_list)))
    #OLD# print("AND IS EMPTY !?!?!? == \n" + str(df_save_list))
    print("\n\n\n >>>>> BUT THAT SEXY save_list == \n" + str(save_list))
    print("of type =====================" + str(type(save_list)))
    #################### CREATE [save_list] DATAFRAME #####################
    try: #{
        # WE HAVE THE SAVE_LIST, NOW WE NEED TO FILL THAT DATA IN
        # TO THE MAIN DATAFRAME THAT IT BELONG TO
        df_saveframe = pd.DataFrame(data=save_list, 
                                    columns=['CofA', 'Timestamp'], 
                                    dtype=np.str)
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-DataFrame] SUCCESS! VERY NICE!")
        print(str(df_saveframe))
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("[Create-DataFrame] RUN TIME == " + str(run_time))
    #}
    #################################################
    try: #{
        print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("TODAYS (FAKE) DATE == " + today_date_str)
        ###########################################
        # CREATE TODAY AND YESTERDAY STR
        today_str = str(pd.Timestamp.now())[:10]
        print("TODAYS (REAL) DATE == " + today_str)
        time_now = pd.Timestamp(year=2019, month=8, day=14)
        # CREATE SUTBRACTION DELTA 
        subtraction_delta = pd.Timedelta(value=1, unit='days')
        print("SUBTRACTION DELTA == " + str(subtraction_delta))
        # CREATE "yesterdays date" BY SUTBRACTING
        yesterstr = str(time_now - subtraction_delta)[:10]
        print("YESTERSTR == " + str(yesterstr))
        print("\nTEST GLOB-STRING == " + str("C:/data/inbound/*_" 
                                             + yesterstr 
                                             + "_*"))
        ###########################################
        # BEGIN GLOBBING
        glob_previous = sorted(glob.glob("C:/data/inbound/*_" 
                                         + yesterstr 
                                         + "_*"))
        print("\n\t GLOB_PREVIOUS >>> \n")
        for name in glob_previous: #{
            print(name)
        #}
        #####################################################################
        # < FOR RIGHT NOW WE IMPORT A .CSV FOR THE TODAY_FILE... 
        # THIS IS CREATED MANUALLY EVERY TIME BY CREATING A LIST OF 
        # "F:/APPS/CofA/" AND PUTTING INTO  A DATAFRAME
        # ==============[DIRECTORY CHANGE FOR FINAL VERISON]===========
        # "C:/data/inbound/*_" >>>> "C:/CofA/log/lists/*_"
        #####################################################################
        # RETURN LIST FROM FUNCTION
        #
        #OLD#glob_current = scan_directory("F:/APPS/CofA/")
        #
        ########################################################
        glob_current = sorted(glob.glob("C:/data/inbound/*_" 
                                        + today_date_str 
                                        + "_*"))
        print("\n\t GLOB_CURRENT >>> \n")
        for name in glob_current: #{
            print(name)
        #}
        print("\n\n\n~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #################
        # SETUP IMPORTS #
        #################
        df1 = pd.read_csv(glob_previous[0])
        df2 = pd.read_csv(glob_current[0])
        """
        # we dont use indeces because of LIST
        df2 = pd.DataFrame() # EMPTY AT FIRST
        # ASSIGN COLUMN OF DATAFRAME FROM LIST
        df2['CofA File'] = glob_current
        """
        print("LEN_D1 == " + str(len(df1)))
        print("LEN_D2 == " + str(len(df2)))
        #OLD#print(df1.info)
        #OLD#print(df2.info)
        # SET DIFFERENCE OF TWO DATAFRAMES IN PANDAS PYTHON
        set_diff_df = pd.concat([df2, df1, df1]).drop_duplicates(keep=False)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("\n\tLENGTH OF DIFFERENCE == " + str(len(set_diff_df)))
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
        x = 0  # counter variable
        # CREATE TEMPORARY DIRECTORY (TO WORK INSIDE OF)
        ###################################################################
        with tempfile.TemporaryDirectory() as directory_name: #{
            the_dir = Path(directory_name)
            print("| TEMPORARY DIRECTORY >>> " + str(the_dir) + "\n")
            # ITERATE THRU TUPLES...
            for row in set_diff_df.itertuples(index=False, name="CofA"): #{
                # GET/CREATE BASE_NAME
                base_name = os.path.basename(str(row[0]))  # WAS: the_event_path
                # GET NEW FILE NAME CONVENTION
                file_name_conv = generate_naming_convention(base_name)
                # CREATE "temp_path"
                temp_path = os.path.join(the_dir, file_name_conv)
                # CREATE "dst_path"
                dst_path = os.path.join(out_directory, file_name_conv)
                # WATERMARK A COPY TO G_DRIVE **WITH CORRECT NE W FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=dst_path, watermark=in_file)
                # WATERMARK A COPY INTO TEMP FOLDER ** WITH CORRECT NEW FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=temp_path, watermark=in_file)
                # INCREASE COUNTER
                x += 1
                print("COUNT == " + str(x))
            #}
            ################################################################
            # ZIP THE CURRENT TEMP DIR (no need to create... just rename)
            try: #{
                print("\n\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
                print("\nWORKING DIRECTORY ---BEFORE--- ZIP == " + str(os.getcwd()))
                # path to folder
                directory = "." # (the_dir)
                # CHANGE WORKING DIRECTORY TO THE TEMPORARY DIR
                # (IN ORDER TO PROPERLY ZIP FILES/FOLDER)
                os.chdir(the_dir)   # WAS: "C:/"
                print("\nWORKING DIRECTORY ---DURING--- ZIP == " + str(os.getcwd()))
                # calling function to get all file paths in the directory
                file_paths = get_all_file_paths(the_dir)
                # printing the list of all files to be zipped 
                print('\nFollowing files will be zipped:') 
                for file_name in file_paths: #{
                    print(file_name) 
                #}
                # writing files to a zipfile 
                with ZipFile('CofA-' + str(pd.Timestamp.now())[:10] + ".zip",'w') as zip: #{
                    # writing each file one by one 
                    for file in file_paths: #{
                        zip.write(file) 
                    #}
                #}
                print('All files zipped successfully!\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' 
                      + 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX\n')
                ###################################################
                # ....NOW ZIP THE NEWLY MADE FOLDER INSIDE TEMP FOLDER...
                #WAS#zip_directory = "./" + str(today_date_str)
                """
                zip_dir = Path("/" + str(today_str))
                print("\n MAKE-SHIFT ZIPPY_DIR == " + str(zip_dir) + "\n")
                # CREATE ZIP_DIRECTORY PATH VARIABLE
                zip_directory = os.path.join(".", zip_dir)
                print("\n ZIP_DIRECTORY == " + str(zip_directory) + "\n")
                # calling function to get all file paths in directory
                file_paths = get_all_file_paths(zip_directory)
                # printing the list of all files to be zipped
                print('Following files will be zipped:') 
                """
            #}
            except: #{
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                      "\n" + fileE +
                      "\n" + lineE +
                      "\n" + messageE)
            #}
            else: #{
                print("ALL FILES SUCCESSFULLY ZIPPED!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Zip-Files] RUN TIME == " + str(run_time))
            #}
            # TRY TO FINISH THIS SHIT OFF
            try: #{
                print("\n\t\t\t GLOBBING FOR ZIP FILE !!!")
                for name in sorted(glob.glob(str(the_dir) + "/*.zip")): #{
                    print("NAME OF FILE == " 
                          + str(name))
                    #logging.info(name)
                    print("LENGTH OF GLOB == " 
                          + str(len(sorted(glob.glob(str(the_dir))))))
                    # GET&SET PATH NAME 
                    zip_path = Path(name)
                    print("ZIP_PATH == " 
                          + str(zip_path))
                #}
                """
                # CREATE ZIP_DRIECTORY OFF SINGLE_GLOB_STR
                zip_path = Path(sorted(glob.glob(str(the_dir) + "/*.zip"))[0])
                """
                # >>>>>>>>>>>>> EXPORT DATAFRAME <<<<<<<<<<<<<<<<<<< #
                ###################################################3
                # CREATE STR FOR PATH FOR SAVE_DIFF_DATAFRAME
                df_save_str = str("CofA-" 
                                  + str(pd.Timestamp.now())[:10] 
                                  + ".csv")
                df_save_path = os.path.join(the_dir, df_save_str)
                print("\n\n\tSAVE-PATH FOR DATAFRAME == " + str(df_save_path))
                # SORT THE DATAFRAME BEFORE EXPORTING
                df_save_frame_sorted = df_saveframe.sort_values(by='Timestamp')
                # DROP DUPLICATES BEFORE EXPORTING
                df_save_frame_sorted.drop_duplicates(subset='CofA', 
                                                     keep='last', 
                                                     inplace=True)
                df_save_frame_sorted.to_csv(str(df_save_path), index=False)
                #################### EXPORT DATAFRAME #####################
                # ZIP FILE HAS BEE CREATED NOW WE CAN EXPORT DATAFRAME
                # AND NOT WORRY ABOUT IT ALSO BEING INCLUDE IN ZIP
                #########################################################
                #OLD# df_saveframe.to_csv(str(df_save_path), index=False)
                ##################################################
                # EXPORT THE SET_DIFF_DF TO FILE  IN TEMP FOLDER IN ORDER TO EMAIL
                #set_diff_df.to_csv(str(df_save_path), index=False)
                # CREATE PATH VAR and "Popen" via SUBPROCESS
                print("Opening Explorer Window...")
                the_dir = Path(directory_name)
                # open temp_folder in a new EXPLORER WINDOW
                subprocess.Popen('explorer ' + str(the_dir))
                ###################################################
                # CREATE FILE_LIST VAR
                file_list = [str(zip_path), str(df_save_path)]
                print(">>> FILE LIST : \n\t" 
                      + str(file_list) 
                      + "\n")
                """
                break_input = input("Continue? Y\n")
                if str(break_input).lower() == "n": #{
                    sys.exit(69)
                #}
                """
                elif str(break_input).lower() == "y": #{
                    print("CONT....")
                    #####################################################
                    # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                    # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                    #####################################################
                    try: #{
                        send_mail(send_from="derek.bates@non.agilent.com",
                                  send_to="derek.bates@non.agilent.com", 
                                  subject=str(pd.Timestamp.now())[:10],
                                  message="See File(s) attached",
                                  files=file_list)
                    #}
                    except: #{
                        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                        exc_type, exc_obj, exc_tb = sys.exc_info()
                        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                        typeE = str("TYPE : " + str(exc_type))
                        fileE = str("FILE : " + str(fname))
                        lineE = str("LINE : " + str(exc_tb.tb_lineno))
                        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                        logging.error("\n" + typeE +
                                      "\n" + fileE +
                                      "\n" + lineE +
                                      "\n" + messageE)
                    #}
                    else: #{
                        print("EMAIL SUCCESSFULLY SENT! VERY NICE!")
                    #}
                #}
            #}
            except: #{                
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                              "\n" + fileE +
                              "\n" + lineE +
                              "\n" + messageE)
            #}
            else: #{
                print("[Create-set_diff_df] SUCCESS! VERY NICE!!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Email-Files] FIN...")
                sys.exit(69)
            #}
        #}
        """
        print('Directory exists after?' + str(directory_name.exists()))
        print('Contents after:' + str(list(directory_name.glob('*'))))
        """
        ###################################################
        # OUTSIDE OF TEMP FOLDER
        # EXPORT THE .csv?
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        logging.error("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        isEOD = True
        # BECAUSE WE SET "isEOD" TO TRUE IT WILL STOP WATCHDOG LISTENER, 
        # POST TIME STAMP, THEN EN
        observer.stop()
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("RUN TIME == " + str(run_time))
        print("LINE 352 EXECUTE STAGING()")
    #}
    
#}

# %% [markdown]
# ---

# %% [markdown]
# **OVERWRITE `.txt` FILE WITH DATAFRME**

# %% [raw]
# new_df.to_csv("CofA-backlog-test.txt", columns=None,
#               header=False, index=False, mode='w', escapechar='\r')

# %% [markdown]
# ---

# %% [raw]
# # INSTANTIATE GLOBAL VARIABLES
# in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
# in_file2 = "C:/data/inbound/02OTHER_Rohde Island_Agilent Quality_Digital Letterhead.pdf"
# #in_directory = "F:/APPS/CofA/"
# #out_directory = "G:/C of A's/#Email Node/"
# in_directory = "C:/Temp/F/APPS/CofA/"
# out_directory = "C:/Temp/G/C of A's/#Email Node/"
# save_list = []
# isEOD = False
# time_start = pd.Timestamp.now()
# df_save_list = pd.DataFrame(data=None, dtype=np.str)
# # FAKE VAR TO STAND FOR "todays date"
# today_date_str = "2019-08-14"

# %%
if __name__ == "__main__":
    # SETUP LOGGER
    try: #{
        logging.basicConfig(level=logging.INFO,
                            #stream=sys.stdout,
                            filename="C:/data/outbound/CofA_Daily_Launcher.log",
                            format='%(asctime)s:'
                            + '\n\t\t\t\t'
                            + '<MESG:%(message)s>'
                            + '\n\t\t\t\t'
                            + '<%(threadName)s-ID:%(thread)d>'
                            + '\n\t\t\t\t'
                            + '<%(processName)s-ID:%(process)d>'
                            + '\n\t\t\t\t'
                            + '<FUNC=%(funcName)s>'
                            + '\n\t\t\t\t'
                            + '<LINE:%(lineno)s>'
                            + '\n\t\t\t\t'
                            + '<PATH:%(pathname)s>'
                            + '\n\t\t\t\t'
                            + '<NAME:%(name)s>',
                            # format='%(asctime)s:%(message)s PROCESS=%(processName)s',
                            datefmt='%Y_%d_%m_%H%M%S',
                            filemode='a')
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-Logger] FIN...")
    #}
    ######################################
    # >>>>>>>> GLOBAL VARIABLES <<<<<<<< #
    ######################################
    in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
    save_list = []
    #df_save_list = pd.DataFrame(data=None, columns=['CofA', 'Timestamp'])
    # 'Created/Modified'
    isEOD = False
    in_directory = "C:/Temp/F/APPS/CofA/"  #"F:/APPS/CofA/"
    out_directory =  "C:/Temp/G/C of A's/#Email Node/"  #"G:/C of A's/#Email Node/"
    outbound_directory = "C:/Temp/G/C of A's/Agilent/"  #"G:/C of A's/Agilent/"
    to_email = "agilent_cofa@agilent.com"
    from_email = "derek.bates@non.agilemt.com"
    time_start = pd.Timestamp.now()
    # FAKE VAR TO STAND FOR "todays date"
    today_date_str = "2019-08-14"
    ##########################################
    print("[=================================================]")
    print("| SCANNING DIRECTORY >>> " + str(in_directory))
    print("| STORING IN DATAFRAME >>> " + str(save_list))  # WAS: str(df_save_list.head()))
    print("[=================================================]")
    print("| Initializing Time >>> " + str(pd.Timestamp.now()))
    print("[=================================================]\n\n\n")
    # CREATE TIMER VAR  // 12 HOURS... now 10.5 HOURS !! 08/07/2019
    # 37800
    t = Timer(54000, execute_staging) # WAS 2592000,3600,720,600,43200,300 & 120
    # START TIMER
    t.start()
    # CREATE INSTANCE OF CUSTOM EVENT HANDLER
    print("\n\n<><><><><><><><><><>BEFORE HANDLER START<><><><><><><><><><><>\n")
    print("<><><><><> save_list == \n")
    # PRINT OUT EVERY ITEM & COUNT #
    len_count = len(save_list)
    for save in save_list: #{
        print("SAVE NAME === " + str(save))
        print("COUNT === " + str(len_count))
        # subtract one
        len_count -= 1
    #}
    #print("<><><><><> df_save_list == " + str(df_save_list))
    print("\n<><><><><><><><><><><><><><><><><><><><><><><><><><><>\n\n")
    event_handler = CofA_Event_Handler(save_list, in_directory, out_directory)
    observer = Observer()
    observer.schedule(event_handler=event_handler,
                      path=in_directory,
                      recursive=True)
    observer.start()
    # TRY THE FOLLOWING
    try: #{
        #sleep_counter = 0
        while isEOD is False: #{
            # increase SLEEP COUNTEr & sleep...
            #leep_counter += 1
            print("isEOD == " + str(isEOD))
            sleep(1)
        #}
        else: #{
            print("[EOD] REACHED !!! <CLOSING SCRIPT>>")
            ts = pd.Timestamp.now()
            run_time = ts - time_start
            print("RUN TIME == " + str(run_time))
            sys.exit(0)
        #}
    #}
    except KeyboardInterrupt: #{
        observer.stop()
    #}
    observer.join()
# Out:
# [Create-Logger] FIN...
# [=================================================]
# | SCANNING DIRECTORY >>> C:/Temp/F/APPS/CofA/
# | STORING IN DATAFRAME >>> []
# [=================================================]
# | Initializing Time >>> 2019-08-23 16:35:16.196166
# [=================================================]
#
#
#
#
#
# <><><><><><><><><><>BEFORE HANDLER START<><><><><><><><><><><>
#
# <><><><><> save_list ==
#
#
# <><><><><><><><><><><><><><><><><><><><><><><><><><><>
#
#
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:23.738346
# NON-PDF CREATED AT 2019-08-23 16:35:23.738346
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:07.543185
# isEOD == False
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:24.463781
# 		[*************************]
# 		|>>> HALF 1 == ICP-131
# 		|>>> HALF 2 == 0006480484.pdf
# 		|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:08.267615
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:24.464776
# 		[*************************]
# 		|>>> HALF 1 == ICP-131
# 		|>>> HALF 2 == 0006480484.pdf
# 		|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:08.271624
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:24.467790
# 		[*************************]
# 		|>>> HALF 1 == ICP-131
# 		|>>> HALF 2 == 0006480484.pdf
# 		|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:08.271624
# isEOD == False
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:25.589243
# 		[*************************]
# 		|>>> HALF 1 == ICP-079
# 		|>>> HALF 2 == 0006479330.pdf
# 		|>>> NEW NAME == part ICP-079 CofA Lot# 0006479330.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:09.394081
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:25.590247
# 		[*************************]
# 		|>>> HALF 1 == ICP-079
# 		|>>> HALF 2 == 0006479330.pdf
# 		|>>> NEW NAME == part ICP-079 CofA Lot# 0006479330.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:09.394081
# isEOD == False
# isEOD == False
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:27.281407
# 		[*************************]
# 		|>>> HALF 1 == CH-230-1
# 		|>>> HALF 2 == 0006478438.pdf
# 		|>>> NEW NAME == part CH-230-1 CofA Lot# 0006478438.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:11.086241
# isEOD == False
# isEOD == False
# isEOD == False~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# | CREATED >>> 2019-08-23 16:35:30.208248
# 		[*************************]
# 		|>>> HALF 1 == CH-151-1
# 		|>>> HALF 2 == 0006480845.pdf
# 		|>>> NEW NAME == part CH-151-1 CofA Lot# 0006480845.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:14.014081
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:30.210247
# 		[*************************]
# 		|>>> HALF 1 == CH-151-1
# 		|>>> HALF 2 == 0006480845.pdf
# 		|>>> NEW NAME == part CH-151-1 CofA Lot# 0006480845.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:14.015079
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:30.796275
# NON-PDF CREATED AT 2019-08-23 16:35:30.796275
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:14.601111
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:34.892077
# 		[*************************]
# 		|>>> HALF 1 == ICP-131
# 		|>>> HALF 2 == 0006480484.pdf
# 		|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:18.695911
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:34.892077
# 		[*************************]
# 		|>>> HALF 1 == ICP-131
# 		|>>> HALF 2 == 0006480484.pdf
# 		|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:18.698912
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:34.908076
# 		[*************************]
# 		|>>> HALF 1 == ICP-131
# 		|>>> HALF 2 == 0006480484.pdf
# 		|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.908076']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:18.712909
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:38.265825
# 		[*************************]
# 		|>>> HALF 1 == AM-170-1
# 		|>>> HALF 2 == 0006474446.pdf
# 		|>>> NEW NAME == part AM-170-1 CofA Lot# 0006474446.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.908076'], ['part AM-170-1 CofA Lot# 0006474446.pdf', '2019-08-23 16:35:38.265825']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:22.071658
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-23 16:35:38.268826
# 		[*************************]
# 		|>>> HALF 1 == AM-230-1
# 		|>>> HALF 2 == 0006471880.pdf
# 		|>>> NEW NAME == part AM-230-1 CofA Lot# 0006471880.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.908076'], ['part AM-170-1 CofA Lot# 0006474446.pdf', '2019-08-23 16:35:38.265825'], ['part AM-230-1 CofA Lot# 0006471880.pdf', '2019-08-23 16:35:38.268826']]
# 		[Created-Event] FIN..
# 		[Created-Event] >>> time_alloted: 0 days 00:00:22.072660
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-23 16:35:38.269820
# 		[*************************]
# 		|>>> HALF 1 == AM-230-1
# 		|>>> HALF 2 == 0006471880.pdf
# 		|>>> NEW NAME == part AM-230-1 CofA Lot# 0006471880.pdf
# 		[*************************]
# SAVE LIST ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.908076'], ['part AM-170-1 CofA Lot# 0006474446.pdf', '2019-08-23 16:35:38.265825'], ['part AM-230-1 CofA Lot# 0006471880.pdf', '2019-08-23 16:35:38.268826'], ['part AM-230-1 CofA Lot# 0006471880.pdf', '2019-08-23 16:35:38.269820']]
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:00:22.074655
# isEOD == False
# isEOD == False
#
#
#
#  >>>>> BUT THAT SEXY save_list ==
# [['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.463781'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.464776'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:24.467790'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.589243'], ['part ICP-079 CofA Lot# 0006479330.pdf', '2019-08-23 16:35:25.590247'], ['part CH-230-1 CofA Lot# 0006478438.pdf', '2019-08-23 16:35:27.281407'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.208248'], ['part CH-151-1 CofA Lot# 0006480845.pdf', '2019-08-23 16:35:30.210247'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.892077'], ['part ICP-131 CofA Lot# 0006480484.pdf', '2019-08-23 16:35:34.908076'], ['part AM-170-1 CofA Lot# 0006474446.pdf', '2019-08-23 16:35:38.265825'], ['part AM-230-1 CofA Lot# 0006471880.pdf', '2019-08-23 16:35:38.268826'], ['part AM-230-1 CofA Lot# 0006471880.pdf', '2019-08-23 16:35:38.269820']]
# of type =====================<class 'list'>
# [Create-DataFrame] SUCCESS! VERY NICE!
#                                       CofA                   Timestamp
# 0    part ICP-131 CofA Lot# 0006480484.pdf  2019-08-23 16:35:24.463781
# 1    part ICP-131 CofA Lot# 0006480484.pdf  2019-08-23 16:35:24.464776
# 2    part ICP-131 CofA Lot# 0006480484.pdf  2019-08-23 16:35:24.467790
# 3    part ICP-079 CofA Lot# 0006479330.pdf  2019-08-23 16:35:25.589243
# 4    part ICP-079 CofA Lot# 0006479330.pdf  2019-08-23 16:35:25.590247
# 5   part CH-230-1 CofA Lot# 0006478438.pdf  2019-08-23 16:35:27.281407
# 6   part CH-151-1 CofA Lot# 0006480845.pdf  2019-08-23 16:35:30.208248
# 7   part CH-151-1 CofA Lot# 0006480845.pdf  2019-08-23 16:35:30.210247
# 8    part ICP-131 CofA Lot# 0006480484.pdf  2019-08-23 16:35:34.892077
# 9    part ICP-131 CofA Lot# 0006480484.pdf  2019-08-23 16:35:34.892077
# 10   part ICP-131 CofA Lot# 0006480484.pdf  2019-08-23 16:35:34.908076
# 11  part AM-170-1 CofA Lot# 0006474446.pdf  2019-08-23 16:35:38.265825
# 12  part AM-230-1 CofA Lot# 0006471880.pdf  2019-08-23 16:35:38.268826
# 13  part AM-230-1 CofA Lot# 0006471880.pdf  2019-08-23 16:35:38.269820
# [Create-DataFrame] RUN TIME == 0 days 00:00:25.010156
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# TODAYS (FAKE) DATE == 2019-08-14
# TODAYS (REAL) DATE == 2019-08-23
# SUBTRACTION DELTA == 1 days 00:00:00
# YESTERSTR == 2019-08-13
#
# TEST GLOB-STRING == C:/data/inbound/*_2019-08-13_*
#
# 	 GLOB_PREVIOUS >>>
#
# C:/data/inbound\CofA_Email_Node_List_2019-08-13_pull.csv
# C:/data/inbound\CofA_Email_Node_List_2019-08-13_pull.old
#
# 	 GLOB_CURRENT >>>
#
# C:/data/inbound\CofA_Email_Node_List_2019-08-14_pull.csv
#
#
#
# ~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~~~~
# isEOD == False
# LEN_D1 == 61641
# LEN_D2 == 61671
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 	LENGTH OF DIFFERENCE == 30
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# | TEMPORARY DIRECTORY >>> C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm
#
# 		[*************************]
# 		|>>> HALF 1 == 400505-53
# 		|>>> HALF 2 == 0006482671.pdf
# 		|>>> NEW NAME == part 400505-53 CofA Lot# 0006482671.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:25.329168
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:25.446210
# COUNT == 1
# 		[*************************]
# 		|>>> HALF 1 == 52000
# 		|>>> HALF 2 == 0006481325.pdf
# 		|>>> NEW NAME == part 52000 CofA Lot# 0006481325.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:25.659184
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:25.836197
# COUNT == 2
# 		[*************************]
# 		|>>> HALF 1 == 55400
# 		|>>> HALF 2 == 0006482756.pdf
# 		|>>> NEW NAME == part 55400 CofA Lot# 0006482756.pdf
# 		[*************************]
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:26.032199
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:26.211247
# COUNT == 3
# 		[*************************]
# 		|>>> HALF 1 == AM-170-1
# 		|>>> HALF 2 == 0006480054.pdf
# 		|>>> NEW NAME == part AM-170-1 CofA Lot# 0006480054.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:26.416219
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:26.530748
# COUNT == 4
# 		[*************************]
# 		|>>> HALF 1 == AM-171-1
# 		|>>> HALF 2 == 0006480053.pdf
# 		|>>> NEW NAME == part AM-171-1 CofA Lot# 0006480053.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:26.678752
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:26.843763
# COUNT == 5
# 		[*************************]
# 		|>>> HALF 1 == AM-173-1
# 		|>>> HALF 2 == 0006480052.pdf
# 		|>>> NEW NAME == part AM-173-1 CofA Lot# 0006480052.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.014768
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.143772
# COUNT == 6
# 		[*************************]
# 		|>>> HALF 1 == AMN-603-1
# 		|>>> HALF 2 == 0006480057.pdf
# 		|>>> NEW NAME == part AMN-603-1 CofA Lot# 0006480057.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.298780
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.434790
# COUNT == 7
# 		[*************************]
# 		|>>> HALF 1 == AMN-613-1
# 		|>>> HALF 2 == 0006480056.pdf
# 		|>>> NEW NAME == part AMN-613-1 CofA Lot# 0006480056.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.588794
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.758802
# COUNT == 8
# 		[*************************]
# 		|>>> HALF 1 == AMN-623-1
# 		|>>> HALF 2 == 0006480058.pdf
# 		|>>> NEW NAME == part AMN-623-1 CofA Lot# 0006480058.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:27.940810
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:28.087834
# COUNT == 9
# 		[*************************]
# 		|>>> HALF 1 == AMN-623-1
# 		|>>> HALF 2 == 0006480059.pdf
# 		|>>> NEW NAME == part AMN-623-1 CofA Lot# 0006480059.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:28.236833
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:28.362827
# COUNT == 10
# 		[*************************]
# 		|>>> HALF 1 == AMN-803-1
# 		|>>> HALF 2 == 0006480055.pdf
# 		|>>> NEW NAME == part AMN-803-1 CofA Lot# 0006480055.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:28.494833
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:28.612875
# COUNT == 11
# 		[*************************]
# 		|>>> HALF 1 == ASTM-130-1
# 		|>>> HALF 2 == 0006478494.pdf
# 		|>>> NEW NAME == part ASTM-130-1 CofA Lot# 0006478494.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:28.889045
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.162062
# COUNT == 12
# 		[*************************]
# 		|>>> HALF 1 == BLK-WRK-170D
# 		|>>> HALF 2 == 0006481034.pdf
# 		|>>> NEW NAME == part BLK-WRK-170D CofA Lot# 0006481034.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.310067
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.436087
# COUNT == 13
# 		[*************************]
# 		|>>> HALF 1 == CH-151-1
# 		|>>> HALF 2 == 0006480845.pdf
# 		|>>> NEW NAME == part CH-151-1 CofA Lot# 0006480845.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.589091
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.711083
# COUNT == 14
# 		[*************************]
# 		|>>> HALF 1 == CH-230-1
# 		|>>> HALF 2 == 0006478438.pdf
# 		|>>> NEW NAME == part CH-230-1 CofA Lot# 0006478438.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.861090
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:29.996100
# COUNT == 15
# 		[*************************]
# 		|>>> HALF 1 == CHM-205-1
# 		|>>> HALF 2 == 0006481419.pdf
# 		|>>> NEW NAME == part CHM-205-1 CofA Lot# 0006481419.pdf
# 		[*************************]
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:30.139206
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:30.334263
# COUNT == 16
# 		[*************************]
# 		|>>> HALF 1 == CICM-240
# 		|>>> HALF 2 == 0006477735.pdf
# 		|>>> NEW NAME == part CICM-240 CofA Lot# 0006477735.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:30.913285
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:31.468313
# COUNT == 17
# 		[*************************]
# 		|>>> HALF 1 == CICM-699
# 		|>>> HALF 2 == 0006479581.pdf
# 		|>>> NEW NAME == part CICM-699 CofA Lot# 0006479581.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:32.055390
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:32.627413
# COUNT == 18
# 		[*************************]
# 		|>>> HALF 1 == CLP-252-1
# 		|>>> HALF 2 == 0006482220.pdf
# 		|>>> NEW NAME == part CLP-252-1 CofA Lot# 0006482220.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:32.798449
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:32.968464
# COUNT == 19
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000060
# 		|>>> HALF 2 == 0006478975.pdf
# 		|>>> NEW NAME == part CUS-00000060 CofA Lot# 0006478975.pdf
# 		[*************************]
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:33.271003
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:33.565065
# COUNT == 20
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000062
# 		|>>> HALF 2 == 0006478978.pdf
# 		|>>> NEW NAME == part CUS-00000062 CofA Lot# 0006478978.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:33.707017
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:33.826023
# COUNT == 21
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000165
# 		|>>> HALF 2 == 0006481345.pdf
# 		|>>> NEW NAME == part CUS-00000165 CofA Lot# 0006481345.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:33.984034
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:34.123072
# COUNT == 22
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000173
# 		|>>> HALF 2 == 0006479735.pdf
# 		|>>> NEW NAME == part CUS-00000173 CofA Lot# 0006479735.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:34.278046
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:34.475737
# COUNT == 23
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000324
# 		|>>> HALF 2 == 0006482596.pdf
# 		|>>> NEW NAME == part CUS-00000324 CofA Lot# 0006482596.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:34.619778
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:34.753306
# COUNT == 24
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000325
# 		|>>> HALF 2 == 0006482597.pdf
# 		|>>> NEW NAME == part CUS-00000325 CofA Lot# 0006482597.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:34.938336
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:35.073404
# COUNT == 25
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000326
# 		|>>> HALF 2 == 0006482598.pdf
# 		|>>> NEW NAME == part CUS-00000326 CofA Lot# 0006482598.pdf
# 		[*************************]
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:35.214735
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:35.367705
# COUNT == 26
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000327
# 		|>>> HALF 2 == 0006482599.pdf
# 		|>>> NEW NAME == part CUS-00000327 CofA Lot# 0006482599.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:35.589764
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:35.750773
# COUNT == 27
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000328
# 		|>>> HALF 2 == 0006483070.pdf
# 		|>>> NEW NAME == part CUS-00000328 CofA Lot# 0006483070.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:35.920303
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:36.053312
# COUNT == 28
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000329
# 		|>>> HALF 2 == 0006482600.pdf
# 		|>>> NEW NAME == part CUS-00000329 CofA Lot# 0006482600.pdf
# 		[*************************]
# isEOD == False
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:36.211488
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:36.346459
# COUNT == 29
# 		[*************************]
# 		|>>> HALF 1 == CUS-00000336
# 		|>>> HALF 2 == 0006468674.pdf
# 		|>>> NEW NAME == part CUS-00000336 CofA Lot# 0006468674.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:36.642486
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:36.894498
# COUNT == 30
#
#
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# WORKING DIRECTORY ---BEFORE--- ZIP == C:\Users\derbates\OneDrive - Agilent Technologies\Documents\_staging\Data-Developer-Droolkit\scripts
#
# WORKING DIRECTORY ---DURING--- ZIP == C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm
#
# Following files will be zipped:
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part 400505-53 CofA Lot# 0006482671.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part 52000 CofA Lot# 0006481325.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part 55400 CofA Lot# 0006482756.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AM-170-1 CofA Lot# 0006480054.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AM-171-1 CofA Lot# 0006480053.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AM-173-1 CofA Lot# 0006480052.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AMN-603-1 CofA Lot# 0006480057.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AMN-613-1 CofA Lot# 0006480056.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AMN-623-1 CofA Lot# 0006480058.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AMN-623-1 CofA Lot# 0006480059.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part AMN-803-1 CofA Lot# 0006480055.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part ASTM-130-1 CofA Lot# 0006478494.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part BLK-WRK-170D CofA Lot# 0006481034.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CH-151-1 CofA Lot# 0006480845.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CH-230-1 CofA Lot# 0006478438.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CHM-205-1 CofA Lot# 0006481419.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CICM-240 CofA Lot# 0006477735.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CICM-699 CofA Lot# 0006479581.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CLP-252-1 CofA Lot# 0006482220.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000060 CofA Lot# 0006478975.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000062 CofA Lot# 0006478978.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000165 CofA Lot# 0006481345.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000173 CofA Lot# 0006479735.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000324 CofA Lot# 0006482596.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000325 CofA Lot# 0006482597.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000326 CofA Lot# 0006482598.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000327 CofA Lot# 0006482599.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000328 CofA Lot# 0006483070.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000329 CofA Lot# 0006482600.pdf
# C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\part CUS-00000336 CofA Lot# 0006468674.pdf
# All files zipped successfully!
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# ALL FILES SUCCESSFULLY ZIPPED!
# [Zip-Files] RUN TIME == 0 days 00:00:36.949487
#
# 			 GLOBBING FOR ZIP FILE !!!
# NAME OF FILE == C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\CofA-2019-08-23.zip
# LENGTH OF GLOB == 1
# ZIP_PATH == C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\CofA-2019-08-23.zip
#
#
# 	SAVE-PATH FOR DATAFRAME == C:\Users\derbates\AppData\Local\Temp\tmp6z1fnwfm\CofA-2019-08-23.csv
# Opening Explorer Window...
# >>> FILE LIST :
# 	['C:\\Users\\derbates\\AppData\\Local\\Temp\\tmp6z1fnwfm\\CofA-2019-08-23.zip', 'C:\\Users\\derbates\\AppData\\Local\\Temp\\tmp6z1fnwfm\\CofA-2019-08-23.csv']
#
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# Continue? Y
# y
# CONT....
# SENDING MAIL... DATE == 2019-08-23
# isEOD == False
# isEOD == False
# isEOD == False
# EMAIL SUCCESSFULLY SENT! VERY NICE!
# [Create-set_diff_df] SUCCESS! VERY NICE!!
# [Email-Files] FIN...
# isEOD == False
# RUN TIME == 0 days 00:00:46.131669
# LINE 352 EXECUTE STAGING()
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
# isEOD == False
