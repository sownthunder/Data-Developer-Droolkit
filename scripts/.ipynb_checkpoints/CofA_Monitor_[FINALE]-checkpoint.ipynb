# %% [markdown]
# # `CofA` Daily_Launcher

# %% [markdown]
# ### 1) create `logger`
# ### 2) create global variables
# ### 3) using `watchdog` wait for file to come into:
#     - F:/Apps/CofA/
#
# ## save all created and modified files into the `df_save_list` datafeframe and then when `execute_staging()` is called:
#
# ***_ conpare the two dorectories and only watermark the DIFF***
# ***_ then FINALLY create that garbage temp dir and ZiP it***
# ***_ last but not least email that shit once and for good***

# %%
# IMPORT THE GOODIES
import os, sys, time
from time import sleep
from pathlib import Path
import fnmatch, glob, shutil
import wmi, psutil
import filecmp, tempfile, textwrap
from textwrap import wrap
from zipfile import ZipFile
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import email, smtplib, ssl
import os.path as op
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.utils import COMMASPACE, formatdate
import subprocess, threading, logging
from threading import Timer
from PyPDF2 import PdfFileReader, PdfFileWriter
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler
# INSTANTIATE GLOBAL VARIABLES
in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
#in_directory = "F:/APPS/CofA/"
#out_directory = "G:/C of A's/#Email Node/"
in_directory = "C:/Temp/F/APPS/CofA/"
staging_directory = ""
out_directory = "C:/Temp/G/C of A's/#Email Node/"
save_list = []
isEOD = False
time_start = pd.Timestamp.now()
df_save_list= pd.DataFrame()
# FAKE VAR TO STAND FOR "todays date"
today_date_str = "2019-08-14"

# %% [markdown]
# **CLASSES**

# %%
class CofA_Event_Handler(FileSystemEventHandler): #{
    
    def __init__(self, save_dataframe, in_directory, out_directory): #{
        #self.save_list = save_list
        self.save_dataframe = save_dataframe
        self.in_directory = in_directory
        self.out_directory = out_directory
    #}
    
    """
    # DISPATCH ALWAYS CALLED FIRST JUST DESCRIBE EVENT
    def dispatch(self, event): #{
        event_str = str(event.event_type)
        event_path = Path(event.src_path)
        print("**********************")
        print("EVENT >>> " + event_str)
        print("SRC_PATH >>> " + str(event_path))
        print("**********************")
        # SEND OFF TO PERFORM ACTIONS BASED ON EVENT
        #perform_event_actions(the_event_type=event_str, the_event_path=event_path)
    #}
    """
    
    def on_created(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| CREATED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)  # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                # CREATE str TO HOLD FINAL COLUMN FOR TUPLE
                created_str = "Created"
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT LIST
                event_list = [str(file_name_conv), str(ts), str(created_str)]
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED AT " + str(ts))
            #}
            
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t [Created-Event] FIN..")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t [Created-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    
    def on_modified(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            # CREATE INDEX FROM CURRENT DATAFRAME
            idx = pd.Index(data=df_save_list['Basename'], dtype=np.str)
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            """
            # CREATE FILE NAME CONV GENERATOR
            file_name_conv = generate_naming_convention(str(event.src_path))
            """
            # IF **MODIFIED** SRC_PATH IS ALREADY IN THE DATAFRAME...
            print("\n\t CHECKING IF FILE ADDED IS ALREADY IN DATAFRAME..." + str(file_name))
            if idx.contains(file_name): #{
                print(str(event.src_path) + " IS IN SAVE_DATAFRAME")
                # DONT ADD ANYTHING TO DATAFRAME
            #}
            # APPEND TO "df_save_list" WITH A MODIFIED TYPE
            else: #{
                print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
                ts = pd.Timestamp.now()  # CREATE TIME STAMP
                print("| MODIFIED >>> " + str(ts))
                # CREATE EVENT PATH VAR
                the_event_path = Path(event.src_path)  # WAS: the_event_path
                # CREATE 'file_name' VAR
                file_name = os.path.basename(the_event_path)
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CHECK AND SEE IF FILE IS OF TYPE .PDF
                if fnmatch.fnmatch(file_name, "*.pdf"): #{
                    # CREATE str TO HOLD FINAL COLUMN FOR TUPLE
                    modified_str = "Modified"
                    # CREATE EVENT LIST
                    event_list = [str(file_name_conv), str(ts), str(modified_str)]
                    df_save_list = append_to_dataframe(the_event_list=event_list,
                                                       dataframe_to_append=df_save_list)
                #}
                else: #{
                    print("NON-PDF CREATED AT " + str(ts))
                #}
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t [Modified-Event] VERY NICE GOOD JOB! ")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t [Modified-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    
    """
    def on_deleted(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            ts = pd.Timestamp.now()
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)
            # BASE_NAME
            base_name = os.path.basename(the_event_path)
            # CREATE VAR FOR FILE NAME CHANGE
            file_name_conv = generate_naming_convention(base_name)
            # CREATE dst_dir VARIABLE (G/.../part xxx-225 CofA lot# 9999.../)
            dst_path = os.path.join(out_directory, # WAS: G:/Temp/
                                    file_name_conv)
            print("Dst_PATH = " + str(dst_path))
            # IF FILE EXITS
            if os.path.exists(dst_path): #{
                # DELETE DESTINATON PATH BECAUSE IT NOT LONGER EXISTS IN F:/APPS/COFA/
                os.remove(dst_path)
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t [Deleted-Event] FIN...")
        #}
        finally: #{
            # CREATE END-TIME VAR 
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t [Deleted-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    """
    
#}

# %% [markdown]
# **FUNCTIONS**

# %%
"""
TAKES IN:
PDF TO WATERMARK,
"""
def create_watermark(input_pdf, output, watermark): # {
    try:  # {
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)

        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()

        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()):  # {
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        # }

        with open(output, 'wb') as out:  # {
            pdf_writer.write(out)
        # }
    # }
    except: # {
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
        # }
    else: # {
        print("\t [watermark-pdf] FIN...")
    # }
    finally: # {
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t [watermark-pdf] >>> time_alloted: " + str(run_time))
    # }
    return
# }

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list 
    file_paths = [] 
    
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths
#}

# %%
"""
TAKES IN:
(1) path to pdf 
RETURNS: 
the STRING of that PDF to match the naming convention
in G:/C of A's/#Email Node/ from F:/APPS/CofA/
"""
def generate_naming_convention(the_pdf_path): #{
    # get/set filename to variable
    the_file_name = str(os.path.basename(the_pdf_path))
    # PERFORM STRING OPERATIONS
    #################################
    idx_mrk = the_file_name.rfind('@', 0, len(the_file_name))
    half1 = str(the_file_name[0:idx_mrk])
    half2 = str(the_file_name[idx_mrk + 1:len(the_file_name)])
    print("\t[*************************]")
    print("\t|>>> HALF 1 == " + half1)
    print("\t|>>> HALF 2 == " + half2)
    #  setup NEW FILE NAME (for copy)
    new_name = "part "
    new_name += str(half1)
    new_name += " CofA Lot# "
    new_name += str(half2)
    print("\t|>>> NEW NAME == " + str(new_name))
    print("[*************************]")
    #################################
    return str(new_name)
#}

# %%
"""
TAKES IN: 
(1) LIST-type obj containing:
    - basename (CofA etc)[*.pdf]
    - timestamp
    - "Created" **OR** "Modified category"
(2) DataFrame obj containing:
    - that the newest row will be appended too
RETURNS: 
DataFrame (not in-place) with newly
appended tuple row etc 
"""
def append_to_dataframe(the_event_list, dataframe_to_append): #{
    # TRY THE FOLLOWING
    try: #{
        # CHECK IF LIST
        if type(the_event_list) is list : #{  # WAS: (the_event_list is list)
            print("LIST check == PASS")
            # SEPERATE COLUMNS
            col_1 = str(the_event_list[0])
            col_2 = str(the_event_list[1])
            col_3 = str(the_event_list[2])
            # CREATE APPENDAGE FRAME
            df_appendage = pd.DataFrame(data=[the_event_list], 
                                        columns=['CofA', 'Timestamp', 'Created/Modified'])
            # CREATE INSTANCE OF DATAFRAME WE ARE RETURNING
            return_df = dataframe_to_append.append(df_appendage, ignore_index=True, sort=False)
            print(return_df.tail(5))
        #}
        else: #{
            print("LIST check == FAIL")
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("\t [Append-2-DataFrame] FIN...")
        return return_df
    #}
    finally: #{
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t [Append-2-DataFrame] >>> time_alloted: "+ str(run_time))
    #}
#}

# %% [raw]
# def extract_information(pdf_path): #{
#     with open(pdf_path, 'rb') as f: #{
#         pdf = PdfFileReader(f)
#         information = pdf.getDocumentInfo()
#         number_of_pages = pdf.getNumPages()
#     #}
#     txt = f"""
#     Information about {pdf_path}:
#
#     Author: {information.author}
#     Creator: {information.creator}
#     Producer: {information.producer}
#     Subject: {information.subject}
#     Title: {information.title}
#     Number of Pages: {number_of_pages}
#     """
#
#     print(txt)
#     return information
# #}

# %%
#test_list = scan_directory("F:/APPS/CofA/")

# %%
#print(len(test_list))

# %% [raw]
# def display_pdf_text(pdf_path): #{
#     read_pdf = PyPDF2.PdfFileReader(pdf_path)
#
#     for i in range(read_pdf.getNumPages()): #{
#         page = read_pdf.getPage(i)
#         print("Page No - " + str(1+read_pdf.getPageNumber(page)))
#         page_content = page.extractText()
#         print(page_content)
#     #}
#
# #}

# %%
def send_mail(send_from, send_to, subject, message, files=[], 
              server="cos.smtp.agilent.com", port=587, use_tls=True): #{
    print("SENDING MAIL... DATE == " + str(pd.Timestamp.now())[:10])
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = COMMASPACE.join(send_to)
    msg['Date'] = formatdate(localtime=True)
    msg['Subject'] = subject
    
    msg.attach(MIMEText(message))
    
    for path in files: #{
        part = MIMEBase('application', "octet-stream")
        with open(path, 'rb') as file: #{
            part.set_payload(file.read())
        #}
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                       'attachment; filename="{}"'.format(op.basename(path)))
        msg.attach(part)
    #}
    
    smtp = smtplib.SMTP(server, port)
    if use_tls: #{
        smtp.starttls()
    #}
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
#}

# %% [markdown]
# ---
#
# # compare `F:/APPS/CofA/` scan of `TODAY`
# # to scan of `F:/APPS/CofA/` of `YESTERDAY`
#
# >>> `CREATE DIFF DATAFRAME`
# >>> `ITERATE THRU THAT`
#
# `OVERWRITE` PDFs when *watermarking*
#
# AND THEN `CREATE ZIP` AND *EMAIL THAT ZIP* IN THE TEMP FOLDER

# %%
"""
EXPORTS DATAFRAME
"""
def execute_staging(): #{
    # RE-INSTANTIATE GLOBALS
    global df_save_list
    global in_directory
    global out_directory
    global today_date_str
    global isEOD
    #################################################
    print(df_save_list.head(15))
    try: #{
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("TODAYS (FAKE) DATE == " + today_date_str)
        ###########################################
        # CREATE TODAY AND YESTERDAY STR
        today_str = str(pd.Timestamp.now())[:10]
        print("TODAYS (REAL) DATE == " + today_str)
        time_now = pd.Timestamp(year=2019, month=8, day=14)
        # CREATE SUTBRACTION DELTA 
        subtraction_delta = pd.Timedelta(value=1, unit='days')
        print("SUBTRACTION DELTA == " + str(subtraction_delta))
        # CREATE "yesterdays date" BY SUTBRACTING
        yesterstr = str(time_now - subtraction_delta)[:10]
        print("YESTERSTR == " + str(yesterstr))
        print("\nTEST GLOB-STRING == " + str("C:/data/inbound/*_" 
                                             + yesterstr 
                                             + "_*"))
        ###########################################
        # BEGIN GLOBBING
        glob_previous = sorted(glob.glob("C:/data/inbound/*_" 
                                         + yesterstr 
                                         + "_*"))
        print("\n\t GLOB_PREVIOUS >>> \n")
        for name in glob_previous: #{
            print(name)
        #}
        #####################################################################
        # < FOR RIGHT NOW WE IMPORT A .CSV FOR THE TODAY_FILE... 
        # THIS IS CREATED MANUALLY EVERY TIME BY CREATING A LIST OF 
        # "F:/APPS/CofA/" AND PUTTING INTO  A DATAFRAME
        # ==============[DIRECTORY CHANGE FOR FINAL VERISON]===========
        # "C:/data/inbound/*_" >>>> "C:/CofA/log/lists/*_"
        #####################################################################
        # RETURN LIST FROM FUNCTION
        #
        #OLD#glob_current = scan_directory("F:/APPS/CofA/")
        #
        ########################################################
        glob_current = sorted(glob.glob("C:/data/inbound/*_" 
                                        + today_date_str 
                                        + "_*"))
        print("\n\t GLOB_CURRENT >>> \n")
        for name in glob_current: #{
            print(name)
        #}
        print("~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~")
        #################
        # SETUP IMPORTS #
        #################
        df1 = pd.read_csv(glob_previous[0])
        df2 = pd.read_csv(glob_current[0])
        """
        # we dont use indeces because of LIST
        df2 = pd.DataFrame() # EMPTY AT FIRST
        # ASSIGN COLUMN OF DATAFRAME FROM LIST
        df2['CofA File'] = glob_current
        """
        print("LEN_D1 == " + str(len(df1)))
        print("LEN_D2 == " + str(len(df2)))
        #OLD#print(df1.info)
        #OLD#print(df2.info)
        # SET DIFFERENCE OF TWO DATAFRAMES IN PANDAS PYTHON
        set_diff_df = pd.concat([df2, df1, df1]).drop_duplicates(keep=False)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("\n\tLENGTH OF DATAFRAME: " + str(len(set_diff_df)))
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
        x = 0  # counter variable
        # CREATE TEMPORARY DIRECTORY (TO WORK INSIDE OF)
        ###################################################################
        with tempfile.TemporaryDirectory() as directory_name: #{
            the_dir = Path(directory_name)
            print("| TEMPORARY DIRECTORY >>> " + str(the_dir))
            # CREATE PATH VAR and "Popen" via SUBPROCESS
            print("Opening Explorer Window...")
            the_dir = Path(directory_name)
            # open temp_folder in a new EXPLORER WINDOW
            subprocess.Popen('explorer ' + str(the_dir))
            # ITERATE THRU TUPLES...
            for row in set_diff_df.itertuples(index=False, name="CofA"): #{
                # GET/CREATE BASE_NAME
                base_name = os.path.basename(str(row[0]))  # WAS: the_event_path
                # GET NEW FILE NAME CONVENTION
                file_name_conv = generate_naming_convention(base_name)
                # CREATE "temp_path"
                temp_path = os.path.join(the_dir, file_name_conv)
                # CREATE "dst_path"
                dst_path = os.path.join(out_directory, file_name_conv)
                # WATERMARK A COPY TO G_DRIVE **WITH CORRECT NE W FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=dst_path, watermark=in_file)
                # WATERMARK A COPY INTO TEMP FOLDER ** WITH CORRECT NEW FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=temp_path, watermark=in_file)
                # INCREASE COUNTER
                x += 1
                print("\t\t\t COUNT == " + str(x))
            #}
            ################################################################
            # ZIP THE CURRENT TEMP DIR (no need to create... just rename)
            try: #{
                print("\n\n\tWORKING DIRECTORY ---BEFORE--- ZIP == " + str(os.getcwd()))
                # path to folder
                directory = "." # (the_dir)
                # CHANGE WORKING DIRECTORY TO THE TEMPORARY DIR
                # (IN ORDER TO PROPERLY ZIP FILES/FOLDER)
                os.chdir(the_dir)   # WAS: "C:/"
                print("\n\n\tWORKING DIRECTORY ---DURING--- ZIP == " + str(os.getcwd()))
                # calling function to get all file paths in the directory
                file_paths = get_all_file_paths(the_dir)
                # printing the list of all files to be zipped 
                print('Following files will be zipped:') 
                for file_name in file_paths: #{
                    print(file_name) 
                #}
                # writing files to a zipfile 
                with ZipFile('CofA-' + str(pd.Timestamp.now())[:10] + ".zip",'w') as zip: #{
                    # writing each file one by one 
                    for file in file_paths: #{
                        zip.write(file) 
                    #}
                #}
                print('All files zipped successfully!')
                ###################################################
                # ....NOW ZIP THE NEWLY MADE FOLDER INSIDE TEMP FOLDER...
                #WAS#zip_directory = "./" + str(today_date_str)
                """
                zip_dir = Path("/" + str(today_str))
                print("\n MAKE-SHIFT ZIPPY_DIR == " + str(zip_dir) + "\n")
                # CREATE ZIP_DIRECTORY PATH VARIABLE
                zip_directory = os.path.join(".", zip_dir)
                print("\n ZIP_DIRECTORY == " + str(zip_directory) + "\n")
                # calling function to get all file paths in directory
                file_paths = get_all_file_paths(zip_directory)
                # printing the list of all files to be zipped
                print('Following files will be zipped:') 
                """
            #}
            except: #{
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                      "\n" + fileE +
                      "\n" + lineE +
                      "\n" + messageE)
            #}
            else: #{
                print("ALL FILES SUCCESSFULLY ZIPPED!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("RUN TIME == " + str(run_time))
            #}
            print("/n/t/t/t GLOBBING FOR ZIP FILE !!!")
            for name in sorted(glob.glob(str(the_dir) + "/*.zip")): #{
                print(name)
            #}
            zip_path = Path()
            #################### EXPORT DATAFRAME #####################
            # ZIP FILE HAS BEE CREATED NOW WE CAN EXPORT DATAFRAME
            # AND NOT WORRY ABOUT IT ALSO BEING INCLUDE IN ZIP
            # CREATE PATH FOR DATAFRAME
            df_path = os.path.join(the_dir, 
                                   "CofA-" 
                                   + str(pd.Timestamp.now())[:10] 
                                   + ".csv")
            print("EXPORT-CSV-PATH == " + str(df_path))
            # EXPORT DATAFRAME TO FILE IN TEMP FOLDER IN ORDER TO EMAIL
            df_save_list.to_csv(str(df_path), index=False)
            #####################################################
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            file_list = []
            
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
            #####################################################
            break_input = input("Continue? Y\n")
            #########################
        #}
        ###################################################
        # OUTSIDE OF TEMP FOLDER
        
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        isEOD = True
        # BECAUSE WE SET "isEOD" TO TRUE IT WILL STOP WATCHDOG LISTENER, 
        # POST TIME STAMP, THEN EN
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("RUN TIME == " + str(run_time))
    #}
    
#}

# %%
print(out_directory)
# Out:
# C:/Temp/G/C of A's/#Email Node/

# %% [markdown]
# ---

# %% [markdown]
# **OVERWRITE `.txt` FILE WITH DATAFRME**

# %% [raw]
# new_df.to_csv("CofA-backlog-test.txt", columns=None,
#               header=False, index=False, mode='w', escapechar='\r')

# %% [markdown]
# ---

# %%
if __name__ == "__main__": #{
    # SETUP LOGGER
    try: #{
        logging.basicConfig(level=logging.INFO,
                            stream=sys.stdout,
                            #filename="C:/data/outbound/CofA_Daily_Launcher.log",
                            format='&(asctime)s:%(message)s',
                            datefmt='%Y-%d-%m-%H%M%S',
                            filemode='a')
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-Logger] FIN...")
    #}
    ##########################################
    # RUN THIS CODE EVERY TIME NO MATTER WHAT#
    # REGARDLESS.... TRY THE FOLLOWING....   #
    ##########################################
    finally: #{
        ######################################
        # >>>>>>>> GLOBAL VARIABLES <<<<<<<< #
        ######################################
        in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
        #save_list = []
        df_save_list = pd.DataFrame(data=None, columns=['CofA', 'Timestamp', 'Created/Modified'], dtype=np.str)
        isEOD = False
        in_directory = "C:/Temp/F/APPS/CofA/"  #"F:/APPS/CofA/"
        out_directory =  "C:/Temp/G/C of A's/#Email Node/" #"G:/C of A's/#Email Node/"
        to_email = "agilent_cofa@agilent.com"
        from_email = "dere.bates@non.agilemt.com"
        time_start = pd.Timestamp.now()
    #}
    ##########################################
    print("[=================================================]")
    print("| SCANNING DIRECTORY >>> " + str(in_directory))
    print("| STORING IN DATAFRAME >>> " + str(df_save_list.head()))
    print("[=================================================]")
    print("| Initializing Time >>> " + str(pd.Timestamp.now()))
    print("[=================================================]")
    # CREATE TIMER VAR  // 12 HOURS... now 10.5 HOURS !! 08/07/2019
    # 37800
    t = Timer(25, execute_staging) # WAS 2592000,3600,720,600,43200,300 & 120
    # START TIMER
    t.start()
    # CREATE INSTANCE OF CUSTOM EVENT HANDLER
    event_handler = CofA_Event_Handler(df_save_list, in_directory, out_directory)
    observer = Observer()
    observer.schedule(event_handler=event_handler,
                      path=in_directory,
                      recursive=True)
    observer.start()
    # TRY THE FOLLOWING
    try: #{
        sleep_counter = 0
        while isEOD is False: #{
            # increase SLEEP COUNTEr & sleep...
            sleep_counter += 1
            sleep(1)
        #}
        else: #{
            print("[EOD] REACHED !!! <CLOSING SCRIPT>>")
            ts = pd.Timestamp.now()
            run_time = ts - time_start
            print("RUN TIME == " + str(run_time))
            sys.exit(0)
        #}
    #}
    except KeyboardInterrupt: #{
        observer.stop()
    #}
    observer.join()
    #
#}
# Out:
# [Create-Logger] FIN...
# [=================================================]
# | SCANNING DIRECTORY >>> C:/Temp/F/APPS/CofA/
# | STORING IN DATAFRAME >>> Empty DataFrame
# Columns: [CofA, Timestamp, Created/Modified]
# Index: []
# [=================================================]
# | Initializing Time >>> 2019-08-19 15:25:33.766691
# [=================================================]
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-19 15:25:34.737178
# 	[*************************]
# 	|>>> HALF 1 == ICP-131
# 	|>>> HALF 2 == 0006480484.pdf
# 	|>>> NEW NAME == part ICP-131 CofA Lot# 0006480484.pdf
# [*************************]
# LIST check == PASS
#                                     CofA                   Timestamp  \
# 0  part ICP-131 CofA Lot# 0006480484.pdf  2019-08-19 15:25:34.737178
#
#   Created/Modified
# 0          Created
# 	 [Append-2-DataFrame] FIN...
# 	 [Append-2-DataFrame] >>> time_alloted: 0 days 00:00:00.980487
# 	 [Created-Event] FIN..
# 	 [Created-Event] >>> time_alloted: 0 days 00:00:00.981493
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-19 15:25:34.747182
# 	[*************************]
# 	|>>> HALF 1 == ICP-079
# 	|>>> HALF 2 == 0006479330.pdf
# 	|>>> NEW NAME == part ICP-079 CofA Lot# 0006479330.pdf
# [*************************]
# LIST check == PASS
#                                     CofA                   Timestamp  \
# 0  part ICP-131 CofA Lot# 0006480484.pdf  2019-08-19 15:25:34.737178
# 1  part ICP-079 CofA Lot# 0006479330.pdf  2019-08-19 15:25:34.747182
#
#   Created/Modified
# 0          Created
# 1          Created
# 	 [Append-2-DataFrame] FIN...
# 	 [Append-2-DataFrame] >>> time_alloted: 0 days 00:00:00.984495
# 	 [Created-Event] FIN..
# 	 [Created-Event] >>> time_alloted: 0 days 00:00:00.985488
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-19 15:25:37.662519
# 	[*************************]
# 	|>>> HALF 1 == AM-230-1
# 	|>>> HALF 2 == 0006471880.pdf
# 	|>>> NEW NAME == part AM-230-1 CofA Lot# 0006471880.pdf
# [*************************]
# LIST check == PASS
#                                      CofA                   Timestamp  \
# 0   part ICP-131 CofA Lot# 0006480484.pdf  2019-08-19 15:25:34.737178
# 1   part ICP-079 CofA Lot# 0006479330.pdf  2019-08-19 15:25:34.747182
# 2  part AM-230-1 CofA Lot# 0006471880.pdf  2019-08-19 15:25:37.662519
#
#   Created/Modified
# 0          Created
# 1          Created
# 2          Created
# 	 [Append-2-DataFrame] FIN...
# 	 [Append-2-DataFrame] >>> time_alloted: 0 days 00:00:03.908830
# 	 [Created-Event] FIN..
# 	 [Created-Event] >>> time_alloted: 0 days 00:00:03.909829
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | CREATED >>> 2019-08-19 15:25:37.675518
# 	[*************************]
# 	|>>> HALF 1 == AM-170-1
# 	|>>> HALF 2 == 0006474446.pdf
# 	|>>> NEW NAME == part AM-170-1 CofA Lot# 0006474446.pdf
# [*************************]
# LIST check == PASS
#                                      CofA                   Timestamp  \
# 0   part ICP-131 CofA Lot# 0006480484.pdf  2019-08-19 15:25:34.737178
# 1   part ICP-079 CofA Lot# 0006479330.pdf  2019-08-19 15:25:34.747182
# 2  part AM-230-1 CofA Lot# 0006471880.pdf  2019-08-19 15:25:37.662519
# 3  part AM-170-1 CofA Lot# 0006474446.pdf  2019-08-19 15:25:37.675518
#
#   Created/Modified
# 0          Created
# 1          Created
# 2          Created
# 3          Created
# 	 [Append-2-DataFrame] FIN...
# 	 [Append-2-DataFrame] >>> time_alloted: 0 days 00:00:03.916838
# 	 [Created-Event] FIN..
# 	 [Created-Event] >>> time_alloted: 0 days 00:00:03.916838
#                                      CofA                   Timestamp  \
# 0   part ICP-131 CofA Lot# 0006480484.pdf  2019-08-19 15:25:34.737178
# 1   part ICP-079 CofA Lot# 0006479330.pdf  2019-08-19 15:25:34.747182
# 2  part AM-230-1 CofA Lot# 0006471880.pdf  2019-08-19 15:25:37.662519
# 3  part AM-170-1 CofA Lot# 0006474446.pdf  2019-08-19 15:25:37.675518
#
#   Created/Modified
# 0          Created
# 1          Created
# 2          Created
# 3          Created
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# TODAYS (FAKE) DATE == 2019-08-14
# TODAYS (REAL) DATE == 2019-08-19
# SUBTRACTION DELTA == 1 days 00:00:00
# YESTERSTR == 2019-08-13
#
# TEST GLOB-STRING == C:/data/inbound/*_2019-08-13_*
#
# 	 GLOB_PREVIOUS >>>
#
# C:/data/inbound\CofA_Email_Node_List_2019-08-13_pull.csv
# C:/data/inbound\CofA_Email_Node_List_2019-08-13_pull.old
#
# 	 GLOB_CURRENT >>>
#
# C:/data/inbound\CofA_Email_Node_List_2019-08-14_pull.csv
# ~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~
# LEN_D1 == 61641
# LEN_D2 == 61671
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 	LENGTH OF DATAFRAME: 30
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# | TEMPORARY DIRECTORY >>> C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8
# Opening Explorer Window...
# 	[*************************]
# 	|>>> HALF 1 == 400505-53
# 	|>>> HALF 2 == 0006482671.pdf
# 	|>>> NEW NAME == part 400505-53 CofA Lot# 0006482671.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:25.355131
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:25.496124
# 			 COUNT == 1
# 	[*************************]
# 	|>>> HALF 1 == 52000
# 	|>>> HALF 2 == 0006481325.pdf
# 	|>>> NEW NAME == part 52000 CofA Lot# 0006481325.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:25.713188
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:25.959193
# 			 COUNT == 2
# 	[*************************]
# 	|>>> HALF 1 == 55400
# 	|>>> HALF 2 == 0006482756.pdf
# 	|>>> NEW NAME == part 55400 CofA Lot# 0006482756.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:26.197193
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:26.406266
# 			 COUNT == 3
# 	[*************************]
# 	|>>> HALF 1 == AM-170-1
# 	|>>> HALF 2 == 0006480054.pdf
# 	|>>> NEW NAME == part AM-170-1 CofA Lot# 0006480054.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:26.537268
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:26.696269
# 			 COUNT == 4
# 	[*************************]
# 	|>>> HALF 1 == AM-171-1
# 	|>>> HALF 2 == 0006480053.pdf
# 	|>>> NEW NAME == part AM-171-1 CofA Lot# 0006480053.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:26.903149
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:27.094129
# 			 COUNT == 5
# 	[*************************]
# 	|>>> HALF 1 == AM-173-1
# 	|>>> HALF 2 == 0006480052.pdf
# 	|>>> NEW NAME == part AM-173-1 CofA Lot# 0006480052.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:27.429569
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:27.843233
# 			 COUNT == 6
# 	[*************************]
# 	|>>> HALF 1 == AMN-603-1
# 	|>>> HALF 2 == 0006480057.pdf
# 	|>>> NEW NAME == part AMN-603-1 CofA Lot# 0006480057.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:28.487251
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:28.599261
# 			 COUNT == 7
# 	[*************************]
# 	|>>> HALF 1 == AMN-613-1
# 	|>>> HALF 2 == 0006480056.pdf
# 	|>>> NEW NAME == part AMN-613-1 CofA Lot# 0006480056.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:29.200305
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:29.338309
# 			 COUNT == 8
# 	[*************************]
# 	|>>> HALF 1 == AMN-623-1
# 	|>>> HALF 2 == 0006480058.pdf
# 	|>>> NEW NAME == part AMN-623-1 CofA Lot# 0006480058.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:29.479312
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:29.594329
# 			 COUNT == 9
# 	[*************************]
# 	|>>> HALF 1 == AMN-623-1
# 	|>>> HALF 2 == 0006480059.pdf
# 	|>>> NEW NAME == part AMN-623-1 CofA Lot# 0006480059.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:29.823322
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:30.091326
# 			 COUNT == 10
# 	[*************************]
# 	|>>> HALF 1 == AMN-803-1
# 	|>>> HALF 2 == 0006480055.pdf
# 	|>>> NEW NAME == part AMN-803-1 CofA Lot# 0006480055.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:30.266322
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:30.491327
# 			 COUNT == 11
# 	[*************************]
# 	|>>> HALF 1 == ASTM-130-1
# 	|>>> HALF 2 == 0006478494.pdf
# 	|>>> NEW NAME == part ASTM-130-1 CofA Lot# 0006478494.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:30.724332
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:30.972058
# 			 COUNT == 12
# 	[*************************]
# 	|>>> HALF 1 == BLK-WRK-170D
# 	|>>> HALF 2 == 0006481034.pdf
# 	|>>> NEW NAME == part BLK-WRK-170D CofA Lot# 0006481034.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:31.189905
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:31.414989
# 			 COUNT == 13
# 	[*************************]
# 	|>>> HALF 1 == CH-151-1
# 	|>>> HALF 2 == 0006480845.pdf
# 	|>>> NEW NAME == part CH-151-1 CofA Lot# 0006480845.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:31.585883
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:31.711629
# 			 COUNT == 14
# 	[*************************]
# 	|>>> HALF 1 == CH-230-1
# 	|>>> HALF 2 == 0006478438.pdf
# 	|>>> NEW NAME == part CH-230-1 CofA Lot# 0006478438.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:31.965452
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:32.116743
# 			 COUNT == 15
# 	[*************************]
# 	|>>> HALF 1 == CHM-205-1
# 	|>>> HALF 2 == 0006481419.pdf
# 	|>>> NEW NAME == part CHM-205-1 CofA Lot# 0006481419.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:32.339476
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:32.586479
# 			 COUNT == 16
# 	[*************************]
# 	|>>> HALF 1 == CICM-240
# 	|>>> HALF 2 == 0006477735.pdf
# 	|>>> NEW NAME == part CICM-240 CofA Lot# 0006477735.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:33.740077
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:34.427085
# 			 COUNT == 17
# 	[*************************]
# 	|>>> HALF 1 == CICM-699
# 	|>>> HALF 2 == 0006479581.pdf
# 	|>>> NEW NAME == part CICM-699 CofA Lot# 0006479581.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:34.994094
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:35.576102
# 			 COUNT == 18
# 	[*************************]
# 	|>>> HALF 1 == CLP-252-1
# 	|>>> HALF 2 == 0006482220.pdf
# 	|>>> NEW NAME == part CLP-252-1 CofA Lot# 0006482220.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:35.730113
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:35.879873
# 			 COUNT == 19
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000060
# 	|>>> HALF 2 == 0006478975.pdf
# 	|>>> NEW NAME == part CUS-00000060 CofA Lot# 0006478975.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:36.212888
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:36.490882
# 			 COUNT == 20
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000062
# 	|>>> HALF 2 == 0006478978.pdf
# 	|>>> NEW NAME == part CUS-00000062 CofA Lot# 0006478978.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:36.621881
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:36.741886
# 			 COUNT == 21
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000165
# 	|>>> HALF 2 == 0006481345.pdf
# 	|>>> NEW NAME == part CUS-00000165 CofA Lot# 0006481345.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:36.918886
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.083888
# 			 COUNT == 22
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000173
# 	|>>> HALF 2 == 0006479735.pdf
# 	|>>> NEW NAME == part CUS-00000173 CofA Lot# 0006479735.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.223528
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.373535
# 			 COUNT == 23
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000324
# 	|>>> HALF 2 == 0006482596.pdf
# 	|>>> NEW NAME == part CUS-00000324 CofA Lot# 0006482596.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.552534
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.674538
# 			 COUNT == 24
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000325
# 	|>>> HALF 2 == 0006482597.pdf
# 	|>>> NEW NAME == part CUS-00000325 CofA Lot# 0006482597.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.829556
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:37.954595
# 			 COUNT == 25
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000326
# 	|>>> HALF 2 == 0006482598.pdf
# 	|>>> NEW NAME == part CUS-00000326 CofA Lot# 0006482598.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:38.122601
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:38.242596
# 			 COUNT == 26
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000327
# 	|>>> HALF 2 == 0006482599.pdf
# 	|>>> NEW NAME == part CUS-00000327 CofA Lot# 0006482599.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:38.450641
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:38.597698
# 			 COUNT == 27
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000328
# 	|>>> HALF 2 == 0006483070.pdf
# 	|>>> NEW NAME == part CUS-00000328 CofA Lot# 0006483070.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:38.750701
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:38.890702
# 			 COUNT == 28
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000329
# 	|>>> HALF 2 == 0006482600.pdf
# 	|>>> NEW NAME == part CUS-00000329 CofA Lot# 0006482600.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:39.063713
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:39.191712
# 			 COUNT == 29
# 	[*************************]
# 	|>>> HALF 1 == CUS-00000336
# 	|>>> HALF 2 == 0006468674.pdf
# 	|>>> NEW NAME == part CUS-00000336 CofA Lot# 0006468674.pdf
# [*************************]
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:39.437704
# 	 [watermark-pdf] FIN...
# 	 [watermark-pdf] >>> time_alloted: 0 days 00:00:39.733729
# 			 COUNT == 30
#
#
# 	WORKING DIRECTORY ---BEFORE--- ZIP == C:\Users\derbates\OneDrive - Agilent Technologies\Documents\_staging\Data-Developer-Droolkit\scripts
#
#
# 	WORKING DIRECTORY ---DURING--- ZIP == C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8
# Following files will be zipped:
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part 400505-53 CofA Lot# 0006482671.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part 52000 CofA Lot# 0006481325.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part 55400 CofA Lot# 0006482756.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AM-170-1 CofA Lot# 0006480054.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AM-171-1 CofA Lot# 0006480053.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AM-173-1 CofA Lot# 0006480052.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-603-1 CofA Lot# 0006480057.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-613-1 CofA Lot# 0006480056.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-623-1 CofA Lot# 0006480058.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-623-1 CofA Lot# 0006480059.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-803-1 CofA Lot# 0006480055.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part ASTM-130-1 CofA Lot# 0006478494.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part BLK-WRK-170D CofA Lot# 0006481034.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CH-151-1 CofA Lot# 0006480845.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CH-230-1 CofA Lot# 0006478438.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CHM-205-1 CofA Lot# 0006481419.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CICM-240 CofA Lot# 0006477735.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CICM-699 CofA Lot# 0006479581.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CLP-252-1 CofA Lot# 0006482220.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000060 CofA Lot# 0006478975.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000062 CofA Lot# 0006478978.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000165 CofA Lot# 0006481345.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000173 CofA Lot# 0006479735.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000324 CofA Lot# 0006482596.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000325 CofA Lot# 0006482597.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000326 CofA Lot# 0006482598.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000327 CofA Lot# 0006482599.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000328 CofA Lot# 0006483070.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000329 CofA Lot# 0006482600.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000336 CofA Lot# 0006468674.pdf
# All files zipped successfully!
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part 400505-53 CofA Lot# 0006482671.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part 52000 CofA Lot# 0006481325.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part 55400 CofA Lot# 0006482756.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AM-170-1 CofA Lot# 0006480054.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AM-171-1 CofA Lot# 0006480053.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AM-173-1 CofA Lot# 0006480052.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-603-1 CofA Lot# 0006480057.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-613-1 CofA Lot# 0006480056.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-623-1 CofA Lot# 0006480058.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-623-1 CofA Lot# 0006480059.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part AMN-803-1 CofA Lot# 0006480055.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part ASTM-130-1 CofA Lot# 0006478494.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part BLK-WRK-170D CofA Lot# 0006481034.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CH-151-1 CofA Lot# 0006480845.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CH-230-1 CofA Lot# 0006478438.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CHM-205-1 CofA Lot# 0006481419.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CICM-240 CofA Lot# 0006477735.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CICM-699 CofA Lot# 0006479581.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CLP-252-1 CofA Lot# 0006482220.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000060 CofA Lot# 0006478975.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000062 CofA Lot# 0006478978.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000165 CofA Lot# 0006481345.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000173 CofA Lot# 0006479735.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000324 CofA Lot# 0006482596.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000325 CofA Lot# 0006482597.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000326 CofA Lot# 0006482598.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000327 CofA Lot# 0006482599.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000328 CofA Lot# 0006483070.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000329 CofA Lot# 0006482600.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpnaey4oq8\part CUS-00000336 CofA Lot# 0006468674.pdf
# ALL FILES SUCCESSFULLY ZIPPED!
# RUN TIME == 0 days 00:00:39.812711
# Continue? Y
# y
#
# TYPE : <class 'PermissionError'>
# FILE : <ipython-input-10-22ce6faf1b61>
# LINE : 207
# MESG :
# <class 'PermissionError'>
# 		[WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\derbates\\AppData\\Local\\Temp\\tmpnaey4oq8\\CofA-2019-08-19.zip'
# 		<traceback object at 0x000001CCD76A8C08>
#
#
# RUN TIME == 0 days 01:05:12.746982
