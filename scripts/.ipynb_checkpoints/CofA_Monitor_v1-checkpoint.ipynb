# %% [markdown]
# # `CofA` Daily_Launcher

# %% [markdown]
# ### 1) create `logger`
# ### 2) create global variables
# ### 3) using `watchdog` wait for file to come into:
#     - F:/Apps/CofA/
#
# ## save all created and modified files into the `df_save_list` datafeframe and then when `execute_staging()` is called:
#
# ***_ conpare the two dorectories and only watermark the DIFF***
# ***_ then FINALLY create that garbage temp dir and ZiP it***
# ***_ last but not least email that shit once and for good***

# %%
# IMPORT THE GOODIES
import os, sys, time
from time import sleep
from pathlib import Path
import fnmatch, glob, shutil
import wmi, psutil
import filecmp, tempfile, textwrap
from textwrap import wrap
from zipfile import ZipFile
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import email, smtplib, ssl
import os.path as op
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.utils import COMMASPACE, formatdate
import subprocess, threading, logging
from threading import Timer
from PyPDF2 import PdfFileReader, PdfFileWriter
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# %% [markdown]
# **CLASSES**

# %%
class CofA_Event_Handler(FileSystemEventHandler): #{
    
    def __init__(self, save_dataframe, in_directory, observer): #{
        
        self.save_dataframe = save_dataframe
        self.in_directory = in_directory
        self.observer = observer
        #self.out_directory = out_directory
    #}
    
    """
    # DISPATCH ALWAYS CALLED FIRST JUST DESCRIBE EVENT
    def dispatch(self, event): #{
        event_str = str(event.event_type)
        event_path = Path(event.src_path)
        print("**********************")
        print("EVENT >>> " + event_str)
        print("SRC_PATH >>> " + str(event_path))
        print("**********************")
        # SEND OFF TO PERFORM ACTIONS BASED ON EVENT
        #perform_event_actions(the_event_type=event_str, the_event_path=event_path)
    #}
    """
    
    def on_any_event(self,event): #{
        # RE-INSTANTIATE GLOBALS
        global isEOD, t
        global observer
        # TRY THE FOLLOWING
        print("e=" + str(event))
        
        try: #{
            print(t.)
            print("checking for isEOD...")
            if isEOD is True: #{
                # STOP OBSERVER
                observer.stop()
                print("TRUE! ENDING SCRIPT!")
                # QUIT SCRIPT
                sys.exit(69)
            #}
            else: #{
                print("FALSE! \n STILL RUNNING AT " + str(pd.Timestamp.now()))
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("SUCCESS! VERY NICE!!")
        #}
        finally: #{
            print("[isEOD-check]FIN...")
        #}
    #}
    
    def on_created(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| CREATED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)  # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                """
                # CREATE str TO HOLD FINAL COLUMN FOR TUPLE
                created_str = "Created"
                """
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  #WAS: (created_str)
                """
                # APPEND EVENT ITEM TO "save_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
                print(df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED AT " + str(ts))
            #}
            
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Created-Event] FIN..")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Created-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    
    def on_modified(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| MODIFIED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)   # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  # WAS: (modified_str)
                """
                # APPEND EVENT ITEM TO "Createed_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED ON " + str(ts))
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Modified-Event] VERY NICE GOOD JOB! ")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Modified-Event] >>> time_alloted: " + str(run_time))
        #}
    #}

#}

# %% [markdown]
# **FUNCTIONS**

# %%
"""
TAKES IN:
PDF TO WATERMARK,
"""
def create_watermark(input_pdf, output, watermark): # {
    try:  # {
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)

        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()

        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()):  # {
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        # }

        with open(output, 'wb') as out:  # {
            pdf_writer.write(out)
        # }
    # }
    except: # {
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
        # }
    else: # {
        print("\t\t[watermark-pdf] FIN...")
    # }
    finally: # {
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[watermark-pdf] >>> time_alloted: " + str(run_time))
    # }
    return
# }

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list 
    file_paths = [] 
    
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths
#}

# %%
"""
TAKES IN:
(1) path to pdf 
RETURNS: 
the STRING of that PDF to match the naming convention
in G:/C of A's/#Email Node/ from F:/APPS/CofA/
"""
def generate_naming_convention(the_pdf_path): #{
    # get/set filename to variable
    the_file_name = str(os.path.basename(the_pdf_path))
    # PERFORM STRING OPERATIONS
    #################################
    idx_mrk = the_file_name.rfind('@', 0, len(the_file_name))
    half1 = str(the_file_name[0:idx_mrk])
    half2 = str(the_file_name[idx_mrk + 1:len(the_file_name)])
    print("\t\t[*************************]")
    print("\t\t|>>> HALF 1 == " + half1)
    print("\t\t|>>> HALF 2 == " + half2)
    #  setup NEW FILE NAME (for copy)
    new_name = "part "
    new_name += str(half1)
    new_name += " CofA Lot# "
    new_name += str(half2)
    print("\t\t|>>> NEW NAME == " + str(new_name))
    print("\t\t[*************************]")
    #################################
    return str(new_name)
#}

# %%
"""
TAKES IN: 
(1) LIST-type obj containing:
    - basename (CofA etc)[*.pdf]
    - timestamp
    - "Created" **OR** "Modified category"
(2) DataFrame obj containing:
    - that the newest row will be appended too
RETURNS: 
DataFrame (not in-place) with newly
appended tuple row etc 
"""
def append_to_dataframe(the_event_list, dataframe_to_append): #{
    # TRY THE FOLLOWING
    try: #{
        # CHECK IF LIST
        if type(the_event_list) is list : #{  # WAS: (the_event_list is list)
            print("\t\tLIST check == PASS")
            # SEPERATE COLUMNS
            col_1 = str(the_event_list[0])
            col_2 = str(the_event_list[1])
            # CREATE APPENDAGE FRAME
            df_appendage = pd.DataFrame(data=[the_event_list], 
                                        columns=['CofA', 'Timestamp'])
            # CREATE INSTANCE OF DATAFRAME WE ARE RETURNING
            return_df = dataframe_to_append.append(df_appendage, ignore_index=True, sort=False)
            #OLD# print(return_df.tail(5))
        #}
        else: #{
            print("\t\tLIST check == FAIL")
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("\t\t[Append-2-DataFrame] FIN...")
        return return_df
    #}
    finally: #{
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[Append-2-DataFrame] >>> time_alloted: "+ str(run_time))
    #}
#}

# %% [raw]
# def extract_information(pdf_path): #{
#     with open(pdf_path, 'rb') as f: #{
#         pdf = PdfFileReader(f)
#         information = pdf.getDocumentInfo()
#         number_of_pages = pdf.getNumPages()
#     #}
#     txt = f"""
#     Information about {pdf_path}:
#
#     Author: {information.author}
#     Creator: {information.creator}
#     Producer: {information.producer}
#     Subject: {information.subject}
#     Title: {information.title}
#     Number of Pages: {number_of_pages}
#     """
#
#     print(txt)
#     return information
# #}

# %%
"""
TAKES IN:
(1) file_path to file 
RETURNS: 
The create time or modified time, whichever is older
"""
def pull_creation_timetamp(a_file_path): #{
    # FORCE PATH VARIABLE
    the_path = Path(a_file_path)
    # GET MODIFIED TIME
    mtime = os.path.getmtime(the_path)
    # GET CREATE TIME
    ctime = os.path.getctime(the_path)
    # CREATE DATE VAR
    # IF CREATE TIME IS OLDER...
    if ctime < mtime: #{
        # FORMAT DATE VAR as str
        date_str = str(datetime.fromtimestamp(ctime))
    #}
    # ELSE.... MODIFIED TIME IS OLDER...
    else: #{
        # FORMAT DATE VAR as str
        date_str = str(datetime.fromtimestamp(mtime))
    #}
    # RETURN THE DATE WE PULLED AS STRING
    return date_str
#}

# %%
#test_list = scan_directory("F:/APPS/CofA/")

# %%
#print(len(test_list))

# %% [raw]
# def display_pdf_text(pdf_path): #{
#     read_pdf = PyPDF2.PdfFileReader(pdf_path)
#
#     for i in range(read_pdf.getNumPages()): #{
#         page = read_pdf.getPage(i)
#         print("Page No - " + str(1+read_pdf.getPageNumber(page)))
#         page_content = page.extractText()
#         print(page_content)
#     #}
#
# #}

# %%
def send_mail(send_from, send_to, subject, message, files=[], 
              server="cos.smtp.agilent.com", port=587, use_tls=True): #{
    print("SENDING MAIL... DATE == " + str(pd.Timestamp.now())[:10])
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = COMMASPACE.join(send_to)
    msg['Date'] = formatdate(localtime=True)
    msg['Subject'] = subject
    
    msg.attach(MIMEText(message))
    
    for path in files: #{
        part = MIMEBase('application', "octet-stream")
        with open(path, 'rb') as file: #{
            part.set_payload(file.read())
        #}
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                       'attachment; filename="{}"'.format(op.basename(path)))
        msg.attach(part)
    #}
    
    smtp = smtplib.SMTP(server, port)
    if use_tls: #{
        smtp.starttls()
    #}
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
#}

# %% [markdown]
# ---
#
# # compare `F:/APPS/CofA/` scan of `TODAY`
# # to scan of `F:/APPS/CofA/` of `YESTERDAY`
#
# >>> `CREATE DIFF DATAFRAME`
# >>> `ITERATE THRU THAT`
#
# `OVERWRITE` PDFs when *watermarking*
#
# AND THEN `CREATE ZIP` AND *EMAIL THAT ZIP* IN THE TEMP FOLDER

# %%
"""
EXPORTS DATAFRAME
TAKES IN:
(1) DATAFRAME OBJECT THAT HAS BEEN CREATED VIA WATCHODG
"""
def execute_staging(): #{
    # RE-INSTANTIATE GLOBALS
    #OLD# global save_list
    global df_save_list
    global observer
    global in_directory
    global out_directory
    #OLD# global today_date_str
    global isEOD
    #OLD# print("DATAFRAME IS OF TYPE ==\n\t\t" + str(type(df_save_list)))
    #OLD# print("AND IS EMPTY !?!?!? == \n" + str(df_save_list))
    print("\n\n\n >>>>> BUT THAT SEXY save_list == \n" + str(df_save_list))
    print("of type =====================" + str(type(df_save_list)))
    """
    #################### CREATE [save_list] DATAFRAME #####################
    try: #{
        # WE HAVE THE SAVE_LIST, NOW WE NEED TO FILL THAT DATA IN
        # TO THE MAIN DATAFRAME THAT IT BELONG TO
        df_saveframe = pd.DataFrame(data=save_list, 
                                    columns=['CofA', 'Timestamp'], 
                                    dtype=np.str)
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-DataFrame] SUCCESS! VERY NICE!")
        print(str(df_saveframe))
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("[Create-DataFrame] RUN TIME == " + str(run_time))
    #}
    """
    #################################################
    try: #{
        print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #OLD# print("TODAYS (FAKE) DATE == " + today_date_str)
        ###########################################
        # CREATE TODAY AND YESTERDAY STR
        today_str = str(pd.Timestamp.now())[:10]
        print("TODAYS (REAL) DATE == " + today_str)
        ######################################################
        #time_now = pd.Timestamp(year=2019, month=8, day=14) #
        ######################################################
        time_now = pd.Timestamp.now()
        # CREATE SUTBRACTION DELTA 
        subtraction_delta = pd.Timedelta(value=1, unit='days')
        print("SUBTRACTION DELTA == " + str(subtraction_delta))
        # CREATE "yesterdays date" BY SUTBRACTING
        yesterstr = str(time_now - subtraction_delta)[:10]
        print("YESTERSTR == " + str(yesterstr))
        print("\nTEST GLOB-STRING == " + str("C:/CofA/log/lists/*_" 
                                             + yesterstr 
                                             + "_*"))
        ###########################################
        # BEGIN GLOBBING (WAS: C:/data/inbound/)
        glob_previous = sorted(glob.glob("CC:/CofA/log/lists/*_" 
                                         + yesterstr 
                                         + "_*"))
        print("\n\t GLOB_PREVIOUS >>> \n")
        for name in glob_previous: #{
            print(name)
        #}
        #####################################################################
        # < FOR RIGHT NOW WE IMPORT A .CSV FOR THE TODAY_FILE... 
        # THIS IS CREATED MANUALLY EVERY TIME BY CREATING A LIST OF 
        # "F:/APPS/CofA/" AND PUTTING INTO  A DATAFRAME
        # ==============[DIRECTORY CHANGE FOR FINAL VERISON]===========
        # "C:/data/inbound/*_" >>>> "C:/CofA/log/lists/*_"
        #####################################################################
        # RETURN LIST FROM FUNCTION
        #
        #OLD#glob_current = scan_directory("F:/APPS/CofA/")
        #
        ########################################################
        glob_current = sorted(glob.glob("C:/CofA/log/lists/*_" 
                                        + today_str 
                                        + "_*"))
        print("\n\t GLOB_CURRENT >>> \n")
        for name in glob_current: #{
            print(name)
        #}
        print("\n\n\n~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #################
        # SETUP IMPORTS #
        #################
        df1 = pd.read_csv(glob_previous[0])
        df2 = pd.read_csv(glob_current[0])
        """
        # we dont use indeces because of LIST
        df2 = pd.DataFrame() # EMPTY AT FIRST
        # ASSIGN COLUMN OF DATAFRAME FROM LIST
        df2['CofA File'] = glob_current
        """
        print("LEN_D1 == " + str(len(df1)))
        print("LEN_D2 == " + str(len(df2)))
        #OLD#print(df1.info)
        #OLD#print(df2.info)
        # SET DIFFERENCE OF TWO DATAFRAMES IN PANDAS PYTHON
        set_diff_df = pd.concat([df2, df1, df1]).drop_duplicates(keep=False)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("\n\tLENGTH OF DIFFERENCE == " + str(len(set_diff_df)))
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
        x = 0  # counter variable
        # CREATE TEMPORARY DIRECTORY (TO WORK INSIDE OF)
        ###################################################################
        with tempfile.TemporaryDirectory() as directory_name: #{
            the_dir = Path(directory_name)
            print("| TEMPORARY DIRECTORY >>> " + str(the_dir) + "\n")
            # ITERATE THRU TUPLES...
            for row in set_diff_df.itertuples(index=False, name="CofA"): #{
                # GET/CREATE BASE_NAME
                base_name = os.path.basename(str(row[0]))  # WAS: the_event_path
                # GET NEW FILE NAME CONVENTION
                file_name_conv = generate_naming_convention(base_name)
                # CREATE "temp_path"
                temp_path = os.path.join(the_dir, file_name_conv)
                # CREATE "dst_path"
                dst_path = os.path.join(out_directory, file_name_conv)
                # WATERMARK A COPY TO G_DRIVE **WITH CORRECT NE W FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=dst_path, watermark=in_file)
                # WATERMARK A COPY INTO TEMP FOLDER ** WITH CORRECT NEW FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=temp_path, watermark=in_file)
                # INCREASE COUNTER
                x += 1
                print("COUNT == " + str(x))
            #}
            ################################################################
            # ZIP THE CURRENT TEMP DIR (no need to create... just rename)
            try: #{
                print("\n\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
                print("\nWORKING DIRECTORY ---BEFORE--- ZIP == " + str(os.getcwd()))
                # path to folder
                directory = "." # (the_dir)
                # CHANGE WORKING DIRECTORY TO THE TEMPORARY DIR
                # (IN ORDER TO PROPERLY ZIP FILES/FOLDER)
                os.chdir(the_dir)   # WAS: "C:/"
                print("\nWORKING DIRECTORY ---DURING--- ZIP == " + str(os.getcwd()))
                # calling function to get all file paths in the directory
                file_paths = get_all_file_paths(the_dir)
                # printing the list of all files to be zipped 
                print('\nFollowing files will be zipped:') 
                for file_name in file_paths: #{
                    print(file_name) 
                #}
                # writing files to a zipfile 
                with ZipFile('CofA-' + str(pd.Timestamp.now())[:10] + ".zip",'w') as zip: #{
                    # writing each file one by one 
                    for file in file_paths: #{
                        zip.write(file) 
                    #}
                #}
                print('All files zipped successfully!\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' 
                      + 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX\n')
                ###################################################
                # ....NOW ZIP THE NEWLY MADE FOLDER INSIDE TEMP FOLDER...
                #WAS#zip_directory = "./" + str(today_date_str)
                """
                zip_dir = Path("/" + str(today_str))
                print("\n MAKE-SHIFT ZIPPY_DIR == " + str(zip_dir) + "\n")
                # CREATE ZIP_DIRECTORY PATH VARIABLE
                zip_directory = os.path.join(".", zip_dir)
                print("\n ZIP_DIRECTORY == " + str(zip_directory) + "\n")
                # calling function to get all file paths in directory
                file_paths = get_all_file_paths(zip_directory)
                # printing the list of all files to be zipped
                print('Following files will be zipped:') 
                """
            #}
            except: #{
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                      "\n" + fileE +
                      "\n" + lineE +
                      "\n" + messageE)
            #}
            else: #{
                print("ALL FILES SUCCESSFULLY ZIPPED!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Zip-Files] RUN TIME == " + str(run_time))
            #}
            # TRY TO FINISH THIS SHIT OFF
            try: #{
                print("\n\t\t\t GLOBBING FOR ZIP FILE !!!")
                for name in sorted(glob.glob(str(the_dir) + "/*.zip")): #{
                    print("NAME OF FILE == " 
                          + str(name))
                    #logging.info(name)
                    print("LENGTH OF GLOB == " 
                          + str(len(sorted(glob.glob(str(the_dir))))))
                    # GET&SET PATH NAME 
                    zip_path = Path(name)
                    print("ZIP_PATH == " 
                          + str(zip_path))
                #}
                """
                # CREATE ZIP_DRIECTORY OFF SINGLE_GLOB_STR
                zip_path = Path(sorted(glob.glob(str(the_dir) + "/*.zip"))[0])
                """
                # >>>>>>>>>>>>> EXPORT DATAFRAME <<<<<<<<<<<<<<<<<<< #
                ###################################################3
                # CREATE STR FOR PATH FOR SAVE_DIFF_DATAFRAME
                df_save_str = str("CofA-" 
                                  + str(pd.Timestamp.now())[:10] 
                                  + ".csv")
                df_save_path = os.path.join(the_dir, df_save_str)
                print("\n\n\tSAVE-PATH FOR DATAFRAME == " + str(df_save_path))
                # SORT THE DATAFRAME BEFORE EXPORTING
                df_save_frame_sorted = df_saveframe.sort_values(by='Timestamp')
                # DROP DUPLICATES BEFORE EXPORTING
                df_save_frame_sorted.drop_duplicates(subset='CofA', 
                                                     keep='last', 
                                                     inplace=True)
                df_save_frame_sorted.to_csv(str(df_save_path), index=False)
                #################### EXPORT DATAFRAME #####################
                # ZIP FILE HAS BEE CREATED NOW WE CAN EXPORT DATAFRAME
                # AND NOT WORRY ABOUT IT ALSO BEING INCLUDE IN ZIP
                #########################################################
                #OLD# df_saveframe.to_csv(str(df_save_path), index=False)
                ##################################################
                # EXPORT THE SET_DIFF_DF TO FILE  IN TEMP FOLDER IN ORDER TO EMAIL
                #set_diff_df.to_csv(str(df_save_path), index=False)
                # CREATE PATH VAR and "Popen" via SUBPROCESS
                print("Opening Explorer Window...")
                the_dir = Path(directory_name)
                # open temp_folder in a new EXPLORER WINDOW
                subprocess.Popen('explorer ' + str(the_dir))
                ###################################################
                # CREATE FILE_LIST VAR
                file_list = [str(zip_path), str(df_save_path)]
                print(">>> FILE LIST : \n\t" 
                      + str(file_list) 
                      + "\n")
                """
                break_input = input("Continue? Y\n")
                if str(break_input).lower() == "n": #{
                    sys.exit(69)
                #}
                elif str(break_input).lower() == "y": #{
                """
                print("CONT....")
                #####################################################
                # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                #####################################################
                try: #{
                    send_mail(send_from="derek.bates@non.agilent.com",
                              send_to="derek.bates@non.agilent.com", 
                              subject=str(pd.Timestamp.now())[:10],
                              message="See File(s) attached",
                              files=file_list)
                #}
                except: #{
                    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                    exc_type, exc_obj, exc_tb = sys.exc_info()
                    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                    typeE = str("TYPE : " + str(exc_type))
                    fileE = str("FILE : " + str(fname))
                    lineE = str("LINE : " + str(exc_tb.tb_lineno))
                    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                    print("\n" + typeE +
                                  "\n" + fileE +
                                  "\n" + lineE +
                                  "\n" + messageE)
                #}
                else: #{
                    print("EMAIL SUCCESSFULLY SENT! VERY NICE!")
                #}
            #}
            except: #{                
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                              "\n" + fileE +
                              "\n" + lineE +
                              "\n" + messageE)
            #}
            else: #{
                print("[Create-set_diff_df] SUCCESS! VERY NICE!!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Email-Files] FIN...")
                sys.exit(69)
            #}
        #}
        """
        print('Directory exists after?' + str(directory_name.exists()))
        print('Contents after:' + str(list(directory_name.glob('*'))))
        """
        ###################################################
        # OUTSIDE OF TEMP FOLDER
        # EXPORT THE .csv?
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        isEOD = True
        # BECAUSE WE SET "isEOD" TO TRUE IT WILL STOP WATCHDOG LISTENER, 
        # POST TIME STAMP, THEN EN
        observer.stop()
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("RUN TIME == " + str(run_time))
        print("LINE 352 EXECUTE STAGING()")
    #}
    
#}

# %% [markdown]
# ---

# %% [markdown]
# **OVERWRITE `.txt` FILE WITH DATAFRME**

# %% [raw]
# new_df.to_csv("CofA-backlog-test.txt", columns=None,
#               header=False, index=False, mode='w', escapechar='\r')

# %% [markdown]
# ---

# %% [raw]
# # INSTANTIATE GLOBAL VARIABLES
# in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
# in_file2 = "C:/data/inbound/02OTHER_Rohde Island_Agilent Quality_Digital Letterhead.pdf"
# #in_directory = "F:/APPS/CofA/"
# #out_directory = "G:/C of A's/#Email Node/"
# in_directory = "C:/Temp/F/APPS/CofA/"
# out_directory = "C:/Temp/G/C of A's/#Email Node/"
# save_list = []
# isEOD = False
# time_start = pd.Timestamp.now()
# df_save_list = pd.DataFrame(data=None, dtype=np.str)
# # FAKE VAR TO STAND FOR "todays date"
# today_date_str = "2019-08-14"

# %%
if __name__ == "__main__":
    # SETUP LOGGER
    try: #{
        logging.basicConfig(level=logging.INFO,
                            #stream=sys.stdout,
                            filename="C:/data/outbound/CofA_Daily_Launcher.log",
                            format='%(asctime)s:'
                            + '\n\t\t\t\t'
                            + '<MESG:%(message)s>'
                            + '\n\t\t\t\t'
                            + '<%(threadName)s-ID:%(thread)d>'
                            + '\n\t\t\t\t'
                            + '<%(processName)s-ID:%(process)d>'
                            + '\n\t\t\t\t'
                            + '<FUNC=%(funcName)s>'
                            + '\n\t\t\t\t'
                            + '<LINE:%(lineno)s>'
                            + '\n\t\t\t\t'
                            + '<PATH:%(pathname)s>'
                            + '\n\t\t\t\t'
                            + '<NAME:%(name)s>',
                            # format='%(asctime)s:%(message)s PROCESS=%(processName)s',
                            datefmt='%Y_%d_%m_%H%M%S',
                            filemode='a')
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-Logger] FIN...")
    #}
    ######################################
    # >>>>>>>> GLOBAL VARIABLES <<<<<<<< #
    ######################################
    in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
    #OLD# save_list = []
    df_save_list = pd.DataFrame(data=None, columns=['CofA', 'Timestamp'])
    # 'Created/Modified'
    isEOD = False
    in_directory = "F:/APPS/CofA/"  #"C:/Temp/F/APPS/CofA/"
    out_directory =  "G:/C of A's/#Email Node/"  #"C:/Temp/G/C of A's/#Email Node/"
    outbound_directory = "C:/Temp/G/C of A's/Agilent/"  #"G:/C of A's/Agilent/"
    to_email = "derek.bates@non.agilent.com"
    from_email = "derek.bates@non.agilemt.com"
    time_start = pd.Timestamp.now()
    # FAKE VAR TO STAND FOR "todays date"
    #OLD# today_date_str = "2019-08-24"  # WAS: 8/14
    ##########################################
    print("[=================================================]")
    print("| SCANNING DIRECTORY >>> " + str(in_directory))
    print("| STORING IN DATAFRAME >>> " + str(df_save_list))  # WAS: str(df_save_list.head()))
    print("[=================================================]")
    print("| Initializing Timer >>> " + str(pd.Timestamp.now()))
    print("[=================================================]\n\n\n")
    # CREATE TIMER VAR  // 12 HOURS... now 10.5 HOURS !! 08/07/2019
    # 37800 / USE == 54000
    t = Timer(39600, execute_staging) # WAS 2592000,3600,720,600,43200,300 & 120
    # START TIMER
    t.start()
    """
    print("\n\n<><><><><><><><><><>BEFORE HANDLER START<><><><><><><><><><><>\n")
    print("<><><><><> save_list == \n")
    # PRINT OUT EVERY ITEM & COUNT #
    len_count = len(df_save_list)
    for save in df_save_list: #{
        print("SAVE NAME === " + str(save))
        print("COUNT === " + str(len_count))
        # subtract one
        len_count -= 1
    #}
    #print("<><><><><> df_save_list == " + str(df_save_list))
    print("\n<><><><><><><><><><><><><><><><><><><><><><><><><><><>\n\n")
    """
    ###################
    # ALSO GLOBAL VAR # 
    ###################
    observer = Observer()
    # CREATE INSTANCE OF CUSTOM EVENT HANDLER
    event_handler = CofA_Event_Handler(df_save_list, in_directory, observer)
    #OLD# observer = Observer()
    observer.schedule(event_handler=event_handler,
                      path=in_directory,
                      recursive=True)
    observer.start()
    # TRY THE FOLLOWING
    try: #{
        while True: #{
            sleep(1)
        #}
    #}
    except KeyboardInterrupt: #{
        observer.stop()
    #}
    observer.join()
# Out:
# [Create-Logger] FIN...
# [=================================================]
# | SCANNING DIRECTORY >>> F:/APPS/CofA/
# | STORING IN DATAFRAME >>> Empty DataFrame
# Columns: [CofA, Timestamp]
# Index: []
# [=================================================]
# | Initializing Timer >>> 2019-08-26 10:05:47.426397
# [=================================================]
#
#
#
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 10:25:23.294768
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 10:25:23.295770
# 		[*************************]
# 		|>>> HALF 1 == PST-3050A1000
# 		|>>> HALF 2 == 0006486284.pdf
# 		|>>> NEW NAME == part PST-3050A1000 CofA Lot# 0006486284.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:19:35.871372
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:19:35.871372
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 10:25:29.536656
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 10:25:29.536656
# 		[*************************]
# 		|>>> HALF 1 == PST-3275M100A01
# 		|>>> HALF 2 == 0006486285.pdf
# 		|>>> NEW NAME == part PST-3275M100A01 CofA Lot# 0006486285.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:19:42.113255
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:19:42.113255
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 10:45:06.023628
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 10:45:06.023628
# 		[*************************]
# 		|>>> HALF 1 == CUS-11423
# 		|>>> HALF 2 == 0006486909.pdf
# 		|>>> NEW NAME == part CUS-11423 CofA Lot# 0006486909.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:39:18.602276
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:39:18.603282
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:00.693155
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:00.694173
# 		[*************************]
# 		|>>> HALF 1 == PST-2520-10MG
# 		|>>> HALF 2 == 0006484517.pdf
# 		|>>> NEW NAME == part PST-2520-10MG CofA Lot# 0006484517.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:55:13.273760
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:55:13.274771
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:08.924367
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:08.924367
# 		[*************************]
# 		|>>> HALF 1 == PST-2505-10MG
# 		|>>> HALF 2 == 0006484514.pdf
# 		|>>> NEW NAME == part PST-2505-10MG CofA Lot# 0006484514.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:55:21.510039
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:55:21.512029
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:15.020913
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:15.020913
# 		[*************************]
# 		|>>> HALF 1 == PST-2490-10MG
# 		|>>> HALF 2 == 0006484508.pdf
# 		|>>> NEW NAME == part PST-2490-10MG CofA Lot# 0006484508.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:55:27.597461
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:55:27.597461
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:26.044556
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:26.044556
# 		[*************************]
# 		|>>> HALF 1 == PST-2495-10MG
# 		|>>> HALF 2 == 0006484509.pdf
# 		|>>> NEW NAME == part PST-2495-10MG CofA Lot# 0006484509.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:55:38.622162
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:55:38.622162
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:34.197943
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:34.197943
# 		[*************************]
# 		|>>> HALF 1 == PST-2495-10MG
# 		|>>> HALF 2 == 0006484510.pdf
# 		|>>> NEW NAME == part PST-2495-10MG CofA Lot# 0006484510.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:55:46.773549
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:55:46.774572
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:38.261795
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:38.261795
# 		[*************************]
# 		|>>> HALF 1 == PST-250
# 		|>>> HALF 2 == 0006484511.pdf
# 		|>>> NEW NAME == part PST-250 CofA Lot# 0006484511.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:55:50.838399
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:55:50.838399
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:49.001082
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:49.003089
# 		[*************************]
# 		|>>> HALF 1 == PST-2500-100MG
# 		|>>> HALF 2 == 0006484512.pdf
# 		|>>> NEW NAME == part PST-2500-100MG CofA Lot# 0006484512.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:01.580691
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:01.580691
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:01:56.100752
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:01:56.100752
# 		[*************************]
# 		|>>> HALF 1 == PST-2505-100MG
# 		|>>> HALF 2 == 0006484513.pdf
# 		|>>> NEW NAME == part PST-2505-100MG CofA Lot# 0006484513.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:08.678406
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:08.679405
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:04.167590
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:04.168591
# 		[*************************]
# 		|>>> HALF 1 == PST-2510-10MG
# 		|>>> HALF 2 == 0006484515.pdf
# 		|>>> NEW NAME == part PST-2510-10MG CofA Lot# 0006484515.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:16.747137
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:16.748152
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:14.676637
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:14.676637
# 		[*************************]
# 		|>>> HALF 1 == PST-2520-10MG
# 		|>>> HALF 2 == 0006484516.pdf
# 		|>>> NEW NAME == part PST-2520-10MG CofA Lot# 0006484516.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:27.252208
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:27.252208
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:21.750853
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:21.750853
# 		[*************************]
# 		|>>> HALF 1 == PST-2525-10MG
# 		|>>> HALF 2 == 0006484518.pdf
# 		|>>> NEW NAME == part PST-2525-10MG CofA Lot# 0006484518.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:34.329497
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:34.329497
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:30.727973
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:30.727973
# 		[*************************]
# 		|>>> HALF 1 == PST-2530-10MG
# 		|>>> HALF 2 == 0006484519.pdf
# 		|>>> NEW NAME == part PST-2530-10MG CofA Lot# 0006484519.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:43.306622
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:43.306622
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:38.778640
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:38.779639
# 		[*************************]
# 		|>>> HALF 1 == PST-2535-10MG
# 		|>>> HALF 2 == 0006484520.pdf
# 		|>>> NEW NAME == part PST-2535-10MG CofA Lot# 0006484520.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:56:51.356243
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:56:51.357243
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:48.314405
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:48.314405
# 		[*************************]
# 		|>>> HALF 1 == PST-2540-100MG
# 		|>>> HALF 2 == 0006484521.pdf
# 		|>>> NEW NAME == part PST-2540-100MG CofA Lot# 0006484521.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:57:00.890011
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:57:00.890011
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:02:58.226315
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:02:58.226315
# 		[*************************]
# 		|>>> HALF 1 == PST-2545-100MG
# 		|>>> HALF 2 == 0006484522.pdf
# 		|>>> NEW NAME == part PST-2545-100MG CofA Lot# 0006484522.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:57:10.809923
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:57:10.809923
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:03:05.450889
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:03:05.450889
# 		[*************************]
# 		|>>> HALF 1 == PST-2550-10MG
# 		|>>> HALF 2 == 0006484523.pdf
# 		|>>> NEW NAME == part PST-2550-10MG CofA Lot# 0006484523.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:57:18.030534
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:57:18.030534
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:03:16.488374
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:03:16.489426
# 		[*************************]
# 		|>>> HALF 1 == PST-2555-10MG
# 		|>>> HALF 2 == 0006484524.pdf
# 		|>>> NEW NAME == part PST-2555-10MG CofA Lot# 0006484524.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:57:29.068019
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:57:29.068019
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:03:24.470794
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:03:24.470794
# 		[*************************]
# 		|>>> HALF 1 == PST-2560-10MG
# 		|>>> HALF 2 == 0006484525.pdf
# 		|>>> NEW NAME == part PST-2560-10MG CofA Lot# 0006484525.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:57:37.048388
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:57:37.048388
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:03:31.491720
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:03:31.492715
# 		[*************************]
# 		|>>> HALF 1 == PST-2565-10MG
# 		|>>> HALF 2 == 0006484526.pdf
# 		|>>> NEW NAME == part PST-2565-10MG CofA Lot# 0006484526.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 00:57:44.068319
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 00:57:44.068319
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:16:12.113179
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:16:12.113179
# 		[*************************]
# 		|>>> HALF 1 == ICC-004A
# 		|>>> HALF 2 == CS-1084.pdf
# 		|>>> NEW NAME == part ICC-004A CofA Lot# CS-1084.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:10:24.689780
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:10:24.689780
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:16:39.249843
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:16:39.249843
# 		[*************************]
# 		|>>> HALF 1 == ICC-005A
# 		|>>> HALF 2 == CS-1687.pdf
# 		|>>> NEW NAME == part ICC-005A CofA Lot# CS-1687.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:10:51.827449
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:10:51.827449
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:16:56.454954
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:16:56.457003
# 		[*************************]
# 		|>>> HALF 1 == ICC-210
# 		|>>> HALF 2 == 0006471722.pdf
# 		|>>> NEW NAME == part ICC-210 CofA Lot# 0006471722.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:11:09.035622
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:11:09.035622
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:17:10.158345
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:17:10.160412
# 		[*************************]
# 		|>>> HALF 1 == ICP-012
# 		|>>> HALF 2 == CS-4180.pdf
# 		|>>> NEW NAME == part ICP-012 CofA Lot# CS-4180.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:11:22.739007
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:11:22.739007
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:17:14.612879
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:17:14.612879
# 		[*************************]
# 		|>>> HALF 1 == ICP-014
# 		|>>> HALF 2 == CR-2464.pdf
# 		|>>> NEW NAME == part ICP-014 CofA Lot# CR-2464.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:11:27.188456
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:11:27.188456
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:17:22.747647
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:17:22.747647
# 		[*************************]
# 		|>>> HALF 1 == ICP-004
# 		|>>> HALF 2 == CR-3964.pdf
# 		|>>> NEW NAME == part ICP-004 CofA Lot# CR-3964.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:11:35.327254
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:11:35.327254
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:17:29.191909
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:17:29.191909
# 		[*************************]
# 		|>>> HALF 1 == ICP-015
# 		|>>> HALF 2 == 0006471725.pdf
# 		|>>> NEW NAME == part ICP-015 CofA Lot# 0006471725.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:11:41.767528
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:11:41.767528
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:17:39.818452
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:17:39.819505
# 		[*************************]
# 		|>>> HALF 1 == ICP-020
# 		|>>> HALF 2 == CS-1975.pdf
# 		|>>> NEW NAME == part ICP-020 CofA Lot# CS-1975.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:11:52.398041
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:11:52.398041
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:18:10.193296
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:18:10.193296
# 		[*************************]
# 		|>>> HALF 1 == ICP-048
# 		|>>> HALF 2 == CP-5285.pdf
# 		|>>> NEW NAME == part ICP-048 CofA Lot# CP-5285.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:12:22.769916
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:12:22.769916
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:18:14.052431
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:18:14.052431
# 		[*************************]
# 		|>>> HALF 1 == ICP-092
# 		|>>> HALF 2 == 0006473164.pdf
# 		|>>> NEW NAME == part ICP-092 CofA Lot# 0006473164.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:12:26.635091
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:12:26.636046
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:18:19.078065
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:18:19.079126
# 		[*************************]
# 		|>>> HALF 1 == ICP-081
# 		|>>> HALF 2 == CT-1393.pdf
# 		|>>> NEW NAME == part ICP-081 CofA Lot# CT-1393.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:12:31.657730
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:12:31.657730
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:18:25.994242
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:18:25.994242
# 		[*************************]
# 		|>>> HALF 1 == PAH-615-1
# 		|>>> HALF 2 == CS-4836.PDF
# 		|>>> NEW NAME == part PAH-615-1 CofA Lot# CS-4836.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:12:38.569856
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:12:38.569856
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:18:39.534359
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:18:39.535361
# 		[*************************]
# 		|>>> HALF 1 == ICP-030
# 		|>>> HALF 2 == CT-1392.pdf
# 		|>>> NEW NAME == part ICP-030 CofA Lot# CT-1392.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:12:52.111965
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:12:52.111965
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:18:49.627063
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:18:49.627063
# 		[*************************]
# 		|>>> HALF 1 == ICP-019
# 		|>>> HALF 2 == CS-1360.pdf
# 		|>>> NEW NAME == part ICP-019 CofA Lot# CS-1360.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:13:02.202666
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:13:02.202666
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:25.557378
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:25.558330
# 		[*************************]
# 		|>>> HALF 1 == ICUS-0000584
# 		|>>> HALF 2 == 0006485733.pdf
# 		|>>> NEW NAME == part ICUS-0000584 CofA Lot# 0006485733.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:37:38.138980
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:37:38.139980
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.191489
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.191489
# NON-PDF CREATED ON 2019-08-26 11:43:55.191489
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:07.766092
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.227525
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.227525
# NON-PDF CREATED ON 2019-08-26 11:43:55.227525
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:07.803142
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.637906
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.637906
# NON-PDF CREATED ON 2019-08-26 11:43:55.637906
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.212509
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.650869
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.650869
# NON-PDF CREATED ON 2019-08-26 11:43:55.650869
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.226475
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.655905
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.655905
# NON-PDF CREATED ON 2019-08-26 11:43:55.655905
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.231473
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.676905
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.676905
# NON-PDF CREATED ON 2019-08-26 11:43:55.676905
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.251508
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.705910
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.705910
# NON-PDF CREATED ON 2019-08-26 11:43:55.705910
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.280513
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.756879
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.756879
# NON-PDF CREATED ON 2019-08-26 11:43:55.756879
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.331482
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.764886
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.764886
# NON-PDF CREATED ON 2019-08-26 11:43:55.764886
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.339489
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.801874
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.805873
# NON-PDF CREATED ON 2019-08-26 11:43:55.805873
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.382476
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.837872
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.837872
# NON-PDF CREATED ON 2019-08-26 11:43:55.837872
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.412475
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:55.868874
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:55.869874
# NON-PDF CREATED ON 2019-08-26 11:43:55.869874
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.445479
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:56.406882
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:56.408883
# NON-PDF CREATED ON 2019-08-26 11:43:56.408883
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.988484
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:43:56.416882
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:43:56.418881
# NON-PDF CREATED ON 2019-08-26 11:43:56.418881
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:38:08.994486
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:49:23.875166
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:49:23.875166
# 		[*************************]
# 		|>>> HALF 1 == ICP-080
# 		|>>> HALF 2 == CT-1449.pdf
# 		|>>> NEW NAME == part ICP-080 CofA Lot# CT-1449.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:43:36.455767
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:43:36.456769
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:49:29.733357
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:49:29.733357
# 		[*************************]
# 		|>>> HALF 1 == ICP-033
# 		|>>> HALF 2 == CT-0993.pdf
# 		|>>> NEW NAME == part ICP-033 CofA Lot# CT-0993.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:43:42.311999
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:43:42.311999
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:49:51.503398
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:49:51.503398
# 		[*************************]
# 		|>>> HALF 1 == CUS-30697
# 		|>>> HALF 2 == CS-6216.PDF
# 		|>>> NEW NAME == part CUS-30697 CofA Lot# CS-6216.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:44:04.080038
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:44:04.081037
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:49:59.222426
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:49:59.222426
# NON-PDF CREATED ON 2019-08-26 11:49:59.222426
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:44:11.798015
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 11:51:42.621509
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 11:51:42.621509
# 		[*************************]
# 		|>>> HALF 1 == ICUS-2585
# 		|>>> HALF 2 == 0006460259.pdf
# 		|>>> NEW NAME == part ICUS-2585 CofA Lot# 0006460259.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:45:55.201156
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:45:55.202112
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:03:56.910807
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:03:56.910807
# 		[*************************]
# 		|>>> HALF 1 == SVM-8270-1
# 		|>>> HALF 2 == 0006482193.pdf
# 		|>>> NEW NAME == part SVM-8270-1 CofA Lot# 0006482193.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 01:58:09.488444
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 01:58:09.488444
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:18:40.551938
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:18:40.552997
# 		[*************************]
# 		|>>> HALF 1 == SPM-630-1
# 		|>>> HALF 2 == 0006486209.pdf
# 		|>>> NEW NAME == part SPM-630-1 CofA Lot# 0006486209.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:12:53.131595
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:12:53.131595
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:19:09.750937
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:19:09.750937
# 		[*************************]
# 		|>>> HALF 1 == US-108N
# 		|>>> HALF 2 == CS-2098.PDF
# 		|>>> NEW NAME == part US-108N CofA Lot# CS-2098.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:13:22.327538
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:13:22.328538
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:19:10.412933
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:19:10.412933
# 		[*************************]
# 		|>>> HALF 1 == PST-1435M100A01
# 		|>>> HALF 2 == CS-0059.PDF
# 		|>>> NEW NAME == part PST-1435M100A01 CofA Lot# CS-0059.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:13:22.989540
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:13:22.990540
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:21:30.119195
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:21:30.119195
# 		[*************************]
# 		|>>> HALF 1 == SFL-610-1
# 		|>>> HALF 2 == 0006472268.pdf
# 		|>>> NEW NAME == part SFL-610-1 CofA Lot# 0006472268.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:15:42.698808
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:15:42.698808
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:22:16.705265
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:22:16.706252
# 		[*************************]
# 		|>>> HALF 1 == ICP-151
# 		|>>> HALF 2 == CS-6114.pdf
# 		|>>> NEW NAME == part ICP-151 CofA Lot# CS-6114.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:16:29.283853
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:16:29.284854
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:22:17.385828
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:22:17.385828
# 		[*************************]
# 		|>>> HALF 1 == US-108N
# 		|>>> HALF 2 == CS-2098.PDF
# 		|>>> NEW NAME == part US-108N CofA Lot# CS-2098.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:16:29.963470
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:16:29.963470
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:24:26.214439
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:24:26.214439
# 		[*************************]
# 		|>>> HALF 1 == ALD-101-1
# 		|>>> HALF 2 == CS-5795.PDF
# 		|>>> NEW NAME == part ALD-101-1 CofA Lot# CS-5795.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:18:38.794039
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:18:38.794039
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:29:15.638588
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:29:15.639459
# 		[*************************]
# 		|>>> HALF 1 == SMA-300
# 		|>>> HALF 2 == CT-0115.pdf
# 		|>>> NEW NAME == part SMA-300 CofA Lot# CT-0115.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:23:28.215092
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:23:28.215092
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:29:47.048174
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:29:47.048174
# 		[*************************]
# 		|>>> HALF 1 == AMN-803-1
# 		|>>> HALF 2 == 0006485055.pdf
# 		|>>> NEW NAME == part AMN-803-1 CofA Lot# 0006485055.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:23:59.625775
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:23:59.625775
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:35:37.246077
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:35:37.248077
# 		[*************************]
# 		|>>> HALF 1 == ICP-052
# 		|>>> HALF 2 == CS-5777.pdf
# 		|>>> NEW NAME == part ICP-052 CofA Lot# CS-5777.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:29:49.827648
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:29:49.827648
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:43:41.730007
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:43:41.730007
# 		[*************************]
# 		|>>> HALF 1 == PHM-5524A
# 		|>>> HALF 2 == CS-4175.PDF
# 		|>>> NEW NAME == part PHM-5524A CofA Lot# CS-4175.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:37:54.306613
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:37:54.307665
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:55:24.803386
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:55:24.804293
# 		[*************************]
# 		|>>> HALF 1 == ISM-520-1
# 		|>>> HALF 2 == CT-1283.pdf
# 		|>>> NEW NAME == part ISM-520-1 CofA Lot# CT-1283.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:49:37.379924
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:49:37.379924
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:57:12.482162
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:57:12.482162
# 		[*************************]
# 		|>>> HALF 1 == DWM-589N
# 		|>>> HALF 2 == CS-5746.PDF
# 		|>>> NEW NAME == part DWM-589N CofA Lot# CS-5746.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:51:25.060819
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:51:25.060819
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:58:04.155485
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:58:04.155485
# 		[*************************]
# 		|>>> HALF 1 == US-106N
# 		|>>> HALF 2 == CS-2324.PDF
# 		|>>> NEW NAME == part US-106N CofA Lot# CS-2324.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:52:16.733145
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:52:16.734137
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:58:10.291809
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:58:10.291809
# 		[*************************]
# 		|>>> HALF 1 == ISM-560-1
# 		|>>> HALF 2 == 0006471679.pdf
# 		|>>> NEW NAME == part ISM-560-1 CofA Lot# 0006471679.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:52:22.867412
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:52:22.867412
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 12:58:16.790101
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 12:58:16.791095
# 		[*************************]
# 		|>>> HALF 1 == ISM-331-1
# 		|>>> HALF 2 == 0006469481.pdf
# 		|>>> NEW NAME == part ISM-331-1 CofA Lot# 0006469481.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 02:52:29.368682
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 02:52:29.369683
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:07:41.255469
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:07:41.256351
# 		[*************************]
# 		|>>> HALF 1 == CUS-11423
# 		|>>> HALF 2 == CS-5573.PDF
# 		|>>> NEW NAME == part CUS-11423 CofA Lot# CS-5573.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:01:53.831981
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:01:53.831981
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:09:08.442239
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:09:08.442239
# 		[*************************]
# 		|>>> HALF 1 == UST-200
# 		|>>> HALF 2 == CP-2351A.pdf
# 		|>>> NEW NAME == part UST-200 CofA Lot# CP-2351A.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:03:21.017866
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:03:21.017866
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:16:06.178059
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:16:06.178059
# 		[*************************]
# 		|>>> HALF 1 == ICP-080
# 		|>>> HALF 2 == CT-1449.pdf
# 		|>>> NEW NAME == part ICP-080 CofA Lot# CT-1449.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:10:18.753662
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:10:18.753662
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:17:37.593450
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:17:37.593450
# NON-PDF CREATED ON 2019-08-26 13:17:37.593450
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:11:50.170052
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:19:13.112817
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:19:13.112817
# 		[*************************]
# 		|>>> HALF 1 == ATS-111
# 		|>>> HALF 2 == CR-2695.PDF
# 		|>>> NEW NAME == part ATS-111 CofA Lot# CR-2695.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:13:25.688445
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:13:25.689419
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:19:19.307408
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:19:19.307408
# 		[*************************]
# 		|>>> HALF 1 == PPS-211
# 		|>>> HALF 2 == CT-0105.PDF
# 		|>>> NEW NAME == part PPS-211 CofA Lot# CT-0105.PDF
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:13:31.883031
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:13:31.883031
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:20:45.793715
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:20:45.793715
# 		[*************************]
# 		|>>> HALF 1 == CUS-7529
# 		|>>> HALF 2 == 0006486675.pdf
# 		|>>> NEW NAME == part CUS-7529 CofA Lot# 0006486675.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:14:58.373273
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:14:58.374328
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.263995
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.263995
# NON-PDF CREATED ON 2019-08-26 13:26:52.263995
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:04.838598
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.291994
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.291994
# NON-PDF CREATED ON 2019-08-26 13:26:52.291994
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:04.866597
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.593998
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.595006
# NON-PDF CREATED ON 2019-08-26 13:26:52.595006
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.169609
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.612998
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.612998
# NON-PDF CREATED ON 2019-08-26 13:26:52.612998
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.187601
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.618999
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.618999
# NON-PDF CREATED ON 2019-08-26 13:26:52.618999
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.194605
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.632002
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.632002
# NON-PDF CREATED ON 2019-08-26 13:26:52.632002
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.207605
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.665003
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.665003
# NON-PDF CREATED ON 2019-08-26 13:26:52.665003
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.239606
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.678004
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.678004
# NON-PDF CREATED ON 2019-08-26 13:26:52.678004
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.252607
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.683003
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.683003
# NON-PDF CREATED ON 2019-08-26 13:26:52.683003
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.257606
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.721005
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.721005
# NON-PDF CREATED ON 2019-08-26 13:26:52.721005
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.295608
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.742005
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.742005
# NON-PDF CREATED ON 2019-08-26 13:26:52.742005
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.316608
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:52.757004
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:52.758005
# NON-PDF CREATED ON 2019-08-26 13:26:52.758005
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.332608
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:53.061005
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:53.062004
# NON-PDF CREATED ON 2019-08-26 13:26:53.062004
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.636607
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:26:53.072006
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:26:53.072006
# NON-PDF CREATED ON 2019-08-26 13:26:53.072006
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:21:05.647607
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:28:05.384349
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:28:05.385290
# 		[*************************]
# 		|>>> HALF 1 == CUS-13494
# 		|>>> HALF 2 == 0006486674.pdf
# 		|>>> NEW NAME == part CUS-13494 CofA Lot# 0006486674.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:22:17.961935
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:22:17.961935
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:37:40.936293
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:37:40.937286
# 		[*************************]
# 		|>>> HALF 1 == IBF-040
# 		|>>> HALF 2 == 0006471407.pdf
# 		|>>> NEW NAME == part IBF-040 CofA Lot# 0006471407.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:31:53.513905
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:31:53.513905
# checking for isEOD...
# FALSE!
#  STILL RUNNING AT 2019-08-26 13:38:00.263647
# SUCCESS! VERY NICE!!
# [isEOD-check]FIN...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# | MODIFIED >>> 2019-08-26 13:38:00.264646
# 		[*************************]
# 		|>>> HALF 1 == IBF-070
# 		|>>> HALF 2 == 0006468215.pdf
# 		|>>> NEW NAME == part IBF-070 CofA Lot# 0006468215.pdf
# 		[*************************]
# 		LIST check == PASS
# 		[Append-2-DataFrame] FIN...
# 		[Append-2-DataFrame] >>> time_alloted: 0 days 03:32:12.843250
# 		[Modified-Event] VERY NICE GOOD JOB!
# 		[Modified-Event] >>> time_alloted: 0 days 03:32:12.843250
