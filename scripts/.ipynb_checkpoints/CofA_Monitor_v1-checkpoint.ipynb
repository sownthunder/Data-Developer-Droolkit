# %% [markdown]
# # `CofA` Daily_Launcher

# %% [markdown]
# ### 1) create `logger`
# ### 2) create global variables
# ### 3) using `watchdog` wait for file to come into:
#     - F:/Apps/CofA/
#
# ## save all created and modified files into the `df_save_list` datafeframe and then when `execute_staging()` is called:
#
# ***_ conpare the two dorectories and only watermark the DIFF***
# ***_ then FINALLY create that garbage temp dir and ZiP it***
# ***_ last but not least email that shit once and for good***

# %%
# IMPORT THE GOODIES
import os, sys, time
from time import sleep
from pathlib import Path
import fnmatch, glob, shutil
import wmi, psutil
import filecmp, tempfile, textwrap
from textwrap import wrap
from zipfile import ZipFile
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
import email, smtplib, ssl
import os.path as op
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.utils import COMMASPACE, formatdate
import subprocess, threading, logging
from threading import Timer
from PyPDF2 import PdfFileReader, PdfFileWriter
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# %% [markdown]
# **CLASSES**

# %%
class CofA_Event_Handler(FileSystemEventHandler): #{
    
    def __init__(self, save_dataframe, in_directory, observer): #{
        
        self.save_dataframe = save_dataframe
        self.in_directory = in_directory
        self.observer = observer
        #self.out_directory = out_directory
    #}
    
    """
    # DISPATCH ALWAYS CALLED FIRST JUST DESCRIBE EVENT
    def dispatch(self, event): #{
        event_str = str(event.event_type)
        event_path = Path(event.src_path)
        print("**********************")
        print("EVENT >>> " + event_str)
        print("SRC_PATH >>> " + str(event_path))
        print("**********************")
        # SEND OFF TO PERFORM ACTIONS BASED ON EVENT
        #perform_event_actions(the_event_type=event_str, the_event_path=event_path)
    #}
    """
    
    def on_any_event(self,event): #{
        # RE-INSTANTIATE GLOBALS
        global isEOD, t
        # TRY THE FOLLOWING
        print("\ne=" + str(event) + "\n")
        
        try: #{
            #OLD# print(str(t))
            print("checking for isEOD...")
            if isEOD is True: #{
                # STOP OBSERVER
                self.observer.stop()
                print("TRUE! ENDING SCRIPT!")
                # QUIT SCRIPT
                sys.exit(69)
            #}
            else: #{
                print("FALSE! \n STILL RUNNING AT " 
                      + str(pd.Timestamp.now()) 
                      + "\n")
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("SUCCESS! VERY NICE!!")
        #}
        finally: #{
            print("[isEOD-check]FIN...")
        #}
    #}
    
    def on_created(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| CREATED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)  # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                """int
                # CREATE str TO HOLD FINAL COLUMN FOR TUPLE
                created_str = "Created"
                """
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  #WAS: (created_str)
                """
                # APPEND EVENT ITEM TO "save_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
                print(df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED AT " + str(ts))
            #}
            
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Created-Event] FIN..")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Created-Event] >>> time_alloted: " + str(run_time))
        #}
    #}
    
    def on_modified(self, event): #{
        # RE-INSTANTIATE GLOBALS
        global df_save_list
        # TRY THE FOLLOWING
        try: #{
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            ts = pd.Timestamp.now()  # CREATE TIME STAMP
            print("| MODIFIED >>> " + str(ts))
            # CREATE EVENT PATH VAR
            the_event_path = Path(event.src_path)   # WAS: the_event_path
            # CREATE 'file_name' VAR
            file_name = os.path.basename(the_event_path)
            # CHECK AND SEE IF FILE IS OF TYPE .PDF
            if fnmatch.fnmatch(file_name, "*.pdf"): #{
                # CREATE NEW FILE NAME CONV
                file_name_conv = generate_naming_convention(file_name)
                # CREATE EVENT ITEM FOR LIST
                event_list = [str(file_name_conv), str(ts)]  # WAS: (modified_str)
                """
                # APPEND EVENT ITEM TO "Createed_list"
                save_list.append(event_list)
                print("SAVE LIST == \n" 
                      + str(save_list))
                """
                df_save_list = append_to_dataframe(the_event_list=event_list,
                                    dataframe_to_append=df_save_list)
            #}
            else: #{
                print("NON-PDF CREATED ON " + str(ts))
            #}
        #}
        except: #{
            errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
            errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
            exc_type, exc_obj, exc_tb = sys.exc_info()
            fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
            typeE = str("TYPE : " + str(exc_type))
            fileE = str("FILE : " + str(fname))
            lineE = str("LINE : " + str(exc_tb.tb_lineno))
            messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
            print("\n" + typeE +
                          "\n" + fileE +
                          "\n" + lineE +
                          "\n" + messageE)
        #}
        else: #{
            print("\t\t[Modified-Event] VERY NICE GOOD JOB! ")
        #}
        finally: #{
            # CREATE END-TIME VAR
            time_end = pd.Timestamp.now()
            # DETERMINE OVERALL RUN-TIME
            run_time = pd.Timedelta(time_end - time_start)
            # PRINT TOTAL RUNTIME
            print("\t\t[Modified-Event] >>> time_alloted: " + str(run_time))
        #}
    #}

#}

# %% [markdown]
# **FUNCTIONS**

# %%
"""
TAKES IN:
PDF TO WATERMARK,
"""
def create_watermark(input_pdf, output, watermark): # {
    try:  # {
        watermark_obj = PdfFileReader(watermark)
        watermark_page = watermark_obj.getPage(0)

        pdf_reader = PdfFileReader(input_pdf)
        pdf_writer = PdfFileWriter()

        # Watermark all the pages
        for page in range(pdf_reader.getNumPages()):  # {
            page = pdf_reader.getPage(page)
            page.mergePage(watermark_page)
            pdf_writer.addPage(page)
        # }

        with open(output, 'wb') as out:  # {
            pdf_writer.write(out)
        # }
    # }
    except: # {
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
        # }
    else: # {
        print("\t\t[watermark-pdf] FIN...")
    # }
    finally: # {
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[watermark-pdf] >>> time_alloted: " + str(run_time))
    # }
    return
# }

# %%
def get_all_file_paths(directory): #{
    
    # initializing empty file paths list 
    file_paths = [] 
    
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): #{
        for filename in files: #{
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath)
        #}
    #}
    
    # returning all file paths
    return file_paths
#}

# %%
"""
TAKES IN:
(1) path to pdf 
RETURNS: 
the STRING of that PDF to match the naming convention
in G:/C of A's/#Email Node/ from F:/APPS/CofA/
"""
def generate_naming_convention(the_pdf_path): #{
    # get/set filename to variable
    the_file_name = str(os.path.basename(the_pdf_path))
    # PERFORM STRING OPERATIONS
    #################################
    idx_mrk = the_file_name.rfind('@', 0, len(the_file_name))
    half1 = str(the_file_name[0:idx_mrk])
    half2 = str(the_file_name[idx_mrk + 1:len(the_file_name)])
    print("\t\t[*************************]")
    print("\t\t|>>> HALF 1 == " + half1)
    print("\t\t|>>> HALF 2 == " + half2)
    #  setup NEW FILE NAME (for copy)
    new_name = "part "
    new_name += str(half1)
    new_name += " CofA Lot# "
    new_name += str(half2)
    print("\t\t|>>> NEW NAME == " + str(new_name))
    print("\t\t[*************************]")
    #################################
    return str(new_name)
#}

# %%
"""
TAKES IN: 
(1) LIST-type obj containing:
    - basename (CofA etc)[*.pdf]
    - timestamp
    - "Created" **OR** "Modified category"
(2) DataFrame obj containing:
    - that the newest row will be appended too
RETURNS: 
DataFrame (not in-place) with newly
appended tuple row etc 
"""
def append_to_dataframe(the_event_list, dataframe_to_append): #{
    # TRY THE FOLLOWING
    try: #{
        # CHECK IF LIST
        if type(the_event_list) is list : #{  # WAS: (the_event_list is list)
            print("\t\tLIST check == PASS")
            # SEPERATE COLUMNS
            col_1 = str(the_event_list[0])
            col_2 = str(the_event_list[1])
            # CREATE APPENDAGE FRAME
            df_appendage = pd.DataFrame(data=[the_event_list], 
                                        columns=['CofA', 'Timestamp'])
            # CREATE INSTANCE OF DATAFRAME WE ARE RETURNING
            return_df = dataframe_to_append.append(df_appendage, ignore_index=True, sort=False)
            #OLD# print(return_df.tail(5))
        #}
        else: #{
            print("\t\tLIST check == FAIL")
        #}
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("\t\t[Append-2-DataFrame] FIN...")
        return return_df
    #}
    finally: #{
        # CREATE END-TIME VAR
        time_end = pd.Timestamp.now()
        # DETERMINE OVERALL RUN-TIME
        run_time = pd.Timedelta(time_end - time_start)
        # PRINT TOTAL RUNTIME
        print("\t\t[Append-2-DataFrame] >>> time_alloted: "+ str(run_time))
    #}
#}

# %% [raw]
# def extract_information(pdf_path): #{
#     with open(pdf_path, 'rb') as f: #{
#         pdf = PdfFileReader(f)
#         information = pdf.getDocumentInfo()
#         number_of_pages = pdf.getNumPages()
#     #}
#     txt = f"""
#     Information about {pdf_path}:
#
#     Author: {information.author}
#     Creator: {information.creator}
#     Producer: {information.producer}
#     Subject: {information.subject}
#     Title: {information.title}
#     Number of Pages: {number_of_pages}
#     """
#
#     print(txt)
#     return information
# #}

# %%
"""
TAKES IN:
(1) file_path to file 
RETURNS: 
The create time or modified time, whichever is older
"""
def pull_creation_timetamp(a_file_path): #{
    # FORCE PATH VARIABLE
    the_path = Path(a_file_path)
    # GET MODIFIED TIME
    mtime = os.path.getmtime(the_path)
    # GET CREATE TIME
    ctime = os.path.getctime(the_path)
    # CREATE DATE VAR
    # IF CREATE TIME IS OLDER...
    if ctime < mtime: #{
        # FORMAT DATE VAR as str
        date_str = str(datetime.fromtimestamp(ctime))
    #}
    # ELSE.... MODIFIED TIME IS OLDER...
    else: #{
        # FORMAT DATE VAR as str
        date_str = str(datetime.fromtimestamp(mtime))
    #}
    # RETURN THE DATE WE PULLED AS STRING
    return date_str
#}

# %%
#test_list = scan_directory("F:/APPS/CofA/")

# %%
#print(len(test_list))

# %% [raw]
# def display_pdf_text(pdf_path): #{
#     read_pdf = PyPDF2.PdfFileReader(pdf_path)
#
#     for i in range(read_pdf.getNumPages()): #{
#         page = read_pdf.getPage(i)
#         print("Page No - " + str(1+read_pdf.getPageNumber(page)))
#         page_content = page.extractText()
#         print(page_content)
#     #}
#
# #}

# %%
def send_mail(send_from, send_to, subject, message, files=[], 
              server="cos.smtp.agilent.com", port=587, use_tls=True): #{
    print("SENDING MAIL... DATE == " + str(pd.Timestamp.now())[:10])
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = COMMASPACE.join(send_to)
    msg['Date'] = formatdate(localtime=True)
    msg['Subject'] = subject
    
    msg.attach(MIMEText(message))
    
    for path in files: #{
        part = MIMEBase('application', "octet-stream")
        with open(path, 'rb') as file: #{
            part.set_payload(file.read())
        #}
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',
                       'attachment; filename="{}"'.format(op.basename(path)))
        msg.attach(part)
    #}
    
    smtp = smtplib.SMTP(server, port)
    if use_tls: #{
        smtp.starttls()
    #}
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
#}

# %% [markdown]
# ---
#
# # compare `F:/APPS/CofA/` scan of `TODAY`
# # to scan of `F:/APPS/CofA/` of `YESTERDAY`
#
# >>> `CREATE DIFF DATAFRAME`
# >>> `ITERATE THRU THAT`
#
# `OVERWRITE` PDFs when *watermarking*
#
# AND THEN `CREATE ZIP` AND *EMAIL THAT ZIP* IN THE TEMP FOLDER

# %%
"""
EXPORTS DATAFRAME
TAKES IN:
(1) DATAFRAME OBJECT THAT HAS BEEN CREATED VIA WATCHODG
"""
def execute_staging(the_observer): #{
    # RE-INSTANTIATE GLOBALS
    #OLD# global save_list
    global df_save_list
    obsserver = the_observer
    global in_directory
    global out_directory
    #OLD# global today_date_str
    global isEOD
    #OLD# print("DATAFRAME IS OF TYPE ==\n\t\t" + str(type(df_save_list)))
    #OLD# print("AND IS EMPTY !?!?!? == \n" + str(df_save_list))
    print("\n\n\n >>>>> BUT THAT SEXY save_list == \n" + str(df_save_list))
    print("of type =====================" + str(type(df_save_list)))
    """
    #################### CREATE [save_list] DATAFRAME #####################
    try: #{
        # WE HAVE THE SAVE_LIST, NOW WE NEED TO FILL THAT DATA IN
        # TO THE MAIN DATAFRAME THAT IT BELONG TO
        df_saveframe = pd.DataFrame(data=save_list, 
                                    columns=['CofA', 'Timestamp'], 
                                    dtype=np.str)
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-DataFrame] SUCCESS! VERY NICE!")
        print(str(df_saveframe))
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("[Create-DataFrame] RUN TIME == " + str(run_time))
    #}
    """
    #################################################
    try: #{
        print("\n\n\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #OLD# print("TODAYS (FAKE) DATE == " + today_date_str)
        ###########################################
        # CREATE TODAY AND YESTERDAY STR
        today_str = str(pd.Timestamp.now())[:10]
        print("TODAYS (REAL) DATE == " + today_str)
        ######################################################
        #time_now = pd.Timestamp(year=2019, month=8, day=14) #
        ######################################################
        time_now = pd.Timestamp.now()
        # CREATE SUTBRACTION DELTA 
        subtraction_delta = pd.Timedelta(value=1, unit='days')
        print("SUBTRACTION DELTA == " + str(subtraction_delta))
        # CREATE "yesterdays date" BY SUTBRACTING
        yesterstr = str(time_now - subtraction_delta)[:10]
        print("YESTERSTR == " + str(yesterstr))
        print("\nTEST GLOB-STRING == " + str("C:/data/outbound/CofA/*_" 
                                             + yesterstr 
                                             + "_F_*"))
        ###########################################
        # BEGIN GLOBBING (WAS: C:/data/inbound/)
        glob_previous = sorted(glob.glob("C:/data/outbound/CofA/*_" 
                                         + yesterstr 
                                         + "_F_*"))
        print("\n\t GLOB_PREVIOUS >>> \n")
        for name in glob_previous: #{
            print(name)
        #}
        #####################################################################
        # < FOR RIGHT NOW WE IMPORT A .CSV FOR THE TODAY_FILE... 
        # THIS IS CREATED MANUALLY EVERY TIME BY CREATING A LIST OF 
        # "F:/APPS/CofA/" AND PUTTING INTO  A DATAFRAME
        # ==============[DIRECTORY CHANGE FOR FINAL VERISON]===========
        # "C:/data/inbound/*_" >>>> "C:/CofA/log/lists/*_"
        #####################################################################
        # RETURN LIST FROM FUNCTION
        #
        #OLD#glob_current = scan_directory("F:/APPS/CofA/")
        #
        ########################################################
        glob_current = sorted(glob.glob("C:/data/outbound/CofA/*_" 
                                        + today_str 
                                        + "_F_*"))
        print("\n\t GLOB_CURRENT >>> \n")
        for name in glob_current: #{
            print(name)
        #}
        print("\n\n\n~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~~~~")
        #################
        # SETUP IMPORTS #
        #################
        df1 = pd.read_csv(glob_previous[0])
        df2 = pd.read_csv(glob_current[0])
        """
        # we dont use indeces because of LIST
        df2 = pd.DataFrame() # EMPTY AT FIRST
        # ASSIGN COLUMN OF DATAFRAME FROM LIST
        df2['CofA File'] = glob_current
        """
        print("LEN_D1 == " + str(len(df1)))
        print("LEN_D2 == " + str(len(df2)))
        #OLD#print(df1.info)
        #OLD#print(df2.info)
        # SET DIFFERENCE OF TWO DATAFRAMES IN PANDAS PYTHON
        set_diff_df = pd.concat([df2, df1, df1]).drop_duplicates(keep=False)
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
        print("\n\tLENGTH OF DIFFERENCE == " + str(len(set_diff_df)))
        print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
        x = 0  # counter variable
        # CREATE TEMPORARY DIRECTORY (TO WORK INSIDE OF)
        ###################################################################
        with tempfile.TemporaryDirectory() as directory_name: #{
            the_dir = Path(directory_name)
            print("| TEMPORARY DIRECTORY >>> " + str(the_dir) + "\n")
            # ITERATE THRU TUPLES...
            for row in set_diff_df.itertuples(index=False, name="CofA"): #{
                # GET/CREATE BASE_NAME
                base_name = os.path.basename(str(row[0]))  # WAS: the_event_path
                # GET NEW FILE NAME CONVENTION
                file_name_conv = generate_naming_convention(base_name)
                # CREATE "temp_path"
                temp_path = os.path.join(the_dir, file_name_conv)
                # CREATE "dst_path"
                dst_path = os.path.join(out_directory, file_name_conv)
                # WATERMARK A COPY TO G_DRIVE **WITH CORRECT NE W FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=dst_path, watermark=in_file)
                # WATERMARK A COPY INTO TEMP FOLDER ** WITH CORRECT NEW FILE NAME**
                create_watermark(input_pdf=str(row[0]), 
                                 output=temp_path, watermark=in_file)
                # INCREASE COUNTER
                x += 1
                print("COUNT == " + str(x))
            #}
            ################################################################
            # ZIP THE CURRENT TEMP DIR (no need to create... just rename)
            try: #{
                print("\n\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
                print("\nWORKING DIRECTORY ---BEFORE--- ZIP == " + str(os.getcwd()))
                # path to folder
                directory = "." # (the_dir)
                # CHANGE WORKING DIRECTORY TO THE TEMPORARY DIR
                # (IN ORDER TO PROPERLY ZIP FILES/FOLDER)
                os.chdir(the_dir)   # WAS: "C:/"
                print("\nWORKING DIRECTORY ---DURING--- ZIP == " + str(os.getcwd()))
                # calling function to get all file paths in the directory
                file_paths = get_all_file_paths(the_dir)
                # printing the list of all files to be zipped 
                print('\nFollowing files will be zipped:') 
                for file_name in file_paths: #{
                    print(file_name) 
                #}
                # writing files to a zipfile 
                with ZipFile('CofA-' + str(pd.Timestamp.now())[:10] + ".zip",'w') as zip: #{
                    # writing each file one by one 
                    for file in file_paths: #{
                        zip.write(file) 
                    #}
                #}
                print('All files zipped successfully!\n\nXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' 
                      + 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXX\n')
                ###################################################
                # ....NOW ZIP THE NEWLY MADE FOLDER INSIDE TEMP FOLDER...
                #WAS#zip_directory = "./" + str(today_date_str)
                """
                zip_dir = Path("/" + str(today_str))
                print("\n MAKE-SHIFT ZIPPY_DIR == " + str(zip_dir) + "\n")
                # CREATE ZIP_DIRECTORY PATH VARIABLE
                zip_directory = os.path.join(".", zip_dir)
                print("\n ZIP_DIRECTORY == " + str(zip_directory) + "\n")
                # calling function to get all file paths in directory
                file_paths = get_all_file_paths(zip_directory)
                # printing the list of all files to be zipped
                print('Following files will be zipped:') 
                """
            #}
            except: #{
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                      "\n" + fileE +
                      "\n" + lineE +
                      "\n" + messageE)
            #}
            else: #{
                print("ALL FILES SUCCESSFULLY ZIPPED!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Zip-Files] RUN TIME == " + str(run_time))
            #}
            # TRY TO FINISH THIS SHIT OFF
            try: #{
                print("\n\t\t\t GLOBBING FOR ZIP FILE !!!")
                for name in sorted(glob.glob(str(the_dir) + "/*.zip")): #{
                    print("NAME OF FILE == " 
                          + str(name))
                    #logging.info(name)
                    print("LENGTH OF GLOB == " 
                          + str(len(sorted(glob.glob(str(the_dir))))))
                    # GET&SET PATH NAME 
                    zip_path = Path(name)
                    print("ZIP_PATH == " 
                          + str(zip_path))
                #}
                """
                # CREATE ZIP_DRIECTORY OFF SINGLE_GLOB_STR
                zip_path = Path(sorted(glob.glob(str(the_dir) + "/*.zip"))[0])
                """
                # >>>>>>>>>>>>> EXPORT DATAFRAME <<<<<<<<<<<<<<<<<<< #
                ###################################################3
                # CREATE STR FOR PATH FOR SAVE_DIFF_DATAFRAME
                df_save_str = str("CofA-" 
                                  + str(pd.Timestamp.now())[:10] 
                                  + ".csv")
                df_save_path = os.path.join(the_dir, df_save_str)
                print("\n\n\tSAVE-PATH FOR DATAFRAME == " + str(df_save_path))
                # SORT THE DATAFRAME BEFORE EXPORTING
                df_save_frame_sorted = df_save_list.sort_values(by='Timestamp')
                # DROP DUPLICATES BEFORE EXPORTING
                df_save_frame_sorted.drop_duplicates(subset='CofA', 
                                                     keep='last', 
                                                     inplace=True)
                df_save_frame_sorted.to_csv(str(df_save_path), index=False)
                #################### EXPORT DATAFRAME #####################
                # ZIP FILE HAS BEE CREATED NOW WE CAN EXPORT DATAFRAME
                # AND NOT WORRY ABOUT IT ALSO BEING INCLUDE IN ZIP
                #########################################################
                #OLD# df_saveframe.to_csv(str(df_save_path), index=False)
                ##################################################
                # EXPORT THE SET_DIFF_DF TO FILE  IN TEMP FOLDER IN ORDER TO EMAIL
                #set_diff_df.to_csv(str(df_save_path), index=False)
                # CREATE PATH VAR and "Popen" via SUBPROCESS
                print("Opening Explorer Window...")
                the_dir = Path(directory_name)
                # open temp_folder in a new EXPLORER WINDOW
                subprocess.Popen('explorer ' + str(the_dir))
                ###################################################
                # CREATE FILE_LIST VAR
                file_list = [str(zip_path), str(df_save_path)]
                print(">>> FILE LIST : \n\t" 
                      + str(file_list) 
                      + "\n")
                break_input = input("Continue? Y\n")
                if str(break_input).lower() == "n": #{
                    sys.exit(69)
                #}
                elif str(break_input).lower() == "y": #{
                    print("CONT....")
                #}
                #####################################################
                # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                # >>>>>>>>>>>>> SEND EMAIL HERE <<<<<<<<<<<<<<<<<<< #
                #####################################################
                try: #{
                    send_mail(send_from="derek.bates@non.agilent.com",
                              send_to="derek.bates@non.agilent.com", 
                              subject=str(pd.Timestamp.now())[:10],
                              message="See File(s) attached",
                              files=file_list)
                #}
                except: #{
                    errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                    errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                    errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                    exc_type, exc_obj, exc_tb = sys.exc_info()
                    fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                    typeE = str("TYPE : " + str(exc_type))
                    fileE = str("FILE : " + str(fname))
                    lineE = str("LINE : " + str(exc_tb.tb_lineno))
                    messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                    print("\n" + typeE +
                                  "\n" + fileE +
                                  "\n" + lineE +
                                  "\n" + messageE)
                #}
                else: #{
                    print("EMAIL SUCCESSFULLY SENT! VERY NICE!")
                #}
            #}
            except: #{                
                errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
                errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
                exc_type, exc_obj, exc_tb = sys.exc_info()
                fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
                typeE = str("TYPE : " + str(exc_type))
                fileE = str("FILE : " + str(fname))
                lineE = str("LINE : " + str(exc_tb.tb_lineno))
                messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
                print("\n" + typeE +
                              "\n" + fileE +
                              "\n" + lineE +
                              "\n" + messageE)
            #}
            else: #{
                print("[Create-set_diff_df] SUCCESS! VERY NICE!!")
            #}
            finally: #{
                ts = pd.Timestamp.now()
                run_time = ts - time_start
                print("[Email-Files] FIN...")
                observer.stop() #  WAS: sys.exit(69)
            #}
        #}
        """
        print('Directory exists after?' + str(directory_name.exists()))
        print('Contents after:' + str(list(directory_name.glob('*'))))
        """
        ###################################################
        # OUTSIDE OF TEMP FOLDER
        # EXPORT THE .csv?
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        isEOD = True
        # BECAUSE WE SET "isEOD" TO TRUE IT WILL STOP WATCHDOG LISTENER, 
        # POST TIME STAMP, THEN EN
        observer.stop()
    #}
    finally: #{
        ts = pd.Timestamp.now()
        run_time = ts - time_start
        print("RUN TIME == " + str(run_time))
        print("LINE 352 EXECUTE STAGING()")
        print(str(observer))
    #}
    
#}

# %% [markdown]
# ---

# %% [markdown]
# **OVERWRITE `.txt` FILE WITH DATAFRME**

# %% [raw]
# new_df.to_csv("CofA-backlog-test.txt", columns=None,
#               header=False, index=False, mode='w', escapechar='\r')

# %% [markdown]
# ---

# %% [raw]
# # INSTANTIATE GLOBAL VARIABLES
# in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
# in_file2 = "C:/data/inbound/02OTHER_Rohde Island_Agilent Quality_Digital Letterhead.pdf"
# #in_directory = "F:/APPS/CofA/"
# #out_directory = "G:/C of A's/#Email Node/"
# in_directory = "C:/Temp/F/APPS/CofA/"
# out_directory = "C:/Temp/G/C of A's/#Email Node/"
# save_list = []
# isEOD = False
# time_start = pd.Timestamp.now()
# df_save_list = pd.DataFrame(data=None, dtype=np.str)
# # FAKE VAR TO STAND FOR "todays date"
# today_date_str = "2019-08-14"

# %%
if __name__ == "__main__":
    # SETUP LOGGER
    try: #{
        logging.basicConfig(level=logging.INFO,
                            #stream=sys.stdout,
                            filename="C:/data/outbound/CofA_Daily_Launcher.log",
                            format='%(asctime)s:'
                            + '\n\t\t\t\t'
                            + '<MESG:%(message)s>'
                            + '\n\t\t\t\t'
                            + '<%(threadName)s-ID:%(thread)d>'
                            + '\n\t\t\t\t'
                            + '<%(processName)s-ID:%(process)d>'
                            + '\n\t\t\t\t'
                            + '<FUNC=%(funcName)s>'
                            + '\n\t\t\t\t'
                            + '<LINE:%(lineno)s>'
                            + '\n\t\t\t\t'
                            + '<PATH:%(pathname)s>'
                            + '\n\t\t\t\t'
                            + '<NAME:%(name)s>',
                            # format='%(asctime)s:%(message)s PROCESS=%(processName)s',
                            datefmt='%Y_%d_%m_%H%M%S',
                            filemode='a')
    #}
    except: #{
        errorMessage = str(sys.exc_info()[0]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[1]) + "\n\t\t"
        errorMessage = errorMessage + str(sys.exc_info()[2]) + "\n"
        exc_type, exc_obj, exc_tb = sys.exc_info()
        fname = os.path.split(exc_tb.tb_frame.f_code.co_filename)[1]
        typeE = str("TYPE : " + str(exc_type))
        fileE = str("FILE : " + str(fname))
        lineE = str("LINE : " + str(exc_tb.tb_lineno))
        messageE = str("MESG : " + "\n" + str(errorMessage) + "\n")
        print("\n" + typeE +
              "\n" + fileE +
              "\n" + lineE +
              "\n" + messageE)
    #}
    else: #{
        print("[Create-Logger] FIN...")
    #}
    ######################################
    # >>>>>>>> GLOBAL VARIABLES <<<<<<<< #
    ######################################
    in_file = "C:/CofA/imp/Agilent_CofA_Letterhead_03-21-19.pdf"
    #OLD# save_list = []
    df_save_list = pd.DataFrame(data=None, columns=['CofA', 'Timestamp'])
    # 'Created/Modified'
    isEOD = False
    in_directory = "F:/APPS/CofA/"  #"C:/Temp/F/APPS/CofA/"
    out_directory =  "G:/C of A's/#Email Node/"  #"C:/Temp/G/C of A's/#Email Node/"
    outbound_directory = "C:/Temp/G/C of A's/Agilent/"  #"G:/C of A's/Agilent/"
    to_email = "derek.bates@non.agilent.com"
    from_email = "derek.bates@non.agilemt.com"
    time_start = pd.Timestamp.now()
    # FAKE VAR TO STAND FOR "todays date"
    #OLD# today_date_str = "2019-08-24"  # WAS: 8/14
    ##########################################
    print("[=================================================]")
    print("| SCANNING DIRECTORY >>> " + str(in_directory))
    print("| STORING IN DATAFRAME >>> " + str(df_save_list))  # WAS: str(df_save_list.head()))
    print("[=================================================]")
    print("| Initializing Timer >>> " + str(pd.Timestamp.now()))
    print("[=================================================]\n\n\n")
    # CREATE TIMER VAR  // 12 HOURS... now 10.5 HOURS !! 08/07/2019
    # 37800 / USE == 54000
    t = Timer(10, execute_staging, ['observer']) # WAS 2592000,3600,720,600,43200,300 & 120
    # START TIMER
    t.start()
    """
    print("\n\n<><><><><><><><><><>BEFORE HANDLER START<><><><><><><><><><><>\n")
    print("<><><><><> save_list == \n")
    # PRINT OUT EVERY ITEM & COUNT #
    len_count = len(df_save_list)
    for save in df_save_list: #{
        print("SAVE NAME === " + str(save))
        print("COUNT === " + str(len_count))
        # subtract one
        len_count -= 1
    #}
    #print("<><><><><> df_save_list == " + str(df_save_list))
    print("\n<><><><><><><><><><><><><><><><><><><><><><><><><><><>\n\n")
    """
    ###################
    # ALSO GLOBAL VAR # 
    ###################
    observer = Observer()
    # CREATE INSTANCE OF CUSTOM EVENT HANDLER
    event_handler = CofA_Event_Handler(df_save_list, in_directory, observer)
    #OLD# observer = Observer()
    observer.schedule(event_handler=event_handler,
                      path=in_directory,
                      recursive=True)
    observer.start()
    # TRY THE FOLLOWING
    try: #{
        while True: #{
            sleep(1)
        #}
    #}
    except KeyboardInterrupt: #{
        observer.stop()
    #}
    observer.join()
# Out:
# [Create-Logger] FIN...
# [=================================================]
# | SCANNING DIRECTORY >>> F:/APPS/CofA/
# | STORING IN DATAFRAME >>> Empty DataFrame
# Columns: [CofA, Timestamp]
# Index: []
# [=================================================]
# | Initializing Timer >>> 2019-08-28 10:37:12.422421
# [=================================================]
#
#
#
#
#
#
#  >>>>> BUT THAT SEXY save_list ==
# Empty DataFrame
# Columns: [CofA, Timestamp]
# Index: []
# of type =====================<class 'pandas.core.frame.DataFrame'>
#
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# TODAYS (REAL) DATE == 2019-08-28
# SUBTRACTION DELTA == 1 days 00:00:00
# YESTERSTR == 2019-08-27
#
# TEST GLOB-STRING == C:/data/outbound/CofA/*_2019-08-27_F_*
#
# 	 GLOB_PREVIOUS >>>
#
# C:/data/outbound/CofA\CofA_Email_Node_list_2019-08-27_F_pull.csv
#
# 	 GLOB_CURRENT >>>
#
# C:/data/outbound/CofA\CofA_Email_Node_list_2019-08-28_F_pull.csv
#
#
#
# ~~~~~~~~~~~~~~~~~~~8==D~~~~~~~~~~~~~~~~~~~~~~~~~~
# LEN_D1 == 62133
# LEN_D2 == 62167
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# 	LENGTH OF DIFFERENCE == 34
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# | TEMPORARY DIRECTORY >>> C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2
#
# 		[*************************]
# 		|>>> HALF 1 == 1260TK-1
# 		|>>> HALF 2 == 0006481072.pdf
# 		|>>> NEW NAME == part 1260TK-1 CofA Lot# 0006481072.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:10.402938
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:10.505868
# COUNT == 1
# 		[*************************]
# 		|>>> HALF 1 == CLP-250-1
# 		|>>> HALF 2 == 0006478487.pdf
# 		|>>> NEW NAME == part CLP-250-1 CofA Lot# 0006478487.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:10.814384
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:11.007381
# COUNT == 2
# 		[*************************]
# 		|>>> HALF 1 == CUS-12251-5
# 		|>>> HALF 2 == 0006486896.pdf
# 		|>>> NEW NAME == part CUS-12251-5 CofA Lot# 0006486896.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:11.205388
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:11.374915
# COUNT == 3
# 		[*************************]
# 		|>>> HALF 1 == EPA-1199-1
# 		|>>> HALF 2 == 0006483625.pdf
# 		|>>> NEW NAME == part EPA-1199-1 CofA Lot# 0006483625.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:11.588921
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:11.694945
# COUNT == 4
# 		[*************************]
# 		|>>> HALF 1 == GCM-152-1
# 		|>>> HALF 2 == 0006486324.pdf
# 		|>>> NEW NAME == part GCM-152-1 CofA Lot# 0006486324.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:11.936940
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:12.072979
# COUNT == 5
# 		[*************************]
# 		|>>> HALF 1 == HC-072-1
# 		|>>> HALF 2 == 0006486741.pdf
# 		|>>> NEW NAME == part HC-072-1 CofA Lot# 0006486741.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:12.303989
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:12.463018
# COUNT == 6
# 		[*************************]
# 		|>>> HALF 1 == IST-343-1
# 		|>>> HALF 2 == 0006486327.pdf
# 		|>>> NEW NAME == part IST-343-1 CofA Lot# 0006486327.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:12.677051
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:12.796031
# COUNT == 7
# 		[*************************]
# 		|>>> HALF 1 == N-0000000318
# 		|>>> HALF 2 == 0006487551.pdf
# 		|>>> NEW NAME == part N-0000000318 CofA Lot# 0006487551.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:13.091153
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:13.228912
# COUNT == 8
# 		[*************************]
# 		|>>> HALF 1 == PMX-165-1
# 		|>>> HALF 2 == 0006486742.pdf
# 		|>>> NEW NAME == part PMX-165-1 CofA Lot# 0006486742.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:13.602065
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:13.845072
# COUNT == 9
# 		[*************************]
# 		|>>> HALF 1 == PP-361-1
# 		|>>> HALF 2 == 0006486581.pdf
# 		|>>> NEW NAME == part PP-361-1 CofA Lot# 0006486581.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:14.073113
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:14.175079
# COUNT == 10
# 		[*************************]
# 		|>>> HALF 1 == PST-110
# 		|>>> HALF 2 == 0006485664.pdf
# 		|>>> NEW NAME == part PST-110 CofA Lot# 0006485664.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:14.416099
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:14.617924
# COUNT == 11
# 		[*************************]
# 		|>>> HALF 1 == PST-111
# 		|>>> HALF 2 == 0006484348.pdf
# 		|>>> NEW NAME == part PST-111 CofA Lot# 0006484348.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:14.947671
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:15.086676
# COUNT == 12
# 		[*************************]
# 		|>>> HALF 1 == PST-2435-10MG
# 		|>>> HALF 2 == 0006484498.pdf
# 		|>>> NEW NAME == part PST-2435-10MG CofA Lot# 0006484498.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:15.289758
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:15.485698
# COUNT == 13
# 		[*************************]
# 		|>>> HALF 1 == PST-2455-10MG
# 		|>>> HALF 2 == 0006484499.pdf
# 		|>>> NEW NAME == part PST-2455-10MG CofA Lot# 0006484499.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:15.681742
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:15.929704
# COUNT == 14
# 		[*************************]
# 		|>>> HALF 1 == PST-2455-10MG
# 		|>>> HALF 2 == 0006484500.pdf
# 		|>>> NEW NAME == part PST-2455-10MG CofA Lot# 0006484500.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:16.150710
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:16.295837
# COUNT == 15
# 		[*************************]
# 		|>>> HALF 1 == PST-2455-10MG
# 		|>>> HALF 2 == 0006484501.pdf
# 		|>>> NEW NAME == part PST-2455-10MG CofA Lot# 0006484501.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:16.517823
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:16.652827
# COUNT == 16
# 		[*************************]
# 		|>>> HALF 1 == PST-2465-100MG
# 		|>>> HALF 2 == 0006484502.pdf
# 		|>>> NEW NAME == part PST-2465-100MG CofA Lot# 0006484502.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:17.002931
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:17.187935
# COUNT == 17
# 		[*************************]
# 		|>>> HALF 1 == PST-2470-10MG
# 		|>>> HALF 2 == 0006484503.pdf
# 		|>>> NEW NAME == part PST-2470-10MG CofA Lot# 0006484503.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:17.448071
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:17.614289
# COUNT == 18
# 		[*************************]
# 		|>>> HALF 1 == PST-2470-10MG
# 		|>>> HALF 2 == 0006484504.pdf
# 		|>>> NEW NAME == part PST-2470-10MG CofA Lot# 0006484504.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:17.857229
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:18.026235
# COUNT == 19
# 		[*************************]
# 		|>>> HALF 1 == PST-2480-10MG
# 		|>>> HALF 2 == 0006484505.pdf
# 		|>>> NEW NAME == part PST-2480-10MG CofA Lot# 0006484505.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:18.269294
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:18.457299
# COUNT == 20
# 		[*************************]
# 		|>>> HALF 1 == PST-2485-10MG
# 		|>>> HALF 2 == 0006484506.pdf
# 		|>>> NEW NAME == part PST-2485-10MG CofA Lot# 0006484506.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:18.658447
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:18.790338
# COUNT == 21
# 		[*************************]
# 		|>>> HALF 1 == PST-2485-10MG
# 		|>>> HALF 2 == 0006484507.pdf
# 		|>>> NEW NAME == part PST-2485-10MG CofA Lot# 0006484507.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:19.068310
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:19.214346
# COUNT == 22
# 		[*************************]
# 		|>>> HALF 1 == PST-2570-10MG
# 		|>>> HALF 2 == 0006484528.pdf
# 		|>>> NEW NAME == part PST-2570-10MG CofA Lot# 0006484528.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:19.793776
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:19.995743
# COUNT == 23
# 		[*************************]
# 		|>>> HALF 1 == PST-2575-10MG
# 		|>>> HALF 2 == 0006484529.pdf
# 		|>>> NEW NAME == part PST-2575-10MG CofA Lot# 0006484529.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:20.244868
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:20.441866
# COUNT == 24
# 		[*************************]
# 		|>>> HALF 1 == PST-2580-10MG
# 		|>>> HALF 2 == 0006484530.pdf
# 		|>>> NEW NAME == part PST-2580-10MG CofA Lot# 0006484530.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:20.700869
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:20.915878
# COUNT == 25
# 		[*************************]
# 		|>>> HALF 1 == PST-2580-10MG
# 		|>>> HALF 2 == 0006484531.pdf
# 		|>>> NEW NAME == part PST-2580-10MG CofA Lot# 0006484531.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:21.211880
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:21.418891
# COUNT == 26
# 		[*************************]
# 		|>>> HALF 1 == PST-2585-10MG
# 		|>>> HALF 2 == 0006484532.pdf
# 		|>>> NEW NAME == part PST-2585-10MG CofA Lot# 0006484532.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:21.668894
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:21.880900
# COUNT == 27
# 		[*************************]
# 		|>>> HALF 1 == PST-2585-10MG
# 		|>>> HALF 2 == 0006484533.pdf
# 		|>>> NEW NAME == part PST-2585-10MG CofA Lot# 0006484533.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:22.111904
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:22.276912
# COUNT == 28
# 		[*************************]
# 		|>>> HALF 1 == PST-2590-10MG
# 		|>>> HALF 2 == 0006484534.pdf
# 		|>>> NEW NAME == part PST-2590-10MG CofA Lot# 0006484534.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:22.555916
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:22.760924
# COUNT == 29
# 		[*************************]
# 		|>>> HALF 1 == PST-2595-10MG
# 		|>>> HALF 2 == 0006484535.pdf
# 		|>>> NEW NAME == part PST-2595-10MG CofA Lot# 0006484535.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:23.031928
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:23.235955
# COUNT == 30
# 		[*************************]
# 		|>>> HALF 1 == PST-2595-10MG
# 		|>>> HALF 2 == 0006484536.pdf
# 		|>>> NEW NAME == part PST-2595-10MG CofA Lot# 0006484536.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:23.475942
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:23.694975
# COUNT == 31
# 		[*************************]
# 		|>>> HALF 1 == PST-2700-10MG
# 		|>>> HALF 2 == 0006485852.pdf
# 		|>>> NEW NAME == part PST-2700-10MG CofA Lot# 0006485852.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:23.991956
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:24.184962
# COUNT == 32
# 		[*************************]
# 		|>>> HALF 1 == SVM-500-1
# 		|>>> HALF 2 == 0006486210.pdf
# 		|>>> NEW NAME == part SVM-500-1 CofA Lot# 0006486210.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:24.387986
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:24.552993
# COUNT == 33
# 		[*************************]
# 		|>>> HALF 1 == US-117N-1
# 		|>>> HALF 2 == 0006486599.pdf
# 		|>>> NEW NAME == part US-117N-1 CofA Lot# 0006486599.pdf
# 		[*************************]
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:25.003004
# 		[watermark-pdf] FIN...
# 		[watermark-pdf] >>> time_alloted: 0 days 00:00:25.167013
# COUNT == 34
#
#
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# WORKING DIRECTORY ---BEFORE--- ZIP == C:\Users\derbates\OneDrive - Agilent Technologies\Documents\_staging\Data-Developer-Droolkit\scripts
#
# WORKING DIRECTORY ---DURING--- ZIP == C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2
#
# Following files will be zipped:
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part 1260TK-1 CofA Lot# 0006481072.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part CLP-250-1 CofA Lot# 0006478487.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part CUS-12251-5 CofA Lot# 0006486896.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part EPA-1199-1 CofA Lot# 0006483625.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part GCM-152-1 CofA Lot# 0006486324.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part HC-072-1 CofA Lot# 0006486741.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part IST-343-1 CofA Lot# 0006486327.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part N-0000000318 CofA Lot# 0006487551.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PMX-165-1 CofA Lot# 0006486742.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PP-361-1 CofA Lot# 0006486581.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-110 CofA Lot# 0006485664.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-111 CofA Lot# 0006484348.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2435-10MG CofA Lot# 0006484498.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2455-10MG CofA Lot# 0006484499.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2455-10MG CofA Lot# 0006484500.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2455-10MG CofA Lot# 0006484501.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2465-100MG CofA Lot# 0006484502.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2470-10MG CofA Lot# 0006484503.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2470-10MG CofA Lot# 0006484504.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2480-10MG CofA Lot# 0006484505.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2485-10MG CofA Lot# 0006484506.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2485-10MG CofA Lot# 0006484507.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2570-10MG CofA Lot# 0006484528.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2575-10MG CofA Lot# 0006484529.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2580-10MG CofA Lot# 0006484530.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2580-10MG CofA Lot# 0006484531.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2585-10MG CofA Lot# 0006484532.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2585-10MG CofA Lot# 0006484533.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2590-10MG CofA Lot# 0006484534.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2595-10MG CofA Lot# 0006484535.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2595-10MG CofA Lot# 0006484536.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part PST-2700-10MG CofA Lot# 0006485852.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part SVM-500-1 CofA Lot# 0006486210.pdf
# C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\part US-117N-1 CofA Lot# 0006486599.pdf
# All files zipped successfully!
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#
# ALL FILES SUCCESSFULLY ZIPPED!
# [Zip-Files] RUN TIME == 0 days 00:00:25.213009
#
# 			 GLOBBING FOR ZIP FILE !!!
# NAME OF FILE == C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\CofA-2019-08-28.zip
# LENGTH OF GLOB == 1
# ZIP_PATH == C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\CofA-2019-08-28.zip
#
#
# 	SAVE-PATH FOR DATAFRAME == C:\Users\derbates\AppData\Local\Temp\tmpz7hkm0e2\CofA-2019-08-28.csv
# Opening Explorer Window...
# >>> FILE LIST :
# 	['C:\\Users\\derbates\\AppData\\Local\\Temp\\tmpz7hkm0e2\\CofA-2019-08-28.zip', 'C:\\Users\\derbates\\AppData\\Local\\Temp\\tmpz7hkm0e2\\CofA-2019-08-28.csv']
#
# Continue? Y
# Y
# CONT....
# SENDING MAIL... DATE == 2019-08-28
# EMAIL SUCCESSFULLY SENT! VERY NICE!
# [Create-set_diff_df] SUCCESS! VERY NICE!!
# [Email-Files] FIN...
#
# TYPE : <class 'PermissionError'>
# FILE : <ipython-input-11-e07cf7ed6f15>
# LINE : 325
# MESG :
# <class 'PermissionError'>
# 		[WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\derbates\\AppData\\Local\\Temp\\tmpz7hkm0e2'
# 		<traceback object at 0x0000011C5C42AF08>
#
#
# RUN TIME == 0 days 00:01:40.858863
# LINE 352 EXECUTE STAGING()
# <WindowsApiObserver(Thread-7, started daemon 47444)>
