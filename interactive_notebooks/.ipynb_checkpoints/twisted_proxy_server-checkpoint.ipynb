# %%
from twisted.web import proxy, http
from twisted.internet import reactor
from twisted.python import log
import sys
log.startLogging(sys.stdout)
 
class ProxyFactory(http.HTTPFactory): #{
    protocol = proxy.Proxy
#}
 
reactor.listenTCP(8080, ProxyFactory())
reactor.run()
# Out:
# 2019-11-08 13:09:40-0500 [-] Log opened.
# 2019-11-08 13:09:40-0500 [-] ProxyFactory starting on 8080
# 2019-11-08 13:09:40-0500 [-] Starting factory <__main__.ProxyFactory object at 0x000001DA92B65CC0>
# 2019-11-08 13:10:08-0500 [Proxy,0,127.0.0.1] Unhandled Error
# 	Traceback (most recent call last):
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 103, in callWithLogger
# 	    return callWithContext({"system": lp}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 86, in callWithContext
# 	    return context.call({ILogContext: newCtx}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 122, in callWithContext
# 	    return self.currentContext().callWithContext(ctx, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 85, in callWithContext
# 	    return func(*args,**kw)
# 	--- <exception caught here> ---
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\selectreactor.py", line 149, in _doReadOrWrite
# 	    why = getattr(selectable, method)()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 243, in doRead
# 	    return self._dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 249, in _dataReceived
# 	    rval = self.protocol.dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2258, in dataReceived
# 	    return basic.LineReceiver.dataReceived(self, data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\protocols\basic.py", line 572, in dataReceived
# 	    why = self.lineReceived(line)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2146, in lineReceived
# 	    self.allContentReceived()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2237, in allContentReceived
# 	    req.requestReceived(command, path, version)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 937, in requestReceived
# 	    self.process()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\proxy.py", line 146, in process
# 	    port = self.ports[protocol]
# 	builtins.KeyError: b''
#
# 2019-11-08 13:10:09-0500 [Proxy,1,127.0.0.1] Unhandled Error
# 	Traceback (most recent call last):
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 103, in callWithLogger
# 	    return callWithContext({"system": lp}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 86, in callWithContext
# 	    return context.call({ILogContext: newCtx}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 122, in callWithContext
# 	    return self.currentContext().callWithContext(ctx, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 85, in callWithContext
# 	    return func(*args,**kw)
# 	--- <exception caught here> ---
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\selectreactor.py", line 149, in _doReadOrWrite
# 	    why = getattr(selectable, method)()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 243, in doRead
# 	    return self._dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 249, in _dataReceived
# 	    rval = self.protocol.dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2258, in dataReceived
# 	    return basic.LineReceiver.dataReceived(self, data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\protocols\basic.py", line 572, in dataReceived
# 	    why = self.lineReceived(line)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2146, in lineReceived
# 	    self.allContentReceived()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2237, in allContentReceived
# 	    req.requestReceived(command, path, version)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 937, in requestReceived
# 	    self.process()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\proxy.py", line 146, in process
# 	    port = self.ports[protocol]
# 	builtins.KeyError: b''
#
# 2019-11-08 13:10:09-0500 [Proxy,2,127.0.0.1] Unhandled Error
# 	Traceback (most recent call last):
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 103, in callWithLogger
# 	    return callWithContext({"system": lp}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 86, in callWithContext
# 	    return context.call({ILogContext: newCtx}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 122, in callWithContext
# 	    return self.currentContext().callWithContext(ctx, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 85, in callWithContext
# 	    return func(*args,**kw)
# 	--- <exception caught here> ---
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\selectreactor.py", line 149, in _doReadOrWrite
# 	    why = getattr(selectable, method)()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 243, in doRead
# 	    return self._dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 249, in _dataReceived
# 	    rval = self.protocol.dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2258, in dataReceived
# 	    return basic.LineReceiver.dataReceived(self, data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\protocols\basic.py", line 572, in dataReceived
# 	    why = self.lineReceived(line)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2146, in lineReceived
# 	    self.allContentReceived()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2237, in allContentReceived
# 	    req.requestReceived(command, path, version)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 937, in requestReceived
# 	    self.process()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\proxy.py", line 146, in process
# 	    port = self.ports[protocol]
# 	builtins.KeyError: b''
#
# 2019-11-08 13:10:14-0500 [Proxy,3,127.0.0.1] Unhandled Error
# 	Traceback (most recent call last):
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 103, in callWithLogger
# 	    return callWithContext({"system": lp}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\log.py", line 86, in callWithContext
# 	    return context.call({ILogContext: newCtx}, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 122, in callWithContext
# 	    return self.currentContext().callWithContext(ctx, func, *args, **kw)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\python\context.py", line 85, in callWithContext
# 	    return func(*args,**kw)
# 	--- <exception caught here> ---
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\selectreactor.py", line 149, in _doReadOrWrite
# 	    why = getattr(selectable, method)()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 243, in doRead
# 	    return self._dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\internet\tcp.py", line 249, in _dataReceived
# 	    rval = self.protocol.dataReceived(data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2258, in dataReceived
# 	    return basic.LineReceiver.dataReceived(self, data)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\protocols\basic.py", line 572, in dataReceived
# 	    why = self.lineReceived(line)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2146, in lineReceived
# 	    self.allContentReceived()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 2237, in allContentReceived
# 	    req.requestReceived(command, path, version)
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\http.py", line 937, in requestReceived
# 	    self.process()
# 	  File "C:\Users\derbates\miniconda3\envs\py3\lib\site-packages\twisted\web\proxy.py", line 146, in process
# 	    port = self.ports[protocol]
# 	builtins.KeyError: b''

# %% [markdown]
# Connect your internet browser to the proxy server you just created **(localhost:8080)** and you have written a **simple proxy server** using Python and Twisted.
